# %% [markdown]
# ### **`03-Exploración de modelos-CNN`**
# ### **PROYECTO: DETECCIÓN HISTOPATOLÓGICA DEL CANCER**
# ### Fundamentos de Deep Learning - 2023-2
#
# $ \mathcal{Daniel ~H. ~Martínez ~S. ~-~ UdeA} $ \
# dhumberto.martinez@udea.edu.co
# $ $
#
# **Descripción del notebook:**
#
# Se prueban diferentes arquitecturas de Redes Neuronales Convolucionales (CNN), variando tanto el número como el tipo capas. Se evalúan 6 modelos (A, B, C, D, E, F) en función de las métricas de validación.

# %%
# Librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tempfile
from time import time
import os

from skimage import io
from pathlib import Path
from humanize import naturalsize
import tensorflow as tf
from tensorflow import keras
from tqdm.auto import tqdm
import h5py

import seaborn as sns
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Definitions
def load_data():
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_00.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_01.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_02.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_00.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_01.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_02.h5
    path_train_labels ='https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/'
    train_hc = []
    for j in range(2):
      for i in range(3):
        file = 'H_c'+str(j)+'_0'+str(i)+'.h5'
        with h5py.File('/content/'+file,'r') as f:
          train_hc.append(f['train_img'][:])
    train_hc = np.r_[train_hc].reshape(int(6*900), 96, 96, 3)
    train_labels = pd.read_csv(path_train_labels+'train_labels.csv')
    return train_hc, train_labels

def Norm_img(img):
    # Normalización min-max
    return (img-np.min(img))/(np.max(img)-np.min(img))

def show_mosaic_class(train_labels,class_h,num_rand =5):
    # Mostrar mosaico para un rand dado
    num_class = len(class_h)
    for j in class_h:
      img_rand = np.random.choice(train_labels['id'][train_labels['label'] == j],num_rand)
      fig = plt.figure(figsize=(12,14))
      for i,k in enumerate(img_rand):
        ax = fig.add_subplot(num_class, num_rand, i+1)
        img = io.imread(k+'.tif')
        ax.imshow(Norm_img(img))
        if i == 0:
          ax.set(title = 'CLASS: '+str(j))

def rand_img(train_labels,class_h_,choose_ran = 'si',id='',show_plot = 'si'):
    if choose_ran == 'si':
      img_ = np.random.choice(train_labels['id'][train_labels['label'] == class_h_],1)
      img = io.imread(img_[0]+'.tif')
    elif choose_ran == 'no':
      img = io.imread(id+'.tif')
    if show_plot == 'si':
      fig, ax = plt.subplots(figsize = (5,4))
      ax.imshow(Norm_img(img))
      ax.set(title = 'CLASS: '+str(class_h_))
    plt.show()
    return img

def choose_img(train_labels,id,show_plot = 'si'):
    # Esoger imagen aleatoria para un clases dada
    img = io.imread(id+'.tif')
    if show_plot == 'si':
      fig, ax = plt.subplots(figsize = (5,4))
      ax.imshow(Norm_img(img))
      class_h_ = train_labels['label'][train_labels['id'] == id]
      class_h_ = class_h_.reset_index()
      print(class_h_)
      ax.set(title = 'Index: '+str(class_h_['index'].iloc[0])+' :--: CLASS: '+str(class_h_['label'].iloc[0]))
    plt.show();
    return img

def h5_w(path,N_img,data_ran):
    # Guardar archivo en formaro h5
    train_shape = (N_img,96,96,3)
    hf = h5py.File(path,'w')                            # Open a hdf5 file and create earrays
    hf.create_dataset('train_img',train_shape,np.uint8) #,compression="gzip", compression_opts=9)    # The pixels range is 0-255, dtype is uint
    for i,k in tqdm(enumerate(data_ran)):
      hf['train_img'][i,...] = choose_img(k, show_plot='no')
    hf.close()

def choose_img_label(h,choose_ran = 'si',show_plot = 'si',img_id=''):
    # Escoger imagen para un id dado o random
    if choose_ran == 'si':
      img_id = np.random.choice(np.arange(len(h)),1)[0]
      img = h[img_id]
    elif choose_ran == 'no':
      img = h[img_id]
    if show_plot == 'si':
      fig, ax = plt.subplots(figsize = (4,4))
      ax.imshow(Norm_img(img))
      if img_id < int(len(h)/2):
        class_h_ = 0
      else:
        class_h_ = 1
      ax.set(title = 'New index: '+str(img_id)+' :--: CLASS: '+str(class_h_))
    plt.show();
    return img

def train_val_test(train_hc,test_size=.2,show_val = 'no'):
    # Asignación de clases para los datos cargados
    class_aux =[]
    for j in class_h:
      class_aux.append(j*np.ones(int(len(train_hc)/2)).astype(int))
    class_aux = np.array(class_aux).reshape(1,len(train_hc))
    x_train_ori, x_test, y_train, y_test = train_test_split(train_hc, class_aux[0], test_size=test_size)
    x_train, x_val, y_train, y_val = train_test_split(x_train_ori, y_train, test_size=test_size)
    if show_val == 'si':
        print ('x_train, y_train:',x_train.shape, y_train.shape)
        print ('x_test, y_test:',x_test.shape, y_test.shape)
        print ('x_val, y_val:',x_val.shape, y_val.shape)
        print ("\n * Distribución de clases de train: ")
        print (pd.Series(y_train).value_counts())
        print ("\n * Distribución de clases de test: ")
        print (pd.Series(y_test).value_counts())
        print ("\n * Distribución de clases de val: ")
        print (pd.Series(y_val).value_counts())
    return x_train,y_train, x_val,y_val, x_test,y_test

def norm255 (imgs):
    imgs = tf.cast(imgs,tf.float32)
    imgs /= 255  # 0-255 --> 0-1
    return imgs

def norm255_mm_auto(imgs):
    imgs = tf.cast(imgs,tf.float32)
    imgs = (imgs-imgs.numpy().min())/(imgs.numpy().max()-imgs.numpy().min())
    return imgs

def norm255_mm_man(imgs,vmin,vmax):
    imgs = tf.cast(imgs,tf.float32)
    imgs = (imgs-vmin)/(vmax-vmin)
    return imgs

def Metr():
  return([ keras.metrics.AUC(name='AUC'), keras.metrics.AUC(name='PRC', curve='PR'), keras.metrics.Recall(name='RECALL'),
          keras.metrics.MeanSquaredError(name='Error Cuadrático Medio'), keras.metrics.TruePositives(name='Verdadero Positivo'),
          keras.metrics.FalsePositives(name='Falso Positivo'), keras.metrics.TrueNegatives(name='Verdadero Negativo'),
          keras.metrics.FalseNegatives(name='Falso Negativo'), keras.metrics.BinaryAccuracy(name='Accuracy'),
          keras.metrics.Precision(name='Precision')])

def bias_0(train_labels,print_desbal = 'si'):
    # Inicialización del BIAS
    neg, pos = np.bincount(train_labels['label']) # Desbalanceo de clases original
    total = neg + pos
    if print_desbal == 'si':
      print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(total, pos, 100 * pos / total))
    ini_bias = np.log([pos/neg])
    return ini_bias

def train(x_train, y_train,x_val, y_val,x_test,y_test,model, batch_size, epochs, model_name="",log_dir="logs/"):
    print('\n ::::::----- Inicio de Entrenamiento -----:::::: \n')
    # Generación de call-backs
    # early_stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='AUC',
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

    # tensorboard
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir=log_dir+model_name+"_"+"{}".format(time()))
    model.reset_states()
    base_hist = model.fit(x_train, y_train, epochs=epochs, callbacks=[tensorboard,early_stopping],
              batch_size=batch_size,
              validation_data=(x_val, y_val))
    metrics2 = model.evaluate(x_test, y_test)
    dict_results = {k:v for k,v in zip (model.metrics_names, metrics2)}
    print(dict_results)
    return base_hist, dict_results

def plot_metrics(hist,metrics,col=3):
    fig = plt.figure(figsize=(14,8))
    for n, metric in enumerate(metrics):
      ax = fig.add_subplot(int(len(metrics)/col), col, n+1)
      ax.plot(hist.epoch, hist.history[metric], color='b', label='Train')
      ax.plot(hist.epoch, hist.history['val_'+metric], color='r', linestyle="--", label='Val')
      ax.set_xlabel('Epoch')
      ax.set_ylabel(metric)
      ax.legend()

def conf_matrix(labels, preds, ax,thres=0.5):
    C = confusion_matrix(labels, preds > thres)
    # plt.figure(figsize=(3,3))
    # ax = fig.add_subplot(1, 2, 1)
    sns.heatmap(C, annot=True, fmt="d")
    ax.set_title('Matriz de Confusión -- Umbral: {:.2f}'.format(thres))
    ax.set_ylabel('Etiqueta real')
    ax.set_xlabel('Etiqueta predicha')
    print('\n')
    print('--> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS): ', C[0][0])
    print('--> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS): ', C[0][1])
    print('--> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS): ', C[1][0])
    print('--> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS): ', C[1][1])
    print('\n')

def ROC(name, labels, pred,ax, **kwargs):
    Fal_Pos, Ver_Pos, _ = sklearn.metrics.roc_curve(labels, pred)
    # ax = fig.add_subplot(1, 2, 2)
    ax.plot(100*Fal_Pos, 100*Ver_Pos, label=name, linewidth=2, **kwargs)
    plt.xlabel('Falsos Positivos [%]')
    plt.ylabel('Verdaderos Positivos [%]')
    plt.grid(True)
    plt.title('Curva ROC')

def medidas_AUC(model,base_hist,metrics,x_train,x_test,batch_size):
    plot_metrics(base_hist,metrics)
    # Evaluación de las métricas
    print('\n ...Calculando valores predichos para train y test: ...')
    y_train_predict = model.predict(x_train, batch_size=batch_size)
    y_test_predict = model.predict(x_test, batch_size=batch_size)

    Results = model.evaluate(x_test, y_test, batch_size=batch_size, verbose=0)
    print('\n ** Resultados de las métricas:...')
    for name, value in zip(model.metrics_names, Results):
      print(name, ': ', value)

    # fig, ax = plt.subplots(figsize = (12,4))
    fig = plt.figure(figsize=(12,4))

    ax = fig.add_subplot(1, 2, 1)
    # Matriz de confuxión
    conf_matrix(y_test, y_test_predict,ax)

    ax = fig.add_subplot(1, 2, 2)
    # Curva ROC
    ROC("Train ", y_train, y_train_predict,ax, color='b',marker='.')
    ROC("Test ", y_test, y_test_predict,ax, color='r', linestyle='--',marker='.')
    plt.legend(loc='best'); # 'lower right'

def apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir):
    display(model.summary())
    base_hist, dict_results = train(x_train, y_train,x_val, y_val,x_test,y_test,model, batch_size=batch_size,
                                    epochs=epochs, model_name=model_name,log_dir=log_dir)
    # Métricas y Gráficas
    metrics = ['AUC','loss', 'Precision', 'RECALL','Falso Positivo','Verdadero Positivo','Accuracy','Verdadero Negativo','Falso Negativo']
    medidas_AUC(model,base_hist,metrics,x_train,x_test,batch_size)

def h5_tensor_v2(path,train_shape,Img):
  # Guardar archivo en formaro h5 para un tensor
  hf = h5py.File(path,'w')                            # Open a hdf5 file and create earrays
  hf.create_dataset('train_img',train_shape,np.uint8) #,compression="gzip", compression_opts=9)    # The pixels range is 0-255, dtype is uint
  for i in range(len(Img)):  # tqdm(
    hf['train_img'][i,...] = Img[i] #.numpy().astype('float16')
  hf.close()

# %% [markdown]
# #### `dataset`

# %%
train_hc, train_labels = load_data()
class_h = train_labels['label'].unique()
num_class = len(class_h)
# Out:
# --2023-11-19 05:04:03--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_00.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_00.h5 [following]
# --2023-11-19 05:04:03--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_00.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_00.h5.1’
#
# H_c0_00.h5.1        100%[===================>]  23.73M   157MB/s    in 0.2s
#
# 2023-11-19 05:04:03 (157 MB/s) - ‘H_c0_00.h5.1’ saved [24885248/24885248]
#
# --2023-11-19 05:04:03--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_01.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_01.h5 [following]
# --2023-11-19 05:04:04--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_01.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_01.h5.1’
#
# H_c0_01.h5.1        100%[===================>]  23.73M   108MB/s    in 0.2s
#
# 2023-11-19 05:04:04 (108 MB/s) - ‘H_c0_01.h5.1’ saved [24885248/24885248]
#
# --2023-11-19 05:04:04--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_02.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_02.h5 [following]
# --2023-11-19 05:04:04--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_02.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_02.h5.1’
#
# H_c0_02.h5.1        100%[===================>]  23.73M   121MB/s    in 0.2s
#
# 2023-11-19 05:04:05 (121 MB/s) - ‘H_c0_02.h5.1’ saved [24885248/24885248]
#
# --2023-11-19 05:04:05--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_00.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_00.h5 [following]
# --2023-11-19 05:04:05--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_00.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_00.h5.1’
#
# H_c1_00.h5.1        100%[===================>]  23.73M   141MB/s    in 0.2s
#
# 2023-11-19 05:04:05 (141 MB/s) - ‘H_c1_00.h5.1’ saved [24885248/24885248]
#
# --2023-11-19 05:04:05--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_01.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_01.h5 [following]
# --2023-11-19 05:04:05--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_01.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_01.h5.1’
#
# H_c1_01.h5.1        100%[===================>]  23.73M   115MB/s    in 0.2s
#
# 2023-11-19 05:04:06 (115 MB/s) - ‘H_c1_01.h5.1’ saved [24885248/24885248]
#
# --2023-11-19 05:04:06--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_02.h5
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_02.h5 [following]
# --2023-11-19 05:04:06--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_02.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_02.h5.1’
#
# H_c1_02.h5.1        100%[===================>]  23.73M  89.6MB/s    in 0.3s
#
# 2023-11-19 05:04:06 (89.6 MB/s) - ‘H_c1_02.h5.1’ saved [24885248/24885248]

# %% [markdown]
# #### `train`, `val`, `test`

# %%
x_train,y_train, x_val,y_val, x_test,y_test = train_val_test(train_hc) #,test_size=.25)
x_train = norm255_mm_auto(x_train)
x_val  = norm255_mm_auto(x_val)
x_test  = norm255_mm_auto(x_test)
x_train.shape, x_val.shape, x_test.shape
# Out:
# (TensorShape([3456, 96, 96, 3]),
#  TensorShape([864, 96, 96, 3]),
#  TensorShape([1080, 96, 96, 3]))

# %% [markdown]
# #### ***Model-A***:  $~~~3 \times $*`Conv2D`*+ $1\times $*`Dropout(0.3)`*+ $3\times $*`Denses`*

# %%
def model_A(img_size=96, compile=True,output_bias=None):

    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    # Capa convolucional: 15 filtros, de 3x3, padding="SAME" para que el tamaño de la salida sea el mismo que la entrada
    # layers = tf.keras.layers.Conv2D(16,(3,3), activation="relu", padding="SAME",name='Conv2D_1')(inputs)
    layers = tf.keras.layers.Conv2D(32,(3,3), activation="relu", padding="SAME",name='Conv2D_2')(inputs)
    layers = tf.keras.layers.Conv2D(64,(3,3), activation="relu", padding="SAME",name='Conv2D_3')(inputs)
    layers = tf.keras.layers.Conv2D(128,(3,3), activation="relu", padding="SAME",name='Conv2D_4')(layers)

    # Transición fully-conected, para que sea compatible con una densa
    layers = tf.keras.layers.Flatten()(layers)

    # Capas densas
    layers = tf.keras.layers.Dense(120, activation=tf.nn.relu,name='densa_1')(layers)
    layers = tf.keras.layers.Dense(24, activation=tf.nn.relu,name='densa_2')(layers)

    # Dropout
    layers = tf.keras.layers.Dropout(0.5)(layers)
    layers = tf.keras.layers.Dense(12, activation=tf.nn.relu,name='densa_3')(layers)
    predict= tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, name="output")(layers)  # tf.nn.softmax
    model = tf.keras.Model(inputs = inputs, outputs=predict)

    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(),metrics=Metr())
    return model

model_name="model_A"
log_dir="logs/v0/"
batch_size=32
epochs=50
model = model_A(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias

apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  Conv2D_3 (Conv2D)           (None, 96, 96, 64)        1792
#
#  Conv2D_4 (Conv2D)           (None, 96, 96, 128)       73856
#
#  flatten (Flatten)           (None, 1179648)           0
#
#  densa_1 (Dense)             (None, 120)               141557880
#
#  densa_2 (Dense)             (None, 24)                2904
#
#  dropout (Dropout)           (None, 24)                0
#
#  densa_3 (Dense)             (None, 12)                300
#
#  output (Dense)              (None, 1)                 13
#
# =================================================================
# Total params: 141636745 (540.30 MB)
# Trainable params: 141636745 (540.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 108/108 [==============================] - 30s 97ms/step - loss: 0.9409 - AUC: 0.5216 - PRC: 0.5107 - RECALL: 0.0676 - Error Cuadrático Medio: 0.2573 - Verdadero Positivo: 117.0000 - Falso Positivo: 137.0000 - Verdadero Negativo: 1588.0000 - Falso Negativo: 1614.0000 - Accuracy: 0.4933 - Precision: 0.4606 - val_loss: 0.6920 - val_AUC: 0.5540 - val_PRC: 0.5230 - val_RECALL: 0.0094 - val_Error Cuadrático Medio: 0.2494 - val_Verdadero Positivo: 4.0000 - val_Falso Positivo: 17.0000 - val_Verdadero Negativo: 420.0000 - val_Falso Negativo: 423.0000 - val_Accuracy: 0.4907 - val_Precision: 0.1905
# Epoch 2/50
# 108/108 [==============================] - 9s 85ms/step - loss: 0.6744 - AUC: 0.5872 - PRC: 0.5539 - RECALL: 0.5552 - Error Cuadrático Medio: 0.2413 - Verdadero Positivo: 961.0000 - Falso Positivo: 773.0000 - Verdadero Negativo: 952.0000 - Falso Negativo: 770.0000 - Accuracy: 0.5535 - Precision: 0.5542 - val_loss: 0.6479 - val_AUC: 0.6757 - val_PRC: 0.6084 - val_RECALL: 0.5855 - val_Error Cuadrático Medio: 0.2291 - val_Verdadero Positivo: 250.0000 - val_Falso Positivo: 145.0000 - val_Verdadero Negativo: 292.0000 - val_Falso Negativo: 177.0000 - val_Accuracy: 0.6273 - val_Precision: 0.6329
# Epoch 3/50
# 108/108 [==============================] - 9s 80ms/step - loss: 0.6930 - AUC: 0.4906 - PRC: 0.4885 - RECALL: 0.9936 - Error Cuadrático Medio: 0.2499 - Verdadero Positivo: 1720.0000 - Falso Positivo: 1699.0000 - Verdadero Negativo: 26.0000 - Falso Negativo: 11.0000 - Accuracy: 0.5052 - Precision: 0.5031 - val_loss: 0.6936 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2502 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 4/50
# 108/108 [==============================] - 8s 78ms/step - loss: 0.6933 - AUC: 0.4927 - PRC: 0.4951 - RECALL: 1.0000 - Error Cuadrático Medio: 0.2501 - Verdadero Positivo: 1731.0000 - Falso Positivo: 1725.0000 - Verdadero Negativo: 0.0000e+00 - Falso Negativo: 0.0000e+00 - Accuracy: 0.5009 - Precision: 0.5009 - val_loss: 0.6934 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2501 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 5/50
# 108/108 [==============================] - 9s 81ms/step - loss: 0.6932 - AUC: 0.5079 - PRC: 0.5080 - RECALL: 1.0000 - Error Cuadrático Medio: 0.2500 - Verdadero Positivo: 1731.0000 - Falso Positivo: 1725.0000 - Verdadero Negativo: 0.0000e+00 - Falso Negativo: 0.0000e+00 - Accuracy: 0.5009 - Precision: 0.5009 - val_loss: 0.6933 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2501 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 6/50
# 108/108 [==============================] - 8s 79ms/step - loss: 0.6932 - AUC: 0.4985 - PRC: 0.5001 - RECALL: 1.0000 - Error Cuadrático Medio: 0.2500 - Verdadero Positivo: 1731.0000 - Falso Positivo: 1725.0000 - Verdadero Negativo: 0.0000e+00 - Falso Negativo: 0.0000e+00 - Accuracy: 0.5009 - Precision: 0.5009 - val_loss: 0.6932 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2500 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 7/50
# 108/108 [==============================] - 9s 85ms/step - loss: 0.6932 - AUC: 0.4935 - PRC: 0.4959 - RECALL: 1.0000 - Error Cuadrático Medio: 0.2500 - Verdadero Positivo: 1731.0000 - Falso Positivo: 1725.0000 - Verdadero Negativo: 0.0000e+00 - Falso Negativo: 0.0000e+00 - Accuracy: 0.5009 - Precision: 0.5009 - val_loss: 0.6932 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2500 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 8/50
# 108/108 [==============================] - 9s 80ms/step - loss: 0.6932 - AUC: 0.5005 - PRC: 0.5013 - RECALL: 1.0000 - Error Cuadrático Medio: 0.2500 - Verdadero Positivo: 1731.0000 - Falso Positivo: 1724.0000 - Verdadero Negativo: 1.0000 - Falso Negativo: 0.0000e+00 - Accuracy: 0.5012 - Precision: 0.5010 - val_loss: 0.6932 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2500 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 9/50
# 108/108 [==============================] - 8s 78ms/step - loss: 0.6931 - AUC: 0.4978 - PRC: 0.4986 - RECALL: 1.0000 - Error Cuadrático Medio: 0.2500 - Verdadero Positivo: 1731.0000 - Falso Positivo: 1724.0000 - Verdadero Negativo: 1.0000 - Falso Negativo: 0.0000e+00 - Accuracy: 0.5012 - Precision: 0.5010 - val_loss: 0.6931 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2500 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 10/50
# 108/108 [==============================] - 9s 79ms/step - loss: 0.6930 - AUC: 0.5113 - PRC: 0.5146 - RECALL: 0.7568 - Error Cuadrático Medio: 0.2499 - Verdadero Positivo: 1310.0000 - Falso Positivo: 1275.0000 - Verdadero Negativo: 450.0000 - Falso Negativo: 421.0000 - Accuracy: 0.5093 - Precision: 0.5068 - val_loss: 0.6932 - val_AUC: 0.5000 - val_PRC: 0.4942 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2500 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 11/50
# 108/108 [==============================] - 9s 81ms/step - loss: 0.6931 - AUC: 0.4980 - PRC: 0.5001 - RECALL: 0.9856 - Error Cuadrático Medio: 0.2500 - Verdadero Positivo: 1706.0000 - Falso Positivo: 1699.0000 - Verdadero Negativo: 26.0000 - Falso Negativo: 25.0000 - Accuracy: 0.5012 - Precision: 0.5010 - val_loss: 0.6930 - val_AUC: 0.5091 - val_PRC: 0.4988 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.2499 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 437.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4942 - val_Precision: 0.4942
# Epoch 12/50
# 108/108 [==============================] - ETA: 0s - loss: 0.6927 - AUC: 0.5276 - PRC: 0.5285 - RECALL: 0.9659 - Error Cuadrático Medio: 0.2498 - Verdadero Positivo: 1672.0000 - Falso Positivo: 1657.0000 - Verdadero Negativo: 68.0000 - Falso Negativo: 59.0000 - Accuracy: 0.5035 - Precision: 0.5023Restoring model weights from the end of the best epoch: 2.
# 108/108 [==============================] - 9s 86ms/step - loss: 0.6927 - AUC: 0.5276 - PRC: 0.5285 - RECALL: 0.9659 - Error Cuadrático Medio: 0.2498 - Verdadero Positivo: 1672.0000 - Falso Positivo: 1657.0000 - Verdadero Negativo: 68.0000 - Falso Negativo: 59.0000 - Accuracy: 0.5035 - Precision: 0.5023 - val_loss: 0.6920 - val_AUC: 0.6511 - val_PRC: 0.5971 - val_RECALL: 0.9906 - val_Error Cuadrático Medio: 0.2494 - val_Verdadero Positivo: 423.0000 - val_Falso Positivo: 427.0000 - val_Verdadero Negativo: 10.0000 - val_Falso Negativo: 4.0000 - val_Accuracy: 0.5012 - val_Precision: 0.4976
# Epoch 12: early stopping
# 34/34 [==============================] - 1s 25ms/step - loss: 0.6548 - AUC: 0.6500 - PRC: 0.6082 - RECALL: 0.5406 - Error Cuadrático Medio: 0.2333 - Verdadero Positivo: 293.0000 - Falso Positivo: 187.0000 - Verdadero Negativo: 351.0000 - Falso Negativo: 249.0000 - Accuracy: 0.5963 - Precision: 0.6104
# {'loss': 0.6548437476158142, 'AUC': 0.6499849557876587, 'PRC': 0.6082175374031067, 'RECALL': 0.5405904054641724, 'Error Cuadrático Medio': 0.23333431780338287, 'Verdadero Positivo': 293.0, 'Falso Positivo': 187.0, 'Verdadero Negativo': 351.0, 'Falso Negativo': 249.0, 'Accuracy': 0.5962963104248047, 'Precision': 0.6104166507720947}
#
#  ...Calculando valores predichos para train y test: ...
# 108/108 [==============================] - 2s 13ms/step
# 34/34 [==============================] - 1s 13ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.6548437476158142
# AUC :  0.6499849557876587
# PRC :  0.6082175374031067
# RECALL :  0.5405904054641724
# Error Cuadrático Medio :  0.23333431780338287
# Verdadero Positivo :  293.0
# Falso Positivo :  187.0
# Verdadero Negativo :  351.0
# Falso Negativo :  249.0
# Accuracy :  0.5962963104248047
# Precision :  0.6104166507720947
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  351
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  187
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  249
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  293

# %% [markdown]
# #### ***Model-B***:  $~~~3 \times $*`Conv2D`*+$2\times $*`MaxPooling2D`*+$2\times $*`Dropout(0.5-0.2)`*+$3\times $*`Denses`*

# %%
def model_B(img_size=96, compile=True,output_bias=None):

    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    # Capa convolucional: 15 filtros, de 3x3, padding="SAME" para que el tamaño de la salida sea el mismo que la entrada
    # layers = tf.keras.layers.Conv2D(16,(3,3), activation="relu", padding="SAME")(inputs)
    # layers = tf.keras.layers.MaxPooling2D(2,2)(layers)
    layers = tf.keras.layers.Conv2D(32,(3,3), activation="relu", padding="SAME")(inputs)
    layers = tf.keras.layers.MaxPooling2D(1,1)(layers)
    layers = tf.keras.layers.Conv2D(64,(3,3), activation="relu", padding="SAME")(layers)
    layers = tf.keras.layers.MaxPooling2D(1,1)(layers)
    layers = tf.keras.layers.Conv2D(128,(3,3), activation="relu", padding="SAME")(layers)

    # Dropout
    layers = tf.keras.layers.Dropout(0.5)(layers)

    # Transición fully-conected, para que sea compatible con una densa
    layers = tf.keras.layers.Flatten()(layers)

    # Capas densas
    layers = tf.keras.layers.Dense(120, activation=tf.nn.relu,name='densa_1')(layers)
    layers = tf.keras.layers.Dense(24, activation=tf.nn.relu,name='densa_2')(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    layers = tf.keras.layers.Dense(12, activation=tf.nn.relu,name='densa_3')(layers)

    predict= tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, name="output")(layers)  # tf.nn.softmax
    model = tf.keras.Model(inputs = inputs, outputs=predict)

    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), #'sparse_categorical_crossentropy',
                                      metrics=Metr())
    return model

model_name="model_B_v3"
log_dir="logs/v3/"
batch_size=32
epochs=50
model = model_B(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias

apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  conv2d (Conv2D)             (None, 96, 96, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 96, 96, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 96, 96, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  dropout (Dropout)           (None, 96, 96, 128)       0
#
#  flatten (Flatten)           (None, 1179648)           0
#
#  densa_1 (Dense)             (None, 120)               141557880
#
#  densa_2 (Dense)             (None, 24)                2904
#
#  dropout_1 (Dropout)         (None, 24)                0
#
#  densa_3 (Dense)             (None, 12)                300
#
#  output (Dense)              (None, 1)                 13
#
# =================================================================
# Total params: 141654345 (540.37 MB)
# Trainable params: 141654345 (540.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 108/108 [==============================] - 19s 140ms/step - loss: 1.2113 - AUC: 0.5561 - PRC: 0.5355 - RECALL: 0.4235 - Error Cuadrático Medio: 0.2567 - Verdadero Positivo: 733.0000 - Falso Positivo: 599.0000 - Verdadero Negativo: 1126.0000 - Falso Negativo: 998.0000 - Accuracy: 0.5379 - Precision: 0.5503 - val_loss: 0.6790 - val_AUC: 0.7999 - val_PRC: 0.7656 - val_RECALL: 0.7892 - val_Error Cuadrático Medio: 0.2429 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 126.0000 - val_Verdadero Negativo: 311.0000 - val_Falso Negativo: 90.0000 - val_Accuracy: 0.7500 - val_Precision: 0.7279
# Epoch 2/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.6603 - AUC: 0.6326 - PRC: 0.6178 - RECALL: 0.7423 - Error Cuadrático Medio: 0.2343 - Verdadero Positivo: 1285.0000 - Falso Positivo: 954.0000 - Verdadero Negativo: 771.0000 - Falso Negativo: 446.0000 - Accuracy: 0.5949 - Precision: 0.5739 - val_loss: 0.6206 - val_AUC: 0.8402 - val_PRC: 0.8397 - val_RECALL: 0.9602 - val_Error Cuadrático Medio: 0.2175 - val_Verdadero Positivo: 410.0000 - val_Falso Positivo: 321.0000 - val_Verdadero Negativo: 116.0000 - val_Falso Negativo: 17.0000 - val_Accuracy: 0.6088 - val_Precision: 0.5609
# Epoch 3/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.5782 - AUC: 0.7735 - PRC: 0.7634 - RECALL: 0.7221 - Error Cuadrático Medio: 0.1955 - Verdadero Positivo: 1250.0000 - Falso Positivo: 515.0000 - Verdadero Negativo: 1210.0000 - Falso Negativo: 481.0000 - Accuracy: 0.7118 - Precision: 0.7082 - val_loss: 0.5124 - val_AUC: 0.8578 - val_PRC: 0.8560 - val_RECALL: 0.8923 - val_Error Cuadrático Medio: 0.1706 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 180.0000 - val_Verdadero Negativo: 257.0000 - val_Falso Negativo: 46.0000 - val_Accuracy: 0.7384 - val_Precision: 0.6791
# Epoch 4/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.5851 - AUC: 0.7643 - PRC: 0.7441 - RECALL: 0.7655 - Error Cuadrático Medio: 0.1989 - Verdadero Positivo: 1325.0000 - Falso Positivo: 621.0000 - Verdadero Negativo: 1104.0000 - Falso Negativo: 406.0000 - Accuracy: 0.7028 - Precision: 0.6809 - val_loss: 0.5802 - val_AUC: 0.8525 - val_PRC: 0.8612 - val_RECALL: 0.9016 - val_Error Cuadrático Medio: 0.1961 - val_Verdadero Positivo: 385.0000 - val_Falso Positivo: 192.0000 - val_Verdadero Negativo: 245.0000 - val_Falso Negativo: 42.0000 - val_Accuracy: 0.7292 - val_Precision: 0.6672
# Epoch 5/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.4959 - AUC: 0.8416 - PRC: 0.8268 - RECALL: 0.8007 - Error Cuadrático Medio: 0.1627 - Verdadero Positivo: 1386.0000 - Falso Positivo: 470.0000 - Verdadero Negativo: 1255.0000 - Falso Negativo: 345.0000 - Accuracy: 0.7642 - Precision: 0.7468 - val_loss: 0.5005 - val_AUC: 0.8565 - val_PRC: 0.8703 - val_RECALL: 0.7283 - val_Error Cuadrático Medio: 0.1588 - val_Verdadero Positivo: 311.0000 - val_Falso Positivo: 67.0000 - val_Verdadero Negativo: 370.0000 - val_Falso Negativo: 116.0000 - val_Accuracy: 0.7882 - val_Precision: 0.8228
# Epoch 6/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.4290 - AUC: 0.8858 - PRC: 0.8611 - RECALL: 0.8614 - Error Cuadrático Medio: 0.1344 - Verdadero Positivo: 1491.0000 - Falso Positivo: 373.0000 - Verdadero Negativo: 1352.0000 - Falso Negativo: 240.0000 - Accuracy: 0.8226 - Precision: 0.7999 - val_loss: 0.5946 - val_AUC: 0.7951 - val_PRC: 0.8010 - val_RECALL: 0.7892 - val_Error Cuadrático Medio: 0.1954 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 157.0000 - val_Verdadero Negativo: 280.0000 - val_Falso Negativo: 90.0000 - val_Accuracy: 0.7141 - val_Precision: 0.6822
# Epoch 7/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.3406 - AUC: 0.9283 - PRC: 0.9179 - RECALL: 0.8879 - Error Cuadrático Medio: 0.1043 - Verdadero Positivo: 1537.0000 - Falso Positivo: 293.0000 - Verdadero Negativo: 1432.0000 - Falso Negativo: 194.0000 - Accuracy: 0.8591 - Precision: 0.8399 - val_loss: 0.6898 - val_AUC: 0.8243 - val_PRC: 0.8423 - val_RECALL: 0.6300 - val_Error Cuadrático Medio: 0.1868 - val_Verdadero Positivo: 269.0000 - val_Falso Positivo: 52.0000 - val_Verdadero Negativo: 385.0000 - val_Falso Negativo: 158.0000 - val_Accuracy: 0.7569 - val_Precision: 0.8380
# Epoch 8/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.2535 - AUC: 0.9608 - PRC: 0.9589 - RECALL: 0.9133 - Error Cuadrático Medio: 0.0761 - Verdadero Positivo: 1581.0000 - Falso Positivo: 206.0000 - Verdadero Negativo: 1519.0000 - Falso Negativo: 150.0000 - Accuracy: 0.8970 - Precision: 0.8847 - val_loss: 0.6935 - val_AUC: 0.8098 - val_PRC: 0.8050 - val_RECALL: 0.7541 - val_Error Cuadrático Medio: 0.1939 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 110.0000 - val_Verdadero Negativo: 327.0000 - val_Falso Negativo: 105.0000 - val_Accuracy: 0.7512 - val_Precision: 0.7454
# Epoch 9/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.2037 - AUC: 0.9742 - PRC: 0.9726 - RECALL: 0.9330 - Error Cuadrático Medio: 0.0598 - Verdadero Positivo: 1615.0000 - Falso Positivo: 160.0000 - Verdadero Negativo: 1565.0000 - Falso Negativo: 116.0000 - Accuracy: 0.9201 - Precision: 0.9099 - val_loss: 0.8232 - val_AUC: 0.7730 - val_PRC: 0.7526 - val_RECALL: 0.6932 - val_Error Cuadrático Medio: 0.2154 - val_Verdadero Positivo: 296.0000 - val_Falso Positivo: 109.0000 - val_Verdadero Negativo: 328.0000 - val_Falso Negativo: 131.0000 - val_Accuracy: 0.7222 - val_Precision: 0.7309
# Epoch 10/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.1517 - AUC: 0.9855 - PRC: 0.9850 - RECALL: 0.9486 - Error Cuadrático Medio: 0.0429 - Verdadero Positivo: 1642.0000 - Falso Positivo: 107.0000 - Verdadero Negativo: 1618.0000 - Falso Negativo: 89.0000 - Accuracy: 0.9433 - Precision: 0.9388 - val_loss: 1.1007 - val_AUC: 0.7717 - val_PRC: 0.7502 - val_RECALL: 0.7190 - val_Error Cuadrático Medio: 0.2185 - val_Verdadero Positivo: 307.0000 - val_Falso Positivo: 99.0000 - val_Verdadero Negativo: 338.0000 - val_Falso Negativo: 120.0000 - val_Accuracy: 0.7465 - val_Precision: 0.7562
# Epoch 11/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.1054 - AUC: 0.9921 - PRC: 0.9928 - RECALL: 0.9648 - Error Cuadrático Medio: 0.0286 - Verdadero Positivo: 1670.0000 - Falso Positivo: 68.0000 - Verdadero Negativo: 1657.0000 - Falso Negativo: 61.0000 - Accuracy: 0.9627 - Precision: 0.9609 - val_loss: 1.0592 - val_AUC: 0.7606 - val_PRC: 0.7099 - val_RECALL: 0.7377 - val_Error Cuadrático Medio: 0.2282 - val_Verdadero Positivo: 315.0000 - val_Falso Positivo: 114.0000 - val_Verdadero Negativo: 323.0000 - val_Falso Negativo: 112.0000 - val_Accuracy: 0.7384 - val_Precision: 0.7343
# Epoch 12/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.0629 - AUC: 0.9967 - PRC: 0.9960 - RECALL: 0.9809 - Error Cuadrático Medio: 0.0163 - Verdadero Positivo: 1698.0000 - Falso Positivo: 34.0000 - Verdadero Negativo: 1691.0000 - Falso Negativo: 33.0000 - Accuracy: 0.9806 - Precision: 0.9804 - val_loss: 1.5861 - val_AUC: 0.7497 - val_PRC: 0.7587 - val_RECALL: 0.4918 - val_Error Cuadrático Medio: 0.2738 - val_Verdadero Positivo: 210.0000 - val_Falso Positivo: 58.0000 - val_Verdadero Negativo: 379.0000 - val_Falso Negativo: 217.0000 - val_Accuracy: 0.6817 - val_Precision: 0.7836
# Epoch 13/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.1020 - AUC: 0.9926 - PRC: 0.9912 - RECALL: 0.9711 - Error Cuadrático Medio: 0.0273 - Verdadero Positivo: 1681.0000 - Falso Positivo: 72.0000 - Verdadero Negativo: 1653.0000 - Falso Negativo: 50.0000 - Accuracy: 0.9647 - Precision: 0.9589 - val_loss: 1.5734 - val_AUC: 0.7244 - val_PRC: 0.6838 - val_RECALL: 0.6932 - val_Error Cuadrático Medio: 0.2654 - val_Verdadero Positivo: 296.0000 - val_Falso Positivo: 128.0000 - val_Verdadero Negativo: 309.0000 - val_Falso Negativo: 131.0000 - val_Accuracy: 0.7002 - val_Precision: 0.6981
# Epoch 14/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.0553 - AUC: 0.9971 - PRC: 0.9964 - RECALL: 0.9850 - Error Cuadrático Medio: 0.0133 - Verdadero Positivo: 1705.0000 - Falso Positivo: 30.0000 - Verdadero Negativo: 1695.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9838 - Precision: 0.9827 - val_loss: 1.3648 - val_AUC: 0.7404 - val_PRC: 0.7004 - val_RECALL: 0.7752 - val_Error Cuadrático Medio: 0.2592 - val_Verdadero Positivo: 331.0000 - val_Falso Positivo: 161.0000 - val_Verdadero Negativo: 276.0000 - val_Falso Negativo: 96.0000 - val_Accuracy: 0.7025 - val_Precision: 0.6728
# Epoch 15/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.0464 - AUC: 0.9975 - PRC: 0.9971 - RECALL: 0.9884 - Error Cuadrático Medio: 0.0109 - Verdadero Positivo: 1711.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 1699.0000 - Falso Negativo: 20.0000 - Accuracy: 0.9867 - Precision: 0.9850 - val_loss: 1.4795 - val_AUC: 0.7128 - val_PRC: 0.6590 - val_RECALL: 0.7705 - val_Error Cuadrático Medio: 0.2781 - val_Verdadero Positivo: 329.0000 - val_Falso Positivo: 176.0000 - val_Verdadero Negativo: 261.0000 - val_Falso Negativo: 98.0000 - val_Accuracy: 0.6829 - val_Precision: 0.6515
# Epoch 16/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.0524 - AUC: 0.9979 - PRC: 0.9980 - RECALL: 0.9827 - Error Cuadrático Medio: 0.0136 - Verdadero Positivo: 1701.0000 - Falso Positivo: 30.0000 - Verdadero Negativo: 1695.0000 - Falso Negativo: 30.0000 - Accuracy: 0.9826 - Precision: 0.9827 - val_loss: 1.6729 - val_AUC: 0.7328 - val_PRC: 0.6927 - val_RECALL: 0.7588 - val_Error Cuadrático Medio: 0.2803 - val_Verdadero Positivo: 324.0000 - val_Falso Positivo: 176.0000 - val_Verdadero Negativo: 261.0000 - val_Falso Negativo: 103.0000 - val_Accuracy: 0.6771 - val_Precision: 0.6480
# Epoch 17/50
# 108/108 [==============================] - 14s 127ms/step - loss: 0.0358 - AUC: 0.9984 - PRC: 0.9983 - RECALL: 0.9896 - Error Cuadrático Medio: 0.0083 - Verdadero Positivo: 1713.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 1708.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9899 - Precision: 0.9902 - val_loss: 1.8628 - val_AUC: 0.7438 - val_PRC: 0.7137 - val_RECALL: 0.7049 - val_Error Cuadrático Medio: 0.2716 - val_Verdadero Positivo: 301.0000 - val_Falso Positivo: 134.0000 - val_Verdadero Negativo: 303.0000 - val_Falso Negativo: 126.0000 - val_Accuracy: 0.6991 - val_Precision: 0.6920
# Epoch 18/50
# 108/108 [==============================] - 14s 129ms/step - loss: 0.0351 - AUC: 0.9984 - PRC: 0.9983 - RECALL: 0.9913 - Error Cuadrático Medio: 0.0082 - Verdadero Positivo: 1716.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 1709.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9910 - Precision: 0.9908 - val_loss: 1.6424 - val_AUC: 0.7809 - val_PRC: 0.7705 - val_RECALL: 0.6581 - val_Error Cuadrático Medio: 0.2423 - val_Verdadero Positivo: 281.0000 - val_Falso Positivo: 88.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 146.0000 - val_Accuracy: 0.7292 - val_Precision: 0.7615
# Epoch 19/50
# 108/108 [==============================] - 13s 121ms/step - loss: 0.0398 - AUC: 0.9983 - PRC: 0.9982 - RECALL: 0.9896 - Error Cuadrático Medio: 0.0088 - Verdadero Positivo: 1713.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 1708.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9899 - Precision: 0.9902 - val_loss: 1.3939 - val_AUC: 0.7606 - val_PRC: 0.7302 - val_RECALL: 0.7471 - val_Error Cuadrático Medio: 0.2504 - val_Verdadero Positivo: 319.0000 - val_Falso Positivo: 143.0000 - val_Verdadero Negativo: 294.0000 - val_Falso Negativo: 108.0000 - val_Accuracy: 0.7095 - val_Precision: 0.6905
# Epoch 20/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.0220 - AUC: 0.9991 - PRC: 0.9993 - RECALL: 0.9936 - Error Cuadrático Medio: 0.0048 - Verdadero Positivo: 1720.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 1716.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9942 - Precision: 0.9948 - val_loss: 1.3775 - val_AUC: 0.7575 - val_PRC: 0.7405 - val_RECALL: 0.6604 - val_Error Cuadrático Medio: 0.2532 - val_Verdadero Positivo: 282.0000 - val_Falso Positivo: 106.0000 - val_Verdadero Negativo: 331.0000 - val_Falso Negativo: 145.0000 - val_Accuracy: 0.7095 - val_Precision: 0.7268
# Epoch 21/50
# 108/108 [==============================] - 14s 129ms/step - loss: 0.0189 - AUC: 0.9994 - PRC: 0.9996 - RECALL: 0.9931 - Error Cuadrático Medio: 0.0045 - Verdadero Positivo: 1719.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 1716.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9939 - Precision: 0.9948 - val_loss: 1.7393 - val_AUC: 0.7525 - val_PRC: 0.7352 - val_RECALL: 0.6792 - val_Error Cuadrático Medio: 0.2619 - val_Verdadero Positivo: 290.0000 - val_Falso Positivo: 122.0000 - val_Verdadero Negativo: 315.0000 - val_Falso Negativo: 137.0000 - val_Accuracy: 0.7002 - val_Precision: 0.7039
# Epoch 22/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0162 - AUC: 0.9990 - PRC: 0.9989 - RECALL: 0.9977 - Error Cuadrático Medio: 0.0027 - Verdadero Positivo: 1727.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 1719.0000 - Falso Negativo: 4.0000 - Accuracy: 0.9971 - Precision: 0.9965 - val_loss: 1.8080 - val_AUC: 0.7485 - val_PRC: 0.7329 - val_RECALL: 0.6932 - val_Error Cuadrático Medio: 0.2689 - val_Verdadero Positivo: 296.0000 - val_Falso Positivo: 128.0000 - val_Verdadero Negativo: 309.0000 - val_Falso Negativo: 131.0000 - val_Accuracy: 0.7002 - val_Precision: 0.6981
# Epoch 23/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0270 - AUC: 0.9990 - PRC: 0.9983 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0067 - Verdadero Positivo: 1717.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 1710.0000 - Falso Negativo: 14.0000 - Accuracy: 0.9916 - Precision: 0.9913 - val_loss: 1.5363 - val_AUC: 0.7677 - val_PRC: 0.7601 - val_RECALL: 0.6417 - val_Error Cuadrático Medio: 0.2584 - val_Verdadero Positivo: 274.0000 - val_Falso Positivo: 109.0000 - val_Verdadero Negativo: 328.0000 - val_Falso Negativo: 153.0000 - val_Accuracy: 0.6968 - val_Precision: 0.7154
# Epoch 24/50
# 108/108 [==============================] - 14s 129ms/step - loss: 0.0110 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 1726.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 1719.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9968 - Precision: 0.9965 - val_loss: 2.0403 - val_AUC: 0.7554 - val_PRC: 0.7509 - val_RECALL: 0.6019 - val_Error Cuadrático Medio: 0.2710 - val_Verdadero Positivo: 257.0000 - val_Falso Positivo: 88.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 170.0000 - val_Accuracy: 0.7014 - val_Precision: 0.7449
# Epoch 25/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0400 - AUC: 0.9976 - PRC: 0.9984 - RECALL: 0.9902 - Error Cuadrático Medio: 0.0086 - Verdadero Positivo: 1714.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 1707.0000 - Falso Negativo: 17.0000 - Accuracy: 0.9899 - Precision: 0.9896 - val_loss: 1.8246 - val_AUC: 0.7154 - val_PRC: 0.6600 - val_RECALL: 0.7260 - val_Error Cuadrático Medio: 0.2973 - val_Verdadero Positivo: 310.0000 - val_Falso Positivo: 171.0000 - val_Verdadero Negativo: 266.0000 - val_Falso Negativo: 117.0000 - val_Accuracy: 0.6667 - val_Precision: 0.6445
# Epoch 26/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0207 - AUC: 0.9994 - PRC: 0.9996 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0052 - Verdadero Positivo: 1717.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 1715.0000 - Falso Negativo: 14.0000 - Accuracy: 0.9931 - Precision: 0.9942 - val_loss: 1.9485 - val_AUC: 0.7296 - val_PRC: 0.6904 - val_RECALL: 0.7518 - val_Error Cuadrático Medio: 0.2892 - val_Verdadero Positivo: 321.0000 - val_Falso Positivo: 167.0000 - val_Verdadero Negativo: 270.0000 - val_Falso Negativo: 106.0000 - val_Accuracy: 0.6840 - val_Precision: 0.6578
# Epoch 27/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0115 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0025 - Verdadero Positivo: 1726.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 1721.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9974 - Precision: 0.9977 - val_loss: 1.8002 - val_AUC: 0.7291 - val_PRC: 0.6914 - val_RECALL: 0.7119 - val_Error Cuadrático Medio: 0.2864 - val_Verdadero Positivo: 304.0000 - val_Falso Positivo: 154.0000 - val_Verdadero Negativo: 283.0000 - val_Falso Negativo: 123.0000 - val_Accuracy: 0.6794 - val_Precision: 0.6638
# Epoch 28/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0196 - AUC: 0.9989 - PRC: 0.9989 - RECALL: 0.9931 - Error Cuadrático Medio: 0.0040 - Verdadero Positivo: 1719.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 1721.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9954 - Precision: 0.9977 - val_loss: 1.4249 - val_AUC: 0.7760 - val_PRC: 0.7428 - val_RECALL: 0.7611 - val_Error Cuadrático Medio: 0.2494 - val_Verdadero Positivo: 325.0000 - val_Falso Positivo: 137.0000 - val_Verdadero Negativo: 300.0000 - val_Falso Negativo: 102.0000 - val_Accuracy: 0.7234 - val_Precision: 0.7035
# Epoch 29/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0573 - AUC: 0.9957 - PRC: 0.9926 - RECALL: 0.9850 - Error Cuadrático Medio: 0.0125 - Verdadero Positivo: 1705.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 1700.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9852 - Precision: 0.9855 - val_loss: 1.7202 - val_AUC: 0.7558 - val_PRC: 0.7305 - val_RECALL: 0.6979 - val_Error Cuadrático Medio: 0.2663 - val_Verdadero Positivo: 298.0000 - val_Falso Positivo: 130.0000 - val_Verdadero Negativo: 307.0000 - val_Falso Negativo: 129.0000 - val_Accuracy: 0.7002 - val_Precision: 0.6963
# Epoch 30/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0294 - AUC: 0.9984 - PRC: 0.9980 - RECALL: 0.9913 - Error Cuadrático Medio: 0.0067 - Verdadero Positivo: 1716.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1713.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9922 - Precision: 0.9931 - val_loss: 1.8051 - val_AUC: 0.7120 - val_PRC: 0.6695 - val_RECALL: 0.6440 - val_Error Cuadrático Medio: 0.2880 - val_Verdadero Positivo: 275.0000 - val_Falso Positivo: 131.0000 - val_Verdadero Negativo: 306.0000 - val_Falso Negativo: 152.0000 - val_Accuracy: 0.6725 - val_Precision: 0.6773
# Epoch 31/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0122 - AUC: 0.9996 - PRC: 0.9993 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0025 - Verdadero Positivo: 1726.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 1719.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9968 - Precision: 0.9965 - val_loss: 2.0965 - val_AUC: 0.7372 - val_PRC: 0.7066 - val_RECALL: 0.6792 - val_Error Cuadrático Medio: 0.2814 - val_Verdadero Positivo: 290.0000 - val_Falso Positivo: 133.0000 - val_Verdadero Negativo: 304.0000 - val_Falso Negativo: 137.0000 - val_Accuracy: 0.6875 - val_Precision: 0.6856
# Epoch 32/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.0106 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0027 - Verdadero Positivo: 1724.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 1721.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9968 - Precision: 0.9977 - val_loss: 1.8176 - val_AUC: 0.7619 - val_PRC: 0.7245 - val_RECALL: 0.7518 - val_Error Cuadrático Medio: 0.2659 - val_Verdadero Positivo: 321.0000 - val_Falso Positivo: 146.0000 - val_Verdadero Negativo: 291.0000 - val_Falso Negativo: 106.0000 - val_Accuracy: 0.7083 - val_Precision: 0.6874
# Epoch 33/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0204 - AUC: 0.9987 - PRC: 0.9983 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0034 - Verdadero Positivo: 1724.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 1718.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9959 - Precision: 0.9960 - val_loss: 1.3678 - val_AUC: 0.7618 - val_PRC: 0.7403 - val_RECALL: 0.6159 - val_Error Cuadrático Medio: 0.2603 - val_Verdadero Positivo: 263.0000 - val_Falso Positivo: 94.0000 - val_Verdadero Negativo: 343.0000 - val_Falso Negativo: 164.0000 - val_Accuracy: 0.7014 - val_Precision: 0.7367
# Epoch 34/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0099 - AUC: 0.9996 - PRC: 0.9998 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0021 - Verdadero Positivo: 1724.0000 - Falso Positivo: 3.0000 - Verdadero Negativo: 1722.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9971 - Precision: 0.9983 - val_loss: 1.9692 - val_AUC: 0.7490 - val_PRC: 0.7283 - val_RECALL: 0.6721 - val_Error Cuadrático Medio: 0.2809 - val_Verdadero Positivo: 287.0000 - val_Falso Positivo: 134.0000 - val_Verdadero Negativo: 303.0000 - val_Falso Negativo: 140.0000 - val_Accuracy: 0.6829 - val_Precision: 0.6817
# Epoch 35/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0091 - AUC: 0.9997 - PRC: 0.9994 - RECALL: 0.9965 - Error Cuadrático Medio: 0.0022 - Verdadero Positivo: 1725.0000 - Falso Positivo: 2.0000 - Verdadero Negativo: 1723.0000 - Falso Negativo: 6.0000 - Accuracy: 0.9977 - Precision: 0.9988 - val_loss: 2.0603 - val_AUC: 0.7180 - val_PRC: 0.6833 - val_RECALL: 0.6768 - val_Error Cuadrático Medio: 0.2994 - val_Verdadero Positivo: 289.0000 - val_Falso Positivo: 147.0000 - val_Verdadero Negativo: 290.0000 - val_Falso Negativo: 138.0000 - val_Accuracy: 0.6701 - val_Precision: 0.6628
# Epoch 36/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0125 - AUC: 0.9996 - PRC: 0.9993 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0032 - Verdadero Positivo: 1722.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 1719.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9957 - Precision: 0.9965 - val_loss: 2.3075 - val_AUC: 0.7171 - val_PRC: 0.6781 - val_RECALL: 0.6885 - val_Error Cuadrático Medio: 0.3008 - val_Verdadero Positivo: 294.0000 - val_Falso Positivo: 149.0000 - val_Verdadero Negativo: 288.0000 - val_Falso Negativo: 133.0000 - val_Accuracy: 0.6736 - val_Precision: 0.6637
# Epoch 37/50
# 108/108 [==============================] - 14s 129ms/step - loss: 0.0078 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0021 - Verdadero Positivo: 1726.0000 - Falso Positivo: 3.0000 - Verdadero Negativo: 1722.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9977 - Precision: 0.9983 - val_loss: 1.9077 - val_AUC: 0.7252 - val_PRC: 0.7000 - val_RECALL: 0.6276 - val_Error Cuadrático Medio: 0.2991 - val_Verdadero Positivo: 268.0000 - val_Falso Positivo: 131.0000 - val_Verdadero Negativo: 306.0000 - val_Falso Negativo: 159.0000 - val_Accuracy: 0.6644 - val_Precision: 0.6717
# Epoch 38/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0048 - AUC: 0.9997 - PRC: 0.9998 - RECALL: 0.9988 - Error Cuadrático Medio: 8.8559e-04 - Verdadero Positivo: 1729.0000 - Falso Positivo: 1.0000 - Verdadero Negativo: 1724.0000 - Falso Negativo: 2.0000 - Accuracy: 0.9991 - Precision: 0.9994 - val_loss: 2.3253 - val_AUC: 0.7237 - val_PRC: 0.6768 - val_RECALL: 0.7541 - val_Error Cuadrático Medio: 0.3114 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 186.0000 - val_Verdadero Negativo: 251.0000 - val_Falso Negativo: 105.0000 - val_Accuracy: 0.6632 - val_Precision: 0.6339
# Epoch 39/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0101 - AUC: 0.9994 - PRC: 0.9988 - RECALL: 0.9983 - Error Cuadrático Medio: 0.0017 - Verdadero Positivo: 1728.0000 - Falso Positivo: 2.0000 - Verdadero Negativo: 1723.0000 - Falso Negativo: 3.0000 - Accuracy: 0.9986 - Precision: 0.9988 - val_loss: 1.9338 - val_AUC: 0.7430 - val_PRC: 0.7246 - val_RECALL: 0.6347 - val_Error Cuadrático Medio: 0.2801 - val_Verdadero Positivo: 271.0000 - val_Falso Positivo: 112.0000 - val_Verdadero Negativo: 325.0000 - val_Falso Negativo: 156.0000 - val_Accuracy: 0.6898 - val_Precision: 0.7076
# Epoch 40/50
# 108/108 [==============================] - 13s 121ms/step - loss: 0.0131 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0031 - Verdadero Positivo: 1723.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 1719.0000 - Falso Negativo: 8.0000 - Accuracy: 0.9959 - Precision: 0.9965 - val_loss: 2.1731 - val_AUC: 0.7230 - val_PRC: 0.7202 - val_RECALL: 0.5527 - val_Error Cuadrático Medio: 0.2923 - val_Verdadero Positivo: 236.0000 - val_Falso Positivo: 86.0000 - val_Verdadero Negativo: 351.0000 - val_Falso Negativo: 191.0000 - val_Accuracy: 0.6794 - val_Precision: 0.7329
# Epoch 41/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0167 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0041 - Verdadero Positivo: 1724.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 1714.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9948 - Precision: 0.9937 - val_loss: 2.6944 - val_AUC: 0.7423 - val_PRC: 0.7274 - val_RECALL: 0.6112 - val_Error Cuadrático Medio: 0.2775 - val_Verdadero Positivo: 261.0000 - val_Falso Positivo: 89.0000 - val_Verdadero Negativo: 348.0000 - val_Falso Negativo: 166.0000 - val_Accuracy: 0.7049 - val_Precision: 0.7457
# Epoch 42/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0320 - AUC: 0.9981 - PRC: 0.9983 - RECALL: 0.9902 - Error Cuadrático Medio: 0.0067 - Verdadero Positivo: 1714.0000 - Falso Positivo: 14.0000 - Verdadero Negativo: 1711.0000 - Falso Negativo: 17.0000 - Accuracy: 0.9910 - Precision: 0.9919 - val_loss: 2.1061 - val_AUC: 0.7305 - val_PRC: 0.7005 - val_RECALL: 0.7073 - val_Error Cuadrático Medio: 0.2817 - val_Verdadero Positivo: 302.0000 - val_Falso Positivo: 141.0000 - val_Verdadero Negativo: 296.0000 - val_Falso Negativo: 125.0000 - val_Accuracy: 0.6921 - val_Precision: 0.6817
# Epoch 43/50
# 108/108 [==============================] - 14s 128ms/step - loss: 0.0034 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9994 - Error Cuadrático Medio: 6.9718e-04 - Verdadero Positivo: 1730.0000 - Falso Positivo: 2.0000 - Verdadero Negativo: 1723.0000 - Falso Negativo: 1.0000 - Accuracy: 0.9991 - Precision: 0.9988 - val_loss: 2.5156 - val_AUC: 0.7226 - val_PRC: 0.6882 - val_RECALL: 0.6674 - val_Error Cuadrático Medio: 0.2902 - val_Verdadero Positivo: 285.0000 - val_Falso Positivo: 128.0000 - val_Verdadero Negativo: 309.0000 - val_Falso Negativo: 142.0000 - val_Accuracy: 0.6875 - val_Precision: 0.6901
# Epoch 44/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0038 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9983 - Error Cuadrático Medio: 8.6233e-04 - Verdadero Positivo: 1728.0000 - Falso Positivo: 1.0000 - Verdadero Negativo: 1724.0000 - Falso Negativo: 3.0000 - Accuracy: 0.9988 - Precision: 0.9994 - val_loss: 2.3721 - val_AUC: 0.7226 - val_PRC: 0.7054 - val_RECALL: 0.6089 - val_Error Cuadrático Medio: 0.2878 - val_Verdadero Positivo: 260.0000 - val_Falso Positivo: 103.0000 - val_Verdadero Negativo: 334.0000 - val_Falso Negativo: 167.0000 - val_Accuracy: 0.6875 - val_Precision: 0.7163
# Epoch 45/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0037 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9988 - Error Cuadrático Medio: 8.8285e-04 - Verdadero Positivo: 1729.0000 - Falso Positivo: 1.0000 - Verdadero Negativo: 1724.0000 - Falso Negativo: 2.0000 - Accuracy: 0.9991 - Precision: 0.9994 - val_loss: 2.4671 - val_AUC: 0.7353 - val_PRC: 0.7128 - val_RECALL: 0.6651 - val_Error Cuadrático Medio: 0.2749 - val_Verdadero Positivo: 284.0000 - val_Falso Positivo: 110.0000 - val_Verdadero Negativo: 327.0000 - val_Falso Negativo: 143.0000 - val_Accuracy: 0.7072 - val_Precision: 0.7208
# Epoch 46/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0201 - AUC: 0.9990 - PRC: 0.9985 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0039 - Verdadero Positivo: 1718.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 1721.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9951 - Precision: 0.9977 - val_loss: 2.2615 - val_AUC: 0.6855 - val_PRC: 0.6483 - val_RECALL: 0.6698 - val_Error Cuadrático Medio: 0.3092 - val_Verdadero Positivo: 286.0000 - val_Falso Positivo: 156.0000 - val_Verdadero Negativo: 281.0000 - val_Falso Negativo: 141.0000 - val_Accuracy: 0.6562 - val_Precision: 0.6471
# Epoch 47/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0213 - AUC: 0.9984 - PRC: 0.9972 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0038 - Verdadero Positivo: 1723.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 1718.0000 - Falso Negativo: 8.0000 - Accuracy: 0.9957 - Precision: 0.9960 - val_loss: 1.4816 - val_AUC: 0.7317 - val_PRC: 0.7007 - val_RECALL: 0.6815 - val_Error Cuadrático Medio: 0.2830 - val_Verdadero Positivo: 291.0000 - val_Falso Positivo: 142.0000 - val_Verdadero Negativo: 295.0000 - val_Falso Negativo: 136.0000 - val_Accuracy: 0.6782 - val_Precision: 0.6721
# Epoch 48/50
# 108/108 [==============================] - 13s 122ms/step - loss: 0.0071 - AUC: 0.9997 - PRC: 0.9998 - RECALL: 0.9983 - Error Cuadrático Medio: 0.0014 - Verdadero Positivo: 1728.0000 - Falso Positivo: 3.0000 - Verdadero Negativo: 1722.0000 - Falso Negativo: 3.0000 - Accuracy: 0.9983 - Precision: 0.9983 - val_loss: 1.9172 - val_AUC: 0.7434 - val_PRC: 0.7149 - val_RECALL: 0.6838 - val_Error Cuadrático Medio: 0.2754 - val_Verdadero Positivo: 292.0000 - val_Falso Positivo: 135.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 135.0000 - val_Accuracy: 0.6875 - val_Precision: 0.6838
# Epoch 49/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0039 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9988 - Error Cuadrático Medio: 8.1081e-04 - Verdadero Positivo: 1729.0000 - Falso Positivo: 0.0000e+00 - Verdadero Negativo: 1725.0000 - Falso Negativo: 2.0000 - Accuracy: 0.9994 - Precision: 1.0000 - val_loss: 2.1481 - val_AUC: 0.7295 - val_PRC: 0.6894 - val_RECALL: 0.6979 - val_Error Cuadrático Medio: 0.2873 - val_Verdadero Positivo: 298.0000 - val_Falso Positivo: 143.0000 - val_Verdadero Negativo: 294.0000 - val_Falso Negativo: 129.0000 - val_Accuracy: 0.6852 - val_Precision: 0.6757
# Epoch 50/50
# 108/108 [==============================] - 13s 123ms/step - loss: 0.0059 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9983 - Error Cuadrático Medio: 0.0013 - Verdadero Positivo: 1728.0000 - Falso Positivo: 2.0000 - Verdadero Negativo: 1723.0000 - Falso Negativo: 3.0000 - Accuracy: 0.9986 - Precision: 0.9988 - val_loss: 2.6947 - val_AUC: 0.7297 - val_PRC: 0.7016 - val_RECALL: 0.6674 - val_Error Cuadrático Medio: 0.2890 - val_Verdadero Positivo: 285.0000 - val_Falso Positivo: 134.0000 - val_Verdadero Negativo: 303.0000 - val_Falso Negativo: 142.0000 - val_Accuracy: 0.6806 - val_Precision: 0.6802
# 34/34 [==============================] - 1s 25ms/step - loss: 2.7952 - AUC: 0.7172 - PRC: 0.6976 - RECALL: 0.6697 - Error Cuadrático Medio: 0.2898 - Verdadero Positivo: 363.0000 - Falso Positivo: 161.0000 - Verdadero Negativo: 377.0000 - Falso Negativo: 179.0000 - Accuracy: 0.6852 - Precision: 0.6927
# {'loss': 2.7952442169189453, 'AUC': 0.7172338366508484, 'PRC': 0.6976144313812256, 'RECALL': 0.669741690158844, 'Error Cuadrático Medio': 0.2897540330886841, 'Verdadero Positivo': 363.0, 'Falso Positivo': 161.0, 'Verdadero Negativo': 377.0, 'Falso Negativo': 179.0, 'Accuracy': 0.6851851940155029, 'Precision': 0.6927480697631836}
#
#  ...Calculando valores predichos para train y test: ...
# 108/108 [==============================] - 2s 17ms/step
# 34/34 [==============================] - 1s 17ms/step
#
#  ** Resultados de las métricas:...
# loss :  2.7952442169189453
# AUC :  0.7172338366508484
# PRC :  0.6976144313812256
# RECALL :  0.669741690158844
# Error Cuadrático Medio :  0.2897540330886841
# Verdadero Positivo :  363.0
# Falso Positivo :  161.0
# Verdadero Negativo :  377.0
# Falso Negativo :  179.0
# Accuracy :  0.6851851940155029
# Precision :  0.6927480697631836
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  377
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  161
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  179
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  363

# %% [markdown]
# #### ***Model-C***:  $~~~1 \times $*`Inceptionv-3`*+$1\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
def model_C(img_size=96, compile=True,output_bias=None):
    from keras.applications.inception_v3 import InceptionV3

    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    inceptionv3 = InceptionV3(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = inceptionv3(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)

    # layers2 = tf.keras.layers.Conv2D(16,(3,3), activation="relu", padding="SAME")(inputs)
    # layers2 = tf.keras.layers.MaxPooling2D(1,1)(layers2)
    # layers2 = tf.keras.layers.Conv2D(32,(3,3), activation="relu", padding="SAME")(layers2)
    # layers2 = tf.keras.layers.MaxPooling2D(1,1)(layers2)
    # layers2 = tf.keras.layers.Conv2D(64,(3,3), activation="relu", padding="SAME")(layers2)
    # layers2 = tf.keras.layers.GlobalAveragePooling2D()(layers2)

    # layers = tf.keras.layers.Concatenate()([layers1 ,layers2])
    # layers = tf.keras.layers.GlobalMaxPooling2D()(layers)

    layers = tf.keras.layers.Dropout(0.5)(layers1)

    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam', loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

# %%
model_name="model_C"
log_dir="logs/v0/"
batch_size=32
epochs=50
model = model_C(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias

apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  inception_v3 (Functional)   (None, 1, 1, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 22049885 (84.11 MB)
# Trainable params: 22015453 (83.98 MB)
# Non-trainable params: 34432 (134.50 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 108/108 [==============================] - 60s 92ms/step - loss: 0.5282 - AUC: 0.8176 - PRC: 0.8280 - RECALL: 0.7534 - Error Cuadrático Medio: 0.1748 - Verdadero Positivo: 1326.0000 - Falso Positivo: 437.0000 - Verdadero Negativo: 1259.0000 - Falso Negativo: 434.0000 - Accuracy: 0.7480 - Precision: 0.7521 - val_loss: 5.2177 - val_AUC: 0.8274 - val_PRC: 0.8147 - val_RECALL: 0.2672 - val_Error Cuadrático Medio: 0.2784 - val_Verdadero Positivo: 109.0000 - val_Falso Positivo: 10.0000 - val_Verdadero Negativo: 446.0000 - val_Falso Negativo: 299.0000 - val_Accuracy: 0.6424 - val_Precision: 0.9160
# Epoch 2/50
# 108/108 [==============================] - 10s 90ms/step - loss: 0.4471 - AUC: 0.8745 - PRC: 0.8834 - RECALL: 0.7898 - Error Cuadrático Medio: 0.1426 - Verdadero Positivo: 1390.0000 - Falso Positivo: 327.0000 - Verdadero Negativo: 1369.0000 - Falso Negativo: 370.0000 - Accuracy: 0.7983 - Precision: 0.8096 - val_loss: 0.7392 - val_AUC: 0.5944 - val_PRC: 0.6227 - val_RECALL: 0.0392 - val_Error Cuadrático Medio: 0.2665 - val_Verdadero Positivo: 16.0000 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 392.0000 - val_Accuracy: 0.5463 - val_Precision: 1.0000
# Epoch 3/50
# 108/108 [==============================] - 7s 67ms/step - loss: 0.4279 - AUC: 0.8811 - PRC: 0.8945 - RECALL: 0.7682 - Error Cuadrático Medio: 0.1360 - Verdadero Positivo: 1352.0000 - Falso Positivo: 239.0000 - Verdadero Negativo: 1457.0000 - Falso Negativo: 408.0000 - Accuracy: 0.8128 - Precision: 0.8498 - val_loss: 0.8955 - val_AUC: 0.6576 - val_PRC: 0.5797 - val_RECALL: 0.4461 - val_Error Cuadrático Medio: 0.2757 - val_Verdadero Positivo: 182.0000 - val_Falso Positivo: 82.0000 - val_Verdadero Negativo: 374.0000 - val_Falso Negativo: 226.0000 - val_Accuracy: 0.6435 - val_Precision: 0.6894
# Epoch 4/50
# 108/108 [==============================] - 9s 87ms/step - loss: 0.3790 - AUC: 0.9096 - PRC: 0.9206 - RECALL: 0.8108 - Error Cuadrático Medio: 0.1180 - Verdadero Positivo: 1427.0000 - Falso Positivo: 234.0000 - Verdadero Negativo: 1462.0000 - Falso Negativo: 333.0000 - Accuracy: 0.8359 - Precision: 0.8591 - val_loss: 0.5090 - val_AUC: 0.8878 - val_PRC: 0.9021 - val_RECALL: 0.7181 - val_Error Cuadrático Medio: 0.1415 - val_Verdadero Positivo: 293.0000 - val_Falso Positivo: 31.0000 - val_Verdadero Negativo: 425.0000 - val_Falso Negativo: 115.0000 - val_Accuracy: 0.8310 - val_Precision: 0.9043
# Epoch 5/50
# 108/108 [==============================] - 8s 70ms/step - loss: 0.4298 - AUC: 0.8836 - PRC: 0.8897 - RECALL: 0.7528 - Error Cuadrático Medio: 0.1362 - Verdadero Positivo: 1325.0000 - Falso Positivo: 224.0000 - Verdadero Negativo: 1472.0000 - Falso Negativo: 435.0000 - Accuracy: 0.8093 - Precision: 0.8554 - val_loss: 1.0312 - val_AUC: 0.7370 - val_PRC: 0.7753 - val_RECALL: 0.2083 - val_Error Cuadrático Medio: 0.2997 - val_Verdadero Positivo: 85.0000 - val_Falso Positivo: 1.0000 - val_Verdadero Negativo: 455.0000 - val_Falso Negativo: 323.0000 - val_Accuracy: 0.6250 - val_Precision: 0.9884
# Epoch 6/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.5454 - AUC: 0.7888 - PRC: 0.8068 - RECALL: 0.6580 - Error Cuadrático Medio: 0.1852 - Verdadero Positivo: 1158.0000 - Falso Positivo: 452.0000 - Verdadero Negativo: 1244.0000 - Falso Negativo: 602.0000 - Accuracy: 0.6950 - Precision: 0.7193 - val_loss: 0.7110 - val_AUC: 0.3862 - val_PRC: 0.4060 - val_RECALL: 0.2108 - val_Error Cuadrático Medio: 0.2582 - val_Verdadero Positivo: 86.0000 - val_Falso Positivo: 159.0000 - val_Verdadero Negativo: 297.0000 - val_Falso Negativo: 322.0000 - val_Accuracy: 0.4433 - val_Precision: 0.3510
# Epoch 7/50
# 108/108 [==============================] - 8s 70ms/step - loss: 0.5775 - AUC: 0.7749 - PRC: 0.7807 - RECALL: 0.6386 - Error Cuadrático Medio: 0.1960 - Verdadero Positivo: 1124.0000 - Falso Positivo: 355.0000 - Verdadero Negativo: 1341.0000 - Falso Negativo: 636.0000 - Accuracy: 0.7133 - Precision: 0.7600 - val_loss: 0.6149 - val_AUC: 0.7886 - val_PRC: 0.7984 - val_RECALL: 0.7500 - val_Error Cuadrático Medio: 0.2019 - val_Verdadero Positivo: 306.0000 - val_Falso Positivo: 123.0000 - val_Verdadero Negativo: 333.0000 - val_Falso Negativo: 102.0000 - val_Accuracy: 0.7396 - val_Precision: 0.7133
# Epoch 8/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.4453 - AUC: 0.8741 - PRC: 0.8767 - RECALL: 0.7858 - Error Cuadrático Medio: 0.1406 - Verdadero Positivo: 1383.0000 - Falso Positivo: 288.0000 - Verdadero Negativo: 1408.0000 - Falso Negativo: 377.0000 - Accuracy: 0.8076 - Precision: 0.8276 - val_loss: 0.9197 - val_AUC: 0.8237 - val_PRC: 0.8009 - val_RECALL: 0.9608 - val_Error Cuadrático Medio: 0.2776 - val_Verdadero Positivo: 392.0000 - val_Falso Positivo: 281.0000 - val_Verdadero Negativo: 175.0000 - val_Falso Negativo: 16.0000 - val_Accuracy: 0.6562 - val_Precision: 0.5825
# Epoch 9/50
# 108/108 [==============================] - 8s 73ms/step - loss: 0.4222 - AUC: 0.8853 - PRC: 0.8976 - RECALL: 0.7932 - Error Cuadrático Medio: 0.1312 - Verdadero Positivo: 1396.0000 - Falso Positivo: 255.0000 - Verdadero Negativo: 1441.0000 - Falso Negativo: 364.0000 - Accuracy: 0.8209 - Precision: 0.8455 - val_loss: 0.5363 - val_AUC: 0.8558 - val_PRC: 0.8537 - val_RECALL: 0.8603 - val_Error Cuadrático Medio: 0.1764 - val_Verdadero Positivo: 351.0000 - val_Falso Positivo: 164.0000 - val_Verdadero Negativo: 292.0000 - val_Falso Negativo: 57.0000 - val_Accuracy: 0.7442 - val_Precision: 0.6816
# Epoch 10/50
# 108/108 [==============================] - 7s 67ms/step - loss: 0.3936 - AUC: 0.9015 - PRC: 0.9126 - RECALL: 0.8256 - Error Cuadrático Medio: 0.1232 - Verdadero Positivo: 1453.0000 - Falso Positivo: 260.0000 - Verdadero Negativo: 1436.0000 - Falso Negativo: 307.0000 - Accuracy: 0.8359 - Precision: 0.8482 - val_loss: 0.5334 - val_AUC: 0.8320 - val_PRC: 0.8380 - val_RECALL: 0.6740 - val_Error Cuadrático Medio: 0.1683 - val_Verdadero Positivo: 275.0000 - val_Falso Positivo: 49.0000 - val_Verdadero Negativo: 407.0000 - val_Falso Negativo: 133.0000 - val_Accuracy: 0.7894 - val_Precision: 0.8488
# Epoch 11/50
# 108/108 [==============================] - 8s 71ms/step - loss: 0.3475 - AUC: 0.9218 - PRC: 0.9333 - RECALL: 0.8551 - Error Cuadrático Medio: 0.1061 - Verdadero Positivo: 1505.0000 - Falso Positivo: 224.0000 - Verdadero Negativo: 1472.0000 - Falso Negativo: 255.0000 - Accuracy: 0.8614 - Precision: 0.8704 - val_loss: 0.6046 - val_AUC: 0.8039 - val_PRC: 0.8224 - val_RECALL: 0.7230 - val_Error Cuadrático Medio: 0.1868 - val_Verdadero Positivo: 295.0000 - val_Falso Positivo: 90.0000 - val_Verdadero Negativo: 366.0000 - val_Falso Negativo: 113.0000 - val_Accuracy: 0.7650 - val_Precision: 0.7662
# Epoch 12/50
# 108/108 [==============================] - 8s 71ms/step - loss: 0.3685 - AUC: 0.9166 - PRC: 0.9225 - RECALL: 0.8114 - Error Cuadrático Medio: 0.1150 - Verdadero Positivo: 1428.0000 - Falso Positivo: 222.0000 - Verdadero Negativo: 1474.0000 - Falso Negativo: 332.0000 - Accuracy: 0.8397 - Precision: 0.8655 - val_loss: 1.2767 - val_AUC: 0.6718 - val_PRC: 0.7080 - val_RECALL: 0.0417 - val_Error Cuadrático Medio: 0.3811 - val_Verdadero Positivo: 17.0000 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 391.0000 - val_Accuracy: 0.5475 - val_Precision: 1.0000
# Epoch 13/50
# 108/108 [==============================] - 7s 69ms/step - loss: 0.3659 - AUC: 0.9179 - PRC: 0.9203 - RECALL: 0.8222 - Error Cuadrático Medio: 0.1129 - Verdadero Positivo: 1447.0000 - Falso Positivo: 231.0000 - Verdadero Negativo: 1465.0000 - Falso Negativo: 313.0000 - Accuracy: 0.8426 - Precision: 0.8623 - val_loss: 0.8835 - val_AUC: 0.8366 - val_PRC: 0.8393 - val_RECALL: 0.1961 - val_Error Cuadrático Medio: 0.2867 - val_Verdadero Positivo: 80.0000 - val_Falso Positivo: 4.0000 - val_Verdadero Negativo: 452.0000 - val_Falso Negativo: 328.0000 - val_Accuracy: 0.6157 - val_Precision: 0.9524
# Epoch 14/50
# 108/108 [==============================] - 8s 72ms/step - loss: 0.3842 - AUC: 0.9104 - PRC: 0.9124 - RECALL: 0.7903 - Error Cuadrático Medio: 0.1221 - Verdadero Positivo: 1391.0000 - Falso Positivo: 239.0000 - Verdadero Negativo: 1457.0000 - Falso Negativo: 369.0000 - Accuracy: 0.8241 - Precision: 0.8534 - val_loss: 1.0060 - val_AUC: 0.8577 - val_PRC: 0.8182 - val_RECALL: 0.9706 - val_Error Cuadrático Medio: 0.2793 - val_Verdadero Positivo: 396.0000 - val_Falso Positivo: 301.0000 - val_Verdadero Negativo: 155.0000 - val_Falso Negativo: 12.0000 - val_Accuracy: 0.6377 - val_Precision: 0.5681
# Epoch 15/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.4003 - AUC: 0.9033 - PRC: 0.8997 - RECALL: 0.8352 - Error Cuadrático Medio: 0.1223 - Verdadero Positivo: 1470.0000 - Falso Positivo: 289.0000 - Verdadero Negativo: 1407.0000 - Falso Negativo: 290.0000 - Accuracy: 0.8325 - Precision: 0.8357 - val_loss: 1.4090 - val_AUC: 0.4722 - val_PRC: 0.5420 - val_RECALL: 0.0025 - val_Error Cuadrático Medio: 0.4200 - val_Verdadero Positivo: 1.0000 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 407.0000 - val_Accuracy: 0.5289 - val_Precision: 1.0000
# Epoch 16/50
# 108/108 [==============================] - 8s 72ms/step - loss: 0.3737 - AUC: 0.9139 - PRC: 0.9131 - RECALL: 0.8210 - Error Cuadrático Medio: 0.1160 - Verdadero Positivo: 1445.0000 - Falso Positivo: 265.0000 - Verdadero Negativo: 1431.0000 - Falso Negativo: 315.0000 - Accuracy: 0.8322 - Precision: 0.8450 - val_loss: 0.4480 - val_AUC: 0.8767 - val_PRC: 0.8709 - val_RECALL: 0.6912 - val_Error Cuadrático Medio: 0.1428 - val_Verdadero Positivo: 282.0000 - val_Falso Positivo: 62.0000 - val_Verdadero Negativo: 394.0000 - val_Falso Negativo: 126.0000 - val_Accuracy: 0.7824 - val_Precision: 0.8198
# Epoch 17/50
# 108/108 [==============================] - 7s 69ms/step - loss: 0.3484 - AUC: 0.9250 - PRC: 0.9276 - RECALL: 0.8330 - Error Cuadrático Medio: 0.1086 - Verdadero Positivo: 1466.0000 - Falso Positivo: 249.0000 - Verdadero Negativo: 1447.0000 - Falso Negativo: 294.0000 - Accuracy: 0.8429 - Precision: 0.8548 - val_loss: 0.8760 - val_AUC: 0.5345 - val_PRC: 0.4936 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.2879 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 408.0000 - val_Accuracy: 0.5278 - val_Precision: 0.0000e+00
# Epoch 18/50
# 108/108 [==============================] - 8s 74ms/step - loss: 0.3583 - AUC: 0.9208 - PRC: 0.9242 - RECALL: 0.8290 - Error Cuadrático Medio: 0.1107 - Verdadero Positivo: 1459.0000 - Falso Positivo: 252.0000 - Verdadero Negativo: 1444.0000 - Falso Negativo: 301.0000 - Accuracy: 0.8400 - Precision: 0.8527 - val_loss: 0.7251 - val_AUC: 0.8444 - val_PRC: 0.8496 - val_RECALL: 0.4510 - val_Error Cuadrático Medio: 0.2218 - val_Verdadero Positivo: 184.0000 - val_Falso Positivo: 13.0000 - val_Verdadero Negativo: 443.0000 - val_Falso Negativo: 224.0000 - val_Accuracy: 0.7257 - val_Precision: 0.9340
# Epoch 19/50
# 108/108 [==============================] - 7s 69ms/step - loss: 0.3042 - AUC: 0.9438 - PRC: 0.9445 - RECALL: 0.8364 - Error Cuadrático Medio: 0.0914 - Verdadero Positivo: 1472.0000 - Falso Positivo: 174.0000 - Verdadero Negativo: 1522.0000 - Falso Negativo: 288.0000 - Accuracy: 0.8663 - Precision: 0.8943 - val_loss: 0.4227 - val_AUC: 0.9090 - val_PRC: 0.9072 - val_RECALL: 0.8211 - val_Error Cuadrático Medio: 0.1256 - val_Verdadero Positivo: 335.0000 - val_Falso Positivo: 73.0000 - val_Verdadero Negativo: 383.0000 - val_Falso Negativo: 73.0000 - val_Accuracy: 0.8310 - val_Precision: 0.8211
# Epoch 20/50
# 108/108 [==============================] - 8s 73ms/step - loss: 0.2635 - AUC: 0.9565 - PRC: 0.9602 - RECALL: 0.9000 - Error Cuadrático Medio: 0.0779 - Verdadero Positivo: 1584.0000 - Falso Positivo: 179.0000 - Verdadero Negativo: 1517.0000 - Falso Negativo: 176.0000 - Accuracy: 0.8973 - Precision: 0.8985 - val_loss: 0.3549 - val_AUC: 0.9247 - val_PRC: 0.9177 - val_RECALL: 0.8113 - val_Error Cuadrático Medio: 0.1059 - val_Verdadero Positivo: 331.0000 - val_Falso Positivo: 51.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 77.0000 - val_Accuracy: 0.8519 - val_Precision: 0.8665
# Epoch 21/50
# 108/108 [==============================] - 8s 70ms/step - loss: 0.2757 - AUC: 0.9523 - PRC: 0.9536 - RECALL: 0.9017 - Error Cuadrático Medio: 0.0819 - Verdadero Positivo: 1587.0000 - Falso Positivo: 201.0000 - Verdadero Negativo: 1495.0000 - Falso Negativo: 173.0000 - Accuracy: 0.8918 - Precision: 0.8876 - val_loss: 0.4986 - val_AUC: 0.9097 - val_PRC: 0.9031 - val_RECALL: 0.6740 - val_Error Cuadrático Medio: 0.1430 - val_Verdadero Positivo: 275.0000 - val_Falso Positivo: 26.0000 - val_Verdadero Negativo: 430.0000 - val_Falso Negativo: 133.0000 - val_Accuracy: 0.8160 - val_Precision: 0.9136
# Epoch 22/50
# 108/108 [==============================] - 7s 67ms/step - loss: 0.3382 - AUC: 0.9294 - PRC: 0.9339 - RECALL: 0.8551 - Error Cuadrático Medio: 0.1030 - Verdadero Positivo: 1505.0000 - Falso Positivo: 224.0000 - Verdadero Negativo: 1472.0000 - Falso Negativo: 255.0000 - Accuracy: 0.8614 - Precision: 0.8704 - val_loss: 0.5158 - val_AUC: 0.8868 - val_PRC: 0.8712 - val_RECALL: 0.9167 - val_Error Cuadrático Medio: 0.1522 - val_Verdadero Positivo: 374.0000 - val_Falso Positivo: 129.0000 - val_Verdadero Negativo: 327.0000 - val_Falso Negativo: 34.0000 - val_Accuracy: 0.8113 - val_Precision: 0.7435
# Epoch 23/50
# 108/108 [==============================] - 8s 74ms/step - loss: 0.2646 - AUC: 0.9565 - PRC: 0.9619 - RECALL: 0.8943 - Error Cuadrático Medio: 0.0808 - Verdadero Positivo: 1574.0000 - Falso Positivo: 197.0000 - Verdadero Negativo: 1499.0000 - Falso Negativo: 186.0000 - Accuracy: 0.8892 - Precision: 0.8888 - val_loss: 0.7270 - val_AUC: 0.8106 - val_PRC: 0.8068 - val_RECALL: 0.5956 - val_Error Cuadrático Medio: 0.1957 - val_Verdadero Positivo: 243.0000 - val_Falso Positivo: 47.0000 - val_Verdadero Negativo: 409.0000 - val_Falso Negativo: 165.0000 - val_Accuracy: 0.7546 - val_Precision: 0.8379
# Epoch 24/50
# 108/108 [==============================] - 7s 67ms/step - loss: 0.2685 - AUC: 0.9559 - PRC: 0.9587 - RECALL: 0.8903 - Error Cuadrático Medio: 0.0808 - Verdadero Positivo: 1567.0000 - Falso Positivo: 174.0000 - Verdadero Negativo: 1522.0000 - Falso Negativo: 193.0000 - Accuracy: 0.8938 - Precision: 0.9001 - val_loss: 1.3110 - val_AUC: 0.8190 - val_PRC: 0.8082 - val_RECALL: 0.0588 - val_Error Cuadrático Medio: 0.3816 - val_Verdadero Positivo: 24.0000 - val_Falso Positivo: 3.0000 - val_Verdadero Negativo: 453.0000 - val_Falso Negativo: 384.0000 - val_Accuracy: 0.5521 - val_Precision: 0.8889
# Epoch 25/50
# 108/108 [==============================] - 8s 73ms/step - loss: 0.2180 - AUC: 0.9704 - PRC: 0.9704 - RECALL: 0.9176 - Error Cuadrático Medio: 0.0636 - Verdadero Positivo: 1615.0000 - Falso Positivo: 150.0000 - Verdadero Negativo: 1546.0000 - Falso Negativo: 145.0000 - Accuracy: 0.9146 - Precision: 0.9150 - val_loss: 1.0314 - val_AUC: 0.8612 - val_PRC: 0.8258 - val_RECALL: 0.9730 - val_Error Cuadrático Medio: 0.2424 - val_Verdadero Positivo: 397.0000 - val_Falso Positivo: 233.0000 - val_Verdadero Negativo: 223.0000 - val_Falso Negativo: 11.0000 - val_Accuracy: 0.7176 - val_Precision: 0.6302
# Epoch 26/50
# 108/108 [==============================] - 7s 67ms/step - loss: 0.1988 - AUC: 0.9753 - PRC: 0.9767 - RECALL: 0.9290 - Error Cuadrático Medio: 0.0575 - Verdadero Positivo: 1635.0000 - Falso Positivo: 129.0000 - Verdadero Negativo: 1567.0000 - Falso Negativo: 125.0000 - Accuracy: 0.9265 - Precision: 0.9269 - val_loss: 0.4609 - val_AUC: 0.8942 - val_PRC: 0.8642 - val_RECALL: 0.8162 - val_Error Cuadrático Medio: 0.1304 - val_Verdadero Positivo: 333.0000 - val_Falso Positivo: 66.0000 - val_Verdadero Negativo: 390.0000 - val_Falso Negativo: 75.0000 - val_Accuracy: 0.8368 - val_Precision: 0.8346
# Epoch 27/50
# 108/108 [==============================] - 8s 72ms/step - loss: 0.2145 - AUC: 0.9716 - PRC: 0.9728 - RECALL: 0.9170 - Error Cuadrático Medio: 0.0630 - Verdadero Positivo: 1614.0000 - Falso Positivo: 136.0000 - Verdadero Negativo: 1560.0000 - Falso Negativo: 146.0000 - Accuracy: 0.9184 - Precision: 0.9223 - val_loss: 0.6236 - val_AUC: 0.8579 - val_PRC: 0.8138 - val_RECALL: 0.9534 - val_Error Cuadrático Medio: 0.1756 - val_Verdadero Positivo: 389.0000 - val_Falso Positivo: 170.0000 - val_Verdadero Negativo: 286.0000 - val_Falso Negativo: 19.0000 - val_Accuracy: 0.7812 - val_Precision: 0.6959
# Epoch 28/50
# 108/108 [==============================] - 7s 69ms/step - loss: 0.1483 - AUC: 0.9859 - PRC: 0.9867 - RECALL: 0.9523 - Error Cuadrático Medio: 0.0416 - Verdadero Positivo: 1676.0000 - Falso Positivo: 91.0000 - Verdadero Negativo: 1605.0000 - Falso Negativo: 84.0000 - Accuracy: 0.9494 - Precision: 0.9485 - val_loss: 0.8559 - val_AUC: 0.8994 - val_PRC: 0.9018 - val_RECALL: 0.5172 - val_Error Cuadrático Medio: 0.2059 - val_Verdadero Positivo: 211.0000 - val_Falso Positivo: 14.0000 - val_Verdadero Negativo: 442.0000 - val_Falso Negativo: 197.0000 - val_Accuracy: 0.7558 - val_Precision: 0.9378
# Epoch 29/50
# 108/108 [==============================] - 8s 71ms/step - loss: 0.1079 - AUC: 0.9915 - PRC: 0.9928 - RECALL: 0.9602 - Error Cuadrático Medio: 0.0290 - Verdadero Positivo: 1690.0000 - Falso Positivo: 54.0000 - Verdadero Negativo: 1642.0000 - Falso Negativo: 70.0000 - Accuracy: 0.9641 - Precision: 0.9690 - val_loss: 0.6077 - val_AUC: 0.8907 - val_PRC: 0.8613 - val_RECALL: 0.8260 - val_Error Cuadrático Medio: 0.1494 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 81.0000 - val_Verdadero Negativo: 375.0000 - val_Falso Negativo: 71.0000 - val_Accuracy: 0.8241 - val_Precision: 0.8062
# Epoch 30/50
# 108/108 [==============================] - 8s 71ms/step - loss: 0.1497 - AUC: 0.9855 - PRC: 0.9857 - RECALL: 0.9585 - Error Cuadrático Medio: 0.0429 - Verdadero Positivo: 1687.0000 - Falso Positivo: 113.0000 - Verdadero Negativo: 1583.0000 - Falso Negativo: 73.0000 - Accuracy: 0.9462 - Precision: 0.9372 - val_loss: 0.4787 - val_AUC: 0.9163 - val_PRC: 0.9096 - val_RECALL: 0.8480 - val_Error Cuadrático Medio: 0.1213 - val_Verdadero Positivo: 346.0000 - val_Falso Positivo: 69.0000 - val_Verdadero Negativo: 387.0000 - val_Falso Negativo: 62.0000 - val_Accuracy: 0.8484 - val_Precision: 0.8337
# Epoch 31/50
# 108/108 [==============================] - 8s 70ms/step - loss: 0.1232 - AUC: 0.9890 - PRC: 0.9897 - RECALL: 0.9636 - Error Cuadrático Medio: 0.0336 - Verdadero Positivo: 1696.0000 - Falso Positivo: 83.0000 - Verdadero Negativo: 1613.0000 - Falso Negativo: 64.0000 - Accuracy: 0.9575 - Precision: 0.9533 - val_loss: 0.8831 - val_AUC: 0.8495 - val_PRC: 0.8616 - val_RECALL: 0.6127 - val_Error Cuadrático Medio: 0.1924 - val_Verdadero Positivo: 250.0000 - val_Falso Positivo: 26.0000 - val_Verdadero Negativo: 430.0000 - val_Falso Negativo: 158.0000 - val_Accuracy: 0.7870 - val_Precision: 0.9058
# Epoch 32/50
# 108/108 [==============================] - 8s 71ms/step - loss: 0.1101 - AUC: 0.9905 - PRC: 0.9893 - RECALL: 0.9733 - Error Cuadrático Medio: 0.0281 - Verdadero Positivo: 1713.0000 - Falso Positivo: 68.0000 - Verdadero Negativo: 1628.0000 - Falso Negativo: 47.0000 - Accuracy: 0.9667 - Precision: 0.9618 - val_loss: 1.3881 - val_AUC: 0.7929 - val_PRC: 0.8262 - val_RECALL: 0.4191 - val_Error Cuadrático Medio: 0.2637 - val_Verdadero Positivo: 171.0000 - val_Falso Positivo: 11.0000 - val_Verdadero Negativo: 445.0000 - val_Falso Negativo: 237.0000 - val_Accuracy: 0.7130 - val_Precision: 0.9396
# Epoch 33/50
# 108/108 [==============================] - 7s 68ms/step - loss: 0.0888 - AUC: 0.9941 - PRC: 0.9944 - RECALL: 0.9727 - Error Cuadrático Medio: 0.0226 - Verdadero Positivo: 1712.0000 - Falso Positivo: 41.0000 - Verdadero Negativo: 1655.0000 - Falso Negativo: 48.0000 - Accuracy: 0.9742 - Precision: 0.9766 - val_loss: 0.5862 - val_AUC: 0.8976 - val_PRC: 0.8676 - val_RECALL: 0.9167 - val_Error Cuadrático Medio: 0.1478 - val_Verdadero Positivo: 374.0000 - val_Falso Positivo: 119.0000 - val_Verdadero Negativo: 337.0000 - val_Falso Negativo: 34.0000 - val_Accuracy: 0.8229 - val_Precision: 0.7586
# Epoch 34/50
# 108/108 [==============================] - 8s 73ms/step - loss: 0.0781 - AUC: 0.9946 - PRC: 0.9951 - RECALL: 0.9773 - Error Cuadrático Medio: 0.0194 - Verdadero Positivo: 1720.0000 - Falso Positivo: 40.0000 - Verdadero Negativo: 1656.0000 - Falso Negativo: 40.0000 - Accuracy: 0.9769 - Precision: 0.9773 - val_loss: 0.5186 - val_AUC: 0.9081 - val_PRC: 0.9041 - val_RECALL: 0.8137 - val_Error Cuadrático Medio: 0.1234 - val_Verdadero Positivo: 332.0000 - val_Falso Positivo: 50.0000 - val_Verdadero Negativo: 406.0000 - val_Falso Negativo: 76.0000 - val_Accuracy: 0.8542 - val_Precision: 0.8691
# Epoch 35/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.0877 - AUC: 0.9938 - PRC: 0.9936 - RECALL: 0.9722 - Error Cuadrático Medio: 0.0228 - Verdadero Positivo: 1711.0000 - Falso Positivo: 45.0000 - Verdadero Negativo: 1651.0000 - Falso Negativo: 49.0000 - Accuracy: 0.9728 - Precision: 0.9744 - val_loss: 0.7730 - val_AUC: 0.8776 - val_PRC: 0.8296 - val_RECALL: 0.9240 - val_Error Cuadrático Medio: 0.1714 - val_Verdadero Positivo: 377.0000 - val_Falso Positivo: 146.0000 - val_Verdadero Negativo: 310.0000 - val_Falso Negativo: 31.0000 - val_Accuracy: 0.7951 - val_Precision: 0.7208
# Epoch 36/50
# 108/108 [==============================] - 8s 75ms/step - loss: 0.0753 - AUC: 0.9961 - PRC: 0.9964 - RECALL: 0.9767 - Error Cuadrático Medio: 0.0197 - Verdadero Positivo: 1719.0000 - Falso Positivo: 39.0000 - Verdadero Negativo: 1657.0000 - Falso Negativo: 41.0000 - Accuracy: 0.9769 - Precision: 0.9778 - val_loss: 0.7080 - val_AUC: 0.8808 - val_PRC: 0.8714 - val_RECALL: 0.6691 - val_Error Cuadrático Medio: 0.1659 - val_Verdadero Positivo: 273.0000 - val_Falso Positivo: 33.0000 - val_Verdadero Negativo: 423.0000 - val_Falso Negativo: 135.0000 - val_Accuracy: 0.8056 - val_Precision: 0.8922
# Epoch 37/50
# 108/108 [==============================] - 7s 68ms/step - loss: 0.0943 - AUC: 0.9936 - PRC: 0.9945 - RECALL: 0.9670 - Error Cuadrático Medio: 0.0249 - Verdadero Positivo: 1702.0000 - Falso Positivo: 52.0000 - Verdadero Negativo: 1644.0000 - Falso Negativo: 58.0000 - Accuracy: 0.9682 - Precision: 0.9704 - val_loss: 1.4813 - val_AUC: 0.6687 - val_PRC: 0.5740 - val_RECALL: 0.9657 - val_Error Cuadrático Medio: 0.2789 - val_Verdadero Positivo: 394.0000 - val_Falso Positivo: 258.0000 - val_Verdadero Negativo: 198.0000 - val_Falso Negativo: 14.0000 - val_Accuracy: 0.6852 - val_Precision: 0.6043
# Epoch 38/50
# 108/108 [==============================] - 8s 70ms/step - loss: 0.1403 - AUC: 0.9849 - PRC: 0.9845 - RECALL: 0.9540 - Error Cuadrático Medio: 0.0364 - Verdadero Positivo: 1679.0000 - Falso Positivo: 81.0000 - Verdadero Negativo: 1615.0000 - Falso Negativo: 81.0000 - Accuracy: 0.9531 - Precision: 0.9540 - val_loss: 1.5318 - val_AUC: 0.7876 - val_PRC: 0.7072 - val_RECALL: 0.9608 - val_Error Cuadrático Medio: 0.2980 - val_Verdadero Positivo: 392.0000 - val_Falso Positivo: 277.0000 - val_Verdadero Negativo: 179.0000 - val_Falso Negativo: 16.0000 - val_Accuracy: 0.6609 - val_Precision: 0.5859
# Epoch 39/50
# 108/108 [==============================] - 8s 70ms/step - loss: 0.1894 - AUC: 0.9754 - PRC: 0.9734 - RECALL: 0.9386 - Error Cuadrático Medio: 0.0485 - Verdadero Positivo: 1652.0000 - Falso Positivo: 98.0000 - Verdadero Negativo: 1598.0000 - Falso Negativo: 108.0000 - Accuracy: 0.9404 - Precision: 0.9440 - val_loss: 1.1356 - val_AUC: 0.5000 - val_PRC: 0.4722 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.4059 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 456.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4722 - val_Precision: 0.4722
# Epoch 40/50
# 108/108 [==============================] - 7s 69ms/step - loss: 0.7453 - AUC: 0.5366 - PRC: 0.5324 - RECALL: 0.7051 - Error Cuadrático Medio: 0.2583 - Verdadero Positivo: 1241.0000 - Falso Positivo: 1133.0000 - Verdadero Negativo: 563.0000 - Falso Negativo: 519.0000 - Accuracy: 0.5220 - Precision: 0.5227 - val_loss: 0.9925 - val_AUC: 0.5118 - val_PRC: 0.4782 - val_RECALL: 0.9951 - val_Error Cuadrático Medio: 0.3660 - val_Verdadero Positivo: 406.0000 - val_Falso Positivo: 444.0000 - val_Verdadero Negativo: 12.0000 - val_Falso Negativo: 2.0000 - val_Accuracy: 0.4838 - val_Precision: 0.4776
# Epoch 41/50
# 108/108 [==============================] - 8s 73ms/step - loss: 0.6727 - AUC: 0.6345 - PRC: 0.5768 - RECALL: 0.8392 - Error Cuadrático Medio: 0.2384 - Verdadero Positivo: 1477.0000 - Falso Positivo: 1057.0000 - Verdadero Negativo: 639.0000 - Falso Negativo: 283.0000 - Accuracy: 0.6123 - Precision: 0.5829 - val_loss: 0.7166 - val_AUC: 0.6414 - val_PRC: 0.6032 - val_RECALL: 0.4608 - val_Error Cuadrático Medio: 0.2517 - val_Verdadero Positivo: 188.0000 - val_Falso Positivo: 117.0000 - val_Verdadero Negativo: 339.0000 - val_Falso Negativo: 220.0000 - val_Accuracy: 0.6100 - val_Precision: 0.6164
# Epoch 42/50
# 108/108 [==============================] - 7s 67ms/step - loss: 0.5965 - AUC: 0.7482 - PRC: 0.7190 - RECALL: 0.7778 - Error Cuadrático Medio: 0.2039 - Verdadero Positivo: 1369.0000 - Falso Positivo: 646.0000 - Verdadero Negativo: 1050.0000 - Falso Negativo: 391.0000 - Accuracy: 0.6999 - Precision: 0.6794 - val_loss: 0.5825 - val_AUC: 0.7614 - val_PRC: 0.6967 - val_RECALL: 0.6471 - val_Error Cuadrático Medio: 0.1977 - val_Verdadero Positivo: 264.0000 - val_Falso Positivo: 102.0000 - val_Verdadero Negativo: 354.0000 - val_Falso Negativo: 144.0000 - val_Accuracy: 0.7153 - val_Precision: 0.7213
# Epoch 43/50
# 108/108 [==============================] - 8s 72ms/step - loss: 0.4997 - AUC: 0.8367 - PRC: 0.8239 - RECALL: 0.7688 - Error Cuadrático Medio: 0.1627 - Verdadero Positivo: 1353.0000 - Falso Positivo: 399.0000 - Verdadero Negativo: 1297.0000 - Falso Negativo: 407.0000 - Accuracy: 0.7668 - Precision: 0.7723 - val_loss: 0.5089 - val_AUC: 0.8367 - val_PRC: 0.7898 - val_RECALL: 0.7892 - val_Error Cuadrático Medio: 0.1638 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 104.0000 - val_Verdadero Negativo: 352.0000 - val_Falso Negativo: 86.0000 - val_Accuracy: 0.7801 - val_Precision: 0.7559
# Epoch 44/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.4669 - AUC: 0.8597 - PRC: 0.8385 - RECALL: 0.7881 - Error Cuadrático Medio: 0.1489 - Verdadero Positivo: 1387.0000 - Falso Positivo: 350.0000 - Verdadero Negativo: 1346.0000 - Falso Negativo: 373.0000 - Accuracy: 0.7908 - Precision: 0.7985 - val_loss: 0.4942 - val_AUC: 0.8389 - val_PRC: 0.7659 - val_RECALL: 0.8456 - val_Error Cuadrático Medio: 0.1599 - val_Verdadero Positivo: 345.0000 - val_Falso Positivo: 127.0000 - val_Verdadero Negativo: 329.0000 - val_Falso Negativo: 63.0000 - val_Accuracy: 0.7801 - val_Precision: 0.7309
# Epoch 45/50
# 108/108 [==============================] - 8s 73ms/step - loss: 0.4219 - AUC: 0.8866 - PRC: 0.8766 - RECALL: 0.7932 - Error Cuadrático Medio: 0.1318 - Verdadero Positivo: 1396.0000 - Falso Positivo: 270.0000 - Verdadero Negativo: 1426.0000 - Falso Negativo: 364.0000 - Accuracy: 0.8166 - Precision: 0.8379 - val_loss: 0.6267 - val_AUC: 0.8273 - val_PRC: 0.7476 - val_RECALL: 0.9289 - val_Error Cuadrático Medio: 0.2019 - val_Verdadero Positivo: 379.0000 - val_Falso Positivo: 195.0000 - val_Verdadero Negativo: 261.0000 - val_Falso Negativo: 29.0000 - val_Accuracy: 0.7407 - val_Precision: 0.6603
# Epoch 46/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3865 - AUC: 0.9073 - PRC: 0.9073 - RECALL: 0.8301 - Error Cuadrático Medio: 0.1204 - Verdadero Positivo: 1461.0000 - Falso Positivo: 279.0000 - Verdadero Negativo: 1417.0000 - Falso Negativo: 299.0000 - Accuracy: 0.8328 - Precision: 0.8397Restoring model weights from the end of the best epoch: 36.
# 108/108 [==============================] - 7s 69ms/step - loss: 0.3865 - AUC: 0.9073 - PRC: 0.9073 - RECALL: 0.8301 - Error Cuadrático Medio: 0.1204 - Verdadero Positivo: 1461.0000 - Falso Positivo: 279.0000 - Verdadero Negativo: 1417.0000 - Falso Negativo: 299.0000 - Accuracy: 0.8328 - Precision: 0.8397 - val_loss: 0.7926 - val_AUC: 0.8297 - val_PRC: 0.8246 - val_RECALL: 0.4314 - val_Error Cuadrático Medio: 0.2337 - val_Verdadero Positivo: 176.0000 - val_Falso Positivo: 15.0000 - val_Verdadero Negativo: 441.0000 - val_Falso Negativo: 232.0000 - val_Accuracy: 0.7141 - val_Precision: 0.9215
# Epoch 46: early stopping
# 34/34 [==============================] - 3s 45ms/step - loss: 0.7357 - AUC: 0.8681 - PRC: 0.8820 - RECALL: 0.6635 - Error Cuadrático Medio: 0.1705 - Verdadero Positivo: 353.0000 - Falso Positivo: 35.0000 - Verdadero Negativo: 513.0000 - Falso Negativo: 179.0000 - Accuracy: 0.8019 - Precision: 0.9098
# {'loss': 0.735675036907196, 'AUC': 0.8681346774101257, 'PRC': 0.8819647431373596, 'RECALL': 0.6635338068008423, 'Error Cuadrático Medio': 0.17054685950279236, 'Verdadero Positivo': 353.0, 'Falso Positivo': 35.0, 'Verdadero Negativo': 513.0, 'Falso Negativo': 179.0, 'Accuracy': 0.8018518686294556, 'Precision': 0.9097937941551208}
#
#  ...Calculando valores predichos para train y test: ...
# 108/108 [==============================] - 3s 17ms/step
# 34/34 [==============================] - 2s 16ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.735675036907196
# AUC :  0.8681346774101257
# PRC :  0.8819647431373596
# RECALL :  0.6635338068008423
# Error Cuadrático Medio :  0.17054685950279236
# Verdadero Positivo :  353.0
# Falso Positivo :  35.0
# Verdadero Negativo :  513.0
# Falso Negativo :  179.0
# Accuracy :  0.8018518686294556
# Precision :  0.9097937941551208
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  513
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  35
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  179
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  353

# %% [markdown]
# #### ***Model-D***:  $~~~1 \times $*`ResNet-50`*+$1\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
def model_D(img_size=96, compile=True,output_bias=None):
    from keras.applications.resnet50 import ResNet50
    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    rnet = ResNet50(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = rnet(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)

    layers = tf.keras.layers.Dropout(0.5)(layers1)
    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

model_name="model_D"
log_dir="logs/v0/"
batch_size=32
epochs=50
model = model_D(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias

apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 23834813 (90.92 MB)
# Trainable params: 23781693 (90.72 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 108/108 [==============================] - 45s 112ms/step - loss: 0.5237 - AUC: 0.8435 - PRC: 0.8527 - RECALL: 0.7943 - Error Cuadrático Medio: 0.1617 - Verdadero Positivo: 1398.0000 - Falso Positivo: 416.0000 - Verdadero Negativo: 1280.0000 - Falso Negativo: 362.0000 - Accuracy: 0.7749 - Precision: 0.7707 - val_loss: 0.9916 - val_AUC: 0.5000 - val_PRC: 0.4722 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.3681 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 456.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4722 - val_Precision: 0.4722
# Epoch 2/50
# 108/108 [==============================] - 10s 97ms/step - loss: 0.4042 - AUC: 0.8958 - PRC: 0.8984 - RECALL: 0.8426 - Error Cuadrático Medio: 0.1250 - Verdadero Positivo: 1483.0000 - Falso Positivo: 292.0000 - Verdadero Negativo: 1404.0000 - Falso Negativo: 277.0000 - Accuracy: 0.8354 - Precision: 0.8355 - val_loss: 1.0334 - val_AUC: 0.4684 - val_PRC: 0.4115 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.3797 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 456.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4722 - val_Precision: 0.4722
# Epoch 3/50
# 108/108 [==============================] - 11s 98ms/step - loss: 0.3602 - AUC: 0.9217 - PRC: 0.9209 - RECALL: 0.8562 - Error Cuadrático Medio: 0.1095 - Verdadero Positivo: 1507.0000 - Falso Positivo: 270.0000 - Verdadero Negativo: 1426.0000 - Falso Negativo: 253.0000 - Accuracy: 0.8487 - Precision: 0.8481 - val_loss: 0.8554 - val_AUC: 0.5518 - val_PRC: 0.4534 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.3160 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 408.0000 - val_Accuracy: 0.5278 - val_Precision: 0.0000e+00
# Epoch 4/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.3001 - AUC: 0.9446 - PRC: 0.9489 - RECALL: 0.8835 - Error Cuadrático Medio: 0.0909 - Verdadero Positivo: 1555.0000 - Falso Positivo: 220.0000 - Verdadero Negativo: 1476.0000 - Falso Negativo: 205.0000 - Accuracy: 0.8770 - Precision: 0.8761 - val_loss: 3.3225 - val_AUC: 0.5000 - val_PRC: 0.4722 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.5257 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 456.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4722 - val_Precision: 0.4722
# Epoch 5/50
# 108/108 [==============================] - 10s 97ms/step - loss: 0.2705 - AUC: 0.9545 - PRC: 0.9584 - RECALL: 0.8972 - Error Cuadrático Medio: 0.0800 - Verdadero Positivo: 1579.0000 - Falso Positivo: 186.0000 - Verdadero Negativo: 1510.0000 - Falso Negativo: 181.0000 - Accuracy: 0.8938 - Precision: 0.8946 - val_loss: 2.6068 - val_AUC: 0.6607 - val_PRC: 0.5992 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.5194 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 456.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4722 - val_Precision: 0.4722
# Epoch 6/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.2451 - AUC: 0.9625 - PRC: 0.9654 - RECALL: 0.9057 - Error Cuadrático Medio: 0.0716 - Verdadero Positivo: 1594.0000 - Falso Positivo: 152.0000 - Verdadero Negativo: 1544.0000 - Falso Negativo: 166.0000 - Accuracy: 0.9080 - Precision: 0.9129 - val_loss: 3.8581 - val_AUC: 0.5751 - val_PRC: 0.5124 - val_RECALL: 0.9975 - val_Error Cuadrático Medio: 0.4652 - val_Verdadero Positivo: 407.0000 - val_Falso Positivo: 423.0000 - val_Verdadero Negativo: 33.0000 - val_Falso Negativo: 1.0000 - val_Accuracy: 0.5093 - val_Precision: 0.4904
# Epoch 7/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.2050 - AUC: 0.9731 - PRC: 0.9761 - RECALL: 0.9261 - Error Cuadrático Medio: 0.0590 - Verdadero Positivo: 1630.0000 - Falso Positivo: 135.0000 - Verdadero Negativo: 1561.0000 - Falso Negativo: 130.0000 - Accuracy: 0.9233 - Precision: 0.9235 - val_loss: 1.4307 - val_AUC: 0.5817 - val_PRC: 0.5156 - val_RECALL: 0.9485 - val_Error Cuadrático Medio: 0.3649 - val_Verdadero Positivo: 387.0000 - val_Falso Positivo: 352.0000 - val_Verdadero Negativo: 104.0000 - val_Falso Negativo: 21.0000 - val_Accuracy: 0.5683 - val_Precision: 0.5237
# Epoch 8/50
# 108/108 [==============================] - 11s 100ms/step - loss: 0.1912 - AUC: 0.9769 - PRC: 0.9797 - RECALL: 0.9352 - Error Cuadrático Medio: 0.0559 - Verdadero Positivo: 1646.0000 - Falso Positivo: 136.0000 - Verdadero Negativo: 1560.0000 - Falso Negativo: 114.0000 - Accuracy: 0.9277 - Precision: 0.9237 - val_loss: 3.6257 - val_AUC: 0.5807 - val_PRC: 0.5158 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.5000 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 454.0000 - val_Verdadero Negativo: 2.0000 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4745 - val_Precision: 0.4733
# Epoch 9/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.1615 - AUC: 0.9830 - PRC: 0.9838 - RECALL: 0.9460 - Error Cuadrático Medio: 0.0453 - Verdadero Positivo: 1665.0000 - Falso Positivo: 113.0000 - Verdadero Negativo: 1583.0000 - Falso Negativo: 95.0000 - Accuracy: 0.9398 - Precision: 0.9364 - val_loss: 2.5709 - val_AUC: 0.8009 - val_PRC: 0.7178 - val_RECALL: 0.9730 - val_Error Cuadrático Medio: 0.3574 - val_Verdadero Positivo: 397.0000 - val_Falso Positivo: 338.0000 - val_Verdadero Negativo: 118.0000 - val_Falso Negativo: 11.0000 - val_Accuracy: 0.5961 - val_Precision: 0.5401
# Epoch 10/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.1359 - AUC: 0.9885 - PRC: 0.9881 - RECALL: 0.9517 - Error Cuadrático Medio: 0.0385 - Verdadero Positivo: 1675.0000 - Falso Positivo: 94.0000 - Verdadero Negativo: 1602.0000 - Falso Negativo: 85.0000 - Accuracy: 0.9482 - Precision: 0.9469 - val_loss: 1.4112 - val_AUC: 0.8741 - val_PRC: 0.8330 - val_RECALL: 0.9926 - val_Error Cuadrático Medio: 0.3587 - val_Verdadero Positivo: 405.0000 - val_Falso Positivo: 358.0000 - val_Verdadero Negativo: 98.0000 - val_Falso Negativo: 3.0000 - val_Accuracy: 0.5822 - val_Precision: 0.5308
# Epoch 11/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.1412 - AUC: 0.9871 - PRC: 0.9888 - RECALL: 0.9523 - Error Cuadrático Medio: 0.0399 - Verdadero Positivo: 1676.0000 - Falso Positivo: 94.0000 - Verdadero Negativo: 1602.0000 - Falso Negativo: 84.0000 - Accuracy: 0.9485 - Precision: 0.9469 - val_loss: 0.5585 - val_AUC: 0.8985 - val_PRC: 0.8795 - val_RECALL: 0.7672 - val_Error Cuadrático Medio: 0.1389 - val_Verdadero Positivo: 313.0000 - val_Falso Positivo: 47.0000 - val_Verdadero Negativo: 409.0000 - val_Falso Negativo: 95.0000 - val_Accuracy: 0.8356 - val_Precision: 0.8694
# Epoch 12/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.1274 - AUC: 0.9895 - PRC: 0.9894 - RECALL: 0.9580 - Error Cuadrático Medio: 0.0360 - Verdadero Positivo: 1686.0000 - Falso Positivo: 86.0000 - Verdadero Negativo: 1610.0000 - Falso Negativo: 74.0000 - Accuracy: 0.9537 - Precision: 0.9515 - val_loss: 1.5942 - val_AUC: 0.8225 - val_PRC: 0.7519 - val_RECALL: 0.9338 - val_Error Cuadrático Medio: 0.2871 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 254.0000 - val_Verdadero Negativo: 202.0000 - val_Falso Negativo: 27.0000 - val_Accuracy: 0.6748 - val_Precision: 0.6000
# Epoch 13/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.1065 - AUC: 0.9925 - PRC: 0.9931 - RECALL: 0.9631 - Error Cuadrático Medio: 0.0302 - Verdadero Positivo: 1695.0000 - Falso Positivo: 73.0000 - Verdadero Negativo: 1623.0000 - Falso Negativo: 65.0000 - Accuracy: 0.9601 - Precision: 0.9587 - val_loss: 0.5038 - val_AUC: 0.9207 - val_PRC: 0.9163 - val_RECALL: 0.8260 - val_Error Cuadrático Medio: 0.1172 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 51.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 71.0000 - val_Accuracy: 0.8588 - val_Precision: 0.8686
# Epoch 14/50
# 108/108 [==============================] - 10s 97ms/step - loss: 0.0851 - AUC: 0.9947 - PRC: 0.9958 - RECALL: 0.9716 - Error Cuadrático Medio: 0.0227 - Verdadero Positivo: 1710.0000 - Falso Positivo: 49.0000 - Verdadero Negativo: 1647.0000 - Falso Negativo: 50.0000 - Accuracy: 0.9714 - Precision: 0.9721 - val_loss: 0.9065 - val_AUC: 0.8602 - val_PRC: 0.8540 - val_RECALL: 0.6544 - val_Error Cuadrático Medio: 0.1800 - val_Verdadero Positivo: 267.0000 - val_Falso Positivo: 35.0000 - val_Verdadero Negativo: 421.0000 - val_Falso Negativo: 141.0000 - val_Accuracy: 0.7963 - val_Precision: 0.8841
# Epoch 15/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0891 - AUC: 0.9940 - PRC: 0.9937 - RECALL: 0.9688 - Error Cuadrático Medio: 0.0242 - Verdadero Positivo: 1705.0000 - Falso Positivo: 59.0000 - Verdadero Negativo: 1637.0000 - Falso Negativo: 55.0000 - Accuracy: 0.9670 - Precision: 0.9666 - val_loss: 0.7199 - val_AUC: 0.9013 - val_PRC: 0.8802 - val_RECALL: 0.8775 - val_Error Cuadrático Medio: 0.1511 - val_Verdadero Positivo: 358.0000 - val_Falso Positivo: 101.0000 - val_Verdadero Negativo: 355.0000 - val_Falso Negativo: 50.0000 - val_Accuracy: 0.8252 - val_Precision: 0.7800
# Epoch 16/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0586 - AUC: 0.9977 - PRC: 0.9980 - RECALL: 0.9807 - Error Cuadrático Medio: 0.0159 - Verdadero Positivo: 1726.0000 - Falso Positivo: 33.0000 - Verdadero Negativo: 1663.0000 - Falso Negativo: 34.0000 - Accuracy: 0.9806 - Precision: 0.9812 - val_loss: 1.4788 - val_AUC: 0.7475 - val_PRC: 0.7678 - val_RECALL: 0.4216 - val_Error Cuadrático Medio: 0.2742 - val_Verdadero Positivo: 172.0000 - val_Falso Positivo: 23.0000 - val_Verdadero Negativo: 433.0000 - val_Falso Negativo: 236.0000 - val_Accuracy: 0.7002 - val_Precision: 0.8821
# Epoch 17/50
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0798 - AUC: 0.9953 - PRC: 0.9961 - RECALL: 0.9699 - Error Cuadrático Medio: 0.0220 - Verdadero Positivo: 1707.0000 - Falso Positivo: 50.0000 - Verdadero Negativo: 1646.0000 - Falso Negativo: 53.0000 - Accuracy: 0.9702 - Precision: 0.9715 - val_loss: 1.4005 - val_AUC: 0.7498 - val_PRC: 0.7809 - val_RECALL: 0.3603 - val_Error Cuadrático Medio: 0.2853 - val_Verdadero Positivo: 147.0000 - val_Falso Positivo: 6.0000 - val_Verdadero Negativo: 450.0000 - val_Falso Negativo: 261.0000 - val_Accuracy: 0.6910 - val_Precision: 0.9608
# Epoch 18/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0680 - AUC: 0.9967 - PRC: 0.9961 - RECALL: 0.9795 - Error Cuadrático Medio: 0.0187 - Verdadero Positivo: 1724.0000 - Falso Positivo: 43.0000 - Verdadero Negativo: 1653.0000 - Falso Negativo: 36.0000 - Accuracy: 0.9771 - Precision: 0.9757 - val_loss: 1.2031 - val_AUC: 0.8829 - val_PRC: 0.8193 - val_RECALL: 0.9338 - val_Error Cuadrático Medio: 0.1839 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 154.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 27.0000 - val_Accuracy: 0.7905 - val_Precision: 0.7121
# Epoch 19/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0576 - AUC: 0.9974 - PRC: 0.9974 - RECALL: 0.9818 - Error Cuadrático Medio: 0.0162 - Verdadero Positivo: 1728.0000 - Falso Positivo: 42.0000 - Verdadero Negativo: 1654.0000 - Falso Negativo: 32.0000 - Accuracy: 0.9786 - Precision: 0.9763 - val_loss: 0.7477 - val_AUC: 0.8914 - val_PRC: 0.8944 - val_RECALL: 0.6618 - val_Error Cuadrático Medio: 0.1622 - val_Verdadero Positivo: 270.0000 - val_Falso Positivo: 27.0000 - val_Verdadero Negativo: 429.0000 - val_Falso Negativo: 138.0000 - val_Accuracy: 0.8090 - val_Precision: 0.9091
# Epoch 20/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0471 - AUC: 0.9976 - PRC: 0.9968 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0122 - Verdadero Positivo: 1735.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 1671.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9855 - Precision: 0.9858 - val_loss: 0.7716 - val_AUC: 0.9052 - val_PRC: 0.8752 - val_RECALL: 0.8873 - val_Error Cuadrático Medio: 0.1423 - val_Verdadero Positivo: 362.0000 - val_Falso Positivo: 102.0000 - val_Verdadero Negativo: 354.0000 - val_Falso Negativo: 46.0000 - val_Accuracy: 0.8287 - val_Precision: 0.7802
# Epoch 21/50
# 108/108 [==============================] - 10s 94ms/step - loss: 0.0524 - AUC: 0.9973 - PRC: 0.9979 - RECALL: 0.9847 - Error Cuadrático Medio: 0.0128 - Verdadero Positivo: 1733.0000 - Falso Positivo: 31.0000 - Verdadero Negativo: 1665.0000 - Falso Negativo: 27.0000 - Accuracy: 0.9832 - Precision: 0.9824 - val_loss: 2.4520 - val_AUC: 0.8265 - val_PRC: 0.7279 - val_RECALL: 0.9779 - val_Error Cuadrático Medio: 0.2577 - val_Verdadero Positivo: 399.0000 - val_Falso Positivo: 232.0000 - val_Verdadero Negativo: 224.0000 - val_Falso Negativo: 9.0000 - val_Accuracy: 0.7211 - val_Precision: 0.6323
# Epoch 22/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0593 - AUC: 0.9971 - PRC: 0.9972 - RECALL: 0.9801 - Error Cuadrático Medio: 0.0162 - Verdadero Positivo: 1725.0000 - Falso Positivo: 39.0000 - Verdadero Negativo: 1657.0000 - Falso Negativo: 35.0000 - Accuracy: 0.9786 - Precision: 0.9779 - val_loss: 1.1042 - val_AUC: 0.8672 - val_PRC: 0.8748 - val_RECALL: 0.6765 - val_Error Cuadrático Medio: 0.1703 - val_Verdadero Positivo: 276.0000 - val_Falso Positivo: 25.0000 - val_Verdadero Negativo: 431.0000 - val_Falso Negativo: 132.0000 - val_Accuracy: 0.8183 - val_Precision: 0.9169
# Epoch 23/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0395 - AUC: 0.9985 - PRC: 0.9988 - RECALL: 0.9881 - Error Cuadrático Medio: 0.0105 - Verdadero Positivo: 1739.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 1669.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9861 - Precision: 0.9847 - val_loss: 0.7558 - val_AUC: 0.8946 - val_PRC: 0.8731 - val_RECALL: 0.8407 - val_Error Cuadrático Medio: 0.1459 - val_Verdadero Positivo: 343.0000 - val_Falso Positivo: 80.0000 - val_Verdadero Negativo: 376.0000 - val_Falso Negativo: 65.0000 - val_Accuracy: 0.8322 - val_Precision: 0.8109
# Epoch 24/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0412 - AUC: 0.9984 - PRC: 0.9982 - RECALL: 0.9869 - Error Cuadrático Medio: 0.0109 - Verdadero Positivo: 1737.0000 - Falso Positivo: 29.0000 - Verdadero Negativo: 1667.0000 - Falso Negativo: 23.0000 - Accuracy: 0.9850 - Precision: 0.9836 - val_loss: 1.5707 - val_AUC: 0.8551 - val_PRC: 0.7719 - val_RECALL: 0.9583 - val_Error Cuadrático Medio: 0.2016 - val_Verdadero Positivo: 391.0000 - val_Falso Positivo: 169.0000 - val_Verdadero Negativo: 287.0000 - val_Falso Negativo: 17.0000 - val_Accuracy: 0.7847 - val_Precision: 0.6982
# Epoch 25/50
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0610 - AUC: 0.9974 - PRC: 0.9973 - RECALL: 0.9744 - Error Cuadrático Medio: 0.0173 - Verdadero Positivo: 1715.0000 - Falso Positivo: 36.0000 - Verdadero Negativo: 1660.0000 - Falso Negativo: 45.0000 - Accuracy: 0.9766 - Precision: 0.9794 - val_loss: 2.8158 - val_AUC: 0.6446 - val_PRC: 0.6819 - val_RECALL: 0.1152 - val_Error Cuadrático Medio: 0.4040 - val_Verdadero Positivo: 47.0000 - val_Falso Positivo: 2.0000 - val_Verdadero Negativo: 454.0000 - val_Falso Negativo: 361.0000 - val_Accuracy: 0.5799 - val_Precision: 0.9592
# Epoch 26/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0358 - AUC: 0.9989 - PRC: 0.9986 - RECALL: 0.9898 - Error Cuadrático Medio: 0.0096 - Verdadero Positivo: 1742.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 1674.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9884 - Precision: 0.9875 - val_loss: 1.0246 - val_AUC: 0.8836 - val_PRC: 0.8454 - val_RECALL: 0.8824 - val_Error Cuadrático Medio: 0.1554 - val_Verdadero Positivo: 360.0000 - val_Falso Positivo: 101.0000 - val_Verdadero Negativo: 355.0000 - val_Falso Negativo: 48.0000 - val_Accuracy: 0.8275 - val_Precision: 0.7809
# Epoch 27/50
# 108/108 [==============================] - 10s 97ms/step - loss: 0.0211 - AUC: 0.9995 - PRC: 0.9996 - RECALL: 0.9943 - Error Cuadrático Medio: 0.0055 - Verdadero Positivo: 1750.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 1681.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9928 - Precision: 0.9915 - val_loss: 2.0581 - val_AUC: 0.7326 - val_PRC: 0.7800 - val_RECALL: 0.3039 - val_Error Cuadrático Medio: 0.3130 - val_Verdadero Positivo: 124.0000 - val_Falso Positivo: 3.0000 - val_Verdadero Negativo: 453.0000 - val_Falso Negativo: 284.0000 - val_Accuracy: 0.6678 - val_Precision: 0.9764
# Epoch 28/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0499 - AUC: 0.9983 - PRC: 0.9985 - RECALL: 0.9830 - Error Cuadrático Medio: 0.0143 - Verdadero Positivo: 1730.0000 - Falso Positivo: 36.0000 - Verdadero Negativo: 1660.0000 - Falso Negativo: 30.0000 - Accuracy: 0.9809 - Precision: 0.9796 - val_loss: 1.3739 - val_AUC: 0.8349 - val_PRC: 0.8654 - val_RECALL: 0.4118 - val_Error Cuadrático Medio: 0.2542 - val_Verdadero Positivo: 168.0000 - val_Falso Positivo: 7.0000 - val_Verdadero Negativo: 449.0000 - val_Falso Negativo: 240.0000 - val_Accuracy: 0.7141 - val_Precision: 0.9600
# Epoch 29/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0323 - AUC: 0.9985 - PRC: 0.9985 - RECALL: 0.9915 - Error Cuadrático Medio: 0.0077 - Verdadero Positivo: 1745.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 1677.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9902 - Precision: 0.9892 - val_loss: 1.1087 - val_AUC: 0.8958 - val_PRC: 0.8435 - val_RECALL: 0.9338 - val_Error Cuadrático Medio: 0.1943 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 164.0000 - val_Verdadero Negativo: 292.0000 - val_Falso Negativo: 27.0000 - val_Accuracy: 0.7789 - val_Precision: 0.6991
# Epoch 30/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0293 - AUC: 0.9989 - PRC: 0.9988 - RECALL: 0.9909 - Error Cuadrático Medio: 0.0078 - Verdadero Positivo: 1744.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 1679.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9905 - Precision: 0.9903 - val_loss: 0.6471 - val_AUC: 0.9213 - val_PRC: 0.9012 - val_RECALL: 0.8897 - val_Error Cuadrático Medio: 0.1172 - val_Verdadero Positivo: 363.0000 - val_Falso Positivo: 73.0000 - val_Verdadero Negativo: 383.0000 - val_Falso Negativo: 45.0000 - val_Accuracy: 0.8634 - val_Precision: 0.8326
# Epoch 31/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0215 - AUC: 0.9994 - PRC: 0.9996 - RECALL: 0.9937 - Error Cuadrático Medio: 0.0053 - Verdadero Positivo: 1749.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1684.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9933 - Precision: 0.9932 - val_loss: 0.9820 - val_AUC: 0.8755 - val_PRC: 0.8809 - val_RECALL: 0.6961 - val_Error Cuadrático Medio: 0.1648 - val_Verdadero Positivo: 284.0000 - val_Falso Positivo: 38.0000 - val_Verdadero Negativo: 418.0000 - val_Falso Negativo: 124.0000 - val_Accuracy: 0.8125 - val_Precision: 0.8820
# Epoch 32/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0348 - AUC: 0.9985 - PRC: 0.9985 - RECALL: 0.9881 - Error Cuadrático Medio: 0.0090 - Verdadero Positivo: 1739.0000 - Falso Positivo: 20.0000 - Verdadero Negativo: 1676.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9881 - Precision: 0.9886 - val_loss: 1.5235 - val_AUC: 0.7978 - val_PRC: 0.8298 - val_RECALL: 0.4265 - val_Error Cuadrático Medio: 0.2514 - val_Verdadero Positivo: 174.0000 - val_Falso Positivo: 11.0000 - val_Verdadero Negativo: 445.0000 - val_Falso Negativo: 234.0000 - val_Accuracy: 0.7164 - val_Precision: 0.9405
# Epoch 33/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0383 - AUC: 0.9988 - PRC: 0.9985 - RECALL: 0.9869 - Error Cuadrático Medio: 0.0101 - Verdadero Positivo: 1737.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 1675.0000 - Falso Negativo: 23.0000 - Accuracy: 0.9873 - Precision: 0.9881 - val_loss: 0.8942 - val_AUC: 0.8795 - val_PRC: 0.8813 - val_RECALL: 0.6373 - val_Error Cuadrático Medio: 0.1699 - val_Verdadero Positivo: 260.0000 - val_Falso Positivo: 20.0000 - val_Verdadero Negativo: 436.0000 - val_Falso Negativo: 148.0000 - val_Accuracy: 0.8056 - val_Precision: 0.9286
# Epoch 34/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0302 - AUC: 0.9988 - PRC: 0.9987 - RECALL: 0.9903 - Error Cuadrático Medio: 0.0076 - Verdadero Positivo: 1743.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 1678.0000 - Falso Negativo: 17.0000 - Accuracy: 0.9899 - Precision: 0.9898 - val_loss: 0.7444 - val_AUC: 0.9000 - val_PRC: 0.8927 - val_RECALL: 0.7917 - val_Error Cuadrático Medio: 0.1322 - val_Verdadero Positivo: 323.0000 - val_Falso Positivo: 45.0000 - val_Verdadero Negativo: 411.0000 - val_Falso Negativo: 85.0000 - val_Accuracy: 0.8495 - val_Precision: 0.8777
# Epoch 35/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0518 - AUC: 0.9965 - PRC: 0.9949 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0127 - Verdadero Positivo: 1735.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 1668.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9847 - Precision: 0.9841 - val_loss: 1.5073 - val_AUC: 0.8090 - val_PRC: 0.8390 - val_RECALL: 0.4338 - val_Error Cuadrático Medio: 0.2574 - val_Verdadero Positivo: 177.0000 - val_Falso Positivo: 11.0000 - val_Verdadero Negativo: 445.0000 - val_Falso Negativo: 231.0000 - val_Accuracy: 0.7199 - val_Precision: 0.9415
# Epoch 36/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0181 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9937 - Error Cuadrático Medio: 0.0049 - Verdadero Positivo: 1749.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 1686.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9939 - Precision: 0.9943 - val_loss: 1.8703 - val_AUC: 0.7772 - val_PRC: 0.7848 - val_RECALL: 0.5515 - val_Error Cuadrático Medio: 0.2439 - val_Verdadero Positivo: 225.0000 - val_Falso Positivo: 44.0000 - val_Verdadero Negativo: 412.0000 - val_Falso Negativo: 183.0000 - val_Accuracy: 0.7373 - val_Precision: 0.8364
# Epoch 37/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0358 - AUC: 0.9982 - PRC: 0.9983 - RECALL: 0.9869 - Error Cuadrático Medio: 0.0093 - Verdadero Positivo: 1737.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 1677.0000 - Falso Negativo: 23.0000 - Accuracy: 0.9878 - Precision: 0.9892 - val_loss: 1.0405 - val_AUC: 0.8646 - val_PRC: 0.8689 - val_RECALL: 0.4510 - val_Error Cuadrático Medio: 0.2278 - val_Verdadero Positivo: 184.0000 - val_Falso Positivo: 16.0000 - val_Verdadero Negativo: 440.0000 - val_Falso Negativo: 224.0000 - val_Accuracy: 0.7222 - val_Precision: 0.9200
# Epoch 38/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0368 - AUC: 0.9986 - PRC: 0.9989 - RECALL: 0.9892 - Error Cuadrático Medio: 0.0098 - Verdadero Positivo: 1741.0000 - Falso Positivo: 24.0000 - Verdadero Negativo: 1672.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9876 - Precision: 0.9864 - val_loss: 0.7237 - val_AUC: 0.9059 - val_PRC: 0.8874 - val_RECALL: 0.8260 - val_Error Cuadrático Medio: 0.1291 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 60.0000 - val_Verdadero Negativo: 396.0000 - val_Falso Negativo: 71.0000 - val_Accuracy: 0.8484 - val_Precision: 0.8489
# Epoch 39/50
# 108/108 [==============================] - 10s 95ms/step - loss: 0.0339 - AUC: 0.9986 - PRC: 0.9990 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0091 - Verdadero Positivo: 1735.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 1677.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9873 - Precision: 0.9892 - val_loss: 1.4044 - val_AUC: 0.8922 - val_PRC: 0.8234 - val_RECALL: 0.9632 - val_Error Cuadrático Medio: 0.1912 - val_Verdadero Positivo: 393.0000 - val_Falso Positivo: 175.0000 - val_Verdadero Negativo: 281.0000 - val_Falso Negativo: 15.0000 - val_Accuracy: 0.7801 - val_Precision: 0.6919
# Epoch 40/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0238 - AUC: 0.9993 - PRC: 0.9995 - RECALL: 0.9926 - Error Cuadrático Medio: 0.0060 - Verdadero Positivo: 1747.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 1683.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9925 - Precision: 0.9926 - val_loss: 1.1332 - val_AUC: 0.8520 - val_PRC: 0.8751 - val_RECALL: 0.5809 - val_Error Cuadrático Medio: 0.1914 - val_Verdadero Positivo: 237.0000 - val_Falso Positivo: 13.0000 - val_Verdadero Negativo: 443.0000 - val_Falso Negativo: 171.0000 - val_Accuracy: 0.7870 - val_Precision: 0.9480
# Epoch 41/50
# 108/108 [==============================] - 11s 103ms/step - loss: 0.0186 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9926 - Error Cuadrático Medio: 0.0051 - Verdadero Positivo: 1747.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 1685.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9931 - Precision: 0.9937 - val_loss: 1.9585 - val_AUC: 0.8354 - val_PRC: 0.7624 - val_RECALL: 0.9093 - val_Error Cuadrático Medio: 0.2172 - val_Verdadero Positivo: 371.0000 - val_Falso Positivo: 173.0000 - val_Verdadero Negativo: 283.0000 - val_Falso Negativo: 37.0000 - val_Accuracy: 0.7569 - val_Precision: 0.6820
# Epoch 42/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0267 - AUC: 0.9984 - PRC: 0.9990 - RECALL: 0.9926 - Error Cuadrático Medio: 0.0063 - Verdadero Positivo: 1747.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 1686.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9933 - Precision: 0.9943 - val_loss: 0.8681 - val_AUC: 0.8888 - val_PRC: 0.8849 - val_RECALL: 0.6103 - val_Error Cuadrático Medio: 0.1797 - val_Verdadero Positivo: 249.0000 - val_Falso Positivo: 24.0000 - val_Verdadero Negativo: 432.0000 - val_Falso Negativo: 159.0000 - val_Accuracy: 0.7882 - val_Precision: 0.9121
# Epoch 43/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0222 - AUC: 0.9988 - PRC: 0.9983 - RECALL: 0.9932 - Error Cuadrático Medio: 0.0053 - Verdadero Positivo: 1748.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1684.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9931 - Precision: 0.9932 - val_loss: 2.4280 - val_AUC: 0.8411 - val_PRC: 0.7448 - val_RECALL: 0.9853 - val_Error Cuadrático Medio: 0.2529 - val_Verdadero Positivo: 402.0000 - val_Falso Positivo: 228.0000 - val_Verdadero Negativo: 228.0000 - val_Falso Negativo: 6.0000 - val_Accuracy: 0.7292 - val_Precision: 0.6381
# Epoch 44/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0376 - AUC: 0.9980 - PRC: 0.9978 - RECALL: 0.9903 - Error Cuadrático Medio: 0.0089 - Verdadero Positivo: 1743.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 1678.0000 - Falso Negativo: 17.0000 - Accuracy: 0.9899 - Precision: 0.9898 - val_loss: 0.8940 - val_AUC: 0.8763 - val_PRC: 0.8837 - val_RECALL: 0.5784 - val_Error Cuadrático Medio: 0.1929 - val_Verdadero Positivo: 236.0000 - val_Falso Positivo: 22.0000 - val_Verdadero Negativo: 434.0000 - val_Falso Negativo: 172.0000 - val_Accuracy: 0.7755 - val_Precision: 0.9147
# Epoch 45/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0357 - AUC: 0.9990 - PRC: 0.9992 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0098 - Verdadero Positivo: 1735.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 1678.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9876 - Precision: 0.9897 - val_loss: 0.7492 - val_AUC: 0.9162 - val_PRC: 0.8803 - val_RECALL: 0.9216 - val_Error Cuadrático Medio: 0.1435 - val_Verdadero Positivo: 376.0000 - val_Falso Positivo: 112.0000 - val_Verdadero Negativo: 344.0000 - val_Falso Negativo: 32.0000 - val_Accuracy: 0.8333 - val_Precision: 0.7705
# Epoch 46/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0249 - AUC: 0.9991 - PRC: 0.9993 - RECALL: 0.9915 - Error Cuadrático Medio: 0.0064 - Verdadero Positivo: 1745.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 1683.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9919 - Precision: 0.9926 - val_loss: 0.7688 - val_AUC: 0.9044 - val_PRC: 0.9094 - val_RECALL: 0.7574 - val_Error Cuadrático Medio: 0.1321 - val_Verdadero Positivo: 309.0000 - val_Falso Positivo: 32.0000 - val_Verdadero Negativo: 424.0000 - val_Falso Negativo: 99.0000 - val_Accuracy: 0.8484 - val_Precision: 0.9062
# Epoch 47/50
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0254 - AUC: 0.9986 - PRC: 0.9987 - RECALL: 0.9898 - Error Cuadrático Medio: 0.0063 - Verdadero Positivo: 1742.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1684.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9913 - Precision: 0.9932 - val_loss: 1.0817 - val_AUC: 0.8426 - val_PRC: 0.8394 - val_RECALL: 0.7108 - val_Error Cuadrático Medio: 0.1774 - val_Verdadero Positivo: 290.0000 - val_Falso Positivo: 55.0000 - val_Verdadero Negativo: 401.0000 - val_Falso Negativo: 118.0000 - val_Accuracy: 0.7998 - val_Precision: 0.8406
# Epoch 48/50
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0392 - AUC: 0.9980 - PRC: 0.9977 - RECALL: 0.9881 - Error Cuadrático Medio: 0.0098 - Verdadero Positivo: 1739.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 1674.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9876 - Precision: 0.9875 - val_loss: 1.1194 - val_AUC: 0.8932 - val_PRC: 0.8414 - val_RECALL: 0.9265 - val_Error Cuadrático Medio: 0.1633 - val_Verdadero Positivo: 378.0000 - val_Falso Positivo: 123.0000 - val_Verdadero Negativo: 333.0000 - val_Falso Negativo: 30.0000 - val_Accuracy: 0.8229 - val_Precision: 0.7545
# Epoch 49/50
# 108/108 [==============================] - 10s 96ms/step - loss: 0.0252 - AUC: 0.9987 - PRC: 0.9987 - RECALL: 0.9937 - Error Cuadrático Medio: 0.0061 - Verdadero Positivo: 1749.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 1685.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9936 - Precision: 0.9937 - val_loss: 1.1012 - val_AUC: 0.8324 - val_PRC: 0.8357 - val_RECALL: 0.5588 - val_Error Cuadrático Medio: 0.2164 - val_Verdadero Positivo: 228.0000 - val_Falso Positivo: 25.0000 - val_Verdadero Negativo: 431.0000 - val_Falso Negativo: 180.0000 - val_Accuracy: 0.7627 - val_Precision: 0.9012
# Epoch 50/50
# 108/108 [==============================] - 11s 102ms/step - loss: 0.0168 - AUC: 0.9992 - PRC: 0.9991 - RECALL: 0.9972 - Error Cuadrático Medio: 0.0037 - Verdadero Positivo: 1755.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 1687.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9959 - Precision: 0.9949 - val_loss: 0.6490 - val_AUC: 0.9140 - val_PRC: 0.8893 - val_RECALL: 0.8456 - val_Error Cuadrático Medio: 0.1234 - val_Verdadero Positivo: 345.0000 - val_Falso Positivo: 64.0000 - val_Verdadero Negativo: 392.0000 - val_Falso Negativo: 63.0000 - val_Accuracy: 0.8530 - val_Precision: 0.8435
# 34/34 [==============================] - 3s 44ms/step - loss: 0.6948 - AUC: 0.9023 - PRC: 0.8972 - RECALL: 0.8289 - Error Cuadrático Medio: 0.1282 - Verdadero Positivo: 441.0000 - Falso Positivo: 69.0000 - Verdadero Negativo: 479.0000 - Falso Negativo: 91.0000 - Accuracy: 0.8519 - Precision: 0.8647
# {'loss': 0.6948043704032898, 'AUC': 0.9023311734199524, 'PRC': 0.8972097635269165, 'RECALL': 0.8289473652839661, 'Error Cuadrático Medio': 0.12818202376365662, 'Verdadero Positivo': 441.0, 'Falso Positivo': 69.0, 'Verdadero Negativo': 479.0, 'Falso Negativo': 91.0, 'Accuracy': 0.8518518805503845, 'Precision': 0.8647058606147766}
#
#  ...Calculando valores predichos para train y test: ...
# 108/108 [==============================] - 4s 24ms/step
# 34/34 [==============================] - 2s 25ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.6948043704032898
# AUC :  0.9023311734199524
# PRC :  0.8972097635269165
# RECALL :  0.8289473652839661
# Error Cuadrático Medio :  0.12818202376365662
# Verdadero Positivo :  441.0
# Falso Positivo :  69.0
# Verdadero Negativo :  479.0
# Falso Negativo :  91.0
# Accuracy :  0.8518518805503845
# Precision :  0.8647058606147766
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  479
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  69
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  91
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  441

# %% [markdown]
# #### ***Model-E***:  $~~~1 \times $*`Xception`*+$1\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
def model_E(img_size=96, compile=True,output_bias=None):
    from keras.applications.xception import Xception
    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")
    xc = Xception(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = xc(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)
    layers = tf.keras.layers.Dropout(0.5)(layers1)
    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

model_name="model_E"
log_dir="logs/v0/"
batch_size=32
epochs=50
model = model_E(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias

apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  xception (Functional)       (None, 3, 3, 2048)        20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21108581 (80.52 MB)
# Trainable params: 21054053 (80.31 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 108/108 [==============================] - 40s 127ms/step - loss: 0.4784 - AUC: 0.8614 - PRC: 0.8695 - RECALL: 0.7744 - Error Cuadrático Medio: 0.1517 - Verdadero Positivo: 1363.0000 - Falso Positivo: 344.0000 - Verdadero Negativo: 1352.0000 - Falso Negativo: 397.0000 - Accuracy: 0.7856 - Precision: 0.7985 - val_loss: 4.7050 - val_AUC: 0.6823 - val_PRC: 0.5866 - val_RECALL: 0.9877 - val_Error Cuadrático Medio: 0.4073 - val_Verdadero Positivo: 403.0000 - val_Falso Positivo: 361.0000 - val_Verdadero Negativo: 95.0000 - val_Falso Negativo: 5.0000 - val_Accuracy: 0.5764 - val_Precision: 0.5275
# Epoch 2/50
# 108/108 [==============================] - 12s 115ms/step - loss: 0.3220 - AUC: 0.9368 - PRC: 0.9425 - RECALL: 0.8739 - Error Cuadrático Medio: 0.0964 - Verdadero Positivo: 1538.0000 - Falso Positivo: 218.0000 - Verdadero Negativo: 1478.0000 - Falso Negativo: 222.0000 - Accuracy: 0.8727 - Precision: 0.8759 - val_loss: 1.3323 - val_AUC: 0.8589 - val_PRC: 0.8003 - val_RECALL: 0.9951 - val_Error Cuadrático Medio: 0.3553 - val_Verdadero Positivo: 406.0000 - val_Falso Positivo: 347.0000 - val_Verdadero Negativo: 109.0000 - val_Falso Negativo: 2.0000 - val_Accuracy: 0.5961 - val_Precision: 0.5392
# Epoch 3/50
# 108/108 [==============================] - 13s 120ms/step - loss: 0.2254 - AUC: 0.9666 - PRC: 0.9708 - RECALL: 0.8915 - Error Cuadrático Medio: 0.0648 - Verdadero Positivo: 1569.0000 - Falso Positivo: 105.0000 - Verdadero Negativo: 1591.0000 - Falso Negativo: 191.0000 - Accuracy: 0.9144 - Precision: 0.9373 - val_loss: 0.5390 - val_AUC: 0.8947 - val_PRC: 0.9049 - val_RECALL: 0.7402 - val_Error Cuadrático Medio: 0.1401 - val_Verdadero Positivo: 302.0000 - val_Falso Positivo: 38.0000 - val_Verdadero Negativo: 418.0000 - val_Falso Negativo: 106.0000 - val_Accuracy: 0.8333 - val_Precision: 0.8882
# Epoch 4/50
# 108/108 [==============================] - 12s 116ms/step - loss: 0.1826 - AUC: 0.9792 - PRC: 0.9809 - RECALL: 0.9324 - Error Cuadrático Medio: 0.0524 - Verdadero Positivo: 1641.0000 - Falso Positivo: 116.0000 - Verdadero Negativo: 1580.0000 - Falso Negativo: 119.0000 - Accuracy: 0.9320 - Precision: 0.9340 - val_loss: 1.3283 - val_AUC: 0.8755 - val_PRC: 0.8057 - val_RECALL: 0.9534 - val_Error Cuadrático Medio: 0.2031 - val_Verdadero Positivo: 389.0000 - val_Falso Positivo: 170.0000 - val_Verdadero Negativo: 286.0000 - val_Falso Negativo: 19.0000 - val_Accuracy: 0.7812 - val_Precision: 0.6959
# Epoch 5/50
# 108/108 [==============================] - 13s 117ms/step - loss: 0.1328 - AUC: 0.9883 - PRC: 0.9893 - RECALL: 0.9523 - Error Cuadrático Medio: 0.0365 - Verdadero Positivo: 1676.0000 - Falso Positivo: 77.0000 - Verdadero Negativo: 1619.0000 - Falso Negativo: 84.0000 - Accuracy: 0.9534 - Precision: 0.9561 - val_loss: 0.4817 - val_AUC: 0.9024 - val_PRC: 0.8993 - val_RECALL: 0.8284 - val_Error Cuadrático Medio: 0.1349 - val_Verdadero Positivo: 338.0000 - val_Falso Positivo: 80.0000 - val_Verdadero Negativo: 376.0000 - val_Falso Negativo: 70.0000 - val_Accuracy: 0.8264 - val_Precision: 0.8086
# Epoch 6/50
# 108/108 [==============================] - 13s 116ms/step - loss: 0.1266 - AUC: 0.9892 - PRC: 0.9901 - RECALL: 0.9500 - Error Cuadrático Medio: 0.0358 - Verdadero Positivo: 1672.0000 - Falso Positivo: 75.0000 - Verdadero Negativo: 1621.0000 - Falso Negativo: 88.0000 - Accuracy: 0.9528 - Precision: 0.9571 - val_loss: 0.4195 - val_AUC: 0.9354 - val_PRC: 0.9331 - val_RECALL: 0.8431 - val_Error Cuadrático Medio: 0.1044 - val_Verdadero Positivo: 344.0000 - val_Falso Positivo: 47.0000 - val_Verdadero Negativo: 409.0000 - val_Falso Negativo: 64.0000 - val_Accuracy: 0.8715 - val_Precision: 0.8798
# Epoch 7/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0815 - AUC: 0.9951 - PRC: 0.9958 - RECALL: 0.9710 - Error Cuadrático Medio: 0.0220 - Verdadero Positivo: 1709.0000 - Falso Positivo: 49.0000 - Verdadero Negativo: 1647.0000 - Falso Negativo: 51.0000 - Accuracy: 0.9711 - Precision: 0.9721 - val_loss: 0.6377 - val_AUC: 0.9011 - val_PRC: 0.8626 - val_RECALL: 0.8946 - val_Error Cuadrático Medio: 0.1402 - val_Verdadero Positivo: 365.0000 - val_Falso Positivo: 105.0000 - val_Verdadero Negativo: 351.0000 - val_Falso Negativo: 43.0000 - val_Accuracy: 0.8287 - val_Precision: 0.7766
# Epoch 8/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.1015 - AUC: 0.9926 - PRC: 0.9927 - RECALL: 0.9602 - Error Cuadrático Medio: 0.0271 - Verdadero Positivo: 1690.0000 - Falso Positivo: 53.0000 - Verdadero Negativo: 1643.0000 - Falso Negativo: 70.0000 - Accuracy: 0.9644 - Precision: 0.9696 - val_loss: 0.5653 - val_AUC: 0.9376 - val_PRC: 0.9142 - val_RECALL: 0.9167 - val_Error Cuadrático Medio: 0.1097 - val_Verdadero Positivo: 374.0000 - val_Falso Positivo: 76.0000 - val_Verdadero Negativo: 380.0000 - val_Falso Negativo: 34.0000 - val_Accuracy: 0.8727 - val_Precision: 0.8311
# Epoch 9/50
# 108/108 [==============================] - 13s 118ms/step - loss: 0.0519 - AUC: 0.9978 - PRC: 0.9973 - RECALL: 0.9830 - Error Cuadrático Medio: 0.0142 - Verdadero Positivo: 1730.0000 - Falso Positivo: 31.0000 - Verdadero Negativo: 1665.0000 - Falso Negativo: 30.0000 - Accuracy: 0.9823 - Precision: 0.9824 - val_loss: 0.4939 - val_AUC: 0.9255 - val_PRC: 0.9041 - val_RECALL: 0.8603 - val_Error Cuadrático Medio: 0.1065 - val_Verdadero Positivo: 351.0000 - val_Falso Positivo: 55.0000 - val_Verdadero Negativo: 401.0000 - val_Falso Negativo: 57.0000 - val_Accuracy: 0.8704 - val_Precision: 0.8645
# Epoch 10/50
# 108/108 [==============================] - 13s 117ms/step - loss: 0.0769 - AUC: 0.9953 - PRC: 0.9950 - RECALL: 0.9744 - Error Cuadrático Medio: 0.0199 - Verdadero Positivo: 1715.0000 - Falso Positivo: 43.0000 - Verdadero Negativo: 1653.0000 - Falso Negativo: 45.0000 - Accuracy: 0.9745 - Precision: 0.9755 - val_loss: 1.7363 - val_AUC: 0.8485 - val_PRC: 0.7524 - val_RECALL: 0.9951 - val_Error Cuadrático Medio: 0.2658 - val_Verdadero Positivo: 406.0000 - val_Falso Positivo: 257.0000 - val_Verdadero Negativo: 199.0000 - val_Falso Negativo: 2.0000 - val_Accuracy: 0.7002 - val_Precision: 0.6124
# Epoch 11/50
# 108/108 [==============================] - 13s 118ms/step - loss: 0.0469 - AUC: 0.9981 - PRC: 0.9985 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0120 - Verdadero Positivo: 1735.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 1669.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9850 - Precision: 0.9847 - val_loss: 0.5988 - val_AUC: 0.9274 - val_PRC: 0.8978 - val_RECALL: 0.9387 - val_Error Cuadrático Medio: 0.1282 - val_Verdadero Positivo: 383.0000 - val_Falso Positivo: 106.0000 - val_Verdadero Negativo: 350.0000 - val_Falso Negativo: 25.0000 - val_Accuracy: 0.8484 - val_Precision: 0.7832
# Epoch 12/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0500 - AUC: 0.9978 - PRC: 0.9983 - RECALL: 0.9807 - Error Cuadrático Medio: 0.0138 - Verdadero Positivo: 1726.0000 - Falso Positivo: 31.0000 - Verdadero Negativo: 1665.0000 - Falso Negativo: 34.0000 - Accuracy: 0.9812 - Precision: 0.9824 - val_loss: 0.6488 - val_AUC: 0.8993 - val_PRC: 0.8821 - val_RECALL: 0.7598 - val_Error Cuadrático Medio: 0.1428 - val_Verdadero Positivo: 310.0000 - val_Falso Positivo: 53.0000 - val_Verdadero Negativo: 403.0000 - val_Falso Negativo: 98.0000 - val_Accuracy: 0.8252 - val_Precision: 0.8540
# Epoch 13/50
# 108/108 [==============================] - 13s 117ms/step - loss: 0.0377 - AUC: 0.9986 - PRC: 0.9985 - RECALL: 0.9864 - Error Cuadrático Medio: 0.0103 - Verdadero Positivo: 1736.0000 - Falso Positivo: 23.0000 - Verdadero Negativo: 1673.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9864 - Precision: 0.9869 - val_loss: 0.9098 - val_AUC: 0.8917 - val_PRC: 0.9124 - val_RECALL: 0.6765 - val_Error Cuadrático Medio: 0.1470 - val_Verdadero Positivo: 276.0000 - val_Falso Positivo: 8.0000 - val_Verdadero Negativo: 448.0000 - val_Falso Negativo: 132.0000 - val_Accuracy: 0.8380 - val_Precision: 0.9718
# Epoch 14/50
# 108/108 [==============================] - 13s 117ms/step - loss: 0.0221 - AUC: 0.9997 - PRC: 0.9997 - RECALL: 0.9932 - Error Cuadrático Medio: 0.0056 - Verdadero Positivo: 1748.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1684.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9931 - Precision: 0.9932 - val_loss: 0.3907 - val_AUC: 0.9461 - val_PRC: 0.9375 - val_RECALL: 0.8897 - val_Error Cuadrático Medio: 0.0915 - val_Verdadero Positivo: 363.0000 - val_Falso Positivo: 51.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 45.0000 - val_Accuracy: 0.8889 - val_Precision: 0.8768
# Epoch 15/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0239 - AUC: 0.9991 - PRC: 0.9989 - RECALL: 0.9955 - Error Cuadrático Medio: 0.0057 - Verdadero Positivo: 1752.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 1681.0000 - Falso Negativo: 8.0000 - Accuracy: 0.9933 - Precision: 0.9915 - val_loss: 0.6063 - val_AUC: 0.9208 - val_PRC: 0.9102 - val_RECALL: 0.8333 - val_Error Cuadrático Medio: 0.1070 - val_Verdadero Positivo: 340.0000 - val_Falso Positivo: 32.0000 - val_Verdadero Negativo: 424.0000 - val_Falso Negativo: 68.0000 - val_Accuracy: 0.8843 - val_Precision: 0.9140
# Epoch 16/50
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0387 - AUC: 0.9987 - PRC: 0.9989 - RECALL: 0.9881 - Error Cuadrático Medio: 0.0106 - Verdadero Positivo: 1739.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 1671.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9867 - Precision: 0.9858 - val_loss: 0.6080 - val_AUC: 0.9164 - val_PRC: 0.8999 - val_RECALL: 0.8725 - val_Error Cuadrático Medio: 0.1183 - val_Verdadero Positivo: 356.0000 - val_Falso Positivo: 71.0000 - val_Verdadero Negativo: 385.0000 - val_Falso Negativo: 52.0000 - val_Accuracy: 0.8576 - val_Precision: 0.8337
# Epoch 17/50
# 108/108 [==============================] - 13s 117ms/step - loss: 0.0401 - AUC: 0.9983 - PRC: 0.9983 - RECALL: 0.9864 - Error Cuadrático Medio: 0.0106 - Verdadero Positivo: 1736.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 1668.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9850 - Precision: 0.9841 - val_loss: 0.7185 - val_AUC: 0.9195 - val_PRC: 0.8709 - val_RECALL: 0.9363 - val_Error Cuadrático Medio: 0.1275 - val_Verdadero Positivo: 382.0000 - val_Falso Positivo: 103.0000 - val_Verdadero Negativo: 353.0000 - val_Falso Negativo: 26.0000 - val_Accuracy: 0.8507 - val_Precision: 0.7876
# Epoch 18/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0317 - AUC: 0.9989 - PRC: 0.9992 - RECALL: 0.9892 - Error Cuadrático Medio: 0.0082 - Verdadero Positivo: 1741.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 1678.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9893 - Precision: 0.9898 - val_loss: 0.4612 - val_AUC: 0.9320 - val_PRC: 0.9110 - val_RECALL: 0.9069 - val_Error Cuadrático Medio: 0.1167 - val_Verdadero Positivo: 370.0000 - val_Falso Positivo: 91.0000 - val_Verdadero Negativo: 365.0000 - val_Falso Negativo: 38.0000 - val_Accuracy: 0.8507 - val_Precision: 0.8026
# Epoch 19/50
# 108/108 [==============================] - 12s 113ms/step - loss: 0.0407 - AUC: 0.9982 - PRC: 0.9983 - RECALL: 0.9875 - Error Cuadrático Medio: 0.0108 - Verdadero Positivo: 1738.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 1671.0000 - Falso Negativo: 22.0000 - Accuracy: 0.9864 - Precision: 0.9858 - val_loss: 0.8995 - val_AUC: 0.8906 - val_PRC: 0.9184 - val_RECALL: 0.6397 - val_Error Cuadrático Medio: 0.1574 - val_Verdadero Positivo: 261.0000 - val_Falso Positivo: 4.0000 - val_Verdadero Negativo: 452.0000 - val_Falso Negativo: 147.0000 - val_Accuracy: 0.8252 - val_Precision: 0.9849
# Epoch 20/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0459 - AUC: 0.9978 - PRC: 0.9979 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0113 - Verdadero Positivo: 1735.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 1669.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9850 - Precision: 0.9847 - val_loss: 0.6280 - val_AUC: 0.9024 - val_PRC: 0.8817 - val_RECALL: 0.8505 - val_Error Cuadrático Medio: 0.1347 - val_Verdadero Positivo: 347.0000 - val_Falso Positivo: 75.0000 - val_Verdadero Negativo: 381.0000 - val_Falso Negativo: 61.0000 - val_Accuracy: 0.8426 - val_Precision: 0.8223
# Epoch 21/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0347 - AUC: 0.9981 - PRC: 0.9982 - RECALL: 0.9915 - Error Cuadrático Medio: 0.0081 - Verdadero Positivo: 1745.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 1679.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9907 - Precision: 0.9904 - val_loss: 0.5394 - val_AUC: 0.9286 - val_PRC: 0.9225 - val_RECALL: 0.8211 - val_Error Cuadrático Medio: 0.1113 - val_Verdadero Positivo: 335.0000 - val_Falso Positivo: 38.0000 - val_Verdadero Negativo: 418.0000 - val_Falso Negativo: 73.0000 - val_Accuracy: 0.8715 - val_Precision: 0.8981
# Epoch 22/50
# 108/108 [==============================] - 13s 117ms/step - loss: 0.0279 - AUC: 0.9990 - PRC: 0.9993 - RECALL: 0.9898 - Error Cuadrático Medio: 0.0071 - Verdadero Positivo: 1742.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1684.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9913 - Precision: 0.9932 - val_loss: 0.5622 - val_AUC: 0.9143 - val_PRC: 0.8949 - val_RECALL: 0.8603 - val_Error Cuadrático Medio: 0.1242 - val_Verdadero Positivo: 351.0000 - val_Falso Positivo: 69.0000 - val_Verdadero Negativo: 387.0000 - val_Falso Negativo: 57.0000 - val_Accuracy: 0.8542 - val_Precision: 0.8357
# Epoch 23/50
# 108/108 [==============================] - 12s 112ms/step - loss: 0.0390 - AUC: 0.9984 - PRC: 0.9988 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0103 - Verdadero Positivo: 1735.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 1677.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9873 - Precision: 0.9892 - val_loss: 0.8725 - val_AUC: 0.8866 - val_PRC: 0.9044 - val_RECALL: 0.6716 - val_Error Cuadrático Medio: 0.1553 - val_Verdadero Positivo: 274.0000 - val_Falso Positivo: 14.0000 - val_Verdadero Negativo: 442.0000 - val_Falso Negativo: 134.0000 - val_Accuracy: 0.8287 - val_Precision: 0.9514
# Epoch 24/50
# 108/108 [==============================] - ETA: 0s - loss: 0.0164 - AUC: 0.9992 - PRC: 0.9995 - RECALL: 0.9949 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 1751.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 1691.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9959 - Precision: 0.9972Restoring model weights from the end of the best epoch: 14.
# 108/108 [==============================] - 12s 114ms/step - loss: 0.0164 - AUC: 0.9992 - PRC: 0.9995 - RECALL: 0.9949 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 1751.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 1691.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9959 - Precision: 0.9972 - val_loss: 0.4989 - val_AUC: 0.9358 - val_PRC: 0.9248 - val_RECALL: 0.8529 - val_Error Cuadrático Medio: 0.0985 - val_Verdadero Positivo: 348.0000 - val_Falso Positivo: 40.0000 - val_Verdadero Negativo: 416.0000 - val_Falso Negativo: 60.0000 - val_Accuracy: 0.8843 - val_Precision: 0.8969
# Epoch 24: early stopping
# 34/34 [==============================] - 3s 49ms/step - loss: 0.4596 - AUC: 0.9368 - PRC: 0.9273 - RECALL: 0.8647 - Error Cuadrático Medio: 0.1009 - Verdadero Positivo: 460.0000 - Falso Positivo: 55.0000 - Verdadero Negativo: 493.0000 - Falso Negativo: 72.0000 - Accuracy: 0.8824 - Precision: 0.8932
# {'loss': 0.45957151055336, 'AUC': 0.9367882609367371, 'PRC': 0.9273184537887573, 'RECALL': 0.8646616339683533, 'Error Cuadrático Medio': 0.10091772675514221, 'Verdadero Positivo': 460.0, 'Falso Positivo': 55.0, 'Verdadero Negativo': 493.0, 'Falso Negativo': 72.0, 'Accuracy': 0.8824074268341064, 'Precision': 0.893203854560852}
#
#  ...Calculando valores predichos para train y test: ...
# 108/108 [==============================] - 4s 27ms/step
# 34/34 [==============================] - 2s 29ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.45957151055336
# AUC :  0.9367882609367371
# PRC :  0.9273184537887573
# RECALL :  0.8646616339683533
# Error Cuadrático Medio :  0.10091772675514221
# Verdadero Positivo :  460.0
# Falso Positivo :  55.0
# Verdadero Negativo :  493.0
# Falso Negativo :  72.0
# Accuracy :  0.8824074268341064
# Precision :  0.893203854560852
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  493
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  55
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  72
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  460

# %% [markdown]
# #### ***Model-F***:  $~~~1 \times $*`ResNet50 + Xception`*+$3\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
def model_F(img_size=96, compile=True,output_bias=None):
    from keras.applications.resnet50 import ResNet50
    from keras.applications.xception import Xception
    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")
    rnet = ResNet50(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = rnet(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)
    xc = Xception(include_top=False, input_shape=(img_size,img_size,3))
    layers2 = xc(inputs)
    layers2 = tf.keras.layers.GlobalAveragePooling2D()(layers2)

    layers = tf.keras.layers.Concatenate(axis=-1)([layers1,layers2])
    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

model_name="model_F"
log_dir="logs/v0/"
batch_size=32
epochs=50
model = model_F(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias

apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]          0         []
#
#  resnet50 (Functional)       (None, 3, 3, 2048)           2358771   ['input[0][0]']
#                                                           2
#
#  xception (Functional)       (None, 3, 3, 2048)           2086148   ['input[0][0]']
#                                                           0
#
#  global_average_pooling2d (  (None, 2048)                 0         ['resnet50[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['xception[0][0]']
#   (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)   (None, 4096)                 0         ['global_average_pooling2d[0][
#                                                                     0]',
#                                                                      'global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense (Dense)               (None, 120)                  491640    ['concatenate[0][0]']
#
#  dense_1 (Dense)             (None, 10)                   1210      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    11        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 44942053 (171.44 MB)
# Trainable params: 44834405 (171.03 MB)
# Non-trainable params: 107648 (420.50 KB)
# __________________________________________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 108/108 [==============================] - 81s 237ms/step - loss: 0.5202 - AUC: 0.8312 - PRC: 0.8372 - RECALL: 0.7227 - Error Cuadrático Medio: 0.1644 - Verdadero Positivo: 1272.0000 - Falso Positivo: 288.0000 - Verdadero Negativo: 1408.0000 - Falso Negativo: 488.0000 - Accuracy: 0.7755 - Precision: 0.8154 - val_loss: 1.1212 - val_AUC: 0.5000 - val_PRC: 0.4722 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.3838 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 408.0000 - val_Accuracy: 0.5278 - val_Precision: 0.0000e+00
# Epoch 2/50
# 108/108 [==============================] - 22s 208ms/step - loss: 0.4134 - AUC: 0.8904 - PRC: 0.9028 - RECALL: 0.7937 - Error Cuadrático Medio: 0.1302 - Verdadero Positivo: 1397.0000 - Falso Positivo: 244.0000 - Verdadero Negativo: 1452.0000 - Falso Negativo: 363.0000 - Accuracy: 0.8244 - Precision: 0.8513 - val_loss: 1.1089 - val_AUC: 0.5000 - val_PRC: 0.4722 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.3814 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 408.0000 - val_Accuracy: 0.5278 - val_Precision: 0.0000e+00
# Epoch 3/50
# 108/108 [==============================] - 22s 202ms/step - loss: 0.4167 - AUC: 0.8885 - PRC: 0.8999 - RECALL: 0.7903 - Error Cuadrático Medio: 0.1317 - Verdadero Positivo: 1391.0000 - Falso Positivo: 257.0000 - Verdadero Negativo: 1439.0000 - Falso Negativo: 369.0000 - Accuracy: 0.8189 - Precision: 0.8441 - val_loss: 0.7327 - val_AUC: 0.4587 - val_PRC: 0.4061 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.2687 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 1.0000 - val_Verdadero Negativo: 455.0000 - val_Falso Negativo: 408.0000 - val_Accuracy: 0.5266 - val_Precision: 0.0000e+00
# Epoch 4/50
# 108/108 [==============================] - 23s 215ms/step - loss: 0.3864 - AUC: 0.9049 - PRC: 0.9169 - RECALL: 0.8102 - Error Cuadrático Medio: 0.1200 - Verdadero Positivo: 1426.0000 - Falso Positivo: 234.0000 - Verdadero Negativo: 1462.0000 - Falso Negativo: 334.0000 - Accuracy: 0.8356 - Precision: 0.8590 - val_loss: 0.6964 - val_AUC: 0.4626 - val_PRC: 0.4121 - val_RECALL: 0.8186 - val_Error Cuadrático Medio: 0.2505 - val_Verdadero Positivo: 334.0000 - val_Falso Positivo: 318.0000 - val_Verdadero Negativo: 138.0000 - val_Falso Negativo: 74.0000 - val_Accuracy: 0.5463 - val_Precision: 0.5123
# Epoch 5/50
# 108/108 [==============================] - 22s 205ms/step - loss: 0.3426 - AUC: 0.9265 - PRC: 0.9336 - RECALL: 0.8545 - Error Cuadrático Medio: 0.1049 - Verdadero Positivo: 1504.0000 - Falso Positivo: 242.0000 - Verdadero Negativo: 1454.0000 - Falso Negativo: 256.0000 - Accuracy: 0.8559 - Precision: 0.8614 - val_loss: 1.6211 - val_AUC: 0.5253 - val_PRC: 0.4421 - val_RECALL: 1.0000 - val_Error Cuadrático Medio: 0.3833 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 456.0000 - val_Verdadero Negativo: 0.0000e+00 - val_Falso Negativo: 0.0000e+00 - val_Accuracy: 0.4722 - val_Precision: 0.4722
# Epoch 6/50
# 108/108 [==============================] - 23s 217ms/step - loss: 0.2904 - AUC: 0.9479 - PRC: 0.9535 - RECALL: 0.8761 - Error Cuadrático Medio: 0.0885 - Verdadero Positivo: 1542.0000 - Falso Positivo: 203.0000 - Verdadero Negativo: 1493.0000 - Falso Negativo: 218.0000 - Accuracy: 0.8782 - Precision: 0.8837 - val_loss: 1.2091 - val_AUC: 0.5414 - val_PRC: 0.4537 - val_RECALL: 0.8652 - val_Error Cuadrático Medio: 0.3568 - val_Verdadero Positivo: 353.0000 - val_Falso Positivo: 371.0000 - val_Verdadero Negativo: 85.0000 - val_Falso Negativo: 55.0000 - val_Accuracy: 0.5069 - val_Precision: 0.4876
# Epoch 7/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.3007 - AUC: 0.9430 - PRC: 0.9504 - RECALL: 0.8682 - Error Cuadrático Medio: 0.0914 - Verdadero Positivo: 1528.0000 - Falso Positivo: 184.0000 - Verdadero Negativo: 1512.0000 - Falso Negativo: 232.0000 - Accuracy: 0.8796 - Precision: 0.8925 - val_loss: 1.1418 - val_AUC: 0.5597 - val_PRC: 0.4612 - val_RECALL: 0.8554 - val_Error Cuadrático Medio: 0.3186 - val_Verdadero Positivo: 349.0000 - val_Falso Positivo: 287.0000 - val_Verdadero Negativo: 169.0000 - val_Falso Negativo: 59.0000 - val_Accuracy: 0.5995 - val_Precision: 0.5487
# Epoch 8/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.2955 - AUC: 0.9448 - PRC: 0.9515 - RECALL: 0.8773 - Error Cuadrático Medio: 0.0883 - Verdadero Positivo: 1544.0000 - Falso Positivo: 182.0000 - Verdadero Negativo: 1514.0000 - Falso Negativo: 216.0000 - Accuracy: 0.8848 - Precision: 0.8946 - val_loss: 1.0573 - val_AUC: 0.7178 - val_PRC: 0.6877 - val_RECALL: 0.9191 - val_Error Cuadrático Medio: 0.3195 - val_Verdadero Positivo: 375.0000 - val_Falso Positivo: 327.0000 - val_Verdadero Negativo: 129.0000 - val_Falso Negativo: 33.0000 - val_Accuracy: 0.5833 - val_Precision: 0.5342
# Epoch 9/50
# 108/108 [==============================] - 23s 216ms/step - loss: 0.2354 - AUC: 0.9650 - PRC: 0.9685 - RECALL: 0.9006 - Error Cuadrático Medio: 0.0685 - Verdadero Positivo: 1585.0000 - Falso Positivo: 138.0000 - Verdadero Negativo: 1558.0000 - Falso Negativo: 175.0000 - Accuracy: 0.9094 - Precision: 0.9199 - val_loss: 1.6831 - val_AUC: 0.6931 - val_PRC: 0.6141 - val_RECALL: 0.9804 - val_Error Cuadrático Medio: 0.3784 - val_Verdadero Positivo: 400.0000 - val_Falso Positivo: 365.0000 - val_Verdadero Negativo: 91.0000 - val_Falso Negativo: 8.0000 - val_Accuracy: 0.5683 - val_Precision: 0.5229
# Epoch 10/50
# 108/108 [==============================] - 23s 212ms/step - loss: 0.2384 - AUC: 0.9644 - PRC: 0.9688 - RECALL: 0.8960 - Error Cuadrático Medio: 0.0715 - Verdadero Positivo: 1577.0000 - Falso Positivo: 135.0000 - Verdadero Negativo: 1561.0000 - Falso Negativo: 183.0000 - Accuracy: 0.9080 - Precision: 0.9211 - val_loss: 4.3816 - val_AUC: 0.4538 - val_PRC: 0.4522 - val_RECALL: 0.5588 - val_Error Cuadrático Medio: 0.5273 - val_Verdadero Positivo: 228.0000 - val_Falso Positivo: 338.0000 - val_Verdadero Negativo: 118.0000 - val_Falso Negativo: 180.0000 - val_Accuracy: 0.4005 - val_Precision: 0.4028
# Epoch 11/50
# 108/108 [==============================] - 22s 204ms/step - loss: 0.2138 - AUC: 0.9723 - PRC: 0.9743 - RECALL: 0.9006 - Error Cuadrático Medio: 0.0656 - Verdadero Positivo: 1585.0000 - Falso Positivo: 138.0000 - Verdadero Negativo: 1558.0000 - Falso Negativo: 175.0000 - Accuracy: 0.9094 - Precision: 0.9199 - val_loss: 1.0782 - val_AUC: 0.8116 - val_PRC: 0.8183 - val_RECALL: 0.3578 - val_Error Cuadrático Medio: 0.2686 - val_Verdadero Positivo: 146.0000 - val_Falso Positivo: 7.0000 - val_Verdadero Negativo: 449.0000 - val_Falso Negativo: 262.0000 - val_Accuracy: 0.6887 - val_Precision: 0.9542
# Epoch 12/50
# 108/108 [==============================] - 22s 205ms/step - loss: 0.1798 - AUC: 0.9802 - PRC: 0.9822 - RECALL: 0.9182 - Error Cuadrático Medio: 0.0534 - Verdadero Positivo: 1616.0000 - Falso Positivo: 108.0000 - Verdadero Negativo: 1588.0000 - Falso Negativo: 144.0000 - Accuracy: 0.9271 - Precision: 0.9374 - val_loss: 1.2153 - val_AUC: 0.3976 - val_PRC: 0.3869 - val_RECALL: 0.0466 - val_Error Cuadrático Medio: 0.4066 - val_Verdadero Positivo: 19.0000 - val_Falso Positivo: 107.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 389.0000 - val_Accuracy: 0.4259 - val_Precision: 0.1508
# Epoch 13/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.2274 - AUC: 0.9680 - PRC: 0.9719 - RECALL: 0.9051 - Error Cuadrático Medio: 0.0685 - Verdadero Positivo: 1593.0000 - Falso Positivo: 154.0000 - Verdadero Negativo: 1542.0000 - Falso Negativo: 167.0000 - Accuracy: 0.9071 - Precision: 0.9118 - val_loss: 0.9653 - val_AUC: 0.7193 - val_PRC: 0.7615 - val_RECALL: 0.3407 - val_Error Cuadrático Medio: 0.2584 - val_Verdadero Positivo: 139.0000 - val_Falso Positivo: 4.0000 - val_Verdadero Negativo: 452.0000 - val_Falso Negativo: 269.0000 - val_Accuracy: 0.6840 - val_Precision: 0.9720
# Epoch 14/50
# 108/108 [==============================] - 23s 215ms/step - loss: 0.1486 - AUC: 0.9863 - PRC: 0.9879 - RECALL: 0.9364 - Error Cuadrático Medio: 0.0416 - Verdadero Positivo: 1648.0000 - Falso Positivo: 79.0000 - Verdadero Negativo: 1617.0000 - Falso Negativo: 112.0000 - Accuracy: 0.9447 - Precision: 0.9543 - val_loss: 0.5716 - val_AUC: 0.8737 - val_PRC: 0.8694 - val_RECALL: 0.6789 - val_Error Cuadrático Medio: 0.1588 - val_Verdadero Positivo: 277.0000 - val_Falso Positivo: 51.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 131.0000 - val_Accuracy: 0.7894 - val_Precision: 0.8445
# Epoch 15/50
# 108/108 [==============================] - 22s 205ms/step - loss: 0.1296 - AUC: 0.9887 - PRC: 0.9891 - RECALL: 0.9540 - Error Cuadrático Medio: 0.0360 - Verdadero Positivo: 1679.0000 - Falso Positivo: 78.0000 - Verdadero Negativo: 1618.0000 - Falso Negativo: 81.0000 - Accuracy: 0.9540 - Precision: 0.9556 - val_loss: 1.3869 - val_AUC: 0.8264 - val_PRC: 0.8350 - val_RECALL: 0.2426 - val_Error Cuadrático Medio: 0.3072 - val_Verdadero Positivo: 99.0000 - val_Falso Positivo: 6.0000 - val_Verdadero Negativo: 450.0000 - val_Falso Negativo: 309.0000 - val_Accuracy: 0.6354 - val_Precision: 0.9429
# Epoch 16/50
# 108/108 [==============================] - 22s 206ms/step - loss: 0.1024 - AUC: 0.9927 - PRC: 0.9937 - RECALL: 0.9608 - Error Cuadrático Medio: 0.0285 - Verdadero Positivo: 1691.0000 - Falso Positivo: 52.0000 - Verdadero Negativo: 1644.0000 - Falso Negativo: 69.0000 - Accuracy: 0.9650 - Precision: 0.9702 - val_loss: 2.5004 - val_AUC: 0.5555 - val_PRC: 0.5613 - val_RECALL: 0.0074 - val_Error Cuadrático Medio: 0.4484 - val_Verdadero Positivo: 3.0000 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 405.0000 - val_Accuracy: 0.5312 - val_Precision: 1.0000
# Epoch 17/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.1710 - AUC: 0.9820 - PRC: 0.9833 - RECALL: 0.9290 - Error Cuadrático Medio: 0.0506 - Verdadero Positivo: 1635.0000 - Falso Positivo: 102.0000 - Verdadero Negativo: 1594.0000 - Falso Negativo: 125.0000 - Accuracy: 0.9343 - Precision: 0.9413 - val_loss: 0.5630 - val_AUC: 0.8986 - val_PRC: 0.9070 - val_RECALL: 0.7181 - val_Error Cuadrático Medio: 0.1366 - val_Verdadero Positivo: 293.0000 - val_Falso Positivo: 32.0000 - val_Verdadero Negativo: 424.0000 - val_Falso Negativo: 115.0000 - val_Accuracy: 0.8299 - val_Precision: 0.9015
# Epoch 18/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.1150 - AUC: 0.9913 - PRC: 0.9919 - RECALL: 0.9455 - Error Cuadrático Medio: 0.0333 - Verdadero Positivo: 1664.0000 - Falso Positivo: 55.0000 - Verdadero Negativo: 1641.0000 - Falso Negativo: 96.0000 - Accuracy: 0.9563 - Precision: 0.9680 - val_loss: 1.5760 - val_AUC: 0.8552 - val_PRC: 0.7738 - val_RECALL: 0.9583 - val_Error Cuadrático Medio: 0.2275 - val_Verdadero Positivo: 391.0000 - val_Falso Positivo: 201.0000 - val_Verdadero Negativo: 255.0000 - val_Falso Negativo: 17.0000 - val_Accuracy: 0.7477 - val_Precision: 0.6605
# Epoch 19/50
# 108/108 [==============================] - 22s 205ms/step - loss: 0.0896 - AUC: 0.9948 - PRC: 0.9955 - RECALL: 0.9511 - Error Cuadrático Medio: 0.0274 - Verdadero Positivo: 1674.0000 - Falso Positivo: 43.0000 - Verdadero Negativo: 1653.0000 - Falso Negativo: 86.0000 - Accuracy: 0.9627 - Precision: 0.9750 - val_loss: 0.7560 - val_AUC: 0.8586 - val_PRC: 0.8505 - val_RECALL: 0.7990 - val_Error Cuadrático Medio: 0.1779 - val_Verdadero Positivo: 326.0000 - val_Falso Positivo: 107.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 82.0000 - val_Accuracy: 0.7812 - val_Precision: 0.7529
# Epoch 20/50
# 108/108 [==============================] - 22s 202ms/step - loss: 0.1109 - AUC: 0.9905 - PRC: 0.9916 - RECALL: 0.9483 - Error Cuadrático Medio: 0.0307 - Verdadero Positivo: 1669.0000 - Falso Positivo: 43.0000 - Verdadero Negativo: 1653.0000 - Falso Negativo: 91.0000 - Accuracy: 0.9612 - Precision: 0.9749 - val_loss: 0.8092 - val_AUC: 0.7628 - val_PRC: 0.8070 - val_RECALL: 0.4216 - val_Error Cuadrático Medio: 0.2317 - val_Verdadero Positivo: 172.0000 - val_Falso Positivo: 11.0000 - val_Verdadero Negativo: 445.0000 - val_Falso Negativo: 236.0000 - val_Accuracy: 0.7141 - val_Precision: 0.9399
# Epoch 21/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.1353 - AUC: 0.9887 - PRC: 0.9892 - RECALL: 0.9347 - Error Cuadrático Medio: 0.0399 - Verdadero Positivo: 1645.0000 - Falso Positivo: 72.0000 - Verdadero Negativo: 1624.0000 - Falso Negativo: 115.0000 - Accuracy: 0.9459 - Precision: 0.9581 - val_loss: 1.1072 - val_AUC: 0.7769 - val_PRC: 0.7948 - val_RECALL: 0.3333 - val_Error Cuadrático Medio: 0.2770 - val_Verdadero Positivo: 136.0000 - val_Falso Positivo: 12.0000 - val_Verdadero Negativo: 444.0000 - val_Falso Negativo: 272.0000 - val_Accuracy: 0.6713 - val_Precision: 0.9189
# Epoch 22/50
# 108/108 [==============================] - 22s 202ms/step - loss: 0.0875 - AUC: 0.9941 - PRC: 0.9947 - RECALL: 0.9597 - Error Cuadrático Medio: 0.0248 - Verdadero Positivo: 1689.0000 - Falso Positivo: 42.0000 - Verdadero Negativo: 1654.0000 - Falso Negativo: 71.0000 - Accuracy: 0.9673 - Precision: 0.9757 - val_loss: 0.9860 - val_AUC: 0.8414 - val_PRC: 0.8438 - val_RECALL: 0.4436 - val_Error Cuadrático Medio: 0.2382 - val_Verdadero Positivo: 181.0000 - val_Falso Positivo: 15.0000 - val_Verdadero Negativo: 441.0000 - val_Falso Negativo: 227.0000 - val_Accuracy: 0.7199 - val_Precision: 0.9235
# Epoch 23/50
# 108/108 [==============================] - 23s 217ms/step - loss: 0.0627 - AUC: 0.9967 - PRC: 0.9969 - RECALL: 0.9761 - Error Cuadrático Medio: 0.0168 - Verdadero Positivo: 1718.0000 - Falso Positivo: 30.0000 - Verdadero Negativo: 1666.0000 - Falso Negativo: 42.0000 - Accuracy: 0.9792 - Precision: 0.9828 - val_loss: 2.5211 - val_AUC: 0.7371 - val_PRC: 0.6396 - val_RECALL: 0.7647 - val_Error Cuadrático Medio: 0.2705 - val_Verdadero Positivo: 312.0000 - val_Falso Positivo: 154.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 96.0000 - val_Accuracy: 0.7106 - val_Precision: 0.6695
# Epoch 24/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0798 - AUC: 0.9945 - PRC: 0.9948 - RECALL: 0.9602 - Error Cuadrático Medio: 0.0217 - Verdadero Positivo: 1690.0000 - Falso Positivo: 24.0000 - Verdadero Negativo: 1672.0000 - Falso Negativo: 70.0000 - Accuracy: 0.9728 - Precision: 0.9860 - val_loss: 0.8198 - val_AUC: 0.9105 - val_PRC: 0.8662 - val_RECALL: 0.9461 - val_Error Cuadrático Medio: 0.1630 - val_Verdadero Positivo: 386.0000 - val_Falso Positivo: 142.0000 - val_Verdadero Negativo: 314.0000 - val_Falso Negativo: 22.0000 - val_Accuracy: 0.8102 - val_Precision: 0.7311
# Epoch 25/50
# 108/108 [==============================] - 22s 202ms/step - loss: 0.1445 - AUC: 0.9872 - PRC: 0.9871 - RECALL: 0.9386 - Error Cuadrático Medio: 0.0418 - Verdadero Positivo: 1652.0000 - Falso Positivo: 82.0000 - Verdadero Negativo: 1614.0000 - Falso Negativo: 108.0000 - Accuracy: 0.9450 - Precision: 0.9527 - val_loss: 2.0145 - val_AUC: 0.6423 - val_PRC: 0.5587 - val_RECALL: 0.0049 - val_Error Cuadrático Medio: 0.4458 - val_Verdadero Positivo: 2.0000 - val_Falso Positivo: 3.0000 - val_Verdadero Negativo: 453.0000 - val_Falso Negativo: 406.0000 - val_Accuracy: 0.5266 - val_Precision: 0.4000
# Epoch 26/50
# 108/108 [==============================] - 22s 204ms/step - loss: 0.1988 - AUC: 0.9752 - PRC: 0.9764 - RECALL: 0.9216 - Error Cuadrático Medio: 0.0568 - Verdadero Positivo: 1622.0000 - Falso Positivo: 118.0000 - Verdadero Negativo: 1578.0000 - Falso Negativo: 138.0000 - Accuracy: 0.9259 - Precision: 0.9322 - val_loss: 0.5104 - val_AUC: 0.9137 - val_PRC: 0.9019 - val_RECALL: 0.9191 - val_Error Cuadrático Medio: 0.1394 - val_Verdadero Positivo: 375.0000 - val_Falso Positivo: 117.0000 - val_Verdadero Negativo: 339.0000 - val_Falso Negativo: 33.0000 - val_Accuracy: 0.8264 - val_Precision: 0.7622
# Epoch 27/50
# 108/108 [==============================] - 22s 204ms/step - loss: 0.0929 - AUC: 0.9936 - PRC: 0.9935 - RECALL: 0.9699 - Error Cuadrático Medio: 0.0248 - Verdadero Positivo: 1707.0000 - Falso Positivo: 45.0000 - Verdadero Negativo: 1651.0000 - Falso Negativo: 53.0000 - Accuracy: 0.9716 - Precision: 0.9743 - val_loss: 0.5155 - val_AUC: 0.9093 - val_PRC: 0.9015 - val_RECALL: 0.8186 - val_Error Cuadrático Medio: 0.1219 - val_Verdadero Positivo: 334.0000 - val_Falso Positivo: 51.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 74.0000 - val_Accuracy: 0.8553 - val_Precision: 0.8675
# Epoch 28/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.0704 - AUC: 0.9963 - PRC: 0.9969 - RECALL: 0.9693 - Error Cuadrático Medio: 0.0197 - Verdadero Positivo: 1706.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 1669.0000 - Falso Negativo: 54.0000 - Accuracy: 0.9766 - Precision: 0.9844 - val_loss: 0.6596 - val_AUC: 0.9039 - val_PRC: 0.8697 - val_RECALL: 0.8897 - val_Error Cuadrático Medio: 0.1428 - val_Verdadero Positivo: 363.0000 - val_Falso Positivo: 100.0000 - val_Verdadero Negativo: 356.0000 - val_Falso Negativo: 45.0000 - val_Accuracy: 0.8322 - val_Precision: 0.7840
# Epoch 29/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.0987 - AUC: 0.9931 - PRC: 0.9937 - RECALL: 0.9608 - Error Cuadrático Medio: 0.0277 - Verdadero Positivo: 1691.0000 - Falso Positivo: 52.0000 - Verdadero Negativo: 1644.0000 - Falso Negativo: 69.0000 - Accuracy: 0.9650 - Precision: 0.9702 - val_loss: 1.5212 - val_AUC: 0.8679 - val_PRC: 0.7920 - val_RECALL: 0.9608 - val_Error Cuadrático Medio: 0.2152 - val_Verdadero Positivo: 392.0000 - val_Falso Positivo: 194.0000 - val_Verdadero Negativo: 262.0000 - val_Falso Negativo: 16.0000 - val_Accuracy: 0.7569 - val_Precision: 0.6689
# Epoch 30/50
# 108/108 [==============================] - 23s 216ms/step - loss: 0.0676 - AUC: 0.9970 - PRC: 0.9972 - RECALL: 0.9676 - Error Cuadrático Medio: 0.0195 - Verdadero Positivo: 1703.0000 - Falso Positivo: 32.0000 - Verdadero Negativo: 1664.0000 - Falso Negativo: 57.0000 - Accuracy: 0.9742 - Precision: 0.9816 - val_loss: 7.7407 - val_AUC: 0.6928 - val_PRC: 0.5957 - val_RECALL: 0.9853 - val_Error Cuadrático Medio: 0.4082 - val_Verdadero Positivo: 402.0000 - val_Falso Positivo: 368.0000 - val_Verdadero Negativo: 88.0000 - val_Falso Negativo: 6.0000 - val_Accuracy: 0.5671 - val_Precision: 0.5221
# Epoch 31/50
# 108/108 [==============================] - 23s 216ms/step - loss: 0.0511 - AUC: 0.9976 - PRC: 0.9981 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0122 - Verdadero Positivo: 1735.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 1677.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9873 - Precision: 0.9892 - val_loss: 0.6032 - val_AUC: 0.9145 - val_PRC: 0.8848 - val_RECALL: 0.8848 - val_Error Cuadrático Medio: 0.1327 - val_Verdadero Positivo: 361.0000 - val_Falso Positivo: 89.0000 - val_Verdadero Negativo: 367.0000 - val_Falso Negativo: 47.0000 - val_Accuracy: 0.8426 - val_Precision: 0.8022
# Epoch 32/50
# 108/108 [==============================] - 22s 205ms/step - loss: 0.0311 - AUC: 0.9991 - PRC: 0.9992 - RECALL: 0.9864 - Error Cuadrático Medio: 0.0082 - Verdadero Positivo: 1736.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 1685.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9899 - Precision: 0.9937 - val_loss: 0.6836 - val_AUC: 0.8940 - val_PRC: 0.8844 - val_RECALL: 0.7966 - val_Error Cuadrático Medio: 0.1374 - val_Verdadero Positivo: 325.0000 - val_Falso Positivo: 58.0000 - val_Verdadero Negativo: 398.0000 - val_Falso Negativo: 83.0000 - val_Accuracy: 0.8368 - val_Precision: 0.8486
# Epoch 33/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0350 - AUC: 0.9985 - PRC: 0.9984 - RECALL: 0.9875 - Error Cuadrático Medio: 0.0086 - Verdadero Positivo: 1738.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 1681.0000 - Falso Negativo: 22.0000 - Accuracy: 0.9893 - Precision: 0.9914 - val_loss: 2.4772 - val_AUC: 0.8142 - val_PRC: 0.7176 - val_RECALL: 0.9632 - val_Error Cuadrático Medio: 0.2665 - val_Verdadero Positivo: 393.0000 - val_Falso Positivo: 236.0000 - val_Verdadero Negativo: 220.0000 - val_Falso Negativo: 15.0000 - val_Accuracy: 0.7095 - val_Precision: 0.6248
# Epoch 34/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.0418 - AUC: 0.9982 - PRC: 0.9978 - RECALL: 0.9864 - Error Cuadrático Medio: 0.0109 - Verdadero Positivo: 1736.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 1674.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9867 - Precision: 0.9875 - val_loss: 0.8472 - val_AUC: 0.8949 - val_PRC: 0.8607 - val_RECALL: 0.9191 - val_Error Cuadrático Medio: 0.1706 - val_Verdadero Positivo: 375.0000 - val_Falso Positivo: 139.0000 - val_Verdadero Negativo: 317.0000 - val_Falso Negativo: 33.0000 - val_Accuracy: 0.8009 - val_Precision: 0.7296
# Epoch 35/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.0770 - AUC: 0.9970 - PRC: 0.9975 - RECALL: 0.9761 - Error Cuadrático Medio: 0.0161 - Verdadero Positivo: 1718.0000 - Falso Positivo: 32.0000 - Verdadero Negativo: 1664.0000 - Falso Negativo: 42.0000 - Accuracy: 0.9786 - Precision: 0.9817 - val_loss: 0.6014 - val_AUC: 0.8928 - val_PRC: 0.8899 - val_RECALL: 0.7451 - val_Error Cuadrático Medio: 0.1440 - val_Verdadero Positivo: 304.0000 - val_Falso Positivo: 52.0000 - val_Verdadero Negativo: 404.0000 - val_Falso Negativo: 104.0000 - val_Accuracy: 0.8194 - val_Precision: 0.8539
# Epoch 36/50
# 108/108 [==============================] - 22s 204ms/step - loss: 0.0335 - AUC: 0.9992 - PRC: 0.9993 - RECALL: 0.9858 - Error Cuadrático Medio: 0.0089 - Verdadero Positivo: 1735.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 1678.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9876 - Precision: 0.9897 - val_loss: 1.3194 - val_AUC: 0.8498 - val_PRC: 0.7731 - val_RECALL: 0.9583 - val_Error Cuadrático Medio: 0.2263 - val_Verdadero Positivo: 391.0000 - val_Falso Positivo: 205.0000 - val_Verdadero Negativo: 251.0000 - val_Falso Negativo: 17.0000 - val_Accuracy: 0.7431 - val_Precision: 0.6560
# Epoch 37/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0808 - AUC: 0.9949 - PRC: 0.9952 - RECALL: 0.9642 - Error Cuadrático Medio: 0.0223 - Verdadero Positivo: 1697.0000 - Falso Positivo: 44.0000 - Verdadero Negativo: 1652.0000 - Falso Negativo: 63.0000 - Accuracy: 0.9690 - Precision: 0.9747 - val_loss: 0.8223 - val_AUC: 0.8696 - val_PRC: 0.8403 - val_RECALL: 0.8113 - val_Error Cuadrático Medio: 0.1822 - val_Verdadero Positivo: 331.0000 - val_Falso Positivo: 126.0000 - val_Verdadero Negativo: 330.0000 - val_Falso Negativo: 77.0000 - val_Accuracy: 0.7650 - val_Precision: 0.7243
# Epoch 38/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0706 - AUC: 0.9961 - PRC: 0.9963 - RECALL: 0.9653 - Error Cuadrático Medio: 0.0195 - Verdadero Positivo: 1699.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 1674.0000 - Falso Negativo: 61.0000 - Accuracy: 0.9760 - Precision: 0.9872 - val_loss: 1.4400 - val_AUC: 0.5956 - val_PRC: 0.6014 - val_RECALL: 0.0662 - val_Error Cuadrático Medio: 0.3593 - val_Verdadero Positivo: 27.0000 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 456.0000 - val_Falso Negativo: 381.0000 - val_Accuracy: 0.5590 - val_Precision: 1.0000
# Epoch 39/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.0675 - AUC: 0.9966 - PRC: 0.9972 - RECALL: 0.9693 - Error Cuadrático Medio: 0.0191 - Verdadero Positivo: 1706.0000 - Falso Positivo: 32.0000 - Verdadero Negativo: 1664.0000 - Falso Negativo: 54.0000 - Accuracy: 0.9751 - Precision: 0.9816 - val_loss: 3.3683 - val_AUC: 0.4793 - val_PRC: 0.4412 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.4730 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 3.0000 - val_Verdadero Negativo: 453.0000 - val_Falso Negativo: 408.0000 - val_Accuracy: 0.5243 - val_Precision: 0.0000e+00
# Epoch 40/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.1337 - AUC: 0.9883 - PRC: 0.9893 - RECALL: 0.9477 - Error Cuadrático Medio: 0.0358 - Verdadero Positivo: 1668.0000 - Falso Positivo: 69.0000 - Verdadero Negativo: 1627.0000 - Falso Negativo: 92.0000 - Accuracy: 0.9534 - Precision: 0.9603 - val_loss: 3.9809 - val_AUC: 0.6909 - val_PRC: 0.7361 - val_RECALL: 0.1225 - val_Error Cuadrático Medio: 0.3941 - val_Verdadero Positivo: 50.0000 - val_Falso Positivo: 1.0000 - val_Verdadero Negativo: 455.0000 - val_Falso Negativo: 358.0000 - val_Accuracy: 0.5845 - val_Precision: 0.9804
# Epoch 41/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0571 - AUC: 0.9966 - PRC: 0.9965 - RECALL: 0.9824 - Error Cuadrático Medio: 0.0136 - Verdadero Positivo: 1729.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 1671.0000 - Falso Negativo: 31.0000 - Accuracy: 0.9838 - Precision: 0.9857 - val_loss: 1.0926 - val_AUC: 0.8929 - val_PRC: 0.8470 - val_RECALL: 0.8995 - val_Error Cuadrático Medio: 0.1581 - val_Verdadero Positivo: 367.0000 - val_Falso Positivo: 117.0000 - val_Verdadero Negativo: 339.0000 - val_Falso Negativo: 41.0000 - val_Accuracy: 0.8171 - val_Precision: 0.7583
# Epoch 42/50
# 108/108 [==============================] - 23s 215ms/step - loss: 0.0195 - AUC: 0.9997 - PRC: 0.9997 - RECALL: 0.9926 - Error Cuadrático Medio: 0.0046 - Verdadero Positivo: 1747.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 1688.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9939 - Precision: 0.9954 - val_loss: 0.8291 - val_AUC: 0.8933 - val_PRC: 0.8671 - val_RECALL: 0.8578 - val_Error Cuadrático Medio: 0.1419 - val_Verdadero Positivo: 350.0000 - val_Falso Positivo: 82.0000 - val_Verdadero Negativo: 374.0000 - val_Falso Negativo: 58.0000 - val_Accuracy: 0.8380 - val_Precision: 0.8102
# Epoch 43/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.0167 - AUC: 0.9995 - PRC: 0.9997 - RECALL: 0.9943 - Error Cuadrático Medio: 0.0042 - Verdadero Positivo: 1750.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 1686.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9942 - Precision: 0.9943 - val_loss: 0.7117 - val_AUC: 0.8991 - val_PRC: 0.8894 - val_RECALL: 0.8088 - val_Error Cuadrático Medio: 0.1314 - val_Verdadero Positivo: 330.0000 - val_Falso Positivo: 48.0000 - val_Verdadero Negativo: 408.0000 - val_Falso Negativo: 78.0000 - val_Accuracy: 0.8542 - val_Precision: 0.8730
# Epoch 44/50
# 108/108 [==============================] - 22s 203ms/step - loss: 0.0243 - AUC: 0.9994 - PRC: 0.9995 - RECALL: 0.9898 - Error Cuadrático Medio: 0.0066 - Verdadero Positivo: 1742.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 1684.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9913 - Precision: 0.9932 - val_loss: 1.1705 - val_AUC: 0.8784 - val_PRC: 0.8223 - val_RECALL: 0.8971 - val_Error Cuadrático Medio: 0.1567 - val_Verdadero Positivo: 366.0000 - val_Falso Positivo: 107.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 42.0000 - val_Accuracy: 0.8275 - val_Precision: 0.7738
# Epoch 45/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0341 - AUC: 0.9985 - PRC: 0.9981 - RECALL: 0.9892 - Error Cuadrático Medio: 0.0090 - Verdadero Positivo: 1741.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 1675.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9884 - Precision: 0.9881 - val_loss: 1.0490 - val_AUC: 0.8691 - val_PRC: 0.8735 - val_RECALL: 0.6201 - val_Error Cuadrático Medio: 0.1827 - val_Verdadero Positivo: 253.0000 - val_Falso Positivo: 25.0000 - val_Verdadero Negativo: 431.0000 - val_Falso Negativo: 155.0000 - val_Accuracy: 0.7917 - val_Precision: 0.9101
# Epoch 46/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.0317 - AUC: 0.9989 - PRC: 0.9987 - RECALL: 0.9915 - Error Cuadrático Medio: 0.0084 - Verdadero Positivo: 1745.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 1677.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9902 - Precision: 0.9892 - val_loss: 3.1921 - val_AUC: 0.8314 - val_PRC: 0.7363 - val_RECALL: 0.9608 - val_Error Cuadrático Medio: 0.2285 - val_Verdadero Positivo: 392.0000 - val_Falso Positivo: 200.0000 - val_Verdadero Negativo: 256.0000 - val_Falso Negativo: 16.0000 - val_Accuracy: 0.7500 - val_Precision: 0.6622
# Epoch 47/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.0198 - AUC: 0.9995 - PRC: 0.9996 - RECALL: 0.9909 - Error Cuadrático Medio: 0.0052 - Verdadero Positivo: 1744.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 1687.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9928 - Precision: 0.9949 - val_loss: 1.3859 - val_AUC: 0.8661 - val_PRC: 0.7985 - val_RECALL: 0.9289 - val_Error Cuadrático Medio: 0.1984 - val_Verdadero Positivo: 379.0000 - val_Falso Positivo: 165.0000 - val_Verdadero Negativo: 291.0000 - val_Falso Negativo: 29.0000 - val_Accuracy: 0.7755 - val_Precision: 0.6967
# Epoch 48/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.0166 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9949 - Error Cuadrático Medio: 0.0044 - Verdadero Positivo: 1751.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 1685.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9942 - Precision: 0.9938 - val_loss: 3.0166 - val_AUC: 0.8190 - val_PRC: 0.7220 - val_RECALL: 0.9657 - val_Error Cuadrático Medio: 0.2551 - val_Verdadero Positivo: 394.0000 - val_Falso Positivo: 225.0000 - val_Verdadero Negativo: 231.0000 - val_Falso Negativo: 14.0000 - val_Accuracy: 0.7234 - val_Precision: 0.6365
# Epoch 49/50
# 108/108 [==============================] - 23s 214ms/step - loss: 0.0263 - AUC: 0.9993 - PRC: 0.9995 - RECALL: 0.9892 - Error Cuadrático Medio: 0.0073 - Verdadero Positivo: 1741.0000 - Falso Positivo: 14.0000 - Verdadero Negativo: 1682.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9905 - Precision: 0.9920 - val_loss: 1.6289 - val_AUC: 0.7941 - val_PRC: 0.8260 - val_RECALL: 0.3603 - val_Error Cuadrático Medio: 0.2796 - val_Verdadero Positivo: 147.0000 - val_Falso Positivo: 5.0000 - val_Verdadero Negativo: 451.0000 - val_Falso Negativo: 261.0000 - val_Accuracy: 0.6921 - val_Precision: 0.9671
# Epoch 50/50
# 108/108 [==============================] - 23s 213ms/step - loss: 0.0107 - AUC: 0.9996 - PRC: 0.9998 - RECALL: 0.9966 - Error Cuadrático Medio: 0.0025 - Verdadero Positivo: 1754.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 1691.0000 - Falso Negativo: 6.0000 - Accuracy: 0.9968 - Precision: 0.9972 - val_loss: 0.7275 - val_AUC: 0.9067 - val_PRC: 0.8815 - val_RECALL: 0.8725 - val_Error Cuadrático Medio: 0.1258 - val_Verdadero Positivo: 356.0000 - val_Falso Positivo: 69.0000 - val_Verdadero Negativo: 387.0000 - val_Falso Negativo: 52.0000 - val_Accuracy: 0.8600 - val_Precision: 0.8376
# 34/34 [==============================] - 4s 58ms/step - loss: 0.8220 - AUC: 0.9052 - PRC: 0.8829 - RECALL: 0.8684 - Error Cuadrático Medio: 0.1355 - Verdadero Positivo: 462.0000 - Falso Positivo: 95.0000 - Verdadero Negativo: 453.0000 - Falso Negativo: 70.0000 - Accuracy: 0.8472 - Precision: 0.8294
# {'loss': 0.8220359683036804, 'AUC': 0.9051780700683594, 'PRC': 0.8828872442245483, 'RECALL': 0.8684210777282715, 'Error Cuadrático Medio': 0.13548417389392853, 'Verdadero Positivo': 462.0, 'Falso Positivo': 95.0, 'Verdadero Negativo': 453.0, 'Falso Negativo': 70.0, 'Accuracy': 0.8472222089767456, 'Precision': 0.8294434547424316}
#
#  ...Calculando valores predichos para train y test: ...
# 108/108 [==============================] - 7s 50ms/step
# 34/34 [==============================] - 4s 52ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.8220359683036804
# AUC :  0.9051780700683594
# PRC :  0.8828872442245483
# RECALL :  0.8684210777282715
# Error Cuadrático Medio :  0.13548417389392853
# Verdadero Positivo :  462.0
# Falso Positivo :  95.0
# Verdadero Negativo :  453.0
# Falso Negativo :  70.0
# Accuracy :  0.8472222089767456
# Precision :  0.8294434547424316
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  453
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  95
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  70
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  462

# %% [markdown]
# ## Imágenes con white-padding en la región central

# %%
# Las imágenes que pertenecen a la clase 0 se van a llenar con 0's en la región central
# Las imágenes que pertenecen a la clase 1 se van a llenar con 0's en la región no central (prueba adicional)

idd = int((96-36)/2)

for j in range(2):
  print('j:',j)
  for i in range(3):
    print('i:',i)
    file = 'H_c'+str(j)+'_0'+str(i)+'.h5'
    with h5py.File('/content/'+file,'r') as f:
      tt = f['train_img'][:]                            #)  train_hc.append(

    # Prepocesamiento
    file2 = 'H_c'+str(j)+'_mod_0'+str(i)+'.h5'
    for k in tqdm(range(len(tt))):
      if j == 0:  # Sin Cancer
        tt[k,idd:idd+36,idd:idd+36,:] = 255
      elif j == 1: # Con cancer
        tt[k,0:idd,:] = 255
        tt[k,idd+36:,:] = 255
        tt[k,:,idd+36:] = 255
        tt[k,:,0:idd] = 255
      h5_tensor_v2('/content/'+file2,tt.shape,tt)
