# %% [markdown]
# ### **`04-Datos_aumentados: modelos-CNN`**
# ### **PROYECTO: DETECCIÓN HISTOPATOLÓGICA DEL CANCER**
# ### Fundamentos de Deep Learning - 2023-2
#
# $ \mathcal{Daniel ~H. ~Martínez ~S. ~-~ UdeA} $ \
# dhumberto.martinez@udea.edu.co
# $ $
#
# **Descripción del notebook:**
#
# Con el objetivo de intentar disminuir el *overfiting* encontrado en los resultados del notebook `03-Aplicación_modelos_CNN`, se prueban los 6 modelos en un nuevo dataset con datos aumentados. Para lograr esto, se utilizan las imágenes iniciales y se les agrega un *white-padding (wp)* en la región central a las imágenes correspondientes que no tienen células cancerígenas (`clase 0`), mientras que a las muestras que tienen cáncer (`clase 1`), se hace el *wp* en la región por fuera del centro. Con estas nuevas imágenes se aumentan los datos del entrenamiento.

# %%
# Librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tempfile
from time import time
import os

from skimage import io
from pathlib import Path
from humanize import naturalsize
import tensorflow as tf
from tensorflow import keras
from tqdm.auto import tqdm
import h5py

import seaborn as sns
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Definitions
def load_data():
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_00.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_01.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_02.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_00.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_01.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_02.h5

    # Padding region central
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_mod_00.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_mod_01.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_mod_02.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_mod_00.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_mod_01.h5
    # !wget https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_mod_02.h5

    path_train_labels ='https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/'
    train_hc = []
    train_hc_cen = []
    for j in range(2):
      for i in range(3):
        file = 'H_c'+str(j)+'_0'+str(i)+'.h5'
        file2 = 'H_c'+str(j)+'_mod_0'+str(i)+'.h5'
        with h5py.File('/content/'+file,'r') as f:
          train_hc.append(f['train_img'][:])

        with h5py.File('/content/'+file2,'r') as ff:
          train_hc_cen.append(ff['train_img'][:])

    train_hc = np.r_[train_hc].reshape(int(6*900), 96, 96, 3)
    train_hc_cen = np.r_[train_hc_cen].reshape(int(6*900), 96, 96, 3)
    train_labels = pd.read_csv(path_train_labels+'train_labels.csv')
    return train_hc,train_hc_cen, train_labels

def Norm_img(img):
    # Normalización min-max
    return (img-np.min(img))/(np.max(img)-np.min(img))

def show_mosaic_class(train_labels,class_h,num_rand =5):
    # Mostrar mosaico para un rand dado
    num_class = len(class_h)
    for j in class_h:
      img_rand = np.random.choice(train_labels['id'][train_labels['label'] == j],num_rand)
      fig = plt.figure(figsize=(12,14))
      for i,k in enumerate(img_rand):
        ax = fig.add_subplot(num_class, num_rand, i+1)
        img = io.imread(k+'.tif')
        ax.imshow(Norm_img(img))
        if i == 0:
          ax.set(title = 'CLASS: '+str(j))

def show_mosaic_id(dataset,class_h,num_rand =5):
    # Mostrar mosaico para un rand dado
    num_class = len(class_h)
    for j in class_h:
      img_rand = np.random.choice(np.arange(int(3*900)),num_rand)
      fig = plt.figure(figsize=(12,14))
      for i,k in enumerate(img_rand):
        ax = fig.add_subplot(num_class, num_rand, i+1)
        if j == 0:
          img = dataset[k]
        elif j == 1:
          img = dataset[k+int(3*900)]
        ax.imshow(Norm_img(img))
        if i == 0:
          ax.set(title = 'CLASS: '+str(j))

def rand_img(train_labels,class_h_,choose_ran = 'si',id='',show_plot = 'si'):
    if choose_ran == 'si':
      img_ = np.random.choice(train_labels['id'][train_labels['label'] == class_h_],1)
      img = io.imread(img_[0]+'.tif')
    elif choose_ran == 'no':
      img = io.imread(id+'.tif')
    if show_plot == 'si':
      fig, ax = plt.subplots(figsize = (5,4))
      ax.imshow(Norm_img(img))
      ax.set(title = 'CLASS: '+str(class_h_))
    plt.show()
    return img

def choose_img(train_labels,id,show_plot = 'si'):
    # Esoger imagen aleatoria para un clases dada
    img = io.imread(id+'.tif')
    if show_plot == 'si':
      fig, ax = plt.subplots(figsize = (5,4))
      ax.imshow(Norm_img(img))
      class_h_ = train_labels['label'][train_labels['id'] == id]
      class_h_ = class_h_.reset_index()
      print(class_h_)
      ax.set(title = 'Index: '+str(class_h_['index'].iloc[0])+' :--: CLASS: '+str(class_h_['label'].iloc[0]))
    plt.show();
    return img

def h5_w(path,N_img,data_ran):
    # Guardar archivo en formaro h5
    train_shape = (N_img,96,96,3)
    hf = h5py.File(path,'w')                            # Open a hdf5 file and create earrays
    hf.create_dataset('train_img',train_shape,np.uint8) #,compression="gzip", compression_opts=9)    # The pixels range is 0-255, dtype is uint
    for i,k in tqdm(enumerate(data_ran)):
      hf['train_img'][i,...] = choose_img(k, show_plot='no')
    hf.close()

def choose_img_label(h,choose_ran = 'si',show_plot = 'si',img_id=''):
    # Escoger imagen para un id dado o random
    if choose_ran == 'si':
      img_id = np.random.choice(np.arange(len(h)),1)[0]
      img = h[img_id]
    elif choose_ran == 'no':
      img = h[img_id]
    if show_plot == 'si':
      fig, ax = plt.subplots(figsize = (4,4))
      ax.imshow(Norm_img(img))
      if img_id < int(len(h)/2):
        class_h_ = 0
      else:
        class_h_ = 1
      ax.set(title = 'New index: '+str(img_id)+' :--: CLASS: '+str(class_h_))
    plt.show();
    return img

def train_val_test(train_hc,test_size=.2,show_val = 'no'):
    # Asignación de clases para los datos cargados
    class_aux =[]
    for j in class_h:
      class_aux.append(j*np.ones(int(len(train_hc)/2)).astype(int))
    class_aux = np.array(class_aux).reshape(1,len(train_hc))
    x_train_ori, x_test, y_train, y_test = train_test_split(train_hc, class_aux[0], test_size=test_size)
    x_train, x_val, y_train, y_val = train_test_split(x_train_ori, y_train, test_size=test_size)
    if show_val == 'si':
        print ('x_train, y_train:',x_train.shape, y_train.shape)
        print ('x_test, y_test:',x_test.shape, y_test.shape)
        print ('x_val, y_val:',x_val.shape, y_val.shape)
        print ("\n * Distribución de clases de train: ")
        print (pd.Series(y_train).value_counts())
        print ("\n * Distribución de clases de test: ")
        print (pd.Series(y_test).value_counts())
        print ("\n * Distribución de clases de val: ")
        print (pd.Series(y_val).value_counts())
    return x_train,y_train, x_val,y_val, x_test,y_test

def norm255 (imgs):
    imgs = tf.cast(imgs,tf.float32)
    imgs /= 255  # 0-255 --> 0-1
    return imgs

def norm255_mm_auto(imgs):
    imgs = tf.cast(imgs,tf.float32)
    imgs = (imgs-imgs.numpy().min())/(imgs.numpy().max()-imgs.numpy().min())
    return imgs

def norm255_mm_man(imgs,vmin,vmax):
    imgs = tf.cast(imgs,tf.float32)
    imgs = (imgs-vmin)/(vmax-vmin)
    return imgs

def Metr():
  return([ keras.metrics.AUC(name='AUC'), keras.metrics.AUC(name='PRC', curve='PR'), keras.metrics.Recall(name='RECALL'),
          keras.metrics.MeanSquaredError(name='Error Cuadrático Medio'), keras.metrics.TruePositives(name='Verdadero Positivo'),
          keras.metrics.FalsePositives(name='Falso Positivo'), keras.metrics.TrueNegatives(name='Verdadero Negativo'),
          keras.metrics.FalseNegatives(name='Falso Negativo'), keras.metrics.BinaryAccuracy(name='Accuracy'),
          keras.metrics.Precision(name='Precision')])

def bias_0(train_labels,print_desbal = 'si'):
    # Inicialización del BIAS
    neg, pos = np.bincount(train_labels['label']) # Desbalanceo de clases original
    total = neg + pos
    if print_desbal == 'si':
      print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(total, pos, 100 * pos / total))
    ini_bias = np.log([pos/neg])
    return ini_bias

def train(x_train, y_train,x_val, y_val,x_test,y_test,model, batch_size, epochs, model_name="",log_dir="logs/"):
    print('\n ::::::----- Inicio de Entrenamiento -----:::::: \n')
    # Generación de call-backs
    # early_stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='AUC',
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

    # tensorboard
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir=log_dir+model_name+"_"+"{}".format(time()))
    model.reset_states()
    base_hist = model.fit(x_train, y_train, epochs=epochs, callbacks=[tensorboard,early_stopping],
              batch_size=batch_size,
              validation_data=(x_val, y_val))
    metrics2 = model.evaluate(x_test, y_test)
    dict_results = {k:v for k,v in zip (model.metrics_names, metrics2)}
    print(dict_results)
    return base_hist, dict_results

def plot_metrics(hist,metrics,col=3):
    fig = plt.figure(figsize=(14,8))
    for n, metric in enumerate(metrics):
      ax = fig.add_subplot(int(len(metrics)/col), col, n+1)
      ax.plot(hist.epoch, hist.history[metric], color='b', label='Train')
      ax.plot(hist.epoch, hist.history['val_'+metric], color='r', linestyle="--", label='Val')
      ax.set_xlabel('Epoch')
      ax.set_ylabel(metric)
      ax.legend()

def conf_matrix(labels, preds, ax,thres=0.5):
    C = confusion_matrix(labels, preds > thres)
    # plt.figure(figsize=(3,3))
    # ax = fig.add_subplot(1, 2, 1)
    sns.heatmap(C, annot=True, fmt="d")
    ax.set_title('Matriz de Confusión -- Umbral: {:.2f}'.format(thres))
    ax.set_ylabel('Etiqueta real')
    ax.set_xlabel('Etiqueta predicha')
    print('\n')
    print('--> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS): ', C[0][0])
    print('--> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS): ', C[0][1])
    print('--> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS): ', C[1][0])
    print('--> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS): ', C[1][1])
    print('\n')

def ROC(name, labels, pred,ax, **kwargs):
    Fal_Pos, Ver_Pos, _ = sklearn.metrics.roc_curve(labels, pred)
    # ax = fig.add_subplot(1, 2, 2)
    ax.plot(100*Fal_Pos, 100*Ver_Pos, label=name, linewidth=2, **kwargs)
    plt.xlabel('Falsos Positivos [%]')
    plt.ylabel('Verdaderos Positivos [%]')
    plt.grid(True)
    plt.title('Curva ROC')

def medidas_AUC(model,base_hist,metrics,x_train,x_test,batch_size):
    plot_metrics(base_hist,metrics)
    # Evaluación de las métricas
    print('\n ...Calculando valores predichos para train y test: ...')
    y_train_predict = model.predict(x_train, batch_size=batch_size)
    y_test_predict = model.predict(x_test, batch_size=batch_size)

    Results = model.evaluate(x_test, y_test, batch_size=batch_size, verbose=0)
    print('\n ** Resultados de las métricas:...')
    for name, value in zip(model.metrics_names, Results):
      print(name, ': ', value)

    # fig, ax = plt.subplots(figsize = (12,4))
    fig = plt.figure(figsize=(12,4))

    ax = fig.add_subplot(1, 2, 1)
    # Matriz de confuxión
    conf_matrix(y_test, y_test_predict,ax)

    ax = fig.add_subplot(1, 2, 2)
    # Curva ROC
    ROC("Train ", y_train, y_train_predict,ax, color='b',marker='.')
    ROC("Test ", y_test, y_test_predict,ax, color='r', linestyle='--',marker='.')
    plt.legend(loc='best'); # 'lower right'

def apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir):
    display(model.summary())
    base_hist, dict_results = train(x_train, y_train,x_val, y_val,x_test,y_test,model, batch_size=batch_size,
                                    epochs=epochs, model_name=model_name,log_dir=log_dir)
    # Métricas y Gráficas
    metrics = ['AUC','loss', 'Precision', 'RECALL','Falso Positivo','Verdadero Positivo','Accuracy','Verdadero Negativo','Falso Negativo']
    medidas_AUC(model,base_hist,metrics,x_train,x_test,batch_size)

def model_A(img_size=96, compile=True,output_bias=None):

    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    # Capa convolucional: 15 filtros, de 3x3, padding="SAME" para que el tamaño de la salida sea el mismo que la entrada
    # layers = tf.keras.layers.Conv2D(16,(3,3), activation="relu", padding="SAME",name='Conv2D_1')(inputs)
    layers = tf.keras.layers.Conv2D(32,(3,3), activation="relu", padding="SAME",name='Conv2D_2')(inputs)
    layers = tf.keras.layers.Conv2D(64,(3,3), activation="relu", padding="SAME",name='Conv2D_3')(inputs)
    layers = tf.keras.layers.Conv2D(128,(3,3), activation="relu", padding="SAME",name='Conv2D_4')(layers)

    # Transición fully-conected, para que sea compatible con una densa
    layers = tf.keras.layers.Flatten()(layers)

    # Capas densas
    layers = tf.keras.layers.Dense(120, activation=tf.nn.relu,name='densa_1')(layers)
    layers = tf.keras.layers.Dense(24, activation=tf.nn.relu,name='densa_2')(layers)

    # Dropout
    layers = tf.keras.layers.Dropout(0.5)(layers)
    layers = tf.keras.layers.Dense(12, activation=tf.nn.relu,name='densa_3')(layers)
    predict= tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, name="output")(layers)  # tf.nn.softmax
    model = tf.keras.Model(inputs = inputs, outputs=predict)

    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(),metrics=Metr())
    return model

def model_B(img_size=96, compile=True,output_bias=None):

    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    # Capa convolucional: 15 filtros, de 3x3, padding="SAME" para que el tamaño de la salida sea el mismo que la entrada
    # layers = tf.keras.layers.Conv2D(16,(3,3), activation="relu", padding="SAME")(inputs)
    # layers = tf.keras.layers.MaxPooling2D(2,2)(layers)
    layers = tf.keras.layers.Conv2D(32,(3,3), activation="relu", padding="SAME")(inputs)
    layers = tf.keras.layers.MaxPooling2D(1,1)(layers)
    layers = tf.keras.layers.Conv2D(64,(3,3), activation="relu", padding="SAME")(layers)
    layers = tf.keras.layers.MaxPooling2D(1,1)(layers)
    layers = tf.keras.layers.Conv2D(128,(3,3), activation="relu", padding="SAME")(layers)

    # Dropout
    layers = tf.keras.layers.Dropout(0.5)(layers)

    # Transición fully-conected, para que sea compatible con una densa
    layers = tf.keras.layers.Flatten()(layers)

    # Capas densas
    layers = tf.keras.layers.Dense(120, activation=tf.nn.relu,name='densa_1')(layers)
    layers = tf.keras.layers.Dense(24, activation=tf.nn.relu,name='densa_2')(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    layers = tf.keras.layers.Dense(12, activation=tf.nn.relu,name='densa_3')(layers)

    predict= tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, name="output")(layers)  # tf.nn.softmax
    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(),metrics=Metr())
    return model

def model_C(img_size=96, compile=True,output_bias=None):
    from keras.applications.inception_v3 import InceptionV3

    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    inceptionv3 = InceptionV3(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = inceptionv3(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)

    # layers2 = tf.keras.layers.Conv2D(16,(3,3), activation="relu", padding="SAME")(inputs)
    # layers2 = tf.keras.layers.MaxPooling2D(1,1)(layers2)
    # layers2 = tf.keras.layers.Conv2D(32,(3,3), activation="relu", padding="SAME")(layers2)
    # layers2 = tf.keras.layers.MaxPooling2D(1,1)(layers2)
    # layers2 = tf.keras.layers.Conv2D(64,(3,3), activation="relu", padding="SAME")(layers2)
    # layers2 = tf.keras.layers.GlobalAveragePooling2D()(layers2)

    # layers = tf.keras.layers.Concatenate()([layers1 ,layers2])
    # layers = tf.keras.layers.GlobalMaxPooling2D()(layers)

    layers = tf.keras.layers.Dropout(0.5)(layers1)

    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam', loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

def model_D(img_size=96, compile=True,output_bias=None):
    from keras.applications.resnet50 import ResNet50
    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")

    rnet = ResNet50(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = rnet(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)

    layers = tf.keras.layers.Dropout(0.5)(layers1)
    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

def model_E(img_size=96, compile=True,output_bias=None):
    from keras.applications.xception import Xception
    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")
    xc = Xception(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = xc(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)
    layers = tf.keras.layers.Dropout(0.5)(layers1)
    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

def model_F(img_size=96, compile=True,output_bias=None):
    from keras.applications.resnet50 import ResNet50
    from keras.applications.xception import Xception
    tf.keras.backend.clear_session()
    print ("Clasificador Biclase")

    if output_bias is not None:
      output_bias = tf.keras.initializers.Constant(output_bias)

    # Capa de entrada, decimos que vamos a tener imagenes de 96x96x3
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input")
    nas_net = ResNet50(include_top=False, input_shape=(img_size,img_size,3))
    layers1 = rnet(inputs)
    layers1 = tf.keras.layers.GlobalAveragePooling2D()(layers1)
    xception = Xception(include_top=False, input_shape=(img_size,img_size,3))
    layers2 = xc(inputs)
    layers2 = tf.keras.layers.GlobalAveragePooling2D()(layers2)

    layers = tf.keras.layers.Concatenate(axis=-1)([layers1,layers2])
    layers = tf.keras.layers.Dense(120, activation='elu')(layers)
    layers = tf.keras.layers.Dense(10, activation='elu')(layers)
    predict = tf.keras.layers.Dense(1, activation='sigmoid')(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predict)
    model.compile(optimizer='adam',loss= tf.keras.losses.BinaryCrossentropy(), metrics=Metr())
    return model

# %%
train_hc, train_hc_central,train_labels = load_data()
class_h = train_labels['label'].unique()
num_class = len(class_h)
# Out:
# --2023-11-19 06:02:55--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_00.h5
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_00.h5 [following]
# --2023-11-19 06:02:55--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_00.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_00.h5’
#
# H_c0_00.h5          100%[===================>]  23.73M  --.-KB/s    in 0.1s
#
# 2023-11-19 06:02:56 (175 MB/s) - ‘H_c0_00.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:02:56--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_01.h5
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_01.h5 [following]
# --2023-11-19 06:02:56--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_01.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_01.h5’
#
# H_c0_01.h5          100%[===================>]  23.73M   116MB/s    in 0.2s
#
# 2023-11-19 06:02:57 (116 MB/s) - ‘H_c0_01.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:02:57--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_02.h5
# Resolving github.com (github.com)... 20.29.134.23
# Connecting to github.com (github.com)|20.29.134.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_02.h5 [following]
# --2023-11-19 06:02:57--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_02.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_02.h5’
#
# H_c0_02.h5          100%[===================>]  23.73M  83.2MB/s    in 0.3s
#
# 2023-11-19 06:02:58 (83.2 MB/s) - ‘H_c0_02.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:02:58--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_00.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_00.h5 [following]
# --2023-11-19 06:02:58--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_00.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_00.h5’
#
# H_c1_00.h5          100%[===================>]  23.73M   136MB/s    in 0.2s
#
# 2023-11-19 06:02:59 (136 MB/s) - ‘H_c1_00.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:00--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_01.h5
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_01.h5 [following]
# --2023-11-19 06:03:00--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_01.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_01.h5’
#
# H_c1_01.h5          100%[===================>]  23.73M  --.-KB/s    in 0.1s
#
# 2023-11-19 06:03:01 (195 MB/s) - ‘H_c1_01.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:01--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_02.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_02.h5 [following]
# --2023-11-19 06:03:01--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_02.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_02.h5’
#
# H_c1_02.h5          100%[===================>]  23.73M  --.-KB/s    in 0.1s
#
# 2023-11-19 06:03:02 (177 MB/s) - ‘H_c1_02.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:02--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_mod_00.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_mod_00.h5 [following]
# --2023-11-19 06:03:02--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_mod_00.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_mod_00.h5’
#
# H_c0_mod_00.h5      100%[===================>]  23.73M   127MB/s    in 0.2s
#
# 2023-11-19 06:03:03 (127 MB/s) - ‘H_c0_mod_00.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:03--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_mod_01.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_mod_01.h5 [following]
# --2023-11-19 06:03:03--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_mod_01.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_mod_01.h5’
#
# H_c0_mod_01.h5      100%[===================>]  23.73M   145MB/s    in 0.2s
#
# 2023-11-19 06:03:04 (145 MB/s) - ‘H_c0_mod_01.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:04--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c0_mod_02.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_mod_02.h5 [following]
# --2023-11-19 06:03:04--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c0_mod_02.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c0_mod_02.h5’
#
# H_c0_mod_02.h5      100%[===================>]  23.73M  --.-KB/s    in 0.1s
#
# 2023-11-19 06:03:05 (178 MB/s) - ‘H_c0_mod_02.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:05--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_mod_00.h5
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_mod_00.h5 [following]
# --2023-11-19 06:03:05--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_mod_00.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_mod_00.h5’
#
# H_c1_mod_00.h5      100%[===================>]  23.73M  --.-KB/s    in 0.1s
#
# 2023-11-19 06:03:06 (169 MB/s) - ‘H_c1_mod_00.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:06--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_mod_01.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_mod_01.h5 [following]
# --2023-11-19 06:03:06--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_mod_01.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_mod_01.h5’
#
# H_c1_mod_01.h5      100%[===================>]  23.73M  --.-KB/s    in 0.1s
#
# 2023-11-19 06:03:07 (174 MB/s) - ‘H_c1_mod_01.h5’ saved [24885248/24885248]
#
# --2023-11-19 06:03:07--  https://github.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/raw/main/data/H_c1_mod_02.h5
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_mod_02.h5 [following]
# --2023-11-19 06:03:07--  https://raw.githubusercontent.com/DanielMartinez0/Proyecto_Deteccion_histopatologica_del_cancer/main/data/H_c1_mod_02.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24885248 (24M) [application/octet-stream]
# Saving to: ‘H_c1_mod_02.h5’
#
# H_c1_mod_02.h5      100%[===================>]  23.73M   129MB/s    in 0.2s
#
# 2023-11-19 06:03:08 (129 MB/s) - ‘H_c1_mod_02.h5’ saved [24885248/24885248]

# %%
show_mosaic_id(train_hc,class_h)

# %%
show_mosaic_id(train_hc_central,class_h)

# %%
train_hc.shape, train_hc_central.shape
# Out:
# ((5400, 96, 96, 3), (5400, 96, 96, 3))

# %%
x_train,y_train, x_val,y_val, x_test,y_test = train_val_test(train_hc) #,test_size=.25)
x_train_cen,y_train_cen, x_val_cen,y_val_cen, x_test_cen,y_test_cen = train_val_test(train_hc_central) #,test_size=.25)

x_train = np.r_[x_train,x_train_cen] # Aumentamos los datos de entrenamiento
y_train = np.r_[y_train,y_train_cen]

x_train = norm255_mm_auto(x_train)
x_val  = norm255_mm_auto(x_val)
x_test  = norm255_mm_auto(x_test)
x_train.shape, x_val.shape, x_test.shape
# Out:
# (TensorShape([6912, 96, 96, 3]),
#  TensorShape([864, 96, 96, 3]),
#  TensorShape([1080, 96, 96, 3]))

# %% [markdown]
# #### ***Model-A***:  $~~~3 \times $*`Conv2D`*+ $1\times $*`Dropout(0.5)`*+ $3\times $*`Denses`*

# %%
log_dir="logs/v0/"
batch_size=32
epochs=50

model_name="model_A"
model = model_A(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias
apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  Conv2D_3 (Conv2D)           (None, 96, 96, 64)        1792
#
#  Conv2D_4 (Conv2D)           (None, 96, 96, 128)       73856
#
#  flatten (Flatten)           (None, 1179648)           0
#
#  densa_1 (Dense)             (None, 120)               141557880
#
#  densa_2 (Dense)             (None, 24)                2904
#
#  dropout (Dropout)           (None, 24)                0
#
#  densa_3 (Dense)             (None, 12)                300
#
#  output (Dense)              (None, 1)                 13
#
# =================================================================
# Total params: 141636745 (540.30 MB)
# Trainable params: 141636745 (540.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 216/216 [==============================] - 35s 88ms/step - loss: 0.5943 - AUC: 0.8347 - PRC: 0.8473 - RECALL: 0.7299 - Error Cuadrático Medio: 0.1645 - Verdadero Positivo: 2537.0000 - Falso Positivo: 899.0000 - Verdadero Negativo: 2537.0000 - Falso Negativo: 939.0000 - Accuracy: 0.7341 - Precision: 0.7384 - val_loss: 0.6277 - val_AUC: 0.7666 - val_PRC: 0.7251 - val_RECALL: 0.8315 - val_Error Cuadrático Medio: 0.2136 - val_Verdadero Positivo: 375.0000 - val_Falso Positivo: 159.0000 - val_Verdadero Negativo: 254.0000 - val_Falso Negativo: 76.0000 - val_Accuracy: 0.7280 - val_Precision: 0.7022
# Epoch 2/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.3579 - AUC: 0.9058 - PRC: 0.9134 - RECALL: 0.7135 - Error Cuadrático Medio: 0.1220 - Verdadero Positivo: 2480.0000 - Falso Positivo: 496.0000 - Verdadero Negativo: 2940.0000 - Falso Negativo: 996.0000 - Accuracy: 0.7841 - Precision: 0.8333 - val_loss: 0.5972 - val_AUC: 0.7982 - val_PRC: 0.7865 - val_RECALL: 0.8271 - val_Error Cuadrático Medio: 0.2037 - val_Verdadero Positivo: 373.0000 - val_Falso Positivo: 167.0000 - val_Verdadero Negativo: 246.0000 - val_Falso Negativo: 78.0000 - val_Accuracy: 0.7164 - val_Precision: 0.6907
# Epoch 3/50
# 216/216 [==============================] - 18s 83ms/step - loss: 0.3515 - AUC: 0.9089 - PRC: 0.9145 - RECALL: 0.6913 - Error Cuadrático Medio: 0.1193 - Verdadero Positivo: 2403.0000 - Falso Positivo: 449.0000 - Verdadero Negativo: 2987.0000 - Falso Negativo: 1073.0000 - Accuracy: 0.7798 - Precision: 0.8426 - val_loss: 0.6257 - val_AUC: 0.7634 - val_PRC: 0.7390 - val_RECALL: 0.6275 - val_Error Cuadrático Medio: 0.2075 - val_Verdadero Positivo: 283.0000 - val_Falso Positivo: 99.0000 - val_Verdadero Negativo: 314.0000 - val_Falso Negativo: 168.0000 - val_Accuracy: 0.6910 - val_Precision: 0.7408
# Epoch 4/50
# 216/216 [==============================] - 17s 81ms/step - loss: 0.2954 - AUC: 0.9379 - PRC: 0.9408 - RECALL: 0.8116 - Error Cuadrático Medio: 0.0984 - Verdadero Positivo: 2821.0000 - Falso Positivo: 531.0000 - Verdadero Negativo: 2905.0000 - Falso Negativo: 655.0000 - Accuracy: 0.8284 - Precision: 0.8416 - val_loss: 0.5990 - val_AUC: 0.7612 - val_PRC: 0.7542 - val_RECALL: 0.9379 - val_Error Cuadrático Medio: 0.2072 - val_Verdadero Positivo: 423.0000 - val_Falso Positivo: 274.0000 - val_Verdadero Negativo: 139.0000 - val_Falso Negativo: 28.0000 - val_Accuracy: 0.6505 - val_Precision: 0.6069
# Epoch 5/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.2689 - AUC: 0.9513 - PRC: 0.9517 - RECALL: 0.9344 - Error Cuadrático Medio: 0.0886 - Verdadero Positivo: 3248.0000 - Falso Positivo: 641.0000 - Verdadero Negativo: 2795.0000 - Falso Negativo: 228.0000 - Accuracy: 0.8743 - Precision: 0.8352 - val_loss: 1.0969 - val_AUC: 0.7554 - val_PRC: 0.7280 - val_RECALL: 0.5211 - val_Error Cuadrático Medio: 0.2729 - val_Verdadero Positivo: 235.0000 - val_Falso Positivo: 81.0000 - val_Verdadero Negativo: 332.0000 - val_Falso Negativo: 216.0000 - val_Accuracy: 0.6562 - val_Precision: 0.7437
# Epoch 6/50
# 216/216 [==============================] - 18s 81ms/step - loss: 0.2398 - AUC: 0.9612 - PRC: 0.9604 - RECALL: 0.9557 - Error Cuadrático Medio: 0.0768 - Verdadero Positivo: 3322.0000 - Falso Positivo: 584.0000 - Verdadero Negativo: 2852.0000 - Falso Negativo: 154.0000 - Accuracy: 0.8932 - Precision: 0.8505 - val_loss: 0.7323 - val_AUC: 0.7830 - val_PRC: 0.7646 - val_RECALL: 0.7007 - val_Error Cuadrático Medio: 0.2161 - val_Verdadero Positivo: 316.0000 - val_Falso Positivo: 118.0000 - val_Verdadero Negativo: 295.0000 - val_Falso Negativo: 135.0000 - val_Accuracy: 0.7072 - val_Precision: 0.7281
# Epoch 7/50
# 216/216 [==============================] - 18s 81ms/step - loss: 0.1914 - AUC: 0.9754 - PRC: 0.9747 - RECALL: 0.9612 - Error Cuadrático Medio: 0.0607 - Verdadero Positivo: 3341.0000 - Falso Positivo: 438.0000 - Verdadero Negativo: 2998.0000 - Falso Negativo: 135.0000 - Accuracy: 0.9171 - Precision: 0.8841 - val_loss: 0.6487 - val_AUC: 0.7872 - val_PRC: 0.7569 - val_RECALL: 0.8293 - val_Error Cuadrático Medio: 0.1989 - val_Verdadero Positivo: 374.0000 - val_Falso Positivo: 166.0000 - val_Verdadero Negativo: 247.0000 - val_Falso Negativo: 77.0000 - val_Accuracy: 0.7188 - val_Precision: 0.6926
# Epoch 8/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.1540 - AUC: 0.9849 - PRC: 0.9850 - RECALL: 0.9712 - Error Cuadrático Medio: 0.0473 - Verdadero Positivo: 3376.0000 - Falso Positivo: 365.0000 - Verdadero Negativo: 3071.0000 - Falso Negativo: 100.0000 - Accuracy: 0.9327 - Precision: 0.9024 - val_loss: 1.0027 - val_AUC: 0.7870 - val_PRC: 0.7855 - val_RECALL: 0.7805 - val_Error Cuadrático Medio: 0.2319 - val_Verdadero Positivo: 352.0000 - val_Falso Positivo: 145.0000 - val_Verdadero Negativo: 268.0000 - val_Falso Negativo: 99.0000 - val_Accuracy: 0.7176 - val_Precision: 0.7082
# Epoch 9/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.1216 - AUC: 0.9909 - PRC: 0.9908 - RECALL: 0.9747 - Error Cuadrático Medio: 0.0370 - Verdadero Positivo: 3388.0000 - Falso Positivo: 312.0000 - Verdadero Negativo: 3124.0000 - Falso Negativo: 88.0000 - Accuracy: 0.9421 - Precision: 0.9157 - val_loss: 1.0698 - val_AUC: 0.7209 - val_PRC: 0.6863 - val_RECALL: 0.7295 - val_Error Cuadrático Medio: 0.2684 - val_Verdadero Positivo: 329.0000 - val_Falso Positivo: 166.0000 - val_Verdadero Negativo: 247.0000 - val_Falso Negativo: 122.0000 - val_Accuracy: 0.6667 - val_Precision: 0.6646
# Epoch 10/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.0800 - AUC: 0.9956 - PRC: 0.9950 - RECALL: 0.9813 - Error Cuadrático Medio: 0.0227 - Verdadero Positivo: 3411.0000 - Falso Positivo: 167.0000 - Verdadero Negativo: 3269.0000 - Falso Negativo: 65.0000 - Accuracy: 0.9664 - Precision: 0.9533 - val_loss: 1.7198 - val_AUC: 0.7505 - val_PRC: 0.7314 - val_RECALL: 0.5565 - val_Error Cuadrático Medio: 0.2754 - val_Verdadero Positivo: 251.0000 - val_Falso Positivo: 79.0000 - val_Verdadero Negativo: 334.0000 - val_Falso Negativo: 200.0000 - val_Accuracy: 0.6771 - val_Precision: 0.7606
# Epoch 11/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.0450 - AUC: 0.9986 - PRC: 0.9988 - RECALL: 0.9905 - Error Cuadrático Medio: 0.0119 - Verdadero Positivo: 3443.0000 - Falso Positivo: 72.0000 - Verdadero Negativo: 3364.0000 - Falso Negativo: 33.0000 - Accuracy: 0.9848 - Precision: 0.9795 - val_loss: 1.9169 - val_AUC: 0.7433 - val_PRC: 0.7248 - val_RECALL: 0.5610 - val_Error Cuadrático Medio: 0.2831 - val_Verdadero Positivo: 253.0000 - val_Falso Positivo: 80.0000 - val_Verdadero Negativo: 333.0000 - val_Falso Negativo: 198.0000 - val_Accuracy: 0.6782 - val_Precision: 0.7598
# Epoch 12/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0464 - AUC: 0.9983 - PRC: 0.9980 - RECALL: 0.9850 - Error Cuadrático Medio: 0.0120 - Verdadero Positivo: 3424.0000 - Falso Positivo: 49.0000 - Verdadero Negativo: 3387.0000 - Falso Negativo: 52.0000 - Accuracy: 0.9854 - Precision: 0.9859 - val_loss: 2.0529 - val_AUC: 0.7340 - val_PRC: 0.7209 - val_RECALL: 0.5920 - val_Error Cuadrático Medio: 0.2817 - val_Verdadero Positivo: 267.0000 - val_Falso Positivo: 93.0000 - val_Verdadero Negativo: 320.0000 - val_Falso Negativo: 184.0000 - val_Accuracy: 0.6794 - val_Precision: 0.7417
# Epoch 13/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.0221 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0057 - Verdadero Positivo: 3455.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9942 - Precision: 0.9945 - val_loss: 2.5112 - val_AUC: 0.7392 - val_PRC: 0.7254 - val_RECALL: 0.6231 - val_Error Cuadrático Medio: 0.2841 - val_Verdadero Positivo: 281.0000 - val_Falso Positivo: 95.0000 - val_Verdadero Negativo: 318.0000 - val_Falso Negativo: 170.0000 - val_Accuracy: 0.6933 - val_Precision: 0.7473
# Epoch 14/50
# 216/216 [==============================] - 18s 81ms/step - loss: 0.0174 - AUC: 0.9997 - PRC: 0.9998 - RECALL: 0.9945 - Error Cuadrático Medio: 0.0048 - Verdadero Positivo: 3457.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 3425.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9957 - Precision: 0.9968 - val_loss: 2.5111 - val_AUC: 0.7373 - val_PRC: 0.7108 - val_RECALL: 0.6696 - val_Error Cuadrático Medio: 0.2824 - val_Verdadero Positivo: 302.0000 - val_Falso Positivo: 119.0000 - val_Verdadero Negativo: 294.0000 - val_Falso Negativo: 149.0000 - val_Accuracy: 0.6898 - val_Precision: 0.7173
# Epoch 15/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0371 - AUC: 0.9985 - PRC: 0.9983 - RECALL: 0.9896 - Error Cuadrático Medio: 0.0082 - Verdadero Positivo: 3440.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 3418.0000 - Falso Negativo: 36.0000 - Accuracy: 0.9922 - Precision: 0.9948 - val_loss: 2.0841 - val_AUC: 0.7363 - val_PRC: 0.7080 - val_RECALL: 0.6630 - val_Error Cuadrático Medio: 0.2718 - val_Verdadero Positivo: 299.0000 - val_Falso Positivo: 108.0000 - val_Verdadero Negativo: 305.0000 - val_Falso Negativo: 152.0000 - val_Accuracy: 0.6991 - val_Precision: 0.7346
# Epoch 16/50
# 216/216 [==============================] - 17s 78ms/step - loss: 0.0287 - AUC: 0.9991 - PRC: 0.9986 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0069 - Verdadero Positivo: 3448.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 3415.0000 - Falso Negativo: 28.0000 - Accuracy: 0.9929 - Precision: 0.9939 - val_loss: 1.7735 - val_AUC: 0.6590 - val_PRC: 0.6225 - val_RECALL: 0.7650 - val_Error Cuadrático Medio: 0.3117 - val_Verdadero Positivo: 345.0000 - val_Falso Positivo: 202.0000 - val_Verdadero Negativo: 211.0000 - val_Falso Negativo: 106.0000 - val_Accuracy: 0.6435 - val_Precision: 0.6307
# Epoch 17/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.0171 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0048 - Verdadero Positivo: 3450.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9945 - Precision: 0.9965 - val_loss: 2.3878 - val_AUC: 0.7396 - val_PRC: 0.7241 - val_RECALL: 0.6519 - val_Error Cuadrático Medio: 0.2728 - val_Verdadero Positivo: 294.0000 - val_Falso Positivo: 102.0000 - val_Verdadero Negativo: 311.0000 - val_Falso Negativo: 157.0000 - val_Accuracy: 0.7002 - val_Precision: 0.7424
# Epoch 18/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0132 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0036 - Verdadero Positivo: 3458.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9961 - Precision: 0.9974 - val_loss: 3.3237 - val_AUC: 0.7125 - val_PRC: 0.6802 - val_RECALL: 0.7871 - val_Error Cuadrático Medio: 0.2936 - val_Verdadero Positivo: 355.0000 - val_Falso Positivo: 171.0000 - val_Verdadero Negativo: 242.0000 - val_Falso Negativo: 96.0000 - val_Accuracy: 0.6910 - val_Precision: 0.6749
# Epoch 19/50
# 216/216 [==============================] - 18s 82ms/step - loss: 0.0110 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0031 - Verdadero Positivo: 3458.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9961 - Precision: 0.9974 - val_loss: 2.1123 - val_AUC: 0.6952 - val_PRC: 0.6717 - val_RECALL: 0.6984 - val_Error Cuadrático Medio: 0.2919 - val_Verdadero Positivo: 315.0000 - val_Falso Positivo: 144.0000 - val_Verdadero Negativo: 269.0000 - val_Falso Negativo: 136.0000 - val_Accuracy: 0.6759 - val_Precision: 0.6863
# Epoch 20/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0102 - AUC: 0.9998 - PRC: 0.9996 - RECALL: 0.9968 - Error Cuadrático Medio: 0.0027 - Verdadero Positivo: 3465.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9973 - Precision: 0.9977 - val_loss: 3.3200 - val_AUC: 0.7363 - val_PRC: 0.7179 - val_RECALL: 0.6186 - val_Error Cuadrático Medio: 0.2820 - val_Verdadero Positivo: 279.0000 - val_Falso Positivo: 93.0000 - val_Verdadero Negativo: 320.0000 - val_Falso Negativo: 172.0000 - val_Accuracy: 0.6933 - val_Precision: 0.7500
# Epoch 21/50
# 216/216 [==============================] - 17s 78ms/step - loss: 0.0105 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9951 - Error Cuadrático Medio: 0.0026 - Verdadero Positivo: 3459.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 3430.0000 - Falso Negativo: 17.0000 - Accuracy: 0.9967 - Precision: 0.9983 - val_loss: 2.7772 - val_AUC: 0.7343 - val_PRC: 0.7059 - val_RECALL: 0.6652 - val_Error Cuadrático Medio: 0.2823 - val_Verdadero Positivo: 300.0000 - val_Falso Positivo: 112.0000 - val_Verdadero Negativo: 301.0000 - val_Falso Negativo: 151.0000 - val_Accuracy: 0.6956 - val_Precision: 0.7282
# Epoch 22/50
# 216/216 [==============================] - 17s 80ms/step - loss: 0.1107 - AUC: 0.9921 - PRC: 0.9917 - RECALL: 0.9554 - Error Cuadrático Medio: 0.0312 - Verdadero Positivo: 3321.0000 - Falso Positivo: 133.0000 - Verdadero Negativo: 3303.0000 - Falso Negativo: 155.0000 - Accuracy: 0.9583 - Precision: 0.9615 - val_loss: 2.0229 - val_AUC: 0.6562 - val_PRC: 0.6192 - val_RECALL: 0.6674 - val_Error Cuadrático Medio: 0.3002 - val_Verdadero Positivo: 301.0000 - val_Falso Positivo: 149.0000 - val_Verdadero Negativo: 264.0000 - val_Falso Negativo: 150.0000 - val_Accuracy: 0.6539 - val_Precision: 0.6689
# Epoch 23/50
# 216/216 [==============================] - 17s 80ms/step - loss: 0.0585 - AUC: 0.9977 - PRC: 0.9975 - RECALL: 0.9827 - Error Cuadrático Medio: 0.0151 - Verdadero Positivo: 3416.0000 - Falso Positivo: 61.0000 - Verdadero Negativo: 3375.0000 - Falso Negativo: 60.0000 - Accuracy: 0.9825 - Precision: 0.9825 - val_loss: 3.3017 - val_AUC: 0.7022 - val_PRC: 0.6965 - val_RECALL: 0.5987 - val_Error Cuadrático Medio: 0.2928 - val_Verdadero Positivo: 270.0000 - val_Falso Positivo: 93.0000 - val_Verdadero Negativo: 320.0000 - val_Falso Negativo: 181.0000 - val_Accuracy: 0.6829 - val_Precision: 0.7438
# Epoch 24/50
# 216/216 [==============================] - 17s 78ms/step - loss: 0.0220 - AUC: 0.9990 - PRC: 0.9989 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0044 - Verdadero Positivo: 3455.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 3423.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9951 - Precision: 0.9963 - val_loss: 4.9878 - val_AUC: 0.6807 - val_PRC: 0.7043 - val_RECALL: 0.4501 - val_Error Cuadrático Medio: 0.3324 - val_Verdadero Positivo: 203.0000 - val_Falso Positivo: 64.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 248.0000 - val_Accuracy: 0.6389 - val_Precision: 0.7603
# Epoch 25/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0234 - AUC: 0.9989 - PRC: 0.9988 - RECALL: 0.9922 - Error Cuadrático Medio: 0.0054 - Verdadero Positivo: 3449.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 3423.0000 - Falso Negativo: 27.0000 - Accuracy: 0.9942 - Precision: 0.9962 - val_loss: 3.3829 - val_AUC: 0.6612 - val_PRC: 0.6470 - val_RECALL: 0.6408 - val_Error Cuadrático Medio: 0.3248 - val_Verdadero Positivo: 289.0000 - val_Falso Positivo: 145.0000 - val_Verdadero Negativo: 268.0000 - val_Falso Negativo: 162.0000 - val_Accuracy: 0.6447 - val_Precision: 0.6659
# Epoch 26/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0127 - AUC: 0.9996 - PRC: 0.9995 - RECALL: 0.9957 - Error Cuadrático Medio: 0.0031 - Verdadero Positivo: 3461.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9965 - Precision: 0.9974 - val_loss: 3.8614 - val_AUC: 0.7213 - val_PRC: 0.7025 - val_RECALL: 0.6940 - val_Error Cuadrático Medio: 0.2892 - val_Verdadero Positivo: 313.0000 - val_Falso Positivo: 125.0000 - val_Verdadero Negativo: 288.0000 - val_Falso Negativo: 138.0000 - val_Accuracy: 0.6956 - val_Precision: 0.7146
# Epoch 27/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0408 - AUC: 0.9980 - PRC: 0.9970 - RECALL: 0.9862 - Error Cuadrático Medio: 0.0076 - Verdadero Positivo: 3428.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 3419.0000 - Falso Negativo: 48.0000 - Accuracy: 0.9906 - Precision: 0.9951 - val_loss: 1.6806 - val_AUC: 0.6414 - val_PRC: 0.6190 - val_RECALL: 0.5654 - val_Error Cuadrático Medio: 0.3151 - val_Verdadero Positivo: 255.0000 - val_Falso Positivo: 139.0000 - val_Verdadero Negativo: 274.0000 - val_Falso Negativo: 196.0000 - val_Accuracy: 0.6123 - val_Precision: 0.6472
# Epoch 28/50
# 216/216 [==============================] - 17s 79ms/step - loss: 0.0316 - AUC: 0.9992 - PRC: 0.9991 - RECALL: 0.9868 - Error Cuadrático Medio: 0.0085 - Verdadero Positivo: 3430.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 46.0000 - Accuracy: 0.9896 - Precision: 0.9925 - val_loss: 3.9571 - val_AUC: 0.7106 - val_PRC: 0.7004 - val_RECALL: 0.6164 - val_Error Cuadrático Medio: 0.2966 - val_Verdadero Positivo: 278.0000 - val_Falso Positivo: 104.0000 - val_Verdadero Negativo: 309.0000 - val_Falso Negativo: 173.0000 - val_Accuracy: 0.6794 - val_Precision: 0.7277
# Epoch 29/50
# 216/216 [==============================] - ETA: 0s - loss: 0.1068 - AUC: 0.9964 - PRC: 0.9948 - RECALL: 0.9865 - Error Cuadrático Medio: 0.0087 - Verdadero Positivo: 3429.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 3408.0000 - Falso Negativo: 47.0000 - Accuracy: 0.9891 - Precision: 0.9919Restoring model weights from the end of the best epoch: 19.
# 216/216 [==============================] - 18s 83ms/step - loss: 0.1068 - AUC: 0.9964 - PRC: 0.9948 - RECALL: 0.9865 - Error Cuadrático Medio: 0.0087 - Verdadero Positivo: 3429.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 3408.0000 - Falso Negativo: 47.0000 - Accuracy: 0.9891 - Precision: 0.9919 - val_loss: 2.2042 - val_AUC: 0.6381 - val_PRC: 0.6172 - val_RECALL: 0.3991 - val_Error Cuadrático Medio: 0.3118 - val_Verdadero Positivo: 180.0000 - val_Falso Positivo: 103.0000 - val_Verdadero Negativo: 310.0000 - val_Falso Negativo: 271.0000 - val_Accuracy: 0.5671 - val_Precision: 0.6360
# Epoch 29: early stopping
# 34/34 [==============================] - 2s 28ms/step - loss: 1.9357 - AUC: 0.7196 - PRC: 0.6661 - RECALL: 0.7008 - Error Cuadrático Medio: 0.2842 - Verdadero Positivo: 370.0000 - Falso Positivo: 185.0000 - Verdadero Negativo: 367.0000 - Falso Negativo: 158.0000 - Accuracy: 0.6824 - Precision: 0.6667
# {'loss': 1.9357028007507324, 'AUC': 0.7195889353752136, 'PRC': 0.6660863161087036, 'RECALL': 0.7007575631141663, 'Error Cuadrático Medio': 0.28420522809028625, 'Verdadero Positivo': 370.0, 'Falso Positivo': 185.0, 'Verdadero Negativo': 367.0, 'Falso Negativo': 158.0, 'Accuracy': 0.6824073791503906, 'Precision': 0.6666666865348816}
#
#  ...Calculando valores predichos para train y test: ...
# 216/216 [==============================] - 3s 14ms/step
# 34/34 [==============================] - 1s 15ms/step
#
#  ** Resultados de las métricas:...
# loss :  1.9357028007507324
# AUC :  0.7195889353752136
# PRC :  0.6660863161087036
# RECALL :  0.7007575631141663
# Error Cuadrático Medio :  0.28420522809028625
# Verdadero Positivo :  370.0
# Falso Positivo :  185.0
# Verdadero Negativo :  367.0
# Falso Negativo :  158.0
# Accuracy :  0.6824073791503906
# Precision :  0.6666666865348816
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  367
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  185
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  158
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  370

# %% [markdown]
# #### ***Model-B***:  $~~~3 \times $*`Conv2D`*+$2\times $*`MaxPooling2D`*+$2\times $*`Dropout(0.5-0.2)`*+$3\times $*`Denses`*

# %%
model_name="model_B"
model = model_B(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias
apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  conv2d (Conv2D)             (None, 96, 96, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 96, 96, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 96, 96, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  dropout (Dropout)           (None, 96, 96, 128)       0
#
#  flatten (Flatten)           (None, 1179648)           0
#
#  densa_1 (Dense)             (None, 120)               141557880
#
#  densa_2 (Dense)             (None, 24)                2904
#
#  dropout_1 (Dropout)         (None, 24)                0
#
#  densa_3 (Dense)             (None, 12)                300
#
#  output (Dense)              (None, 1)                 13
#
# =================================================================
# Total params: 141654345 (540.37 MB)
# Trainable params: 141654345 (540.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 216/216 [==============================] - 32s 131ms/step - loss: 0.4406 - AUC: 0.9043 - PRC: 0.9062 - RECALL: 0.8257 - Error Cuadrático Medio: 0.1249 - Verdadero Positivo: 2870.0000 - Falso Positivo: 653.0000 - Verdadero Negativo: 2783.0000 - Falso Negativo: 606.0000 - Accuracy: 0.8179 - Precision: 0.8146 - val_loss: 0.5953 - val_AUC: 0.7807 - val_PRC: 0.7855 - val_RECALL: 0.8115 - val_Error Cuadrático Medio: 0.1968 - val_Verdadero Positivo: 366.0000 - val_Falso Positivo: 172.0000 - val_Verdadero Negativo: 241.0000 - val_Falso Negativo: 85.0000 - val_Accuracy: 0.7025 - val_Precision: 0.6803
# Epoch 2/50
# 216/216 [==============================] - 26s 122ms/step - loss: 0.2743 - AUC: 0.9522 - PRC: 0.9550 - RECALL: 0.8789 - Error Cuadrático Medio: 0.0887 - Verdadero Positivo: 3055.0000 - Falso Positivo: 437.0000 - Verdadero Negativo: 2999.0000 - Falso Negativo: 421.0000 - Accuracy: 0.8759 - Precision: 0.8749 - val_loss: 0.5525 - val_AUC: 0.8103 - val_PRC: 0.8057 - val_RECALL: 0.7184 - val_Error Cuadrático Medio: 0.1826 - val_Verdadero Positivo: 324.0000 - val_Falso Positivo: 104.0000 - val_Verdadero Negativo: 309.0000 - val_Falso Negativo: 127.0000 - val_Accuracy: 0.7326 - val_Precision: 0.7570
# Epoch 3/50
# 216/216 [==============================] - 26s 123ms/step - loss: 0.2322 - AUC: 0.9662 - PRC: 0.9676 - RECALL: 0.9120 - Error Cuadrático Medio: 0.0735 - Verdadero Positivo: 3170.0000 - Falso Positivo: 392.0000 - Verdadero Negativo: 3044.0000 - Falso Negativo: 306.0000 - Accuracy: 0.8990 - Precision: 0.8899 - val_loss: 0.5527 - val_AUC: 0.8045 - val_PRC: 0.7958 - val_RECALL: 0.7761 - val_Error Cuadrático Medio: 0.1816 - val_Verdadero Positivo: 350.0000 - val_Falso Positivo: 119.0000 - val_Verdadero Negativo: 294.0000 - val_Falso Negativo: 101.0000 - val_Accuracy: 0.7454 - val_Precision: 0.7463
# Epoch 4/50
# 216/216 [==============================] - 26s 122ms/step - loss: 0.1668 - AUC: 0.9828 - PRC: 0.9827 - RECALL: 0.9428 - Error Cuadrático Medio: 0.0504 - Verdadero Positivo: 3277.0000 - Falso Positivo: 263.0000 - Verdadero Negativo: 3173.0000 - Falso Negativo: 199.0000 - Accuracy: 0.9332 - Precision: 0.9257 - val_loss: 0.7043 - val_AUC: 0.8149 - val_PRC: 0.8158 - val_RECALL: 0.8891 - val_Error Cuadrático Medio: 0.2227 - val_Verdadero Positivo: 401.0000 - val_Falso Positivo: 212.0000 - val_Verdadero Negativo: 201.0000 - val_Falso Negativo: 50.0000 - val_Accuracy: 0.6968 - val_Precision: 0.6542
# Epoch 5/50
# 216/216 [==============================] - 26s 122ms/step - loss: 0.0926 - AUC: 0.9945 - PRC: 0.9947 - RECALL: 0.9692 - Error Cuadrático Medio: 0.0267 - Verdadero Positivo: 3369.0000 - Falso Positivo: 131.0000 - Verdadero Negativo: 3305.0000 - Falso Negativo: 107.0000 - Accuracy: 0.9656 - Precision: 0.9626 - val_loss: 0.8885 - val_AUC: 0.7779 - val_PRC: 0.7518 - val_RECALL: 0.7140 - val_Error Cuadrático Medio: 0.2223 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 109.0000 - val_Verdadero Negativo: 304.0000 - val_Falso Negativo: 129.0000 - val_Accuracy: 0.7245 - val_Precision: 0.7471
# Epoch 6/50
# 216/216 [==============================] - 26s 123ms/step - loss: 0.0729 - AUC: 0.9961 - PRC: 0.9959 - RECALL: 0.9764 - Error Cuadrático Medio: 0.0197 - Verdadero Positivo: 3394.0000 - Falso Positivo: 82.0000 - Verdadero Negativo: 3354.0000 - Falso Negativo: 82.0000 - Accuracy: 0.9763 - Precision: 0.9764 - val_loss: 0.9121 - val_AUC: 0.7591 - val_PRC: 0.7403 - val_RECALL: 0.7672 - val_Error Cuadrático Medio: 0.2382 - val_Verdadero Positivo: 346.0000 - val_Falso Positivo: 149.0000 - val_Verdadero Negativo: 264.0000 - val_Falso Negativo: 105.0000 - val_Accuracy: 0.7060 - val_Precision: 0.6990
# Epoch 7/50
# 216/216 [==============================] - 26s 122ms/step - loss: 0.0404 - AUC: 0.9985 - PRC: 0.9987 - RECALL: 0.9868 - Error Cuadrático Medio: 0.0102 - Verdadero Positivo: 3430.0000 - Falso Positivo: 45.0000 - Verdadero Negativo: 3391.0000 - Falso Negativo: 46.0000 - Accuracy: 0.9868 - Precision: 0.9871 - val_loss: 1.2716 - val_AUC: 0.7972 - val_PRC: 0.8111 - val_RECALL: 0.7228 - val_Error Cuadrático Medio: 0.2295 - val_Verdadero Positivo: 326.0000 - val_Falso Positivo: 105.0000 - val_Verdadero Negativo: 308.0000 - val_Falso Negativo: 125.0000 - val_Accuracy: 0.7338 - val_Precision: 0.7564
# Epoch 8/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0381 - AUC: 0.9981 - PRC: 0.9976 - RECALL: 0.9894 - Error Cuadrático Medio: 0.0092 - Verdadero Positivo: 3439.0000 - Falso Positivo: 46.0000 - Verdadero Negativo: 3390.0000 - Falso Negativo: 37.0000 - Accuracy: 0.9880 - Precision: 0.9868 - val_loss: 1.3875 - val_AUC: 0.7842 - val_PRC: 0.7997 - val_RECALL: 0.6608 - val_Error Cuadrático Medio: 0.2351 - val_Verdadero Positivo: 298.0000 - val_Falso Positivo: 76.0000 - val_Verdadero Negativo: 337.0000 - val_Falso Negativo: 153.0000 - val_Accuracy: 0.7350 - val_Precision: 0.7968
# Epoch 9/50
# 216/216 [==============================] - 27s 123ms/step - loss: 0.0205 - AUC: 0.9996 - PRC: 0.9996 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0053 - Verdadero Positivo: 3451.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 3414.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9932 - Precision: 0.9937 - val_loss: 1.4581 - val_AUC: 0.8021 - val_PRC: 0.8102 - val_RECALL: 0.7273 - val_Error Cuadrático Medio: 0.2255 - val_Verdadero Positivo: 328.0000 - val_Falso Positivo: 98.0000 - val_Verdadero Negativo: 315.0000 - val_Falso Negativo: 123.0000 - val_Accuracy: 0.7442 - val_Precision: 0.7700
# Epoch 10/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0134 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0032 - Verdadero Positivo: 3458.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9957 - Precision: 0.9965 - val_loss: 1.4857 - val_AUC: 0.7844 - val_PRC: 0.7572 - val_RECALL: 0.8404 - val_Error Cuadrático Medio: 0.2572 - val_Verdadero Positivo: 379.0000 - val_Falso Positivo: 174.0000 - val_Verdadero Negativo: 239.0000 - val_Falso Negativo: 72.0000 - val_Accuracy: 0.7153 - val_Precision: 0.6854
# Epoch 11/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0230 - AUC: 0.9992 - PRC: 0.9992 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0060 - Verdadero Positivo: 3450.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9925 - Precision: 0.9925 - val_loss: 1.5469 - val_AUC: 0.7635 - val_PRC: 0.7574 - val_RECALL: 0.7140 - val_Error Cuadrático Medio: 0.2501 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 123.0000 - val_Verdadero Negativo: 290.0000 - val_Falso Negativo: 129.0000 - val_Accuracy: 0.7083 - val_Precision: 0.7236
# Epoch 12/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0255 - AUC: 0.9992 - PRC: 0.9989 - RECALL: 0.9908 - Error Cuadrático Medio: 0.0064 - Verdadero Positivo: 3444.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 3411.0000 - Falso Negativo: 32.0000 - Accuracy: 0.9918 - Precision: 0.9928 - val_loss: 1.4245 - val_AUC: 0.7897 - val_PRC: 0.7768 - val_RECALL: 0.7871 - val_Error Cuadrático Medio: 0.2262 - val_Verdadero Positivo: 355.0000 - val_Falso Positivo: 122.0000 - val_Verdadero Negativo: 291.0000 - val_Falso Negativo: 96.0000 - val_Accuracy: 0.7477 - val_Precision: 0.7442
# Epoch 13/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0193 - AUC: 0.9991 - PRC: 0.9994 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0044 - Verdadero Positivo: 3460.0000 - Falso Positivo: 20.0000 - Verdadero Negativo: 3416.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9948 - Precision: 0.9943 - val_loss: 1.7204 - val_AUC: 0.7864 - val_PRC: 0.7492 - val_RECALL: 0.8758 - val_Error Cuadrático Medio: 0.2504 - val_Verdadero Positivo: 395.0000 - val_Falso Positivo: 179.0000 - val_Verdadero Negativo: 234.0000 - val_Falso Negativo: 56.0000 - val_Accuracy: 0.7280 - val_Precision: 0.6882
# Epoch 14/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0224 - AUC: 0.9990 - PRC: 0.9989 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0054 - Verdadero Positivo: 3451.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9936 - Precision: 0.9945 - val_loss: 1.3717 - val_AUC: 0.7917 - val_PRC: 0.7623 - val_RECALL: 0.8337 - val_Error Cuadrático Medio: 0.2308 - val_Verdadero Positivo: 376.0000 - val_Falso Positivo: 151.0000 - val_Verdadero Negativo: 262.0000 - val_Falso Negativo: 75.0000 - val_Accuracy: 0.7384 - val_Precision: 0.7135
# Epoch 15/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0344 - AUC: 0.9983 - PRC: 0.9979 - RECALL: 0.9876 - Error Cuadrático Medio: 0.0087 - Verdadero Positivo: 3433.0000 - Falso Positivo: 30.0000 - Verdadero Negativo: 3406.0000 - Falso Negativo: 43.0000 - Accuracy: 0.9894 - Precision: 0.9913 - val_loss: 1.6727 - val_AUC: 0.7848 - val_PRC: 0.7916 - val_RECALL: 0.5676 - val_Error Cuadrático Medio: 0.2635 - val_Verdadero Positivo: 256.0000 - val_Falso Positivo: 63.0000 - val_Verdadero Negativo: 350.0000 - val_Falso Negativo: 195.0000 - val_Accuracy: 0.7014 - val_Precision: 0.8025
# Epoch 16/50
# 216/216 [==============================] - 27s 123ms/step - loss: 0.0148 - AUC: 0.9996 - PRC: 0.9995 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0037 - Verdadero Positivo: 3455.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9957 - Precision: 0.9974 - val_loss: 1.4739 - val_AUC: 0.7703 - val_PRC: 0.7358 - val_RECALL: 0.8093 - val_Error Cuadrático Medio: 0.2471 - val_Verdadero Positivo: 365.0000 - val_Falso Positivo: 161.0000 - val_Verdadero Negativo: 252.0000 - val_Falso Negativo: 86.0000 - val_Accuracy: 0.7141 - val_Precision: 0.6939
# Epoch 17/50
# 216/216 [==============================] - 27s 123ms/step - loss: 0.0066 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9980 - Error Cuadrático Medio: 0.0015 - Verdadero Positivo: 3469.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 3429.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9980 - Precision: 0.9980 - val_loss: 1.7643 - val_AUC: 0.7695 - val_PRC: 0.7437 - val_RECALL: 0.7627 - val_Error Cuadrático Medio: 0.2496 - val_Verdadero Positivo: 344.0000 - val_Falso Positivo: 129.0000 - val_Verdadero Negativo: 284.0000 - val_Falso Negativo: 107.0000 - val_Accuracy: 0.7269 - val_Precision: 0.7273
# Epoch 18/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0192 - AUC: 0.9992 - PRC: 0.9988 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0047 - Verdadero Positivo: 3458.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 3415.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9944 - Precision: 0.9940 - val_loss: 2.0853 - val_AUC: 0.7848 - val_PRC: 0.7684 - val_RECALL: 0.7539 - val_Error Cuadrático Medio: 0.2241 - val_Verdadero Positivo: 340.0000 - val_Falso Positivo: 100.0000 - val_Verdadero Negativo: 313.0000 - val_Falso Negativo: 111.0000 - val_Accuracy: 0.7558 - val_Precision: 0.7727
# Epoch 19/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0086 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9963 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3463.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 3426.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9967 - Precision: 0.9971 - val_loss: 1.6716 - val_AUC: 0.7795 - val_PRC: 0.7636 - val_RECALL: 0.7428 - val_Error Cuadrático Medio: 0.2368 - val_Verdadero Positivo: 335.0000 - val_Falso Positivo: 111.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 116.0000 - val_Accuracy: 0.7373 - val_Precision: 0.7511
# Epoch 20/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0084 - AUC: 0.9997 - PRC: 0.9996 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0019 - Verdadero Positivo: 3467.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9975 - Precision: 0.9977 - val_loss: 1.4929 - val_AUC: 0.7693 - val_PRC: 0.7590 - val_RECALL: 0.7029 - val_Error Cuadrático Medio: 0.2492 - val_Verdadero Positivo: 317.0000 - val_Falso Positivo: 110.0000 - val_Verdadero Negativo: 303.0000 - val_Falso Negativo: 134.0000 - val_Accuracy: 0.7176 - val_Precision: 0.7424
# Epoch 21/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0156 - AUC: 0.9994 - PRC: 0.9994 - RECALL: 0.9942 - Error Cuadrático Medio: 0.0040 - Verdadero Positivo: 3456.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 20.0000 - Accuracy: 0.9949 - Precision: 0.9957 - val_loss: 1.7611 - val_AUC: 0.8014 - val_PRC: 0.7942 - val_RECALL: 0.6718 - val_Error Cuadrático Medio: 0.2315 - val_Verdadero Positivo: 303.0000 - val_Falso Positivo: 81.0000 - val_Verdadero Negativo: 332.0000 - val_Falso Negativo: 148.0000 - val_Accuracy: 0.7350 - val_Precision: 0.7891
# Epoch 22/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0076 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9965 - Error Cuadrático Medio: 0.0022 - Verdadero Positivo: 3464.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9965 - Precision: 0.9965 - val_loss: 1.9909 - val_AUC: 0.7814 - val_PRC: 0.7656 - val_RECALL: 0.6962 - val_Error Cuadrático Medio: 0.2366 - val_Verdadero Positivo: 314.0000 - val_Falso Positivo: 88.0000 - val_Verdadero Negativo: 325.0000 - val_Falso Negativo: 137.0000 - val_Accuracy: 0.7396 - val_Precision: 0.7811
# Epoch 23/50
# 216/216 [==============================] - 26s 123ms/step - loss: 0.0039 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9983 - Error Cuadrático Medio: 0.0011 - Verdadero Positivo: 3470.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 3432.0000 - Falso Negativo: 6.0000 - Accuracy: 0.9986 - Precision: 0.9988 - val_loss: 2.4897 - val_AUC: 0.7725 - val_PRC: 0.7374 - val_RECALL: 0.8027 - val_Error Cuadrático Medio: 0.2379 - val_Verdadero Positivo: 362.0000 - val_Falso Positivo: 132.0000 - val_Verdadero Negativo: 281.0000 - val_Falso Negativo: 89.0000 - val_Accuracy: 0.7442 - val_Precision: 0.7328
# Epoch 24/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0162 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0034 - Verdadero Positivo: 3458.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9957 - Precision: 0.9965 - val_loss: 2.2361 - val_AUC: 0.7412 - val_PRC: 0.7276 - val_RECALL: 0.6652 - val_Error Cuadrático Medio: 0.2823 - val_Verdadero Positivo: 300.0000 - val_Falso Positivo: 121.0000 - val_Verdadero Negativo: 292.0000 - val_Falso Negativo: 151.0000 - val_Accuracy: 0.6852 - val_Precision: 0.7126
# Epoch 25/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0233 - AUC: 0.9992 - PRC: 0.9990 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0051 - Verdadero Positivo: 3450.0000 - Falso Positivo: 24.0000 - Verdadero Negativo: 3412.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9928 - Precision: 0.9931 - val_loss: 1.5607 - val_AUC: 0.7598 - val_PRC: 0.7264 - val_RECALL: 0.7517 - val_Error Cuadrático Medio: 0.2460 - val_Verdadero Positivo: 339.0000 - val_Falso Positivo: 128.0000 - val_Verdadero Negativo: 285.0000 - val_Falso Negativo: 112.0000 - val_Accuracy: 0.7222 - val_Precision: 0.7259
# Epoch 26/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0152 - AUC: 0.9992 - PRC: 0.9989 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0033 - Verdadero Positivo: 3460.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 3425.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9961 - Precision: 0.9968 - val_loss: 1.8641 - val_AUC: 0.7783 - val_PRC: 0.7549 - val_RECALL: 0.7761 - val_Error Cuadrático Medio: 0.2341 - val_Verdadero Positivo: 350.0000 - val_Falso Positivo: 117.0000 - val_Verdadero Negativo: 296.0000 - val_Falso Negativo: 101.0000 - val_Accuracy: 0.7477 - val_Precision: 0.7495
# Epoch 27/50
# 216/216 [==============================] - 26s 119ms/step - loss: 0.0116 - AUC: 0.9996 - PRC: 0.9996 - RECALL: 0.9963 - Error Cuadrático Medio: 0.0030 - Verdadero Positivo: 3463.0000 - Falso Positivo: 14.0000 - Verdadero Negativo: 3422.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9961 - Precision: 0.9960 - val_loss: 2.2021 - val_AUC: 0.7547 - val_PRC: 0.7219 - val_RECALL: 0.7916 - val_Error Cuadrático Medio: 0.2517 - val_Verdadero Positivo: 357.0000 - val_Falso Positivo: 141.0000 - val_Verdadero Negativo: 272.0000 - val_Falso Negativo: 94.0000 - val_Accuracy: 0.7280 - val_Precision: 0.7169
# Epoch 28/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0133 - AUC: 0.9995 - PRC: 0.9993 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0025 - Verdadero Positivo: 3462.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 14.0000 - Accuracy: 0.9967 - Precision: 0.9974 - val_loss: 2.0754 - val_AUC: 0.7804 - val_PRC: 0.7691 - val_RECALL: 0.7206 - val_Error Cuadrático Medio: 0.2401 - val_Verdadero Positivo: 325.0000 - val_Falso Positivo: 96.0000 - val_Verdadero Negativo: 317.0000 - val_Falso Negativo: 126.0000 - val_Accuracy: 0.7431 - val_Precision: 0.7720
# Epoch 29/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0047 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9988 - Error Cuadrático Medio: 0.0011 - Verdadero Positivo: 3472.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 3431.0000 - Falso Negativo: 4.0000 - Accuracy: 0.9987 - Precision: 0.9986 - val_loss: 2.5648 - val_AUC: 0.7495 - val_PRC: 0.7241 - val_RECALL: 0.7406 - val_Error Cuadrático Medio: 0.2568 - val_Verdadero Positivo: 334.0000 - val_Falso Positivo: 121.0000 - val_Verdadero Negativo: 292.0000 - val_Falso Negativo: 117.0000 - val_Accuracy: 0.7245 - val_Precision: 0.7341
# Epoch 30/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0038 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9988 - Error Cuadrático Medio: 9.8615e-04 - Verdadero Positivo: 3472.0000 - Falso Positivo: 3.0000 - Verdadero Negativo: 3433.0000 - Falso Negativo: 4.0000 - Accuracy: 0.9990 - Precision: 0.9991 - val_loss: 2.5919 - val_AUC: 0.7558 - val_PRC: 0.7390 - val_RECALL: 0.7494 - val_Error Cuadrático Medio: 0.2569 - val_Verdadero Positivo: 338.0000 - val_Falso Positivo: 128.0000 - val_Verdadero Negativo: 285.0000 - val_Falso Negativo: 113.0000 - val_Accuracy: 0.7211 - val_Precision: 0.7253
# Epoch 31/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0205 - AUC: 0.9990 - PRC: 0.9985 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0047 - Verdadero Positivo: 3451.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9942 - Precision: 0.9957 - val_loss: 1.6328 - val_AUC: 0.7334 - val_PRC: 0.6970 - val_RECALL: 0.7583 - val_Error Cuadrático Medio: 0.2579 - val_Verdadero Positivo: 342.0000 - val_Falso Positivo: 137.0000 - val_Verdadero Negativo: 276.0000 - val_Falso Negativo: 109.0000 - val_Accuracy: 0.7153 - val_Precision: 0.7140
# Epoch 32/50
# 216/216 [==============================] - 26s 120ms/step - loss: 0.0092 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9963 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3463.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 3430.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9973 - Precision: 0.9983 - val_loss: 2.2250 - val_AUC: 0.7613 - val_PRC: 0.7354 - val_RECALL: 0.7783 - val_Error Cuadrático Medio: 0.2442 - val_Verdadero Positivo: 351.0000 - val_Falso Positivo: 122.0000 - val_Verdadero Negativo: 291.0000 - val_Falso Negativo: 100.0000 - val_Accuracy: 0.7431 - val_Precision: 0.7421
# Epoch 33/50
# 216/216 [==============================] - ETA: 0s - loss: 0.0118 - AUC: 0.9995 - PRC: 0.9997 - RECALL: 0.9963 - Error Cuadrático Medio: 0.0021 - Verdadero Positivo: 3463.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9970 - Precision: 0.9977Restoring model weights from the end of the best epoch: 23.
# 216/216 [==============================] - 27s 124ms/step - loss: 0.0118 - AUC: 0.9995 - PRC: 0.9997 - RECALL: 0.9963 - Error Cuadrático Medio: 0.0021 - Verdadero Positivo: 3463.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9970 - Precision: 0.9977 - val_loss: 2.3851 - val_AUC: 0.7493 - val_PRC: 0.7174 - val_RECALL: 0.8470 - val_Error Cuadrático Medio: 0.2706 - val_Verdadero Positivo: 382.0000 - val_Falso Positivo: 176.0000 - val_Verdadero Negativo: 237.0000 - val_Falso Negativo: 69.0000 - val_Accuracy: 0.7164 - val_Precision: 0.6846
# Epoch 33: early stopping
# 34/34 [==============================] - 2s 28ms/step - loss: 2.5593 - AUC: 0.7846 - PRC: 0.7263 - RECALL: 0.8011 - Error Cuadrático Medio: 0.2374 - Verdadero Positivo: 423.0000 - Falso Positivo: 170.0000 - Verdadero Negativo: 382.0000 - Falso Negativo: 105.0000 - Accuracy: 0.7454 - Precision: 0.7133
# {'loss': 2.5592992305755615, 'AUC': 0.7846262454986572, 'PRC': 0.7263195514678955, 'RECALL': 0.8011363744735718, 'Error Cuadrático Medio': 0.23742029070854187, 'Verdadero Positivo': 423.0, 'Falso Positivo': 170.0, 'Verdadero Negativo': 382.0, 'Falso Negativo': 105.0, 'Accuracy': 0.7453703880310059, 'Precision': 0.713322103023529}
#
#  ...Calculando valores predichos para train y test: ...
# 216/216 [==============================] - 4s 18ms/step
# 34/34 [==============================] - 1s 17ms/step
#
#  ** Resultados de las métricas:...
# loss :  2.5592992305755615
# AUC :  0.7846262454986572
# PRC :  0.7263195514678955
# RECALL :  0.8011363744735718
# Error Cuadrático Medio :  0.23742029070854187
# Verdadero Positivo :  423.0
# Falso Positivo :  170.0
# Verdadero Negativo :  382.0
# Falso Negativo :  105.0
# Accuracy :  0.7453703880310059
# Precision :  0.713322103023529
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  382
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  170
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  105
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  423

# %% [markdown]
# #### ***Model-C***:  $~~~1 \times $*`Inceptionv-3`*+$1\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
model_name="model_C"
model = model_C(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias
apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  inception_v3 (Functional)   (None, 1, 1, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 22049885 (84.11 MB)
# Trainable params: 22015453 (83.98 MB)
# Non-trainable params: 34432 (134.50 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 216/216 [==============================] - 55s 81ms/step - loss: 0.3409 - AUC: 0.9282 - PRC: 0.9315 - RECALL: 0.8452 - Error Cuadrático Medio: 0.1087 - Verdadero Positivo: 2938.0000 - Falso Positivo: 585.0000 - Verdadero Negativo: 2851.0000 - Falso Negativo: 538.0000 - Accuracy: 0.8375 - Precision: 0.8339 - val_loss: 1.9601 - val_AUC: 0.5729 - val_PRC: 0.5381 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.4957 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 413.0000 - val_Falso Negativo: 451.0000 - val_Accuracy: 0.4780 - val_Precision: 0.0000e+00
# Epoch 2/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.3333 - AUC: 0.9297 - PRC: 0.9347 - RECALL: 0.8495 - Error Cuadrático Medio: 0.1076 - Verdadero Positivo: 2953.0000 - Falso Positivo: 567.0000 - Verdadero Negativo: 2869.0000 - Falso Negativo: 523.0000 - Accuracy: 0.8423 - Precision: 0.8389 - val_loss: 1.6253 - val_AUC: 0.7855 - val_PRC: 0.7754 - val_RECALL: 0.7162 - val_Error Cuadrático Medio: 0.1967 - val_Verdadero Positivo: 323.0000 - val_Falso Positivo: 111.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 128.0000 - val_Accuracy: 0.7234 - val_Precision: 0.7442
# Epoch 3/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.2515 - AUC: 0.9607 - PRC: 0.9641 - RECALL: 0.8797 - Error Cuadrático Medio: 0.0790 - Verdadero Positivo: 3058.0000 - Falso Positivo: 340.0000 - Verdadero Negativo: 3096.0000 - Falso Negativo: 418.0000 - Accuracy: 0.8903 - Precision: 0.8999 - val_loss: 2.2606 - val_AUC: 0.8034 - val_PRC: 0.8527 - val_RECALL: 0.5632 - val_Error Cuadrático Medio: 0.2090 - val_Verdadero Positivo: 254.0000 - val_Falso Positivo: 38.0000 - val_Verdadero Negativo: 375.0000 - val_Falso Negativo: 197.0000 - val_Accuracy: 0.7280 - val_Precision: 0.8699
# Epoch 4/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.2485 - AUC: 0.9613 - PRC: 0.9649 - RECALL: 0.8867 - Error Cuadrático Medio: 0.0778 - Verdadero Positivo: 3082.0000 - Falso Positivo: 346.0000 - Verdadero Negativo: 3090.0000 - Falso Negativo: 394.0000 - Accuracy: 0.8929 - Precision: 0.8991 - val_loss: 0.9730 - val_AUC: 0.7942 - val_PRC: 0.8347 - val_RECALL: 0.3681 - val_Error Cuadrático Medio: 0.2906 - val_Verdadero Positivo: 166.0000 - val_Falso Positivo: 12.0000 - val_Verdadero Negativo: 401.0000 - val_Falso Negativo: 285.0000 - val_Accuracy: 0.6562 - val_Precision: 0.9326
# Epoch 5/50
# 216/216 [==============================] - 14s 67ms/step - loss: 0.2537 - AUC: 0.9598 - PRC: 0.9621 - RECALL: 0.8941 - Error Cuadrático Medio: 0.0806 - Verdadero Positivo: 3108.0000 - Falso Positivo: 433.0000 - Verdadero Negativo: 3003.0000 - Falso Negativo: 368.0000 - Accuracy: 0.8841 - Precision: 0.8777 - val_loss: 0.6604 - val_AUC: 0.6927 - val_PRC: 0.6496 - val_RECALL: 0.7273 - val_Error Cuadrático Medio: 0.2284 - val_Verdadero Positivo: 328.0000 - val_Falso Positivo: 175.0000 - val_Verdadero Negativo: 238.0000 - val_Falso Negativo: 123.0000 - val_Accuracy: 0.6551 - val_Precision: 0.6521
# Epoch 6/50
# 216/216 [==============================] - 15s 67ms/step - loss: 0.2649 - AUC: 0.9542 - PRC: 0.9564 - RECALL: 0.8682 - Error Cuadrático Medio: 0.0871 - Verdadero Positivo: 3018.0000 - Falso Positivo: 442.0000 - Verdadero Negativo: 2994.0000 - Falso Negativo: 458.0000 - Accuracy: 0.8698 - Precision: 0.8723 - val_loss: 0.6147 - val_AUC: 0.8265 - val_PRC: 0.8323 - val_RECALL: 0.4767 - val_Error Cuadrático Medio: 0.2079 - val_Verdadero Positivo: 215.0000 - val_Falso Positivo: 35.0000 - val_Verdadero Negativo: 378.0000 - val_Falso Negativo: 236.0000 - val_Accuracy: 0.6863 - val_Precision: 0.8600
# Epoch 7/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.2456 - AUC: 0.9619 - PRC: 0.9633 - RECALL: 0.8947 - Error Cuadrático Medio: 0.0781 - Verdadero Positivo: 3110.0000 - Falso Positivo: 375.0000 - Verdadero Negativo: 3061.0000 - Falso Negativo: 366.0000 - Accuracy: 0.8928 - Precision: 0.8924 - val_loss: 0.8440 - val_AUC: 0.7979 - val_PRC: 0.8246 - val_RECALL: 0.2417 - val_Error Cuadrático Medio: 0.2909 - val_Verdadero Positivo: 109.0000 - val_Falso Positivo: 3.0000 - val_Verdadero Negativo: 410.0000 - val_Falso Negativo: 342.0000 - val_Accuracy: 0.6007 - val_Precision: 0.9732
# Epoch 8/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.2132 - AUC: 0.9717 - PRC: 0.9725 - RECALL: 0.9220 - Error Cuadrático Medio: 0.0666 - Verdadero Positivo: 3205.0000 - Falso Positivo: 382.0000 - Verdadero Negativo: 3054.0000 - Falso Negativo: 271.0000 - Accuracy: 0.9055 - Precision: 0.8935 - val_loss: 0.4895 - val_AUC: 0.8930 - val_PRC: 0.8694 - val_RECALL: 0.8869 - val_Error Cuadrático Medio: 0.1273 - val_Verdadero Positivo: 400.0000 - val_Falso Positivo: 102.0000 - val_Verdadero Negativo: 311.0000 - val_Falso Negativo: 51.0000 - val_Accuracy: 0.8229 - val_Precision: 0.7968
# Epoch 9/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.2070 - AUC: 0.9732 - PRC: 0.9743 - RECALL: 0.9134 - Error Cuadrático Medio: 0.0656 - Verdadero Positivo: 3175.0000 - Falso Positivo: 337.0000 - Verdadero Negativo: 3099.0000 - Falso Negativo: 301.0000 - Accuracy: 0.9077 - Precision: 0.9040 - val_loss: 0.3894 - val_AUC: 0.9081 - val_PRC: 0.9094 - val_RECALL: 0.8271 - val_Error Cuadrático Medio: 0.1232 - val_Verdadero Positivo: 373.0000 - val_Falso Positivo: 71.0000 - val_Verdadero Negativo: 342.0000 - val_Falso Negativo: 78.0000 - val_Accuracy: 0.8275 - val_Precision: 0.8401
# Epoch 10/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.2037 - AUC: 0.9740 - PRC: 0.9753 - RECALL: 0.8956 - Error Cuadrático Medio: 0.0642 - Verdadero Positivo: 3113.0000 - Falso Positivo: 271.0000 - Verdadero Negativo: 3165.0000 - Falso Negativo: 363.0000 - Accuracy: 0.9083 - Precision: 0.9199 - val_loss: 0.4828 - val_AUC: 0.8734 - val_PRC: 0.8624 - val_RECALL: 0.9379 - val_Error Cuadrático Medio: 0.1524 - val_Verdadero Positivo: 423.0000 - val_Falso Positivo: 147.0000 - val_Verdadero Negativo: 266.0000 - val_Falso Negativo: 28.0000 - val_Accuracy: 0.7975 - val_Precision: 0.7421
# Epoch 11/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.1979 - AUC: 0.9755 - PRC: 0.9760 - RECALL: 0.9148 - Error Cuadrático Medio: 0.0626 - Verdadero Positivo: 3180.0000 - Falso Positivo: 312.0000 - Verdadero Negativo: 3124.0000 - Falso Negativo: 296.0000 - Accuracy: 0.9120 - Precision: 0.9107 - val_loss: 0.8489 - val_AUC: 0.7869 - val_PRC: 0.8273 - val_RECALL: 0.7849 - val_Error Cuadrático Medio: 0.2295 - val_Verdadero Positivo: 354.0000 - val_Falso Positivo: 152.0000 - val_Verdadero Negativo: 261.0000 - val_Falso Negativo: 97.0000 - val_Accuracy: 0.7118 - val_Precision: 0.6996
# Epoch 12/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.2553 - AUC: 0.9606 - PRC: 0.9628 - RECALL: 0.8915 - Error Cuadrático Medio: 0.0793 - Verdadero Positivo: 3099.0000 - Falso Positivo: 417.0000 - Verdadero Negativo: 3019.0000 - Falso Negativo: 377.0000 - Accuracy: 0.8851 - Precision: 0.8814 - val_loss: 2.5647 - val_AUC: 0.5855 - val_PRC: 0.5690 - val_RECALL: 0.4479 - val_Error Cuadrático Medio: 0.3560 - val_Verdadero Positivo: 202.0000 - val_Falso Positivo: 114.0000 - val_Verdadero Negativo: 299.0000 - val_Falso Negativo: 249.0000 - val_Accuracy: 0.5799 - val_Precision: 0.6392
# Epoch 13/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.2327 - AUC: 0.9666 - PRC: 0.9693 - RECALL: 0.9059 - Error Cuadrático Medio: 0.0727 - Verdadero Positivo: 3149.0000 - Falso Positivo: 420.0000 - Verdadero Negativo: 3016.0000 - Falso Negativo: 327.0000 - Accuracy: 0.8919 - Precision: 0.8823 - val_loss: 0.5175 - val_AUC: 0.8300 - val_PRC: 0.8617 - val_RECALL: 0.7273 - val_Error Cuadrático Medio: 0.1746 - val_Verdadero Positivo: 328.0000 - val_Falso Positivo: 57.0000 - val_Verdadero Negativo: 356.0000 - val_Falso Negativo: 123.0000 - val_Accuracy: 0.7917 - val_Precision: 0.8519
# Epoch 14/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.2352 - AUC: 0.9650 - PRC: 0.9679 - RECALL: 0.8904 - Error Cuadrático Medio: 0.0758 - Verdadero Positivo: 3095.0000 - Falso Positivo: 344.0000 - Verdadero Negativo: 3092.0000 - Falso Negativo: 381.0000 - Accuracy: 0.8951 - Precision: 0.9000 - val_loss: 0.6006 - val_AUC: 0.8170 - val_PRC: 0.8250 - val_RECALL: 0.3769 - val_Error Cuadrático Medio: 0.2083 - val_Verdadero Positivo: 170.0000 - val_Falso Positivo: 19.0000 - val_Verdadero Negativo: 394.0000 - val_Falso Negativo: 281.0000 - val_Accuracy: 0.6528 - val_Precision: 0.8995
# Epoch 15/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.2421 - AUC: 0.9622 - PRC: 0.9649 - RECALL: 0.8772 - Error Cuadrático Medio: 0.0788 - Verdadero Positivo: 3049.0000 - Falso Positivo: 344.0000 - Verdadero Negativo: 3092.0000 - Falso Negativo: 427.0000 - Accuracy: 0.8885 - Precision: 0.8986 - val_loss: 0.5665 - val_AUC: 0.8777 - val_PRC: 0.8677 - val_RECALL: 0.9379 - val_Error Cuadrático Medio: 0.1715 - val_Verdadero Positivo: 423.0000 - val_Falso Positivo: 165.0000 - val_Verdadero Negativo: 248.0000 - val_Falso Negativo: 28.0000 - val_Accuracy: 0.7766 - val_Precision: 0.7194
# Epoch 16/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.2135 - AUC: 0.9727 - PRC: 0.9737 - RECALL: 0.9148 - Error Cuadrático Medio: 0.0653 - Verdadero Positivo: 3180.0000 - Falso Positivo: 306.0000 - Verdadero Negativo: 3130.0000 - Falso Negativo: 296.0000 - Accuracy: 0.9129 - Precision: 0.9122 - val_loss: 0.4323 - val_AUC: 0.8865 - val_PRC: 0.8988 - val_RECALL: 0.8093 - val_Error Cuadrático Medio: 0.1390 - val_Verdadero Positivo: 365.0000 - val_Falso Positivo: 82.0000 - val_Verdadero Negativo: 331.0000 - val_Falso Negativo: 86.0000 - val_Accuracy: 0.8056 - val_Precision: 0.8166
# Epoch 17/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.2734 - AUC: 0.9519 - PRC: 0.9553 - RECALL: 0.8383 - Error Cuadrático Medio: 0.0889 - Verdadero Positivo: 2914.0000 - Falso Positivo: 343.0000 - Verdadero Negativo: 3093.0000 - Falso Negativo: 562.0000 - Accuracy: 0.8691 - Precision: 0.8947 - val_loss: 0.5489 - val_AUC: 0.8243 - val_PRC: 0.8385 - val_RECALL: 0.6874 - val_Error Cuadrático Medio: 0.1789 - val_Verdadero Positivo: 310.0000 - val_Falso Positivo: 70.0000 - val_Verdadero Negativo: 343.0000 - val_Falso Negativo: 141.0000 - val_Accuracy: 0.7558 - val_Precision: 0.8158
# Epoch 18/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.2504 - AUC: 0.9610 - PRC: 0.9645 - RECALL: 0.8806 - Error Cuadrático Medio: 0.0790 - Verdadero Positivo: 3061.0000 - Falso Positivo: 320.0000 - Verdadero Negativo: 3116.0000 - Falso Negativo: 415.0000 - Accuracy: 0.8937 - Precision: 0.9054 - val_loss: 1.0998 - val_AUC: 0.6338 - val_PRC: 0.7155 - val_RECALL: 0.3747 - val_Error Cuadrático Medio: 0.2802 - val_Verdadero Positivo: 169.0000 - val_Falso Positivo: 40.0000 - val_Verdadero Negativo: 373.0000 - val_Falso Negativo: 282.0000 - val_Accuracy: 0.6273 - val_Precision: 0.8086
# Epoch 19/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.2074 - AUC: 0.9734 - PRC: 0.9756 - RECALL: 0.8915 - Error Cuadrático Medio: 0.0659 - Verdadero Positivo: 3099.0000 - Falso Positivo: 264.0000 - Verdadero Negativo: 3172.0000 - Falso Negativo: 377.0000 - Accuracy: 0.9073 - Precision: 0.9215 - val_loss: 0.5897 - val_AUC: 0.8713 - val_PRC: 0.8902 - val_RECALL: 0.5588 - val_Error Cuadrático Medio: 0.1855 - val_Verdadero Positivo: 252.0000 - val_Falso Positivo: 17.0000 - val_Verdadero Negativo: 396.0000 - val_Falso Negativo: 199.0000 - val_Accuracy: 0.7500 - val_Precision: 0.9368
# Epoch 20/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.2004 - AUC: 0.9758 - PRC: 0.9769 - RECALL: 0.9174 - Error Cuadrático Medio: 0.0619 - Verdadero Positivo: 3189.0000 - Falso Positivo: 301.0000 - Verdadero Negativo: 3135.0000 - Falso Negativo: 287.0000 - Accuracy: 0.9149 - Precision: 0.9138 - val_loss: 0.4231 - val_AUC: 0.8923 - val_PRC: 0.8983 - val_RECALL: 0.8226 - val_Error Cuadrático Medio: 0.1325 - val_Verdadero Positivo: 371.0000 - val_Falso Positivo: 76.0000 - val_Verdadero Negativo: 337.0000 - val_Falso Negativo: 80.0000 - val_Accuracy: 0.8194 - val_Precision: 0.8300
# Epoch 21/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.1878 - AUC: 0.9785 - PRC: 0.9790 - RECALL: 0.9177 - Error Cuadrático Medio: 0.0568 - Verdadero Positivo: 3190.0000 - Falso Positivo: 266.0000 - Verdadero Negativo: 3170.0000 - Falso Negativo: 286.0000 - Accuracy: 0.9201 - Precision: 0.9230 - val_loss: 0.7391 - val_AUC: 0.8859 - val_PRC: 0.8864 - val_RECALL: 0.3880 - val_Error Cuadrático Medio: 0.2317 - val_Verdadero Positivo: 175.0000 - val_Falso Positivo: 8.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 276.0000 - val_Accuracy: 0.6713 - val_Precision: 0.9563
# Epoch 22/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.1760 - AUC: 0.9808 - PRC: 0.9821 - RECALL: 0.9215 - Error Cuadrático Medio: 0.0547 - Verdadero Positivo: 3203.0000 - Falso Positivo: 248.0000 - Verdadero Negativo: 3188.0000 - Falso Negativo: 273.0000 - Accuracy: 0.9246 - Precision: 0.9281 - val_loss: 0.3980 - val_AUC: 0.9113 - val_PRC: 0.9025 - val_RECALL: 0.7916 - val_Error Cuadrático Medio: 0.1196 - val_Verdadero Positivo: 357.0000 - val_Falso Positivo: 48.0000 - val_Verdadero Negativo: 365.0000 - val_Falso Negativo: 94.0000 - val_Accuracy: 0.8356 - val_Precision: 0.8815
# Epoch 23/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.1689 - AUC: 0.9821 - PRC: 0.9833 - RECALL: 0.9264 - Error Cuadrático Medio: 0.0518 - Verdadero Positivo: 3220.0000 - Falso Positivo: 224.0000 - Verdadero Negativo: 3212.0000 - Falso Negativo: 256.0000 - Accuracy: 0.9306 - Precision: 0.9350 - val_loss: 0.3750 - val_AUC: 0.9180 - val_PRC: 0.9244 - val_RECALL: 0.7849 - val_Error Cuadrático Medio: 0.1179 - val_Verdadero Positivo: 354.0000 - val_Falso Positivo: 50.0000 - val_Verdadero Negativo: 363.0000 - val_Falso Negativo: 97.0000 - val_Accuracy: 0.8299 - val_Precision: 0.8762
# Epoch 24/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.1671 - AUC: 0.9826 - PRC: 0.9833 - RECALL: 0.9298 - Error Cuadrático Medio: 0.0504 - Verdadero Positivo: 3232.0000 - Falso Positivo: 205.0000 - Verdadero Negativo: 3231.0000 - Falso Negativo: 244.0000 - Accuracy: 0.9350 - Precision: 0.9404 - val_loss: 0.3886 - val_AUC: 0.9084 - val_PRC: 0.9128 - val_RECALL: 0.8514 - val_Error Cuadrático Medio: 0.1208 - val_Verdadero Positivo: 384.0000 - val_Falso Positivo: 77.0000 - val_Verdadero Negativo: 336.0000 - val_Falso Negativo: 67.0000 - val_Accuracy: 0.8333 - val_Precision: 0.8330
# Epoch 25/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.1518 - AUC: 0.9858 - PRC: 0.9866 - RECALL: 0.9367 - Error Cuadrático Medio: 0.0454 - Verdadero Positivo: 3256.0000 - Falso Positivo: 193.0000 - Verdadero Negativo: 3243.0000 - Falso Negativo: 220.0000 - Accuracy: 0.9402 - Precision: 0.9440 - val_loss: 0.3874 - val_AUC: 0.9137 - val_PRC: 0.9160 - val_RECALL: 0.8647 - val_Error Cuadrático Medio: 0.1169 - val_Verdadero Positivo: 390.0000 - val_Falso Positivo: 81.0000 - val_Verdadero Negativo: 332.0000 - val_Falso Negativo: 61.0000 - val_Accuracy: 0.8356 - val_Precision: 0.8280
# Epoch 26/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.1427 - AUC: 0.9869 - PRC: 0.9876 - RECALL: 0.9324 - Error Cuadrático Medio: 0.0426 - Verdadero Positivo: 3241.0000 - Falso Positivo: 167.0000 - Verdadero Negativo: 3269.0000 - Falso Negativo: 235.0000 - Accuracy: 0.9418 - Precision: 0.9510 - val_loss: 1.1105 - val_AUC: 0.8436 - val_PRC: 0.8105 - val_RECALL: 0.9557 - val_Error Cuadrático Medio: 0.2525 - val_Verdadero Positivo: 431.0000 - val_Falso Positivo: 230.0000 - val_Verdadero Negativo: 183.0000 - val_Falso Negativo: 20.0000 - val_Accuracy: 0.7106 - val_Precision: 0.6520
# Epoch 27/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.1241 - AUC: 0.9901 - PRC: 0.9911 - RECALL: 0.9462 - Error Cuadrático Medio: 0.0365 - Verdadero Positivo: 3289.0000 - Falso Positivo: 140.0000 - Verdadero Negativo: 3296.0000 - Falso Negativo: 187.0000 - Accuracy: 0.9527 - Precision: 0.9592 - val_loss: 0.6593 - val_AUC: 0.7898 - val_PRC: 0.8110 - val_RECALL: 0.5166 - val_Error Cuadrático Medio: 0.2141 - val_Verdadero Positivo: 233.0000 - val_Falso Positivo: 31.0000 - val_Verdadero Negativo: 382.0000 - val_Falso Negativo: 218.0000 - val_Accuracy: 0.7118 - val_Precision: 0.8826
# Epoch 28/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.1169 - AUC: 0.9911 - PRC: 0.9918 - RECALL: 0.9520 - Error Cuadrático Medio: 0.0339 - Verdadero Positivo: 3309.0000 - Falso Positivo: 139.0000 - Verdadero Negativo: 3297.0000 - Falso Negativo: 167.0000 - Accuracy: 0.9557 - Precision: 0.9597 - val_loss: 0.5528 - val_AUC: 0.8903 - val_PRC: 0.8964 - val_RECALL: 0.6718 - val_Error Cuadrático Medio: 0.1623 - val_Verdadero Positivo: 303.0000 - val_Falso Positivo: 24.0000 - val_Verdadero Negativo: 389.0000 - val_Falso Negativo: 148.0000 - val_Accuracy: 0.8009 - val_Precision: 0.9266
# Epoch 29/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.1087 - AUC: 0.9922 - PRC: 0.9928 - RECALL: 0.9531 - Error Cuadrático Medio: 0.0311 - Verdadero Positivo: 3313.0000 - Falso Positivo: 123.0000 - Verdadero Negativo: 3313.0000 - Falso Negativo: 163.0000 - Accuracy: 0.9586 - Precision: 0.9642 - val_loss: 0.7184 - val_AUC: 0.8896 - val_PRC: 0.8799 - val_RECALL: 0.9424 - val_Error Cuadrático Medio: 0.1840 - val_Verdadero Positivo: 425.0000 - val_Falso Positivo: 164.0000 - val_Verdadero Negativo: 249.0000 - val_Falso Negativo: 26.0000 - val_Accuracy: 0.7801 - val_Precision: 0.7216
# Epoch 30/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.1002 - AUC: 0.9933 - PRC: 0.9940 - RECALL: 0.9649 - Error Cuadrático Medio: 0.0281 - Verdadero Positivo: 3354.0000 - Falso Positivo: 128.0000 - Verdadero Negativo: 3308.0000 - Falso Negativo: 122.0000 - Accuracy: 0.9638 - Precision: 0.9632 - val_loss: 1.1053 - val_AUC: 0.8761 - val_PRC: 0.8681 - val_RECALL: 0.9157 - val_Error Cuadrático Medio: 0.1736 - val_Verdadero Positivo: 413.0000 - val_Falso Positivo: 141.0000 - val_Verdadero Negativo: 272.0000 - val_Falso Negativo: 38.0000 - val_Accuracy: 0.7928 - val_Precision: 0.7455
# Epoch 31/50
# 216/216 [==============================] - 16s 73ms/step - loss: 0.0880 - AUC: 0.9946 - PRC: 0.9951 - RECALL: 0.9669 - Error Cuadrático Medio: 0.0240 - Verdadero Positivo: 3361.0000 - Falso Positivo: 110.0000 - Verdadero Negativo: 3326.0000 - Falso Negativo: 115.0000 - Accuracy: 0.9674 - Precision: 0.9683 - val_loss: 0.6658 - val_AUC: 0.8842 - val_PRC: 0.8894 - val_RECALL: 0.6563 - val_Error Cuadrático Medio: 0.1772 - val_Verdadero Positivo: 296.0000 - val_Falso Positivo: 28.0000 - val_Verdadero Negativo: 385.0000 - val_Falso Negativo: 155.0000 - val_Accuracy: 0.7882 - val_Precision: 0.9136
# Epoch 32/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0689 - AUC: 0.9964 - PRC: 0.9969 - RECALL: 0.9753 - Error Cuadrático Medio: 0.0183 - Verdadero Positivo: 3390.0000 - Falso Positivo: 74.0000 - Verdadero Negativo: 3362.0000 - Falso Negativo: 86.0000 - Accuracy: 0.9769 - Precision: 0.9786 - val_loss: 0.4562 - val_AUC: 0.9124 - val_PRC: 0.9178 - val_RECALL: 0.8492 - val_Error Cuadrático Medio: 0.1243 - val_Verdadero Positivo: 383.0000 - val_Falso Positivo: 61.0000 - val_Verdadero Negativo: 352.0000 - val_Falso Negativo: 68.0000 - val_Accuracy: 0.8507 - val_Precision: 0.8626
# Epoch 33/50
# 216/216 [==============================] - 15s 68ms/step - loss: 0.0743 - AUC: 0.9956 - PRC: 0.9960 - RECALL: 0.9718 - Error Cuadrático Medio: 0.0201 - Verdadero Positivo: 3378.0000 - Falso Positivo: 77.0000 - Verdadero Negativo: 3359.0000 - Falso Negativo: 98.0000 - Accuracy: 0.9747 - Precision: 0.9777 - val_loss: 0.7045 - val_AUC: 0.8647 - val_PRC: 0.8838 - val_RECALL: 0.5920 - val_Error Cuadrático Medio: 0.1883 - val_Verdadero Positivo: 267.0000 - val_Falso Positivo: 26.0000 - val_Verdadero Negativo: 387.0000 - val_Falso Negativo: 184.0000 - val_Accuracy: 0.7569 - val_Precision: 0.9113
# Epoch 34/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.0689 - AUC: 0.9964 - PRC: 0.9965 - RECALL: 0.9732 - Error Cuadrático Medio: 0.0189 - Verdadero Positivo: 3383.0000 - Falso Positivo: 75.0000 - Verdadero Negativo: 3361.0000 - Falso Negativo: 93.0000 - Accuracy: 0.9757 - Precision: 0.9783 - val_loss: 1.8940 - val_AUC: 0.6873 - val_PRC: 0.6929 - val_RECALL: 0.0976 - val_Error Cuadrático Medio: 0.4425 - val_Verdadero Positivo: 44.0000 - val_Falso Positivo: 5.0000 - val_Verdadero Negativo: 408.0000 - val_Falso Negativo: 407.0000 - val_Accuracy: 0.5231 - val_Precision: 0.8980
# Epoch 35/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.1691 - AUC: 0.9836 - PRC: 0.9831 - RECALL: 0.9399 - Error Cuadrático Medio: 0.0452 - Verdadero Positivo: 3267.0000 - Falso Positivo: 207.0000 - Verdadero Negativo: 3229.0000 - Falso Negativo: 209.0000 - Accuracy: 0.9398 - Precision: 0.9404 - val_loss: 1.0952 - val_AUC: 0.8491 - val_PRC: 0.8666 - val_RECALL: 0.3149 - val_Error Cuadrático Medio: 0.3033 - val_Verdadero Positivo: 142.0000 - val_Falso Positivo: 7.0000 - val_Verdadero Negativo: 406.0000 - val_Falso Negativo: 309.0000 - val_Accuracy: 0.6343 - val_Precision: 0.9530
# Epoch 36/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.0744 - AUC: 0.9959 - PRC: 0.9959 - RECALL: 0.9738 - Error Cuadrático Medio: 0.0204 - Verdadero Positivo: 3385.0000 - Falso Positivo: 94.0000 - Verdadero Negativo: 3342.0000 - Falso Negativo: 91.0000 - Accuracy: 0.9732 - Precision: 0.9730 - val_loss: 0.8756 - val_AUC: 0.8976 - val_PRC: 0.8763 - val_RECALL: 0.9557 - val_Error Cuadrático Medio: 0.1818 - val_Verdadero Positivo: 431.0000 - val_Falso Positivo: 168.0000 - val_Verdadero Negativo: 245.0000 - val_Falso Negativo: 20.0000 - val_Accuracy: 0.7824 - val_Precision: 0.7195
# Epoch 37/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0586 - AUC: 0.9971 - PRC: 0.9970 - RECALL: 0.9804 - Error Cuadrático Medio: 0.0152 - Verdadero Positivo: 3408.0000 - Falso Positivo: 67.0000 - Verdadero Negativo: 3369.0000 - Falso Negativo: 68.0000 - Accuracy: 0.9805 - Precision: 0.9807 - val_loss: 1.0397 - val_AUC: 0.8783 - val_PRC: 0.8617 - val_RECALL: 0.9202 - val_Error Cuadrático Medio: 0.1744 - val_Verdadero Positivo: 415.0000 - val_Falso Positivo: 138.0000 - val_Verdadero Negativo: 275.0000 - val_Falso Negativo: 36.0000 - val_Accuracy: 0.7986 - val_Precision: 0.7505
# Epoch 38/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.0677 - AUC: 0.9964 - PRC: 0.9968 - RECALL: 0.9784 - Error Cuadrático Medio: 0.0173 - Verdadero Positivo: 3401.0000 - Falso Positivo: 82.0000 - Verdadero Negativo: 3354.0000 - Falso Negativo: 75.0000 - Accuracy: 0.9773 - Precision: 0.9765 - val_loss: 0.6439 - val_AUC: 0.9105 - val_PRC: 0.8970 - val_RECALL: 0.9224 - val_Error Cuadrático Medio: 0.1364 - val_Verdadero Positivo: 416.0000 - val_Falso Positivo: 100.0000 - val_Verdadero Negativo: 313.0000 - val_Falso Negativo: 35.0000 - val_Accuracy: 0.8438 - val_Precision: 0.8062
# Epoch 39/50
# 216/216 [==============================] - 15s 72ms/step - loss: 0.0590 - AUC: 0.9973 - PRC: 0.9972 - RECALL: 0.9781 - Error Cuadrático Medio: 0.0160 - Verdadero Positivo: 3400.0000 - Falso Positivo: 71.0000 - Verdadero Negativo: 3365.0000 - Falso Negativo: 76.0000 - Accuracy: 0.9787 - Precision: 0.9795 - val_loss: 0.5569 - val_AUC: 0.9056 - val_PRC: 0.8969 - val_RECALL: 0.8426 - val_Error Cuadrático Medio: 0.1342 - val_Verdadero Positivo: 380.0000 - val_Falso Positivo: 79.0000 - val_Verdadero Negativo: 334.0000 - val_Falso Negativo: 71.0000 - val_Accuracy: 0.8264 - val_Precision: 0.8279
# Epoch 40/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.0525 - AUC: 0.9972 - PRC: 0.9970 - RECALL: 0.9842 - Error Cuadrático Medio: 0.0137 - Verdadero Positivo: 3421.0000 - Falso Positivo: 62.0000 - Verdadero Negativo: 3374.0000 - Falso Negativo: 55.0000 - Accuracy: 0.9831 - Precision: 0.9822 - val_loss: 0.4895 - val_AUC: 0.9084 - val_PRC: 0.9232 - val_RECALL: 0.7761 - val_Error Cuadrático Medio: 0.1381 - val_Verdadero Positivo: 350.0000 - val_Falso Positivo: 47.0000 - val_Verdadero Negativo: 366.0000 - val_Falso Negativo: 101.0000 - val_Accuracy: 0.8287 - val_Precision: 0.8816
# Epoch 41/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.0419 - AUC: 0.9985 - PRC: 0.9985 - RECALL: 0.9873 - Error Cuadrático Medio: 0.0100 - Verdadero Positivo: 3432.0000 - Falso Positivo: 44.0000 - Verdadero Negativo: 3392.0000 - Falso Negativo: 44.0000 - Accuracy: 0.9873 - Precision: 0.9873 - val_loss: 0.7042 - val_AUC: 0.8829 - val_PRC: 0.9037 - val_RECALL: 0.6386 - val_Error Cuadrático Medio: 0.1838 - val_Verdadero Positivo: 288.0000 - val_Falso Positivo: 31.0000 - val_Verdadero Negativo: 382.0000 - val_Falso Negativo: 163.0000 - val_Accuracy: 0.7755 - val_Precision: 0.9028
# Epoch 42/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0324 - AUC: 0.9989 - PRC: 0.9991 - RECALL: 0.9868 - Error Cuadrático Medio: 0.0086 - Verdadero Positivo: 3430.0000 - Falso Positivo: 32.0000 - Verdadero Negativo: 3404.0000 - Falso Negativo: 46.0000 - Accuracy: 0.9887 - Precision: 0.9908 - val_loss: 0.8129 - val_AUC: 0.8909 - val_PRC: 0.8606 - val_RECALL: 0.9224 - val_Error Cuadrático Medio: 0.1525 - val_Verdadero Positivo: 416.0000 - val_Falso Positivo: 115.0000 - val_Verdadero Negativo: 298.0000 - val_Falso Negativo: 35.0000 - val_Accuracy: 0.8264 - val_Precision: 0.7834
# Epoch 43/50
# 216/216 [==============================] - 15s 71ms/step - loss: 0.0335 - AUC: 0.9986 - PRC: 0.9985 - RECALL: 0.9882 - Error Cuadrático Medio: 0.0088 - Verdadero Positivo: 3435.0000 - Falso Positivo: 38.0000 - Verdadero Negativo: 3398.0000 - Falso Negativo: 41.0000 - Accuracy: 0.9886 - Precision: 0.9891 - val_loss: 0.6248 - val_AUC: 0.8915 - val_PRC: 0.9093 - val_RECALL: 0.7140 - val_Error Cuadrático Medio: 0.1593 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 35.0000 - val_Verdadero Negativo: 378.0000 - val_Falso Negativo: 129.0000 - val_Accuracy: 0.8102 - val_Precision: 0.9020
# Epoch 44/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.0484 - AUC: 0.9980 - PRC: 0.9983 - RECALL: 0.9865 - Error Cuadrático Medio: 0.0128 - Verdadero Positivo: 3429.0000 - Falso Positivo: 68.0000 - Verdadero Negativo: 3368.0000 - Falso Negativo: 47.0000 - Accuracy: 0.9834 - Precision: 0.9806 - val_loss: 1.0031 - val_AUC: 0.8648 - val_PRC: 0.8372 - val_RECALL: 0.9424 - val_Error Cuadrático Medio: 0.1982 - val_Verdadero Positivo: 425.0000 - val_Falso Positivo: 166.0000 - val_Verdadero Negativo: 247.0000 - val_Falso Negativo: 26.0000 - val_Accuracy: 0.7778 - val_Precision: 0.7191
# Epoch 45/50
# 216/216 [==============================] - 15s 69ms/step - loss: 0.0346 - AUC: 0.9985 - PRC: 0.9987 - RECALL: 0.9888 - Error Cuadrático Medio: 0.0087 - Verdadero Positivo: 3437.0000 - Falso Positivo: 35.0000 - Verdadero Negativo: 3401.0000 - Falso Negativo: 39.0000 - Accuracy: 0.9893 - Precision: 0.9899 - val_loss: 0.7041 - val_AUC: 0.8879 - val_PRC: 0.8643 - val_RECALL: 0.8803 - val_Error Cuadrático Medio: 0.1392 - val_Verdadero Positivo: 397.0000 - val_Falso Positivo: 84.0000 - val_Verdadero Negativo: 329.0000 - val_Falso Negativo: 54.0000 - val_Accuracy: 0.8403 - val_Precision: 0.8254
# Epoch 46/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0255 - AUC: 0.9990 - PRC: 0.9986 - RECALL: 0.9931 - Error Cuadrático Medio: 0.0060 - Verdadero Positivo: 3452.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 3408.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9925 - Precision: 0.9920 - val_loss: 0.6710 - val_AUC: 0.8973 - val_PRC: 0.9060 - val_RECALL: 0.8426 - val_Error Cuadrático Medio: 0.1480 - val_Verdadero Positivo: 380.0000 - val_Falso Positivo: 80.0000 - val_Verdadero Negativo: 333.0000 - val_Falso Negativo: 71.0000 - val_Accuracy: 0.8252 - val_Precision: 0.8261
# Epoch 47/50
# 216/216 [==============================] - 16s 72ms/step - loss: 0.0274 - AUC: 0.9992 - PRC: 0.9994 - RECALL: 0.9911 - Error Cuadrático Medio: 0.0071 - Verdadero Positivo: 3445.0000 - Falso Positivo: 33.0000 - Verdadero Negativo: 3403.0000 - Falso Negativo: 31.0000 - Accuracy: 0.9907 - Precision: 0.9905 - val_loss: 1.6469 - val_AUC: 0.8118 - val_PRC: 0.7691 - val_RECALL: 0.8647 - val_Error Cuadrático Medio: 0.2053 - val_Verdadero Positivo: 390.0000 - val_Falso Positivo: 136.0000 - val_Verdadero Negativo: 277.0000 - val_Falso Negativo: 61.0000 - val_Accuracy: 0.7720 - val_Precision: 0.7414
# Epoch 48/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0283 - AUC: 0.9991 - PRC: 0.9991 - RECALL: 0.9902 - Error Cuadrático Medio: 0.0075 - Verdadero Positivo: 3442.0000 - Falso Positivo: 34.0000 - Verdadero Negativo: 3402.0000 - Falso Negativo: 34.0000 - Accuracy: 0.9902 - Precision: 0.9902 - val_loss: 0.7343 - val_AUC: 0.8896 - val_PRC: 0.8709 - val_RECALL: 0.8603 - val_Error Cuadrático Medio: 0.1495 - val_Verdadero Positivo: 388.0000 - val_Falso Positivo: 93.0000 - val_Verdadero Negativo: 320.0000 - val_Falso Negativo: 63.0000 - val_Accuracy: 0.8194 - val_Precision: 0.8067
# Epoch 49/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0237 - AUC: 0.9991 - PRC: 0.9992 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0059 - Verdadero Positivo: 3448.0000 - Falso Positivo: 23.0000 - Verdadero Negativo: 3413.0000 - Falso Negativo: 28.0000 - Accuracy: 0.9926 - Precision: 0.9934 - val_loss: 0.7637 - val_AUC: 0.8921 - val_PRC: 0.9007 - val_RECALL: 0.7206 - val_Error Cuadrático Medio: 0.1685 - val_Verdadero Positivo: 325.0000 - val_Falso Positivo: 45.0000 - val_Verdadero Negativo: 368.0000 - val_Falso Negativo: 126.0000 - val_Accuracy: 0.8021 - val_Precision: 0.8784
# Epoch 50/50
# 216/216 [==============================] - 15s 70ms/step - loss: 0.0251 - AUC: 0.9993 - PRC: 0.9992 - RECALL: 0.9914 - Error Cuadrático Medio: 0.0069 - Verdadero Positivo: 3446.0000 - Falso Positivo: 37.0000 - Verdadero Negativo: 3399.0000 - Falso Negativo: 30.0000 - Accuracy: 0.9903 - Precision: 0.9894 - val_loss: 0.8162 - val_AUC: 0.8872 - val_PRC: 0.9032 - val_RECALL: 0.7029 - val_Error Cuadrático Medio: 0.1685 - val_Verdadero Positivo: 317.0000 - val_Falso Positivo: 31.0000 - val_Verdadero Negativo: 382.0000 - val_Falso Negativo: 134.0000 - val_Accuracy: 0.8090 - val_Precision: 0.9109
# 34/34 [==============================] - 3s 46ms/step - loss: 0.7717 - AUC: 0.8916 - PRC: 0.9057 - RECALL: 0.6629 - Error Cuadrático Medio: 0.1644 - Verdadero Positivo: 350.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 526.0000 - Falso Negativo: 178.0000 - Accuracy: 0.8111 - Precision: 0.9309
# {'loss': 0.7716918587684631, 'AUC': 0.8915600180625916, 'PRC': 0.9056892991065979, 'RECALL': 0.6628788113594055, 'Error Cuadrático Medio': 0.16435468196868896, 'Verdadero Positivo': 350.0, 'Falso Positivo': 26.0, 'Verdadero Negativo': 526.0, 'Falso Negativo': 178.0, 'Accuracy': 0.8111110925674438, 'Precision': 0.9308510422706604}
#
#  ...Calculando valores predichos para train y test: ...
# 216/216 [==============================] - 6s 19ms/step
# 34/34 [==============================] - 3s 22ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.7716918587684631
# AUC :  0.8915600180625916
# PRC :  0.9056892991065979
# RECALL :  0.6628788113594055
# Error Cuadrático Medio :  0.16435468196868896
# Verdadero Positivo :  350.0
# Falso Positivo :  26.0
# Verdadero Negativo :  526.0
# Falso Negativo :  178.0
# Accuracy :  0.8111110925674438
# Precision :  0.9308510422706604
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  526
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  26
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  178
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  350

# %% [markdown]
# #### ***Model-D***:  $~~~1 \times $*`ResNet-50`*+$1\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
model_name="model_D"
model = model_D(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias
apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 23834813 (90.92 MB)
# Trainable params: 23781693 (90.72 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 216/216 [==============================] - 56s 101ms/step - loss: 0.2590 - AUC: 0.9586 - PRC: 0.9610 - RECALL: 0.8677 - Error Cuadrático Medio: 0.0819 - Verdadero Positivo: 3016.0000 - Falso Positivo: 343.0000 - Verdadero Negativo: 3093.0000 - Falso Negativo: 460.0000 - Accuracy: 0.8838 - Precision: 0.8979 - val_loss: 2.9133 - val_AUC: 0.5000 - val_PRC: 0.5220 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.5181 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 413.0000 - val_Falso Negativo: 451.0000 - val_Accuracy: 0.4780 - val_Precision: 0.0000e+00
# Epoch 2/50
# 216/216 [==============================] - 21s 96ms/step - loss: 0.2131 - AUC: 0.9718 - PRC: 0.9734 - RECALL: 0.8990 - Error Cuadrático Medio: 0.0663 - Verdadero Positivo: 3125.0000 - Falso Positivo: 279.0000 - Verdadero Negativo: 3157.0000 - Falso Negativo: 351.0000 - Accuracy: 0.9089 - Precision: 0.9180 - val_loss: 1.6995 - val_AUC: 0.5807 - val_PRC: 0.5746 - val_RECALL: 0.0000e+00 - val_Error Cuadrático Medio: 0.4817 - val_Verdadero Positivo: 0.0000e+00 - val_Falso Positivo: 0.0000e+00 - val_Verdadero Negativo: 413.0000 - val_Falso Negativo: 451.0000 - val_Accuracy: 0.4780 - val_Precision: 0.0000e+00
# Epoch 3/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.1849 - AUC: 0.9788 - PRC: 0.9796 - RECALL: 0.9194 - Error Cuadrático Medio: 0.0557 - Verdadero Positivo: 3196.0000 - Falso Positivo: 242.0000 - Verdadero Negativo: 3194.0000 - Falso Negativo: 280.0000 - Accuracy: 0.9245 - Precision: 0.9296 - val_loss: 1.1645 - val_AUC: 0.5622 - val_PRC: 0.5477 - val_RECALL: 0.0554 - val_Error Cuadrático Medio: 0.3962 - val_Verdadero Positivo: 25.0000 - val_Falso Positivo: 20.0000 - val_Verdadero Negativo: 393.0000 - val_Falso Negativo: 426.0000 - val_Accuracy: 0.4838 - val_Precision: 0.5556
# Epoch 4/50
# 216/216 [==============================] - 21s 95ms/step - loss: 0.1652 - AUC: 0.9832 - PRC: 0.9839 - RECALL: 0.9304 - Error Cuadrático Medio: 0.0508 - Verdadero Positivo: 3234.0000 - Falso Positivo: 249.0000 - Verdadero Negativo: 3187.0000 - Falso Negativo: 242.0000 - Accuracy: 0.9290 - Precision: 0.9285 - val_loss: 0.9379 - val_AUC: 0.7154 - val_PRC: 0.6942 - val_RECALL: 0.8980 - val_Error Cuadrático Medio: 0.2791 - val_Verdadero Positivo: 405.0000 - val_Falso Positivo: 276.0000 - val_Verdadero Negativo: 137.0000 - val_Falso Negativo: 46.0000 - val_Accuracy: 0.6273 - val_Precision: 0.5947
# Epoch 5/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.1490 - AUC: 0.9861 - PRC: 0.9865 - RECALL: 0.9356 - Error Cuadrático Medio: 0.0450 - Verdadero Positivo: 3252.0000 - Falso Positivo: 215.0000 - Verdadero Negativo: 3221.0000 - Falso Negativo: 224.0000 - Accuracy: 0.9365 - Precision: 0.9380 - val_loss: 2.7984 - val_AUC: 0.7767 - val_PRC: 0.7155 - val_RECALL: 0.9889 - val_Error Cuadrático Medio: 0.3401 - val_Verdadero Positivo: 446.0000 - val_Falso Positivo: 321.0000 - val_Verdadero Negativo: 92.0000 - val_Falso Negativo: 5.0000 - val_Accuracy: 0.6227 - val_Precision: 0.5815
# Epoch 6/50
# 216/216 [==============================] - 21s 95ms/step - loss: 0.1314 - AUC: 0.9892 - PRC: 0.9897 - RECALL: 0.9442 - Error Cuadrático Medio: 0.0391 - Verdadero Positivo: 3282.0000 - Falso Positivo: 175.0000 - Verdadero Negativo: 3261.0000 - Falso Negativo: 194.0000 - Accuracy: 0.9466 - Precision: 0.9494 - val_loss: 0.3980 - val_AUC: 0.9229 - val_PRC: 0.9302 - val_RECALL: 0.8182 - val_Error Cuadrático Medio: 0.1178 - val_Verdadero Positivo: 369.0000 - val_Falso Positivo: 49.0000 - val_Verdadero Negativo: 364.0000 - val_Falso Negativo: 82.0000 - val_Accuracy: 0.8484 - val_Precision: 0.8828
# Epoch 7/50
# 216/216 [==============================] - 21s 95ms/step - loss: 0.1250 - AUC: 0.9906 - PRC: 0.9901 - RECALL: 0.9551 - Error Cuadrático Medio: 0.0342 - Verdadero Positivo: 3320.0000 - Falso Positivo: 156.0000 - Verdadero Negativo: 3280.0000 - Falso Negativo: 156.0000 - Accuracy: 0.9549 - Precision: 0.9551 - val_loss: 2.4613 - val_AUC: 0.3953 - val_PRC: 0.4500 - val_RECALL: 0.0133 - val_Error Cuadrático Medio: 0.5070 - val_Verdadero Positivo: 6.0000 - val_Falso Positivo: 15.0000 - val_Verdadero Negativo: 398.0000 - val_Falso Negativo: 445.0000 - val_Accuracy: 0.4676 - val_Precision: 0.2857
# Epoch 8/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.1466 - AUC: 0.9868 - PRC: 0.9870 - RECALL: 0.9379 - Error Cuadrático Medio: 0.0440 - Verdadero Positivo: 3260.0000 - Falso Positivo: 197.0000 - Verdadero Negativo: 3239.0000 - Falso Negativo: 216.0000 - Accuracy: 0.9402 - Precision: 0.9430 - val_loss: 0.4847 - val_AUC: 0.9035 - val_PRC: 0.8924 - val_RECALL: 0.8448 - val_Error Cuadrático Medio: 0.1261 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 71.0000 - val_Verdadero Negativo: 342.0000 - val_Falso Negativo: 70.0000 - val_Accuracy: 0.8368 - val_Precision: 0.8429
# Epoch 9/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.1121 - AUC: 0.9921 - PRC: 0.9924 - RECALL: 0.9548 - Error Cuadrático Medio: 0.0330 - Verdadero Positivo: 3319.0000 - Falso Positivo: 153.0000 - Verdadero Negativo: 3283.0000 - Falso Negativo: 157.0000 - Accuracy: 0.9552 - Precision: 0.9559 - val_loss: 0.5661 - val_AUC: 0.9315 - val_PRC: 0.9321 - val_RECALL: 0.9645 - val_Error Cuadrático Medio: 0.1648 - val_Verdadero Positivo: 435.0000 - val_Falso Positivo: 164.0000 - val_Verdadero Negativo: 249.0000 - val_Falso Negativo: 16.0000 - val_Accuracy: 0.7917 - val_Precision: 0.7262
# Epoch 10/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0924 - AUC: 0.9941 - PRC: 0.9948 - RECALL: 0.9629 - Error Cuadrático Medio: 0.0257 - Verdadero Positivo: 3347.0000 - Falso Positivo: 92.0000 - Verdadero Negativo: 3344.0000 - Falso Negativo: 129.0000 - Accuracy: 0.9680 - Precision: 0.9732 - val_loss: 0.6668 - val_AUC: 0.9100 - val_PRC: 0.8860 - val_RECALL: 0.8647 - val_Error Cuadrático Medio: 0.1155 - val_Verdadero Positivo: 390.0000 - val_Falso Positivo: 61.0000 - val_Verdadero Negativo: 352.0000 - val_Falso Negativo: 61.0000 - val_Accuracy: 0.8588 - val_Precision: 0.8647
# Epoch 11/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.1206 - AUC: 0.9911 - PRC: 0.9908 - RECALL: 0.9557 - Error Cuadrático Medio: 0.0345 - Verdadero Positivo: 3322.0000 - Falso Positivo: 172.0000 - Verdadero Negativo: 3264.0000 - Falso Negativo: 154.0000 - Accuracy: 0.9528 - Precision: 0.9508 - val_loss: 0.4654 - val_AUC: 0.9159 - val_PRC: 0.9253 - val_RECALL: 0.9335 - val_Error Cuadrático Medio: 0.1474 - val_Verdadero Positivo: 421.0000 - val_Falso Positivo: 151.0000 - val_Verdadero Negativo: 262.0000 - val_Falso Negativo: 30.0000 - val_Accuracy: 0.7905 - val_Precision: 0.7360
# Epoch 12/50
# 216/216 [==============================] - 21s 95ms/step - loss: 0.0871 - AUC: 0.9947 - PRC: 0.9945 - RECALL: 0.9707 - Error Cuadrático Medio: 0.0240 - Verdadero Positivo: 3374.0000 - Falso Positivo: 115.0000 - Verdadero Negativo: 3321.0000 - Falso Negativo: 102.0000 - Accuracy: 0.9686 - Precision: 0.9670 - val_loss: 0.4556 - val_AUC: 0.9180 - val_PRC: 0.9286 - val_RECALL: 0.8559 - val_Error Cuadrático Medio: 0.1262 - val_Verdadero Positivo: 386.0000 - val_Falso Positivo: 65.0000 - val_Verdadero Negativo: 348.0000 - val_Falso Negativo: 65.0000 - val_Accuracy: 0.8495 - val_Precision: 0.8559
# Epoch 13/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0725 - AUC: 0.9961 - PRC: 0.9957 - RECALL: 0.9744 - Error Cuadrático Medio: 0.0202 - Verdadero Positivo: 3387.0000 - Falso Positivo: 99.0000 - Verdadero Negativo: 3337.0000 - Falso Negativo: 89.0000 - Accuracy: 0.9728 - Precision: 0.9716 - val_loss: 0.7161 - val_AUC: 0.9062 - val_PRC: 0.9183 - val_RECALL: 0.6475 - val_Error Cuadrático Medio: 0.1750 - val_Verdadero Positivo: 292.0000 - val_Falso Positivo: 20.0000 - val_Verdadero Negativo: 393.0000 - val_Falso Negativo: 159.0000 - val_Accuracy: 0.7928 - val_Precision: 0.9359
# Epoch 14/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0551 - AUC: 0.9977 - PRC: 0.9977 - RECALL: 0.9810 - Error Cuadrático Medio: 0.0153 - Verdadero Positivo: 3410.0000 - Falso Positivo: 70.0000 - Verdadero Negativo: 3366.0000 - Falso Negativo: 66.0000 - Accuracy: 0.9803 - Precision: 0.9799 - val_loss: 0.5156 - val_AUC: 0.9264 - val_PRC: 0.9226 - val_RECALL: 0.9379 - val_Error Cuadrático Medio: 0.1337 - val_Verdadero Positivo: 423.0000 - val_Falso Positivo: 115.0000 - val_Verdadero Negativo: 298.0000 - val_Falso Negativo: 28.0000 - val_Accuracy: 0.8345 - val_Precision: 0.7862
# Epoch 15/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0481 - AUC: 0.9981 - PRC: 0.9982 - RECALL: 0.9827 - Error Cuadrático Medio: 0.0130 - Verdadero Positivo: 3416.0000 - Falso Positivo: 59.0000 - Verdadero Negativo: 3377.0000 - Falso Negativo: 60.0000 - Accuracy: 0.9828 - Precision: 0.9830 - val_loss: 2.3494 - val_AUC: 0.7960 - val_PRC: 0.7339 - val_RECALL: 0.9867 - val_Error Cuadrático Medio: 0.3216 - val_Verdadero Positivo: 445.0000 - val_Falso Positivo: 300.0000 - val_Verdadero Negativo: 113.0000 - val_Falso Negativo: 6.0000 - val_Accuracy: 0.6458 - val_Precision: 0.5973
# Epoch 16/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0501 - AUC: 0.9978 - PRC: 0.9975 - RECALL: 0.9816 - Error Cuadrático Medio: 0.0133 - Verdadero Positivo: 3412.0000 - Falso Positivo: 58.0000 - Verdadero Negativo: 3378.0000 - Falso Negativo: 64.0000 - Accuracy: 0.9823 - Precision: 0.9833 - val_loss: 1.3318 - val_AUC: 0.8218 - val_PRC: 0.8569 - val_RECALL: 0.2949 - val_Error Cuadrático Medio: 0.3210 - val_Verdadero Positivo: 133.0000 - val_Falso Positivo: 5.0000 - val_Verdadero Negativo: 408.0000 - val_Falso Negativo: 318.0000 - val_Accuracy: 0.6262 - val_Precision: 0.9638
# Epoch 17/50
# 216/216 [==============================] - 21s 95ms/step - loss: 0.0408 - AUC: 0.9982 - PRC: 0.9979 - RECALL: 0.9856 - Error Cuadrático Medio: 0.0102 - Verdadero Positivo: 3426.0000 - Falso Positivo: 38.0000 - Verdadero Negativo: 3398.0000 - Falso Negativo: 50.0000 - Accuracy: 0.9873 - Precision: 0.9890 - val_loss: 0.6431 - val_AUC: 0.8985 - val_PRC: 0.9043 - val_RECALL: 0.8581 - val_Error Cuadrático Medio: 0.1497 - val_Verdadero Positivo: 387.0000 - val_Falso Positivo: 93.0000 - val_Verdadero Negativo: 320.0000 - val_Falso Negativo: 64.0000 - val_Accuracy: 0.8183 - val_Precision: 0.8062
# Epoch 18/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.0610 - AUC: 0.9970 - PRC: 0.9973 - RECALL: 0.9773 - Error Cuadrático Medio: 0.0171 - Verdadero Positivo: 3397.0000 - Falso Positivo: 83.0000 - Verdadero Negativo: 3353.0000 - Falso Negativo: 79.0000 - Accuracy: 0.9766 - Precision: 0.9761 - val_loss: 1.1845 - val_AUC: 0.8585 - val_PRC: 0.8869 - val_RECALL: 0.4213 - val_Error Cuadrático Medio: 0.2702 - val_Verdadero Positivo: 190.0000 - val_Falso Positivo: 9.0000 - val_Verdadero Negativo: 404.0000 - val_Falso Negativo: 261.0000 - val_Accuracy: 0.6875 - val_Precision: 0.9548
# Epoch 19/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0386 - AUC: 0.9987 - PRC: 0.9986 - RECALL: 0.9850 - Error Cuadrático Medio: 0.0104 - Verdadero Positivo: 3424.0000 - Falso Positivo: 41.0000 - Verdadero Negativo: 3395.0000 - Falso Negativo: 52.0000 - Accuracy: 0.9865 - Precision: 0.9882 - val_loss: 0.6217 - val_AUC: 0.8855 - val_PRC: 0.8971 - val_RECALL: 0.6918 - val_Error Cuadrático Medio: 0.1625 - val_Verdadero Positivo: 312.0000 - val_Falso Positivo: 35.0000 - val_Verdadero Negativo: 378.0000 - val_Falso Negativo: 139.0000 - val_Accuracy: 0.7986 - val_Precision: 0.8991
# Epoch 20/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.0368 - AUC: 0.9985 - PRC: 0.9982 - RECALL: 0.9882 - Error Cuadrático Medio: 0.0089 - Verdadero Positivo: 3435.0000 - Falso Positivo: 40.0000 - Verdadero Negativo: 3396.0000 - Falso Negativo: 41.0000 - Accuracy: 0.9883 - Precision: 0.9885 - val_loss: 1.1154 - val_AUC: 0.8634 - val_PRC: 0.8214 - val_RECALL: 0.9667 - val_Error Cuadrático Medio: 0.2143 - val_Verdadero Positivo: 436.0000 - val_Falso Positivo: 196.0000 - val_Verdadero Negativo: 217.0000 - val_Falso Negativo: 15.0000 - val_Accuracy: 0.7558 - val_Precision: 0.6899
# Epoch 21/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0339 - AUC: 0.9988 - PRC: 0.9988 - RECALL: 0.9899 - Error Cuadrático Medio: 0.0085 - Verdadero Positivo: 3441.0000 - Falso Positivo: 37.0000 - Verdadero Negativo: 3399.0000 - Falso Negativo: 35.0000 - Accuracy: 0.9896 - Precision: 0.9894 - val_loss: 1.1730 - val_AUC: 0.8656 - val_PRC: 0.8196 - val_RECALL: 0.9512 - val_Error Cuadrático Medio: 0.1810 - val_Verdadero Positivo: 429.0000 - val_Falso Positivo: 150.0000 - val_Verdadero Negativo: 263.0000 - val_Falso Negativo: 22.0000 - val_Accuracy: 0.8009 - val_Precision: 0.7409
# Epoch 22/50
# 216/216 [==============================] - 21s 95ms/step - loss: 0.0333 - AUC: 0.9990 - PRC: 0.9990 - RECALL: 0.9868 - Error Cuadrático Medio: 0.0094 - Verdadero Positivo: 3430.0000 - Falso Positivo: 43.0000 - Verdadero Negativo: 3393.0000 - Falso Negativo: 46.0000 - Accuracy: 0.9871 - Precision: 0.9876 - val_loss: 0.8191 - val_AUC: 0.8909 - val_PRC: 0.8700 - val_RECALL: 0.9202 - val_Error Cuadrático Medio: 0.1625 - val_Verdadero Positivo: 415.0000 - val_Falso Positivo: 127.0000 - val_Verdadero Negativo: 286.0000 - val_Falso Negativo: 36.0000 - val_Accuracy: 0.8113 - val_Precision: 0.7657
# Epoch 23/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.0262 - AUC: 0.9989 - PRC: 0.9988 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0063 - Verdadero Positivo: 3451.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9926 - Precision: 0.9925 - val_loss: 0.6319 - val_AUC: 0.9089 - val_PRC: 0.8992 - val_RECALL: 0.8869 - val_Error Cuadrático Medio: 0.1440 - val_Verdadero Positivo: 400.0000 - val_Falso Positivo: 91.0000 - val_Verdadero Negativo: 322.0000 - val_Falso Negativo: 51.0000 - val_Accuracy: 0.8356 - val_Precision: 0.8147
# Epoch 24/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0319 - AUC: 0.9987 - PRC: 0.9986 - RECALL: 0.9911 - Error Cuadrático Medio: 0.0084 - Verdadero Positivo: 3445.0000 - Falso Positivo: 45.0000 - Verdadero Negativo: 3391.0000 - Falso Negativo: 31.0000 - Accuracy: 0.9890 - Precision: 0.9871 - val_loss: 0.5936 - val_AUC: 0.9119 - val_PRC: 0.9201 - val_RECALL: 0.7384 - val_Error Cuadrático Medio: 0.1449 - val_Verdadero Positivo: 333.0000 - val_Falso Positivo: 39.0000 - val_Verdadero Negativo: 374.0000 - val_Falso Negativo: 118.0000 - val_Accuracy: 0.8183 - val_Precision: 0.8952
# Epoch 25/50
# 216/216 [==============================] - 21s 96ms/step - loss: 0.0216 - AUC: 0.9995 - PRC: 0.9996 - RECALL: 0.9942 - Error Cuadrático Medio: 0.0055 - Verdadero Positivo: 3456.0000 - Falso Positivo: 23.0000 - Verdadero Negativo: 3413.0000 - Falso Negativo: 20.0000 - Accuracy: 0.9938 - Precision: 0.9934 - val_loss: 0.9334 - val_AUC: 0.8677 - val_PRC: 0.8589 - val_RECALL: 0.7761 - val_Error Cuadrático Medio: 0.1694 - val_Verdadero Positivo: 350.0000 - val_Falso Positivo: 68.0000 - val_Verdadero Negativo: 345.0000 - val_Falso Negativo: 101.0000 - val_Accuracy: 0.8044 - val_Precision: 0.8373
# Epoch 26/50
# 216/216 [==============================] - 20s 91ms/step - loss: 0.0297 - AUC: 0.9989 - PRC: 0.9989 - RECALL: 0.9899 - Error Cuadrático Medio: 0.0078 - Verdadero Positivo: 3441.0000 - Falso Positivo: 36.0000 - Verdadero Negativo: 3400.0000 - Falso Negativo: 35.0000 - Accuracy: 0.9897 - Precision: 0.9896 - val_loss: 0.6217 - val_AUC: 0.9141 - val_PRC: 0.8970 - val_RECALL: 0.9091 - val_Error Cuadrático Medio: 0.1270 - val_Verdadero Positivo: 410.0000 - val_Falso Positivo: 84.0000 - val_Verdadero Negativo: 329.0000 - val_Falso Negativo: 41.0000 - val_Accuracy: 0.8553 - val_Precision: 0.8300
# Epoch 27/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0176 - AUC: 0.9995 - PRC: 0.9997 - RECALL: 0.9945 - Error Cuadrático Medio: 0.0048 - Verdadero Positivo: 3457.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 3409.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9933 - Precision: 0.9923 - val_loss: 1.6111 - val_AUC: 0.8294 - val_PRC: 0.7766 - val_RECALL: 0.9601 - val_Error Cuadrático Medio: 0.2358 - val_Verdadero Positivo: 433.0000 - val_Falso Positivo: 216.0000 - val_Verdadero Negativo: 197.0000 - val_Falso Negativo: 18.0000 - val_Accuracy: 0.7292 - val_Precision: 0.6672
# Epoch 28/50
# 216/216 [==============================] - 20s 95ms/step - loss: 0.0248 - AUC: 0.9991 - PRC: 0.9991 - RECALL: 0.9914 - Error Cuadrático Medio: 0.0066 - Verdadero Positivo: 3446.0000 - Falso Positivo: 33.0000 - Verdadero Negativo: 3403.0000 - Falso Negativo: 30.0000 - Accuracy: 0.9909 - Precision: 0.9905 - val_loss: 1.0180 - val_AUC: 0.8396 - val_PRC: 0.8744 - val_RECALL: 0.5743 - val_Error Cuadrático Medio: 0.2223 - val_Verdadero Positivo: 259.0000 - val_Falso Positivo: 28.0000 - val_Verdadero Negativo: 385.0000 - val_Falso Negativo: 192.0000 - val_Accuracy: 0.7454 - val_Precision: 0.9024
# Epoch 29/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0273 - AUC: 0.9993 - PRC: 0.9994 - RECALL: 0.9911 - Error Cuadrático Medio: 0.0077 - Verdadero Positivo: 3445.0000 - Falso Positivo: 39.0000 - Verdadero Negativo: 3397.0000 - Falso Negativo: 31.0000 - Accuracy: 0.9899 - Precision: 0.9888 - val_loss: 0.8228 - val_AUC: 0.8888 - val_PRC: 0.8636 - val_RECALL: 0.9202 - val_Error Cuadrático Medio: 0.1538 - val_Verdadero Positivo: 415.0000 - val_Falso Positivo: 111.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 36.0000 - val_Accuracy: 0.8299 - val_Precision: 0.7890
# Epoch 30/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.0214 - AUC: 0.9995 - PRC: 0.9996 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0056 - Verdadero Positivo: 3451.0000 - Falso Positivo: 31.0000 - Verdadero Negativo: 3405.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9919 - Precision: 0.9911 - val_loss: 1.6931 - val_AUC: 0.7834 - val_PRC: 0.8339 - val_RECALL: 0.3348 - val_Error Cuadrático Medio: 0.3214 - val_Verdadero Positivo: 151.0000 - val_Falso Positivo: 9.0000 - val_Verdadero Negativo: 404.0000 - val_Falso Negativo: 300.0000 - val_Accuracy: 0.6424 - val_Precision: 0.9438
# Epoch 31/50
# 216/216 [==============================] - 21s 96ms/step - loss: 0.0279 - AUC: 0.9991 - PRC: 0.9991 - RECALL: 0.9914 - Error Cuadrático Medio: 0.0071 - Verdadero Positivo: 3446.0000 - Falso Positivo: 34.0000 - Verdadero Negativo: 3402.0000 - Falso Negativo: 30.0000 - Accuracy: 0.9907 - Precision: 0.9902 - val_loss: 1.7861 - val_AUC: 0.8190 - val_PRC: 0.8608 - val_RECALL: 0.4213 - val_Error Cuadrático Medio: 0.2870 - val_Verdadero Positivo: 190.0000 - val_Falso Positivo: 6.0000 - val_Verdadero Negativo: 407.0000 - val_Falso Negativo: 261.0000 - val_Accuracy: 0.6910 - val_Precision: 0.9694
# Epoch 32/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0286 - AUC: 0.9990 - PRC: 0.9988 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0065 - Verdadero Positivo: 3451.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 3408.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9923 - Precision: 0.9920 - val_loss: 1.2380 - val_AUC: 0.8450 - val_PRC: 0.8835 - val_RECALL: 0.5188 - val_Error Cuadrático Medio: 0.2334 - val_Verdadero Positivo: 234.0000 - val_Falso Positivo: 18.0000 - val_Verdadero Negativo: 395.0000 - val_Falso Negativo: 217.0000 - val_Accuracy: 0.7280 - val_Precision: 0.9286
# Epoch 33/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0250 - AUC: 0.9992 - PRC: 0.9990 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0067 - Verdadero Positivo: 3450.0000 - Falso Positivo: 33.0000 - Verdadero Negativo: 3403.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9915 - Precision: 0.9905 - val_loss: 0.6613 - val_AUC: 0.9043 - val_PRC: 0.9141 - val_RECALL: 0.7805 - val_Error Cuadrático Medio: 0.1412 - val_Verdadero Positivo: 352.0000 - val_Falso Positivo: 46.0000 - val_Verdadero Negativo: 367.0000 - val_Falso Negativo: 99.0000 - val_Accuracy: 0.8322 - val_Precision: 0.8844
# Epoch 34/50
# 216/216 [==============================] - 20s 95ms/step - loss: 0.0277 - AUC: 0.9994 - PRC: 0.9994 - RECALL: 0.9899 - Error Cuadrático Medio: 0.0075 - Verdadero Positivo: 3441.0000 - Falso Positivo: 34.0000 - Verdadero Negativo: 3402.0000 - Falso Negativo: 35.0000 - Accuracy: 0.9900 - Precision: 0.9902 - val_loss: 0.6357 - val_AUC: 0.8923 - val_PRC: 0.9006 - val_RECALL: 0.7428 - val_Error Cuadrático Medio: 0.1520 - val_Verdadero Positivo: 335.0000 - val_Falso Positivo: 40.0000 - val_Verdadero Negativo: 373.0000 - val_Falso Negativo: 116.0000 - val_Accuracy: 0.8194 - val_Precision: 0.8933
# Epoch 35/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0185 - AUC: 0.9997 - PRC: 0.9997 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0052 - Verdadero Positivo: 3451.0000 - Falso Positivo: 25.0000 - Verdadero Negativo: 3411.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9928 - Precision: 0.9928 - val_loss: 0.8880 - val_AUC: 0.8930 - val_PRC: 0.9090 - val_RECALL: 0.6851 - val_Error Cuadrático Medio: 0.1676 - val_Verdadero Positivo: 309.0000 - val_Falso Positivo: 25.0000 - val_Verdadero Negativo: 388.0000 - val_Falso Negativo: 142.0000 - val_Accuracy: 0.8067 - val_Precision: 0.9251
# Epoch 36/50
# 216/216 [==============================] - 20s 94ms/step - loss: 0.0270 - AUC: 0.9993 - PRC: 0.9990 - RECALL: 0.9896 - Error Cuadrático Medio: 0.0075 - Verdadero Positivo: 3440.0000 - Falso Positivo: 34.0000 - Verdadero Negativo: 3402.0000 - Falso Negativo: 36.0000 - Accuracy: 0.9899 - Precision: 0.9902 - val_loss: 2.3780 - val_AUC: 0.7449 - val_PRC: 0.8057 - val_RECALL: 0.1885 - val_Error Cuadrático Medio: 0.3948 - val_Verdadero Positivo: 85.0000 - val_Falso Positivo: 3.0000 - val_Verdadero Negativo: 410.0000 - val_Falso Negativo: 366.0000 - val_Accuracy: 0.5729 - val_Precision: 0.9659
# Epoch 37/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0162 - AUC: 0.9994 - PRC: 0.9992 - RECALL: 0.9957 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 3461.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9955 - Precision: 0.9954 - val_loss: 4.0134 - val_AUC: 0.7368 - val_PRC: 0.6763 - val_RECALL: 0.9933 - val_Error Cuadrático Medio: 0.3251 - val_Verdadero Positivo: 448.0000 - val_Falso Positivo: 289.0000 - val_Verdadero Negativo: 124.0000 - val_Falso Negativo: 3.0000 - val_Accuracy: 0.6620 - val_Precision: 0.6079
# Epoch 38/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0171 - AUC: 0.9992 - PRC: 0.9993 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0040 - Verdadero Positivo: 3458.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9951 - Precision: 0.9954 - val_loss: 0.7547 - val_AUC: 0.8793 - val_PRC: 0.8803 - val_RECALL: 0.7472 - val_Error Cuadrático Medio: 0.1627 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 54.0000 - val_Verdadero Negativo: 359.0000 - val_Falso Negativo: 114.0000 - val_Accuracy: 0.8056 - val_Precision: 0.8619
# Epoch 39/50
# 216/216 [==============================] - 20s 95ms/step - loss: 0.0266 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9931 - Error Cuadrático Medio: 0.0049 - Verdadero Positivo: 3452.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 3415.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9935 - Precision: 0.9940 - val_loss: 0.8236 - val_AUC: 0.8324 - val_PRC: 0.8309 - val_RECALL: 0.6608 - val_Error Cuadrático Medio: 0.2080 - val_Verdadero Positivo: 298.0000 - val_Falso Positivo: 68.0000 - val_Verdadero Negativo: 345.0000 - val_Falso Negativo: 153.0000 - val_Accuracy: 0.7442 - val_Precision: 0.8142
# Epoch 40/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0491 - AUC: 0.9984 - PRC: 0.9978 - RECALL: 0.9885 - Error Cuadrático Medio: 0.0092 - Verdadero Positivo: 3436.0000 - Falso Positivo: 42.0000 - Verdadero Negativo: 3394.0000 - Falso Negativo: 40.0000 - Accuracy: 0.9881 - Precision: 0.9879 - val_loss: 1.1011 - val_AUC: 0.7980 - val_PRC: 0.7729 - val_RECALL: 0.7295 - val_Error Cuadrático Medio: 0.2171 - val_Verdadero Positivo: 329.0000 - val_Falso Positivo: 98.0000 - val_Verdadero Negativo: 315.0000 - val_Falso Negativo: 122.0000 - val_Accuracy: 0.7454 - val_Precision: 0.7705
# Epoch 41/50
# 216/216 [==============================] - 20s 95ms/step - loss: 0.0208 - AUC: 0.9989 - PRC: 0.9986 - RECALL: 0.9934 - Error Cuadrático Medio: 0.0049 - Verdadero Positivo: 3453.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 23.0000 - Accuracy: 0.9939 - Precision: 0.9945 - val_loss: 1.6783 - val_AUC: 0.7408 - val_PRC: 0.7790 - val_RECALL: 0.4235 - val_Error Cuadrático Medio: 0.3020 - val_Verdadero Positivo: 191.0000 - val_Falso Positivo: 21.0000 - val_Verdadero Negativo: 392.0000 - val_Falso Negativo: 260.0000 - val_Accuracy: 0.6748 - val_Precision: 0.9009
# Epoch 42/50
# 216/216 [==============================] - 20s 95ms/step - loss: 0.0192 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0054 - Verdadero Positivo: 3455.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 3409.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9931 - Precision: 0.9922 - val_loss: 0.7035 - val_AUC: 0.9115 - val_PRC: 0.8927 - val_RECALL: 0.9224 - val_Error Cuadrático Medio: 0.1292 - val_Verdadero Positivo: 416.0000 - val_Falso Positivo: 93.0000 - val_Verdadero Negativo: 320.0000 - val_Falso Negativo: 35.0000 - val_Accuracy: 0.8519 - val_Precision: 0.8173
# Epoch 43/50
# 216/216 [==============================] - 21s 96ms/step - loss: 0.0083 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0020 - Verdadero Positivo: 3466.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 3430.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9977 - Precision: 0.9983 - val_loss: 0.9766 - val_AUC: 0.8747 - val_PRC: 0.8843 - val_RECALL: 0.7295 - val_Error Cuadrático Medio: 0.1662 - val_Verdadero Positivo: 329.0000 - val_Falso Positivo: 42.0000 - val_Verdadero Negativo: 371.0000 - val_Falso Negativo: 122.0000 - val_Accuracy: 0.8102 - val_Precision: 0.8868
# Epoch 44/50
# 216/216 [==============================] - 20s 95ms/step - loss: 0.0218 - AUC: 0.9992 - PRC: 0.9990 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0056 - Verdadero Positivo: 3448.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 3415.0000 - Falso Negativo: 28.0000 - Accuracy: 0.9929 - Precision: 0.9939 - val_loss: 0.7602 - val_AUC: 0.8921 - val_PRC: 0.9073 - val_RECALL: 0.7361 - val_Error Cuadrático Medio: 0.1481 - val_Verdadero Positivo: 332.0000 - val_Falso Positivo: 27.0000 - val_Verdadero Negativo: 386.0000 - val_Falso Negativo: 119.0000 - val_Accuracy: 0.8310 - val_Precision: 0.9248
# Epoch 45/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0137 - AUC: 0.9997 - PRC: 0.9998 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 3458.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 3425.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9958 - Precision: 0.9968 - val_loss: 1.9409 - val_AUC: 0.8190 - val_PRC: 0.7642 - val_RECALL: 0.9667 - val_Error Cuadrático Medio: 0.2670 - val_Verdadero Positivo: 436.0000 - val_Falso Positivo: 236.0000 - val_Verdadero Negativo: 177.0000 - val_Falso Negativo: 15.0000 - val_Accuracy: 0.7095 - val_Precision: 0.6488
# Epoch 46/50
# 216/216 [==============================] - 21s 96ms/step - loss: 0.0199 - AUC: 0.9996 - PRC: 0.9995 - RECALL: 0.9911 - Error Cuadrático Medio: 0.0054 - Verdadero Positivo: 3445.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 31.0000 - Accuracy: 0.9932 - Precision: 0.9954 - val_loss: 0.8036 - val_AUC: 0.8889 - val_PRC: 0.8784 - val_RECALL: 0.8359 - val_Error Cuadrático Medio: 0.1459 - val_Verdadero Positivo: 377.0000 - val_Falso Positivo: 66.0000 - val_Verdadero Negativo: 347.0000 - val_Falso Negativo: 74.0000 - val_Accuracy: 0.8380 - val_Precision: 0.8510
# Epoch 47/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0161 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0038 - Verdadero Positivo: 3460.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9954 - Precision: 0.9954 - val_loss: 0.6709 - val_AUC: 0.9182 - val_PRC: 0.9021 - val_RECALL: 0.9180 - val_Error Cuadrático Medio: 0.1301 - val_Verdadero Positivo: 414.0000 - val_Falso Positivo: 98.0000 - val_Verdadero Negativo: 315.0000 - val_Falso Negativo: 37.0000 - val_Accuracy: 0.8438 - val_Precision: 0.8086
# Epoch 48/50
# 216/216 [==============================] - 21s 96ms/step - loss: 0.0086 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0022 - Verdadero Positivo: 3466.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9973 - Precision: 0.9974 - val_loss: 1.0347 - val_AUC: 0.8549 - val_PRC: 0.8858 - val_RECALL: 0.6519 - val_Error Cuadrático Medio: 0.1940 - val_Verdadero Positivo: 294.0000 - val_Falso Positivo: 30.0000 - val_Verdadero Negativo: 383.0000 - val_Falso Negativo: 157.0000 - val_Accuracy: 0.7836 - val_Precision: 0.9074
# Epoch 49/50
# 216/216 [==============================] - 20s 92ms/step - loss: 0.0136 - AUC: 0.9995 - PRC: 0.9995 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0030 - Verdadero Positivo: 3462.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 14.0000 - Accuracy: 0.9958 - Precision: 0.9957 - val_loss: 0.9116 - val_AUC: 0.8603 - val_PRC: 0.8484 - val_RECALL: 0.7761 - val_Error Cuadrático Medio: 0.1774 - val_Verdadero Positivo: 350.0000 - val_Falso Positivo: 81.0000 - val_Verdadero Negativo: 332.0000 - val_Falso Negativo: 101.0000 - val_Accuracy: 0.7894 - val_Precision: 0.8121
# Epoch 50/50
# 216/216 [==============================] - 20s 93ms/step - loss: 0.0092 - AUC: 0.9997 - PRC: 0.9996 - RECALL: 0.9977 - Error Cuadrático Medio: 0.0022 - Verdadero Positivo: 3468.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 3426.0000 - Falso Negativo: 8.0000 - Accuracy: 0.9974 - Precision: 0.9971 - val_loss: 2.2781 - val_AUC: 0.7452 - val_PRC: 0.8050 - val_RECALL: 0.3149 - val_Error Cuadrático Medio: 0.3464 - val_Verdadero Positivo: 142.0000 - val_Falso Positivo: 8.0000 - val_Verdadero Negativo: 405.0000 - val_Falso Negativo: 309.0000 - val_Accuracy: 0.6331 - val_Precision: 0.9467
# 34/34 [==============================] - 3s 44ms/step - loss: 2.2335 - AUC: 0.7327 - PRC: 0.7704 - RECALL: 0.2822 - Error Cuadrático Medio: 0.3410 - Verdadero Positivo: 149.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 540.0000 - Falso Negativo: 379.0000 - Accuracy: 0.6380 - Precision: 0.9255
# {'loss': 2.233546733856201, 'AUC': 0.7327178716659546, 'PRC': 0.7704314589500427, 'RECALL': 0.282196968793869, 'Error Cuadrático Medio': 0.3410150110721588, 'Verdadero Positivo': 149.0, 'Falso Positivo': 12.0, 'Verdadero Negativo': 540.0, 'Falso Negativo': 379.0, 'Accuracy': 0.6379629373550415, 'Precision': 0.9254658222198486}
#
#  ...Calculando valores predichos para train y test: ...
# 216/216 [==============================] - 6s 25ms/step
# 34/34 [==============================] - 3s 29ms/step
#
#  ** Resultados de las métricas:...
# loss :  2.233546733856201
# AUC :  0.7327178716659546
# PRC :  0.7704314589500427
# RECALL :  0.282196968793869
# Error Cuadrático Medio :  0.3410150110721588
# Verdadero Positivo :  149.0
# Falso Positivo :  12.0
# Verdadero Negativo :  540.0
# Falso Negativo :  379.0
# Accuracy :  0.6379629373550415
# Precision :  0.9254658222198486
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  540
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  12
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  379
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  149

# %% [markdown]
# #### ***Model-E***:  $~~~1 \times $*`Xception`*+$1\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
model_name="model_E"
model = model_E(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias
apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  xception (Functional)       (None, 3, 3, 2048)        20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21108581 (80.52 MB)
# Trainable params: 21054053 (80.31 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 216/216 [==============================] - 52s 121ms/step - loss: 0.2411 - AUC: 0.9646 - PRC: 0.9657 - RECALL: 0.8959 - Error Cuadrático Medio: 0.0751 - Verdadero Positivo: 3114.0000 - Falso Positivo: 384.0000 - Verdadero Negativo: 3052.0000 - Falso Negativo: 362.0000 - Accuracy: 0.8921 - Precision: 0.8902 - val_loss: 1.0429 - val_AUC: 0.8671 - val_PRC: 0.8270 - val_RECALL: 0.9512 - val_Error Cuadrático Medio: 0.2039 - val_Verdadero Positivo: 429.0000 - val_Falso Positivo: 181.0000 - val_Verdadero Negativo: 232.0000 - val_Falso Negativo: 22.0000 - val_Accuracy: 0.7650 - val_Precision: 0.7033
# Epoch 2/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.1626 - AUC: 0.9835 - PRC: 0.9843 - RECALL: 0.9381 - Error Cuadrático Medio: 0.0487 - Verdadero Positivo: 3261.0000 - Falso Positivo: 219.0000 - Verdadero Negativo: 3217.0000 - Falso Negativo: 215.0000 - Accuracy: 0.9372 - Precision: 0.9371 - val_loss: 0.6542 - val_AUC: 0.9077 - val_PRC: 0.9002 - val_RECALL: 0.9534 - val_Error Cuadrático Medio: 0.1644 - val_Verdadero Positivo: 430.0000 - val_Falso Positivo: 159.0000 - val_Verdadero Negativo: 254.0000 - val_Falso Negativo: 21.0000 - val_Accuracy: 0.7917 - val_Precision: 0.7301
# Epoch 3/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.1358 - AUC: 0.9883 - PRC: 0.9890 - RECALL: 0.9471 - Error Cuadrático Medio: 0.0401 - Verdadero Positivo: 3292.0000 - Falso Positivo: 182.0000 - Verdadero Negativo: 3254.0000 - Falso Negativo: 184.0000 - Accuracy: 0.9470 - Precision: 0.9476 - val_loss: 0.7650 - val_AUC: 0.9069 - val_PRC: 0.8750 - val_RECALL: 0.9667 - val_Error Cuadrático Medio: 0.1596 - val_Verdadero Positivo: 436.0000 - val_Falso Positivo: 159.0000 - val_Verdadero Negativo: 254.0000 - val_Falso Negativo: 15.0000 - val_Accuracy: 0.7986 - val_Precision: 0.7328
# Epoch 4/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0917 - AUC: 0.9945 - PRC: 0.9948 - RECALL: 0.9672 - Error Cuadrático Medio: 0.0259 - Verdadero Positivo: 3362.0000 - Falso Positivo: 113.0000 - Verdadero Negativo: 3323.0000 - Falso Negativo: 114.0000 - Accuracy: 0.9672 - Precision: 0.9675 - val_loss: 1.4397 - val_AUC: 0.8637 - val_PRC: 0.9087 - val_RECALL: 0.6541 - val_Error Cuadrático Medio: 0.1786 - val_Verdadero Positivo: 295.0000 - val_Falso Positivo: 15.0000 - val_Verdadero Negativo: 398.0000 - val_Falso Negativo: 156.0000 - val_Accuracy: 0.8021 - val_Precision: 0.9516
# Epoch 5/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0962 - AUC: 0.9937 - PRC: 0.9942 - RECALL: 0.9709 - Error Cuadrático Medio: 0.0252 - Verdadero Positivo: 3375.0000 - Falso Positivo: 119.0000 - Verdadero Negativo: 3317.0000 - Falso Negativo: 101.0000 - Accuracy: 0.9682 - Precision: 0.9659 - val_loss: 0.5542 - val_AUC: 0.9142 - val_PRC: 0.9066 - val_RECALL: 0.8958 - val_Error Cuadrático Medio: 0.1254 - val_Verdadero Positivo: 404.0000 - val_Falso Positivo: 80.0000 - val_Verdadero Negativo: 333.0000 - val_Falso Negativo: 47.0000 - val_Accuracy: 0.8530 - val_Precision: 0.8347
# Epoch 6/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0673 - AUC: 0.9969 - PRC: 0.9968 - RECALL: 0.9755 - Error Cuadrático Medio: 0.0184 - Verdadero Positivo: 3391.0000 - Falso Positivo: 72.0000 - Verdadero Negativo: 3364.0000 - Falso Negativo: 85.0000 - Accuracy: 0.9773 - Precision: 0.9792 - val_loss: 0.4290 - val_AUC: 0.9294 - val_PRC: 0.9424 - val_RECALL: 0.8359 - val_Error Cuadrático Medio: 0.1152 - val_Verdadero Positivo: 377.0000 - val_Falso Positivo: 56.0000 - val_Verdadero Negativo: 357.0000 - val_Falso Negativo: 74.0000 - val_Accuracy: 0.8495 - val_Precision: 0.8707
# Epoch 7/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0530 - AUC: 0.9979 - PRC: 0.9977 - RECALL: 0.9836 - Error Cuadrático Medio: 0.0140 - Verdadero Positivo: 3419.0000 - Falso Positivo: 62.0000 - Verdadero Negativo: 3374.0000 - Falso Negativo: 57.0000 - Accuracy: 0.9828 - Precision: 0.9822 - val_loss: 0.4419 - val_AUC: 0.9311 - val_PRC: 0.9425 - val_RECALL: 0.8448 - val_Error Cuadrático Medio: 0.1162 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 62.0000 - val_Verdadero Negativo: 351.0000 - val_Falso Negativo: 70.0000 - val_Accuracy: 0.8472 - val_Precision: 0.8600
# Epoch 8/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0334 - AUC: 0.9989 - PRC: 0.9987 - RECALL: 0.9879 - Error Cuadrático Medio: 0.0086 - Verdadero Positivo: 3434.0000 - Falso Positivo: 35.0000 - Verdadero Negativo: 3401.0000 - Falso Negativo: 42.0000 - Accuracy: 0.9889 - Precision: 0.9899 - val_loss: 0.7008 - val_AUC: 0.9079 - val_PRC: 0.8814 - val_RECALL: 0.9490 - val_Error Cuadrático Medio: 0.1498 - val_Verdadero Positivo: 428.0000 - val_Falso Positivo: 128.0000 - val_Verdadero Negativo: 285.0000 - val_Falso Negativo: 23.0000 - val_Accuracy: 0.8252 - val_Precision: 0.7698
# Epoch 9/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0509 - AUC: 0.9977 - PRC: 0.9969 - RECALL: 0.9825 - Error Cuadrático Medio: 0.0133 - Verdadero Positivo: 3415.0000 - Falso Positivo: 53.0000 - Verdadero Negativo: 3383.0000 - Falso Negativo: 61.0000 - Accuracy: 0.9835 - Precision: 0.9847 - val_loss: 0.7417 - val_AUC: 0.9103 - val_PRC: 0.9344 - val_RECALL: 0.7472 - val_Error Cuadrático Medio: 0.1336 - val_Verdadero Positivo: 337.0000 - val_Falso Positivo: 21.0000 - val_Verdadero Negativo: 392.0000 - val_Falso Negativo: 114.0000 - val_Accuracy: 0.8438 - val_Precision: 0.9413
# Epoch 10/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0301 - AUC: 0.9992 - PRC: 0.9991 - RECALL: 0.9899 - Error Cuadrático Medio: 0.0081 - Verdadero Positivo: 3441.0000 - Falso Positivo: 40.0000 - Verdadero Negativo: 3396.0000 - Falso Negativo: 35.0000 - Accuracy: 0.9891 - Precision: 0.9885 - val_loss: 0.8226 - val_AUC: 0.9087 - val_PRC: 0.8790 - val_RECALL: 0.9557 - val_Error Cuadrático Medio: 0.1728 - val_Verdadero Positivo: 431.0000 - val_Falso Positivo: 152.0000 - val_Verdadero Negativo: 261.0000 - val_Falso Negativo: 20.0000 - val_Accuracy: 0.8009 - val_Precision: 0.7393
# Epoch 11/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0338 - AUC: 0.9989 - PRC: 0.9986 - RECALL: 0.9905 - Error Cuadrático Medio: 0.0087 - Verdadero Positivo: 3443.0000 - Falso Positivo: 38.0000 - Verdadero Negativo: 3398.0000 - Falso Negativo: 33.0000 - Accuracy: 0.9897 - Precision: 0.9891 - val_loss: 0.4448 - val_AUC: 0.9440 - val_PRC: 0.9585 - val_RECALL: 0.8337 - val_Error Cuadrático Medio: 0.0988 - val_Verdadero Positivo: 376.0000 - val_Falso Positivo: 25.0000 - val_Verdadero Negativo: 388.0000 - val_Falso Negativo: 75.0000 - val_Accuracy: 0.8843 - val_Precision: 0.9377
# Epoch 12/50
# 216/216 [==============================] - 23s 109ms/step - loss: 0.0249 - AUC: 0.9992 - PRC: 0.9992 - RECALL: 0.9922 - Error Cuadrático Medio: 0.0062 - Verdadero Positivo: 3449.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 27.0000 - Accuracy: 0.9923 - Precision: 0.9925 - val_loss: 0.3935 - val_AUC: 0.9415 - val_PRC: 0.9552 - val_RECALL: 0.8337 - val_Error Cuadrático Medio: 0.1009 - val_Verdadero Positivo: 376.0000 - val_Falso Positivo: 33.0000 - val_Verdadero Negativo: 380.0000 - val_Falso Negativo: 75.0000 - val_Accuracy: 0.8750 - val_Precision: 0.9193
# Epoch 13/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0225 - AUC: 0.9997 - PRC: 0.9997 - RECALL: 0.9922 - Error Cuadrático Medio: 0.0060 - Verdadero Positivo: 3449.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 3415.0000 - Falso Negativo: 27.0000 - Accuracy: 0.9931 - Precision: 0.9939 - val_loss: 0.5012 - val_AUC: 0.9393 - val_PRC: 0.9387 - val_RECALL: 0.9202 - val_Error Cuadrático Medio: 0.1135 - val_Verdadero Positivo: 415.0000 - val_Falso Positivo: 83.0000 - val_Verdadero Negativo: 330.0000 - val_Falso Negativo: 36.0000 - val_Accuracy: 0.8623 - val_Precision: 0.8333
# Epoch 14/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0263 - AUC: 0.9990 - PRC: 0.9988 - RECALL: 0.9931 - Error Cuadrático Medio: 0.0071 - Verdadero Positivo: 3452.0000 - Falso Positivo: 39.0000 - Verdadero Negativo: 3397.0000 - Falso Negativo: 24.0000 - Accuracy: 0.9909 - Precision: 0.9888 - val_loss: 0.4716 - val_AUC: 0.9297 - val_PRC: 0.9299 - val_RECALL: 0.9047 - val_Error Cuadrático Medio: 0.1151 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 76.0000 - val_Verdadero Negativo: 337.0000 - val_Falso Negativo: 43.0000 - val_Accuracy: 0.8623 - val_Precision: 0.8430
# Epoch 15/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0309 - AUC: 0.9989 - PRC: 0.9989 - RECALL: 0.9899 - Error Cuadrático Medio: 0.0078 - Verdadero Positivo: 3441.0000 - Falso Positivo: 32.0000 - Verdadero Negativo: 3404.0000 - Falso Negativo: 35.0000 - Accuracy: 0.9903 - Precision: 0.9908 - val_loss: 0.7542 - val_AUC: 0.9158 - val_PRC: 0.9034 - val_RECALL: 0.9579 - val_Error Cuadrático Medio: 0.1883 - val_Verdadero Positivo: 432.0000 - val_Falso Positivo: 170.0000 - val_Verdadero Negativo: 243.0000 - val_Falso Negativo: 19.0000 - val_Accuracy: 0.7812 - val_Precision: 0.7176
# Epoch 16/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0257 - AUC: 0.9993 - PRC: 0.9990 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0065 - Verdadero Positivo: 3450.0000 - Falso Positivo: 31.0000 - Verdadero Negativo: 3405.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9918 - Precision: 0.9911 - val_loss: 0.9467 - val_AUC: 0.8726 - val_PRC: 0.8994 - val_RECALL: 0.5876 - val_Error Cuadrático Medio: 0.2099 - val_Verdadero Positivo: 265.0000 - val_Falso Positivo: 23.0000 - val_Verdadero Negativo: 390.0000 - val_Falso Negativo: 186.0000 - val_Accuracy: 0.7581 - val_Precision: 0.9201
# Epoch 17/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0137 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0037 - Verdadero Positivo: 3458.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9952 - Precision: 0.9957 - val_loss: 0.6415 - val_AUC: 0.9256 - val_PRC: 0.9434 - val_RECALL: 0.8248 - val_Error Cuadrático Medio: 0.1131 - val_Verdadero Positivo: 372.0000 - val_Falso Positivo: 33.0000 - val_Verdadero Negativo: 380.0000 - val_Falso Negativo: 79.0000 - val_Accuracy: 0.8704 - val_Precision: 0.9185
# Epoch 18/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0209 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9934 - Error Cuadrático Medio: 0.0054 - Verdadero Positivo: 3453.0000 - Falso Positivo: 28.0000 - Verdadero Negativo: 3408.0000 - Falso Negativo: 23.0000 - Accuracy: 0.9926 - Precision: 0.9920 - val_loss: 0.5353 - val_AUC: 0.9212 - val_PRC: 0.9309 - val_RECALL: 0.8647 - val_Error Cuadrático Medio: 0.1267 - val_Verdadero Positivo: 390.0000 - val_Falso Positivo: 67.0000 - val_Verdadero Negativo: 346.0000 - val_Falso Negativo: 61.0000 - val_Accuracy: 0.8519 - val_Precision: 0.8534
# Epoch 19/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0247 - AUC: 0.9991 - PRC: 0.9991 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0063 - Verdadero Positivo: 3448.0000 - Falso Positivo: 23.0000 - Verdadero Negativo: 3413.0000 - Falso Negativo: 28.0000 - Accuracy: 0.9926 - Precision: 0.9934 - val_loss: 0.7536 - val_AUC: 0.9208 - val_PRC: 0.9310 - val_RECALL: 0.8204 - val_Error Cuadrático Medio: 0.1202 - val_Verdadero Positivo: 370.0000 - val_Falso Positivo: 36.0000 - val_Verdadero Negativo: 377.0000 - val_Falso Negativo: 81.0000 - val_Accuracy: 0.8646 - val_Precision: 0.9113
# Epoch 20/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0148 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0036 - Verdadero Positivo: 3458.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9957 - Precision: 0.9965 - val_loss: 0.8587 - val_AUC: 0.9064 - val_PRC: 0.8673 - val_RECALL: 0.9468 - val_Error Cuadrático Medio: 0.1439 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 116.0000 - val_Verdadero Negativo: 297.0000 - val_Falso Negativo: 24.0000 - val_Accuracy: 0.8380 - val_Precision: 0.7864
# Epoch 21/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0233 - AUC: 0.9993 - PRC: 0.9988 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0066 - Verdadero Positivo: 3451.0000 - Falso Positivo: 38.0000 - Verdadero Negativo: 3398.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9909 - Precision: 0.9891 - val_loss: 0.7125 - val_AUC: 0.9052 - val_PRC: 0.9166 - val_RECALL: 0.8337 - val_Error Cuadrático Medio: 0.1506 - val_Verdadero Positivo: 376.0000 - val_Falso Positivo: 78.0000 - val_Verdadero Negativo: 335.0000 - val_Falso Negativo: 75.0000 - val_Accuracy: 0.8229 - val_Precision: 0.8282
# Epoch 22/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0179 - AUC: 0.9994 - PRC: 0.9994 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0043 - Verdadero Positivo: 3455.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9946 - Precision: 0.9954 - val_loss: 0.4339 - val_AUC: 0.9391 - val_PRC: 0.9506 - val_RECALL: 0.7783 - val_Error Cuadrático Medio: 0.1188 - val_Verdadero Positivo: 351.0000 - val_Falso Positivo: 25.0000 - val_Verdadero Negativo: 388.0000 - val_Falso Negativo: 100.0000 - val_Accuracy: 0.8553 - val_Precision: 0.9335
# Epoch 23/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0124 - AUC: 0.9997 - PRC: 0.9998 - RECALL: 0.9942 - Error Cuadrático Medio: 0.0033 - Verdadero Positivo: 3456.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 3430.0000 - Falso Negativo: 20.0000 - Accuracy: 0.9962 - Precision: 0.9983 - val_loss: 0.5228 - val_AUC: 0.9277 - val_PRC: 0.9469 - val_RECALL: 0.7805 - val_Error Cuadrático Medio: 0.1224 - val_Verdadero Positivo: 352.0000 - val_Falso Positivo: 32.0000 - val_Verdadero Negativo: 381.0000 - val_Falso Negativo: 99.0000 - val_Accuracy: 0.8484 - val_Precision: 0.9167
# Epoch 24/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0163 - AUC: 0.9994 - PRC: 0.9992 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0038 - Verdadero Positivo: 3460.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9954 - Precision: 0.9954 - val_loss: 0.4437 - val_AUC: 0.9399 - val_PRC: 0.9341 - val_RECALL: 0.9290 - val_Error Cuadrático Medio: 0.1190 - val_Verdadero Positivo: 419.0000 - val_Falso Positivo: 99.0000 - val_Verdadero Negativo: 314.0000 - val_Falso Negativo: 32.0000 - val_Accuracy: 0.8484 - val_Precision: 0.8089
# Epoch 25/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0114 - AUC: 0.9998 - PRC: 0.9996 - RECALL: 0.9957 - Error Cuadrático Medio: 0.0029 - Verdadero Positivo: 3461.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9965 - Precision: 0.9974 - val_loss: 0.7103 - val_AUC: 0.9130 - val_PRC: 0.9276 - val_RECALL: 0.7517 - val_Error Cuadrático Medio: 0.1301 - val_Verdadero Positivo: 339.0000 - val_Falso Positivo: 21.0000 - val_Verdadero Negativo: 392.0000 - val_Falso Negativo: 112.0000 - val_Accuracy: 0.8461 - val_Precision: 0.9417
# Epoch 26/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0139 - AUC: 0.9998 - PRC: 0.9996 - RECALL: 0.9945 - Error Cuadrático Medio: 0.0037 - Verdadero Positivo: 3457.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 3423.0000 - Falso Negativo: 19.0000 - Accuracy: 0.9954 - Precision: 0.9963 - val_loss: 0.6352 - val_AUC: 0.9109 - val_PRC: 0.8833 - val_RECALL: 0.9202 - val_Error Cuadrático Medio: 0.1303 - val_Verdadero Positivo: 415.0000 - val_Falso Positivo: 96.0000 - val_Verdadero Negativo: 317.0000 - val_Falso Negativo: 36.0000 - val_Accuracy: 0.8472 - val_Precision: 0.8121
# Epoch 27/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0221 - AUC: 0.9991 - PRC: 0.9992 - RECALL: 0.9917 - Error Cuadrático Medio: 0.0055 - Verdadero Positivo: 3447.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 29.0000 - Accuracy: 0.9931 - Precision: 0.9945 - val_loss: 0.4705 - val_AUC: 0.9281 - val_PRC: 0.9209 - val_RECALL: 0.9224 - val_Error Cuadrático Medio: 0.1114 - val_Verdadero Positivo: 416.0000 - val_Falso Positivo: 86.0000 - val_Verdadero Negativo: 327.0000 - val_Falso Negativo: 35.0000 - val_Accuracy: 0.8600 - val_Precision: 0.8287
# Epoch 28/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0165 - AUC: 0.9997 - PRC: 0.9996 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0046 - Verdadero Positivo: 3458.0000 - Falso Positivo: 24.0000 - Verdadero Negativo: 3412.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9939 - Precision: 0.9931 - val_loss: 0.5843 - val_AUC: 0.8977 - val_PRC: 0.9119 - val_RECALL: 0.8914 - val_Error Cuadrático Medio: 0.1528 - val_Verdadero Positivo: 402.0000 - val_Falso Positivo: 111.0000 - val_Verdadero Negativo: 302.0000 - val_Falso Negativo: 49.0000 - val_Accuracy: 0.8148 - val_Precision: 0.7836
# Epoch 29/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0217 - AUC: 0.9994 - PRC: 0.9995 - RECALL: 0.9919 - Error Cuadrático Medio: 0.0055 - Verdadero Positivo: 3448.0000 - Falso Positivo: 20.0000 - Verdadero Negativo: 3416.0000 - Falso Negativo: 28.0000 - Accuracy: 0.9931 - Precision: 0.9942 - val_loss: 0.5815 - val_AUC: 0.9309 - val_PRC: 0.9200 - val_RECALL: 0.9357 - val_Error Cuadrático Medio: 0.1279 - val_Verdadero Positivo: 422.0000 - val_Falso Positivo: 100.0000 - val_Verdadero Negativo: 313.0000 - val_Falso Negativo: 29.0000 - val_Accuracy: 0.8507 - val_Precision: 0.8084
# Epoch 30/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0126 - AUC: 0.9996 - PRC: 0.9995 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0033 - Verdadero Positivo: 3462.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 14.0000 - Accuracy: 0.9958 - Precision: 0.9957 - val_loss: 0.5026 - val_AUC: 0.9349 - val_PRC: 0.9453 - val_RECALL: 0.8337 - val_Error Cuadrático Medio: 0.1043 - val_Verdadero Positivo: 376.0000 - val_Falso Positivo: 29.0000 - val_Verdadero Negativo: 384.0000 - val_Falso Negativo: 75.0000 - val_Accuracy: 0.8796 - val_Precision: 0.9284
# Epoch 31/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0095 - AUC: 0.9998 - PRC: 0.9996 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0023 - Verdadero Positivo: 3467.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9974 - Precision: 0.9974 - val_loss: 0.7854 - val_AUC: 0.9245 - val_PRC: 0.9412 - val_RECALL: 0.7982 - val_Error Cuadrático Medio: 0.1162 - val_Verdadero Positivo: 360.0000 - val_Falso Positivo: 21.0000 - val_Verdadero Negativo: 392.0000 - val_Falso Negativo: 91.0000 - val_Accuracy: 0.8704 - val_Precision: 0.9449
# Epoch 32/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0144 - AUC: 0.9996 - PRC: 0.9995 - RECALL: 0.9951 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 3459.0000 - Falso Positivo: 14.0000 - Verdadero Negativo: 3422.0000 - Falso Negativo: 17.0000 - Accuracy: 0.9955 - Precision: 0.9960 - val_loss: 0.5200 - val_AUC: 0.9306 - val_PRC: 0.9333 - val_RECALL: 0.8625 - val_Error Cuadrático Medio: 0.1276 - val_Verdadero Positivo: 389.0000 - val_Falso Positivo: 74.0000 - val_Verdadero Negativo: 339.0000 - val_Falso Negativo: 62.0000 - val_Accuracy: 0.8426 - val_Precision: 0.8402
# Epoch 33/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0069 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0017 - Verdadero Positivo: 3467.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 3432.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9981 - Precision: 0.9988 - val_loss: 0.6933 - val_AUC: 0.9137 - val_PRC: 0.8809 - val_RECALL: 0.9290 - val_Error Cuadrático Medio: 0.1257 - val_Verdadero Positivo: 419.0000 - val_Falso Positivo: 91.0000 - val_Verdadero Negativo: 322.0000 - val_Falso Negativo: 32.0000 - val_Accuracy: 0.8576 - val_Precision: 0.8216
# Epoch 34/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0116 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9957 - Error Cuadrático Medio: 0.0031 - Verdadero Positivo: 3461.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 3425.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9962 - Precision: 0.9968 - val_loss: 0.7110 - val_AUC: 0.9241 - val_PRC: 0.9416 - val_RECALL: 0.7960 - val_Error Cuadrático Medio: 0.1185 - val_Verdadero Positivo: 359.0000 - val_Falso Positivo: 23.0000 - val_Verdadero Negativo: 390.0000 - val_Falso Negativo: 92.0000 - val_Accuracy: 0.8669 - val_Precision: 0.9398
# Epoch 35/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0281 - AUC: 0.9987 - PRC: 0.9983 - RECALL: 0.9928 - Error Cuadrático Medio: 0.0050 - Verdadero Positivo: 3451.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 25.0000 - Accuracy: 0.9936 - Precision: 0.9945 - val_loss: 3.4868 - val_AUC: 0.5971 - val_PRC: 0.5296 - val_RECALL: 0.5055 - val_Error Cuadrático Medio: 0.3950 - val_Verdadero Positivo: 228.0000 - val_Falso Positivo: 144.0000 - val_Verdadero Negativo: 269.0000 - val_Falso Negativo: 223.0000 - val_Accuracy: 0.5752 - val_Precision: 0.6129
# Epoch 36/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0223 - AUC: 0.9996 - PRC: 0.9997 - RECALL: 0.9905 - Error Cuadrático Medio: 0.0064 - Verdadero Positivo: 3443.0000 - Falso Positivo: 27.0000 - Verdadero Negativo: 3409.0000 - Falso Negativo: 33.0000 - Accuracy: 0.9913 - Precision: 0.9922 - val_loss: 0.5596 - val_AUC: 0.9270 - val_PRC: 0.9118 - val_RECALL: 0.9024 - val_Error Cuadrático Medio: 0.1117 - val_Verdadero Positivo: 407.0000 - val_Falso Positivo: 71.0000 - val_Verdadero Negativo: 342.0000 - val_Falso Negativo: 44.0000 - val_Accuracy: 0.8669 - val_Precision: 0.8515
# Epoch 37/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0122 - AUC: 0.9996 - PRC: 0.9993 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0031 - Verdadero Positivo: 3460.0000 - Falso Positivo: 14.0000 - Verdadero Negativo: 3422.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9957 - Precision: 0.9960 - val_loss: 1.1254 - val_AUC: 0.8577 - val_PRC: 0.8078 - val_RECALL: 0.9557 - val_Error Cuadrático Medio: 0.2025 - val_Verdadero Positivo: 431.0000 - val_Falso Positivo: 175.0000 - val_Verdadero Negativo: 238.0000 - val_Falso Negativo: 20.0000 - val_Accuracy: 0.7743 - val_Precision: 0.7112
# Epoch 38/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0195 - AUC: 0.9995 - PRC: 0.9994 - RECALL: 0.9922 - Error Cuadrático Medio: 0.0050 - Verdadero Positivo: 3449.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 3418.0000 - Falso Negativo: 27.0000 - Accuracy: 0.9935 - Precision: 0.9948 - val_loss: 0.5662 - val_AUC: 0.9300 - val_PRC: 0.9467 - val_RECALL: 0.7650 - val_Error Cuadrático Medio: 0.1190 - val_Verdadero Positivo: 345.0000 - val_Falso Positivo: 18.0000 - val_Verdadero Negativo: 395.0000 - val_Falso Negativo: 106.0000 - val_Accuracy: 0.8565 - val_Precision: 0.9504
# Epoch 39/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0065 - AUC: 0.9997 - PRC: 0.9994 - RECALL: 0.9986 - Error Cuadrático Medio: 0.0014 - Verdadero Positivo: 3471.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 3431.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9986 - Precision: 0.9986 - val_loss: 0.5669 - val_AUC: 0.9292 - val_PRC: 0.9132 - val_RECALL: 0.9047 - val_Error Cuadrático Medio: 0.1186 - val_Verdadero Positivo: 408.0000 - val_Falso Positivo: 76.0000 - val_Verdadero Negativo: 337.0000 - val_Falso Negativo: 43.0000 - val_Accuracy: 0.8623 - val_Precision: 0.8430
# Epoch 40/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0084 - AUC: 0.9998 - PRC: 0.9997 - RECALL: 0.9977 - Error Cuadrático Medio: 0.0021 - Verdadero Positivo: 3468.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 8.0000 - Accuracy: 0.9977 - Precision: 0.9977 - val_loss: 1.4716 - val_AUC: 0.8709 - val_PRC: 0.9130 - val_RECALL: 0.5854 - val_Error Cuadrático Medio: 0.2001 - val_Verdadero Positivo: 264.0000 - val_Falso Positivo: 6.0000 - val_Verdadero Negativo: 407.0000 - val_Falso Negativo: 187.0000 - val_Accuracy: 0.7766 - val_Precision: 0.9778
# Epoch 41/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0030 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9988 - Error Cuadrático Medio: 7.9815e-04 - Verdadero Positivo: 3472.0000 - Falso Positivo: 2.0000 - Verdadero Negativo: 3434.0000 - Falso Negativo: 4.0000 - Accuracy: 0.9991 - Precision: 0.9994 - val_loss: 0.5603 - val_AUC: 0.9327 - val_PRC: 0.9346 - val_RECALL: 0.8559 - val_Error Cuadrático Medio: 0.1024 - val_Verdadero Positivo: 386.0000 - val_Falso Positivo: 35.0000 - val_Verdadero Negativo: 378.0000 - val_Falso Negativo: 65.0000 - val_Accuracy: 0.8843 - val_Precision: 0.9169
# Epoch 42/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0172 - AUC: 0.9993 - PRC: 0.9991 - RECALL: 0.9937 - Error Cuadrático Medio: 0.0041 - Verdadero Positivo: 3454.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 3425.0000 - Falso Negativo: 22.0000 - Accuracy: 0.9952 - Precision: 0.9968 - val_loss: 0.5948 - val_AUC: 0.9168 - val_PRC: 0.8998 - val_RECALL: 0.9091 - val_Error Cuadrático Medio: 0.1318 - val_Verdadero Positivo: 410.0000 - val_Falso Positivo: 92.0000 - val_Verdadero Negativo: 321.0000 - val_Falso Negativo: 41.0000 - val_Accuracy: 0.8461 - val_Precision: 0.8167
# Epoch 43/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0107 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9968 - Error Cuadrático Medio: 0.0029 - Verdadero Positivo: 3465.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9967 - Precision: 0.9965 - val_loss: 1.0171 - val_AUC: 0.8760 - val_PRC: 0.8294 - val_RECALL: 0.9512 - val_Error Cuadrático Medio: 0.1850 - val_Verdadero Positivo: 429.0000 - val_Falso Positivo: 158.0000 - val_Verdadero Negativo: 255.0000 - val_Falso Negativo: 22.0000 - val_Accuracy: 0.7917 - val_Precision: 0.7308
# Epoch 44/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0131 - AUC: 0.9996 - PRC: 0.9996 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3467.0000 - Falso Positivo: 9.0000 - Verdadero Negativo: 3427.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9974 - Precision: 0.9974 - val_loss: 0.8417 - val_AUC: 0.9140 - val_PRC: 0.9380 - val_RECALL: 0.7583 - val_Error Cuadrático Medio: 0.1327 - val_Verdadero Positivo: 342.0000 - val_Falso Positivo: 18.0000 - val_Verdadero Negativo: 395.0000 - val_Falso Negativo: 109.0000 - val_Accuracy: 0.8530 - val_Precision: 0.9500
# Epoch 45/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0121 - AUC: 0.9998 - PRC: 0.9996 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 3460.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9955 - Precision: 0.9957 - val_loss: 0.8898 - val_AUC: 0.9026 - val_PRC: 0.9329 - val_RECALL: 0.6851 - val_Error Cuadrático Medio: 0.1534 - val_Verdadero Positivo: 309.0000 - val_Falso Positivo: 10.0000 - val_Verdadero Negativo: 403.0000 - val_Falso Negativo: 142.0000 - val_Accuracy: 0.8241 - val_Precision: 0.9687
# Epoch 46/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0155 - AUC: 0.9996 - PRC: 0.9993 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0039 - Verdadero Positivo: 3458.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9946 - Precision: 0.9945 - val_loss: 0.7820 - val_AUC: 0.9236 - val_PRC: 0.9419 - val_RECALL: 0.7650 - val_Error Cuadrático Medio: 0.1220 - val_Verdadero Positivo: 345.0000 - val_Falso Positivo: 19.0000 - val_Verdadero Negativo: 394.0000 - val_Falso Negativo: 106.0000 - val_Accuracy: 0.8553 - val_Precision: 0.9478
# Epoch 47/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0082 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3467.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 3426.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9973 - Precision: 0.9971 - val_loss: 0.7285 - val_AUC: 0.9103 - val_PRC: 0.8820 - val_RECALL: 0.9468 - val_Error Cuadrático Medio: 0.1423 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 125.0000 - val_Verdadero Negativo: 288.0000 - val_Falso Negativo: 24.0000 - val_Accuracy: 0.8275 - val_Precision: 0.7736
# Epoch 48/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0110 - AUC: 0.9997 - PRC: 0.9996 - RECALL: 0.9963 - Error Cuadrático Medio: 0.0025 - Verdadero Positivo: 3463.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 3429.0000 - Falso Negativo: 13.0000 - Accuracy: 0.9971 - Precision: 0.9980 - val_loss: 0.5661 - val_AUC: 0.9316 - val_PRC: 0.9452 - val_RECALL: 0.7273 - val_Error Cuadrático Medio: 0.1273 - val_Verdadero Positivo: 328.0000 - val_Falso Positivo: 17.0000 - val_Verdadero Negativo: 396.0000 - val_Falso Negativo: 123.0000 - val_Accuracy: 0.8380 - val_Precision: 0.9507
# Epoch 49/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0051 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9980 - Error Cuadrático Medio: 0.0014 - Verdadero Positivo: 3469.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 3431.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9983 - Precision: 0.9986 - val_loss: 0.5357 - val_AUC: 0.9327 - val_PRC: 0.9288 - val_RECALL: 0.8758 - val_Error Cuadrático Medio: 0.1017 - val_Verdadero Positivo: 395.0000 - val_Falso Positivo: 44.0000 - val_Verdadero Negativo: 369.0000 - val_Falso Negativo: 56.0000 - val_Accuracy: 0.8843 - val_Precision: 0.8998
# Epoch 50/50
# 216/216 [==============================] - 23s 109ms/step - loss: 0.0050 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9983 - Error Cuadrático Medio: 0.0012 - Verdadero Positivo: 3470.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 3432.0000 - Falso Negativo: 6.0000 - Accuracy: 0.9986 - Precision: 0.9988 - val_loss: 0.5736 - val_AUC: 0.9316 - val_PRC: 0.9267 - val_RECALL: 0.8825 - val_Error Cuadrático Medio: 0.1029 - val_Verdadero Positivo: 398.0000 - val_Falso Positivo: 51.0000 - val_Verdadero Negativo: 362.0000 - val_Falso Negativo: 53.0000 - val_Accuracy: 0.8796 - val_Precision: 0.8864
# 34/34 [==============================] - 3s 46ms/step - loss: 0.7870 - AUC: 0.9131 - PRC: 0.9010 - RECALL: 0.8561 - Error Cuadrático Medio: 0.1214 - Verdadero Positivo: 452.0000 - Falso Positivo: 72.0000 - Verdadero Negativo: 480.0000 - Falso Negativo: 76.0000 - Accuracy: 0.8630 - Precision: 0.8626
# {'loss': 0.786997377872467, 'AUC': 0.9131035804748535, 'PRC': 0.9010030031204224, 'RECALL': 0.8560606241226196, 'Error Cuadrático Medio': 0.1213984489440918, 'Verdadero Positivo': 452.0, 'Falso Positivo': 72.0, 'Verdadero Negativo': 480.0, 'Falso Negativo': 76.0, 'Accuracy': 0.8629629611968994, 'Precision': 0.8625954389572144}
#
#  ...Calculando valores predichos para train y test: ...
# 216/216 [==============================] - 7s 27ms/step
# 34/34 [==============================] - 2s 29ms/step
#
#  ** Resultados de las métricas:...
# loss :  0.786997377872467
# AUC :  0.9131035804748535
# PRC :  0.9010030031204224
# RECALL :  0.8560606241226196
# Error Cuadrático Medio :  0.1213984489440918
# Verdadero Positivo :  452.0
# Falso Positivo :  72.0
# Verdadero Negativo :  480.0
# Falso Negativo :  76.0
# Accuracy :  0.8629629611968994
# Precision :  0.8625954389572144
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  480
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  72
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  76
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  452

# %% [markdown]
# #### ***Model-F***:  $~~~1 \times $*`ResNet50 + Xception`*+$3\times $*`GolbalaveragePooling2D`*+$1\times $*`Dropout`*+$3\times $*`Denses`*

# %%
model_name="model_E"
model = model_E(output_bias=bias_0(train_labels,print_desbal = 'no'))  # Inicialización del bias
apply_model_and_metrics(x_train, y_train,x_val, y_val,x_test,y_test,model,epochs,batch_size,model_name,log_dir)
# Out:
# Clasificador Biclase
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  xception (Functional)       (None, 3, 3, 2048)        20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
#  dense_1 (Dense)             (None, 10)                1210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21108581 (80.52 MB)
# Trainable params: 21054053 (80.31 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________
# None
#  ::::::----- Inicio de Entrenamiento -----::::::
#
# Epoch 1/50
# 216/216 [==============================] - 49s 120ms/step - loss: 0.2775 - AUC: 0.9521 - PRC: 0.9559 - RECALL: 0.8734 - Error Cuadrático Medio: 0.0885 - Verdadero Positivo: 3036.0000 - Falso Positivo: 470.0000 - Verdadero Negativo: 2966.0000 - Falso Negativo: 440.0000 - Accuracy: 0.8683 - Precision: 0.8659 - val_loss: 0.7455 - val_AUC: 0.8572 - val_PRC: 0.8628 - val_RECALL: 0.9867 - val_Error Cuadrático Medio: 0.2314 - val_Verdadero Positivo: 445.0000 - val_Falso Positivo: 267.0000 - val_Verdadero Negativo: 146.0000 - val_Falso Negativo: 6.0000 - val_Accuracy: 0.6840 - val_Precision: 0.6250
# Epoch 2/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.1757 - AUC: 0.9809 - PRC: 0.9829 - RECALL: 0.9206 - Error Cuadrático Medio: 0.0534 - Verdadero Positivo: 3200.0000 - Falso Positivo: 238.0000 - Verdadero Negativo: 3198.0000 - Falso Negativo: 276.0000 - Accuracy: 0.9256 - Precision: 0.9308 - val_loss: 0.4828 - val_AUC: 0.9326 - val_PRC: 0.9466 - val_RECALL: 0.9246 - val_Error Cuadrático Medio: 0.1301 - val_Verdadero Positivo: 417.0000 - val_Falso Positivo: 109.0000 - val_Verdadero Negativo: 304.0000 - val_Falso Negativo: 34.0000 - val_Accuracy: 0.8345 - val_Precision: 0.7928
# Epoch 3/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.1368 - AUC: 0.9882 - PRC: 0.9890 - RECALL: 0.9393 - Error Cuadrático Medio: 0.0406 - Verdadero Positivo: 3265.0000 - Falso Positivo: 154.0000 - Verdadero Negativo: 3282.0000 - Falso Negativo: 211.0000 - Accuracy: 0.9472 - Precision: 0.9550 - val_loss: 0.8696 - val_AUC: 0.8389 - val_PRC: 0.8443 - val_RECALL: 0.4523 - val_Error Cuadrático Medio: 0.2550 - val_Verdadero Positivo: 204.0000 - val_Falso Positivo: 34.0000 - val_Verdadero Negativo: 379.0000 - val_Falso Negativo: 247.0000 - val_Accuracy: 0.6748 - val_Precision: 0.8571
# Epoch 4/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.1203 - AUC: 0.9906 - PRC: 0.9914 - RECALL: 0.9505 - Error Cuadrático Medio: 0.0348 - Verdadero Positivo: 3304.0000 - Falso Positivo: 153.0000 - Verdadero Negativo: 3283.0000 - Falso Negativo: 172.0000 - Accuracy: 0.9530 - Precision: 0.9557 - val_loss: 0.3569 - val_AUC: 0.9384 - val_PRC: 0.9478 - val_RECALL: 0.7894 - val_Error Cuadrático Medio: 0.1096 - val_Verdadero Positivo: 356.0000 - val_Falso Positivo: 38.0000 - val_Verdadero Negativo: 375.0000 - val_Falso Negativo: 95.0000 - val_Accuracy: 0.8461 - val_Precision: 0.9036
# Epoch 5/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0901 - AUC: 0.9947 - PRC: 0.9951 - RECALL: 0.9655 - Error Cuadrático Medio: 0.0254 - Verdadero Positivo: 3356.0000 - Falso Positivo: 98.0000 - Verdadero Negativo: 3338.0000 - Falso Negativo: 120.0000 - Accuracy: 0.9685 - Precision: 0.9716 - val_loss: 0.6851 - val_AUC: 0.9253 - val_PRC: 0.9125 - val_RECALL: 0.9601 - val_Error Cuadrático Medio: 0.1559 - val_Verdadero Positivo: 433.0000 - val_Falso Positivo: 144.0000 - val_Verdadero Negativo: 269.0000 - val_Falso Negativo: 18.0000 - val_Accuracy: 0.8125 - val_Precision: 0.7504
# Epoch 6/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0580 - AUC: 0.9976 - PRC: 0.9978 - RECALL: 0.9773 - Error Cuadrático Medio: 0.0162 - Verdadero Positivo: 3397.0000 - Falso Positivo: 66.0000 - Verdadero Negativo: 3370.0000 - Falso Negativo: 79.0000 - Accuracy: 0.9790 - Precision: 0.9809 - val_loss: 0.4522 - val_AUC: 0.9391 - val_PRC: 0.9545 - val_RECALL: 0.7539 - val_Error Cuadrático Medio: 0.1154 - val_Verdadero Positivo: 340.0000 - val_Falso Positivo: 14.0000 - val_Verdadero Negativo: 399.0000 - val_Falso Negativo: 111.0000 - val_Accuracy: 0.8553 - val_Precision: 0.9605
# Epoch 7/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0430 - AUC: 0.9987 - PRC: 0.9986 - RECALL: 0.9830 - Error Cuadrático Medio: 0.0123 - Verdadero Positivo: 3417.0000 - Falso Positivo: 53.0000 - Verdadero Negativo: 3383.0000 - Falso Negativo: 59.0000 - Accuracy: 0.9838 - Precision: 0.9847 - val_loss: 0.4037 - val_AUC: 0.9377 - val_PRC: 0.9469 - val_RECALL: 0.8470 - val_Error Cuadrático Medio: 0.1027 - val_Verdadero Positivo: 382.0000 - val_Falso Positivo: 45.0000 - val_Verdadero Negativo: 368.0000 - val_Falso Negativo: 69.0000 - val_Accuracy: 0.8681 - val_Precision: 0.8946
# Epoch 8/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0492 - AUC: 0.9979 - PRC: 0.9978 - RECALL: 0.9804 - Error Cuadrático Medio: 0.0137 - Verdadero Positivo: 3408.0000 - Falso Positivo: 61.0000 - Verdadero Negativo: 3375.0000 - Falso Negativo: 68.0000 - Accuracy: 0.9813 - Precision: 0.9824 - val_loss: 0.6310 - val_AUC: 0.9369 - val_PRC: 0.9518 - val_RECALL: 0.6142 - val_Error Cuadrático Medio: 0.1695 - val_Verdadero Positivo: 277.0000 - val_Falso Positivo: 5.0000 - val_Verdadero Negativo: 408.0000 - val_Falso Negativo: 174.0000 - val_Accuracy: 0.7928 - val_Precision: 0.9823
# Epoch 9/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0483 - AUC: 0.9977 - PRC: 0.9974 - RECALL: 0.9850 - Error Cuadrático Medio: 0.0128 - Verdadero Positivo: 3424.0000 - Falso Positivo: 60.0000 - Verdadero Negativo: 3376.0000 - Falso Negativo: 52.0000 - Accuracy: 0.9838 - Precision: 0.9828 - val_loss: 0.5771 - val_AUC: 0.9389 - val_PRC: 0.9439 - val_RECALL: 0.9401 - val_Error Cuadrático Medio: 0.1373 - val_Verdadero Positivo: 424.0000 - val_Falso Positivo: 130.0000 - val_Verdadero Negativo: 283.0000 - val_Falso Negativo: 27.0000 - val_Accuracy: 0.8183 - val_Precision: 0.7653
# Epoch 10/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0438 - AUC: 0.9980 - PRC: 0.9972 - RECALL: 0.9862 - Error Cuadrático Medio: 0.0115 - Verdadero Positivo: 3428.0000 - Falso Positivo: 50.0000 - Verdadero Negativo: 3386.0000 - Falso Negativo: 48.0000 - Accuracy: 0.9858 - Precision: 0.9856 - val_loss: 0.9305 - val_AUC: 0.8758 - val_PRC: 0.8451 - val_RECALL: 0.9379 - val_Error Cuadrático Medio: 0.1933 - val_Verdadero Positivo: 423.0000 - val_Falso Positivo: 173.0000 - val_Verdadero Negativo: 240.0000 - val_Falso Negativo: 28.0000 - val_Accuracy: 0.7674 - val_Precision: 0.7097
# Epoch 11/50
# 216/216 [==============================] - 23s 107ms/step - loss: 0.0392 - AUC: 0.9983 - PRC: 0.9982 - RECALL: 0.9868 - Error Cuadrático Medio: 0.0105 - Verdadero Positivo: 3430.0000 - Falso Positivo: 44.0000 - Verdadero Negativo: 3392.0000 - Falso Negativo: 46.0000 - Accuracy: 0.9870 - Precision: 0.9873 - val_loss: 0.8441 - val_AUC: 0.8921 - val_PRC: 0.9231 - val_RECALL: 0.7140 - val_Error Cuadrático Medio: 0.1578 - val_Verdadero Positivo: 322.0000 - val_Falso Positivo: 22.0000 - val_Verdadero Negativo: 391.0000 - val_Falso Negativo: 129.0000 - val_Accuracy: 0.8252 - val_Precision: 0.9360
# Epoch 12/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0377 - AUC: 0.9985 - PRC: 0.9986 - RECALL: 0.9871 - Error Cuadrático Medio: 0.0100 - Verdadero Positivo: 3431.0000 - Falso Positivo: 42.0000 - Verdadero Negativo: 3394.0000 - Falso Negativo: 45.0000 - Accuracy: 0.9874 - Precision: 0.9879 - val_loss: 0.4246 - val_AUC: 0.9423 - val_PRC: 0.9524 - val_RECALL: 0.8315 - val_Error Cuadrático Medio: 0.1004 - val_Verdadero Positivo: 375.0000 - val_Falso Positivo: 30.0000 - val_Verdadero Negativo: 383.0000 - val_Falso Negativo: 76.0000 - val_Accuracy: 0.8773 - val_Precision: 0.9259
# Epoch 13/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0359 - AUC: 0.9988 - PRC: 0.9986 - RECALL: 0.9853 - Error Cuadrático Medio: 0.0094 - Verdadero Positivo: 3425.0000 - Falso Positivo: 38.0000 - Verdadero Negativo: 3398.0000 - Falso Negativo: 51.0000 - Accuracy: 0.9871 - Precision: 0.9890 - val_loss: 2.4665 - val_AUC: 0.7773 - val_PRC: 0.8481 - val_RECALL: 0.2882 - val_Error Cuadrático Medio: 0.3399 - val_Verdadero Positivo: 130.0000 - val_Falso Positivo: 2.0000 - val_Verdadero Negativo: 411.0000 - val_Falso Negativo: 321.0000 - val_Accuracy: 0.6262 - val_Precision: 0.9848
# Epoch 14/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0413 - AUC: 0.9984 - PRC: 0.9985 - RECALL: 0.9845 - Error Cuadrático Medio: 0.0104 - Verdadero Positivo: 3422.0000 - Falso Positivo: 38.0000 - Verdadero Negativo: 3398.0000 - Falso Negativo: 54.0000 - Accuracy: 0.9867 - Precision: 0.9890 - val_loss: 0.6906 - val_AUC: 0.9259 - val_PRC: 0.9050 - val_RECALL: 0.9601 - val_Error Cuadrático Medio: 0.1448 - val_Verdadero Positivo: 433.0000 - val_Falso Positivo: 130.0000 - val_Verdadero Negativo: 283.0000 - val_Falso Negativo: 18.0000 - val_Accuracy: 0.8287 - val_Precision: 0.7691
# Epoch 15/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0165 - AUC: 0.9994 - PRC: 0.9992 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0041 - Verdadero Positivo: 3458.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9946 - Precision: 0.9945 - val_loss: 0.5303 - val_AUC: 0.9322 - val_PRC: 0.9424 - val_RECALL: 0.8559 - val_Error Cuadrático Medio: 0.1022 - val_Verdadero Positivo: 386.0000 - val_Falso Positivo: 37.0000 - val_Verdadero Negativo: 376.0000 - val_Falso Negativo: 65.0000 - val_Accuracy: 0.8819 - val_Precision: 0.9125
# Epoch 16/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0181 - AUC: 0.9995 - PRC: 0.9996 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0046 - Verdadero Positivo: 3460.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 3414.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9945 - Precision: 0.9937 - val_loss: 0.5251 - val_AUC: 0.9308 - val_PRC: 0.9189 - val_RECALL: 0.9202 - val_Error Cuadrático Medio: 0.1157 - val_Verdadero Positivo: 415.0000 - val_Falso Positivo: 85.0000 - val_Verdadero Negativo: 328.0000 - val_Falso Negativo: 36.0000 - val_Accuracy: 0.8600 - val_Precision: 0.8300
# Epoch 17/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0146 - AUC: 0.9994 - PRC: 0.9994 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0034 - Verdadero Positivo: 3460.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 3423.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9958 - Precision: 0.9963 - val_loss: 0.8210 - val_AUC: 0.9132 - val_PRC: 0.8875 - val_RECALL: 0.9335 - val_Error Cuadrático Medio: 0.1344 - val_Verdadero Positivo: 421.0000 - val_Falso Positivo: 99.0000 - val_Verdadero Negativo: 314.0000 - val_Falso Negativo: 30.0000 - val_Accuracy: 0.8507 - val_Precision: 0.8096
# Epoch 18/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0206 - AUC: 0.9995 - PRC: 0.9992 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0056 - Verdadero Positivo: 3455.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9932 - Precision: 0.9925 - val_loss: 1.3520 - val_AUC: 0.8803 - val_PRC: 0.9192 - val_RECALL: 0.6452 - val_Error Cuadrático Medio: 0.1806 - val_Verdadero Positivo: 291.0000 - val_Falso Positivo: 9.0000 - val_Verdadero Negativo: 404.0000 - val_Falso Negativo: 160.0000 - val_Accuracy: 0.8044 - val_Precision: 0.9700
# Epoch 19/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0214 - AUC: 0.9994 - PRC: 0.9991 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0057 - Verdadero Positivo: 3450.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9925 - Precision: 0.9925 - val_loss: 0.6007 - val_AUC: 0.9182 - val_PRC: 0.9282 - val_RECALL: 0.8226 - val_Error Cuadrático Medio: 0.1238 - val_Verdadero Positivo: 371.0000 - val_Falso Positivo: 45.0000 - val_Verdadero Negativo: 368.0000 - val_Falso Negativo: 80.0000 - val_Accuracy: 0.8553 - val_Precision: 0.8918
# Epoch 20/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0243 - AUC: 0.9991 - PRC: 0.9992 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0058 - Verdadero Positivo: 3455.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 3410.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9932 - Precision: 0.9925 - val_loss: 0.5947 - val_AUC: 0.9304 - val_PRC: 0.9189 - val_RECALL: 0.9401 - val_Error Cuadrático Medio: 0.1261 - val_Verdadero Positivo: 424.0000 - val_Falso Positivo: 103.0000 - val_Verdadero Negativo: 310.0000 - val_Falso Negativo: 27.0000 - val_Accuracy: 0.8495 - val_Precision: 0.8046
# Epoch 21/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0208 - AUC: 0.9992 - PRC: 0.9990 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0046 - Verdadero Positivo: 3455.0000 - Falso Positivo: 18.0000 - Verdadero Negativo: 3418.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9944 - Precision: 0.9948 - val_loss: 0.5315 - val_AUC: 0.9388 - val_PRC: 0.9343 - val_RECALL: 0.9290 - val_Error Cuadrático Medio: 0.1243 - val_Verdadero Positivo: 419.0000 - val_Falso Positivo: 95.0000 - val_Verdadero Negativo: 318.0000 - val_Falso Negativo: 32.0000 - val_Accuracy: 0.8530 - val_Precision: 0.8152
# Epoch 22/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0182 - AUC: 0.9995 - PRC: 0.9994 - RECALL: 0.9940 - Error Cuadrático Medio: 0.0047 - Verdadero Positivo: 3455.0000 - Falso Positivo: 21.0000 - Verdadero Negativo: 3415.0000 - Falso Negativo: 21.0000 - Accuracy: 0.9939 - Precision: 0.9940 - val_loss: 0.6634 - val_AUC: 0.9181 - val_PRC: 0.9415 - val_RECALL: 0.7162 - val_Error Cuadrático Medio: 0.1398 - val_Verdadero Positivo: 323.0000 - val_Falso Positivo: 12.0000 - val_Verdadero Negativo: 401.0000 - val_Falso Negativo: 128.0000 - val_Accuracy: 0.8380 - val_Precision: 0.9642
# Epoch 23/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0159 - AUC: 0.9996 - PRC: 0.9995 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0040 - Verdadero Positivo: 3458.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9951 - Precision: 0.9954 - val_loss: 0.7474 - val_AUC: 0.9118 - val_PRC: 0.9043 - val_RECALL: 0.9246 - val_Error Cuadrático Medio: 0.1557 - val_Verdadero Positivo: 417.0000 - val_Falso Positivo: 124.0000 - val_Verdadero Negativo: 289.0000 - val_Falso Negativo: 34.0000 - val_Accuracy: 0.8171 - val_Precision: 0.7708
# Epoch 24/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0193 - AUC: 0.9992 - PRC: 0.9995 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0045 - Verdadero Positivo: 3458.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9946 - Precision: 0.9945 - val_loss: 0.5222 - val_AUC: 0.9165 - val_PRC: 0.9297 - val_RECALL: 0.7849 - val_Error Cuadrático Medio: 0.1293 - val_Verdadero Positivo: 354.0000 - val_Falso Positivo: 38.0000 - val_Verdadero Negativo: 375.0000 - val_Falso Negativo: 97.0000 - val_Accuracy: 0.8438 - val_Precision: 0.9031
# Epoch 25/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0141 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0040 - Verdadero Positivo: 3460.0000 - Falso Positivo: 20.0000 - Verdadero Negativo: 3416.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9948 - Precision: 0.9943 - val_loss: 0.8888 - val_AUC: 0.9023 - val_PRC: 0.8654 - val_RECALL: 0.9579 - val_Error Cuadrático Medio: 0.1486 - val_Verdadero Positivo: 432.0000 - val_Falso Positivo: 132.0000 - val_Verdadero Negativo: 281.0000 - val_Falso Negativo: 19.0000 - val_Accuracy: 0.8252 - val_Precision: 0.7660
# Epoch 26/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0090 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9968 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3465.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 3429.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9974 - Precision: 0.9980 - val_loss: 0.6816 - val_AUC: 0.9122 - val_PRC: 0.8882 - val_RECALL: 0.8914 - val_Error Cuadrático Medio: 0.1283 - val_Verdadero Positivo: 402.0000 - val_Falso Positivo: 83.0000 - val_Verdadero Negativo: 330.0000 - val_Falso Negativo: 49.0000 - val_Accuracy: 0.8472 - val_Precision: 0.8289
# Epoch 27/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0395 - AUC: 0.9991 - PRC: 0.9986 - RECALL: 0.9925 - Error Cuadrático Medio: 0.0067 - Verdadero Positivo: 3450.0000 - Falso Positivo: 33.0000 - Verdadero Negativo: 3403.0000 - Falso Negativo: 26.0000 - Accuracy: 0.9915 - Precision: 0.9905 - val_loss: 0.6709 - val_AUC: 0.9233 - val_PRC: 0.9256 - val_RECALL: 0.8736 - val_Error Cuadrático Medio: 0.1083 - val_Verdadero Positivo: 394.0000 - val_Falso Positivo: 54.0000 - val_Verdadero Negativo: 359.0000 - val_Falso Negativo: 57.0000 - val_Accuracy: 0.8715 - val_Precision: 0.8795
# Epoch 28/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0120 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9965 - Error Cuadrático Medio: 0.0030 - Verdadero Positivo: 3464.0000 - Falso Positivo: 14.0000 - Verdadero Negativo: 3422.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9962 - Precision: 0.9960 - val_loss: 1.0206 - val_AUC: 0.9079 - val_PRC: 0.8980 - val_RECALL: 0.8625 - val_Error Cuadrático Medio: 0.1244 - val_Verdadero Positivo: 389.0000 - val_Falso Positivo: 63.0000 - val_Verdadero Negativo: 350.0000 - val_Falso Negativo: 62.0000 - val_Accuracy: 0.8553 - val_Precision: 0.8606
# Epoch 29/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0110 - AUC: 0.9996 - PRC: 0.9996 - RECALL: 0.9977 - Error Cuadrático Medio: 0.0027 - Verdadero Positivo: 3468.0000 - Falso Positivo: 11.0000 - Verdadero Negativo: 3425.0000 - Falso Negativo: 8.0000 - Accuracy: 0.9973 - Precision: 0.9968 - val_loss: 0.5867 - val_AUC: 0.9257 - val_PRC: 0.9129 - val_RECALL: 0.8936 - val_Error Cuadrático Medio: 0.1135 - val_Verdadero Positivo: 403.0000 - val_Falso Positivo: 65.0000 - val_Verdadero Negativo: 348.0000 - val_Falso Negativo: 48.0000 - val_Accuracy: 0.8692 - val_Precision: 0.8611
# Epoch 30/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0091 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3467.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9970 - Precision: 0.9966 - val_loss: 1.0512 - val_AUC: 0.8906 - val_PRC: 0.9242 - val_RECALL: 0.6275 - val_Error Cuadrático Medio: 0.1770 - val_Verdadero Positivo: 283.0000 - val_Falso Positivo: 7.0000 - val_Verdadero Negativo: 406.0000 - val_Falso Negativo: 168.0000 - val_Accuracy: 0.7975 - val_Precision: 0.9759
# Epoch 31/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0093 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9957 - Error Cuadrático Medio: 0.0026 - Verdadero Positivo: 3461.0000 - Falso Positivo: 10.0000 - Verdadero Negativo: 3426.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9964 - Precision: 0.9971 - val_loss: 0.9140 - val_AUC: 0.8972 - val_PRC: 0.8627 - val_RECALL: 0.9468 - val_Error Cuadrático Medio: 0.1487 - val_Verdadero Positivo: 427.0000 - val_Falso Positivo: 118.0000 - val_Verdadero Negativo: 295.0000 - val_Falso Negativo: 24.0000 - val_Accuracy: 0.8356 - val_Precision: 0.7835
# Epoch 32/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0098 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9965 - Error Cuadrático Medio: 0.0028 - Verdadero Positivo: 3464.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 3423.0000 - Falso Negativo: 12.0000 - Accuracy: 0.9964 - Precision: 0.9963 - val_loss: 0.6710 - val_AUC: 0.9157 - val_PRC: 0.8993 - val_RECALL: 0.9069 - val_Error Cuadrático Medio: 0.1160 - val_Verdadero Positivo: 409.0000 - val_Falso Positivo: 72.0000 - val_Verdadero Negativo: 341.0000 - val_Falso Negativo: 42.0000 - val_Accuracy: 0.8681 - val_Precision: 0.8503
# Epoch 33/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0223 - AUC: 0.9990 - PRC: 0.9987 - RECALL: 0.9937 - Error Cuadrático Medio: 0.0052 - Verdadero Positivo: 3454.0000 - Falso Positivo: 22.0000 - Verdadero Negativo: 3414.0000 - Falso Negativo: 22.0000 - Accuracy: 0.9936 - Precision: 0.9937 - val_loss: 0.7477 - val_AUC: 0.9062 - val_PRC: 0.8969 - val_RECALL: 0.8581 - val_Error Cuadrático Medio: 0.1370 - val_Verdadero Positivo: 387.0000 - val_Falso Positivo: 69.0000 - val_Verdadero Negativo: 344.0000 - val_Falso Negativo: 64.0000 - val_Accuracy: 0.8461 - val_Precision: 0.8487
# Epoch 34/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0175 - AUC: 0.9994 - PRC: 0.9991 - RECALL: 0.9954 - Error Cuadrático Medio: 0.0043 - Verdadero Positivo: 3460.0000 - Falso Positivo: 19.0000 - Verdadero Negativo: 3417.0000 - Falso Negativo: 16.0000 - Accuracy: 0.9949 - Precision: 0.9945 - val_loss: 1.4469 - val_AUC: 0.8836 - val_PRC: 0.8396 - val_RECALL: 0.9690 - val_Error Cuadrático Medio: 0.1778 - val_Verdadero Positivo: 437.0000 - val_Falso Positivo: 161.0000 - val_Verdadero Negativo: 252.0000 - val_Falso Negativo: 14.0000 - val_Accuracy: 0.7975 - val_Precision: 0.7308
# Epoch 35/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0088 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0024 - Verdadero Positivo: 3466.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9968 - Precision: 0.9965 - val_loss: 0.6257 - val_AUC: 0.9228 - val_PRC: 0.9158 - val_RECALL: 0.8736 - val_Error Cuadrático Medio: 0.1145 - val_Verdadero Positivo: 394.0000 - val_Falso Positivo: 58.0000 - val_Verdadero Negativo: 355.0000 - val_Falso Negativo: 57.0000 - val_Accuracy: 0.8669 - val_Precision: 0.8717
# Epoch 36/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0080 - AUC: 0.9997 - PRC: 0.9996 - RECALL: 0.9968 - Error Cuadrático Medio: 0.0020 - Verdadero Positivo: 3465.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 3429.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9974 - Precision: 0.9980 - val_loss: 1.0631 - val_AUC: 0.9137 - val_PRC: 0.9407 - val_RECALL: 0.7073 - val_Error Cuadrático Medio: 0.1463 - val_Verdadero Positivo: 319.0000 - val_Falso Positivo: 11.0000 - val_Verdadero Negativo: 402.0000 - val_Falso Negativo: 132.0000 - val_Accuracy: 0.8345 - val_Precision: 0.9667
# Epoch 37/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0064 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9980 - Error Cuadrático Medio: 0.0016 - Verdadero Positivo: 3469.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 3431.0000 - Falso Negativo: 7.0000 - Accuracy: 0.9983 - Precision: 0.9986 - val_loss: 0.7303 - val_AUC: 0.9277 - val_PRC: 0.9465 - val_RECALL: 0.7627 - val_Error Cuadrático Medio: 0.1256 - val_Verdadero Positivo: 344.0000 - val_Falso Positivo: 17.0000 - val_Verdadero Negativo: 396.0000 - val_Falso Negativo: 107.0000 - val_Accuracy: 0.8565 - val_Precision: 0.9529
# Epoch 38/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0154 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9934 - Error Cuadrático Medio: 0.0042 - Verdadero Positivo: 3453.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 3419.0000 - Falso Negativo: 23.0000 - Accuracy: 0.9942 - Precision: 0.9951 - val_loss: 0.8404 - val_AUC: 0.8992 - val_PRC: 0.8731 - val_RECALL: 0.9180 - val_Error Cuadrático Medio: 0.1417 - val_Verdadero Positivo: 414.0000 - val_Falso Positivo: 107.0000 - val_Verdadero Negativo: 306.0000 - val_Falso Negativo: 37.0000 - val_Accuracy: 0.8333 - val_Precision: 0.7946
# Epoch 39/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0082 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0022 - Verdadero Positivo: 3466.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9974 - Precision: 0.9977 - val_loss: 1.8918 - val_AUC: 0.8630 - val_PRC: 0.9096 - val_RECALL: 0.5255 - val_Error Cuadrático Medio: 0.2292 - val_Verdadero Positivo: 237.0000 - val_Falso Positivo: 2.0000 - val_Verdadero Negativo: 411.0000 - val_Falso Negativo: 214.0000 - val_Accuracy: 0.7500 - val_Precision: 0.9916
# Epoch 40/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0081 - AUC: 0.9998 - PRC: 0.9997 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0020 - Verdadero Positivo: 3466.0000 - Falso Positivo: 8.0000 - Verdadero Negativo: 3428.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9974 - Precision: 0.9977 - val_loss: 0.5605 - val_AUC: 0.9321 - val_PRC: 0.9314 - val_RECALL: 0.8803 - val_Error Cuadrático Medio: 0.1187 - val_Verdadero Positivo: 397.0000 - val_Falso Positivo: 70.0000 - val_Verdadero Negativo: 343.0000 - val_Falso Negativo: 54.0000 - val_Accuracy: 0.8565 - val_Precision: 0.8501
# Epoch 41/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0109 - AUC: 0.9999 - PRC: 0.9999 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0030 - Verdadero Positivo: 3467.0000 - Falso Positivo: 17.0000 - Verdadero Negativo: 3419.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9962 - Precision: 0.9951 - val_loss: 0.6392 - val_AUC: 0.9369 - val_PRC: 0.9388 - val_RECALL: 0.8448 - val_Error Cuadrático Medio: 0.1039 - val_Verdadero Positivo: 381.0000 - val_Falso Positivo: 40.0000 - val_Verdadero Negativo: 373.0000 - val_Falso Negativo: 70.0000 - val_Accuracy: 0.8727 - val_Precision: 0.9050
# Epoch 42/50
# 216/216 [==============================] - 24s 110ms/step - loss: 0.0138 - AUC: 0.9997 - PRC: 0.9996 - RECALL: 0.9960 - Error Cuadrático Medio: 0.0040 - Verdadero Positivo: 3462.0000 - Falso Positivo: 23.0000 - Verdadero Negativo: 3413.0000 - Falso Negativo: 14.0000 - Accuracy: 0.9946 - Precision: 0.9934 - val_loss: 0.6786 - val_AUC: 0.9261 - val_PRC: 0.9295 - val_RECALL: 0.8160 - val_Error Cuadrático Medio: 0.1224 - val_Verdadero Positivo: 368.0000 - val_Falso Positivo: 44.0000 - val_Verdadero Negativo: 369.0000 - val_Falso Negativo: 83.0000 - val_Accuracy: 0.8530 - val_Precision: 0.8932
# Epoch 43/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0132 - AUC: 0.9997 - PRC: 0.9998 - RECALL: 0.9948 - Error Cuadrático Medio: 0.0034 - Verdadero Positivo: 3458.0000 - Falso Positivo: 13.0000 - Verdadero Negativo: 3423.0000 - Falso Negativo: 18.0000 - Accuracy: 0.9955 - Precision: 0.9963 - val_loss: 0.5171 - val_AUC: 0.9373 - val_PRC: 0.9404 - val_RECALL: 0.8381 - val_Error Cuadrático Medio: 0.1083 - val_Verdadero Positivo: 378.0000 - val_Falso Positivo: 41.0000 - val_Verdadero Negativo: 372.0000 - val_Falso Negativo: 73.0000 - val_Accuracy: 0.8681 - val_Precision: 0.9021
# Epoch 44/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0029 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9991 - Error Cuadrático Medio: 7.7124e-04 - Verdadero Positivo: 3473.0000 - Falso Positivo: 4.0000 - Verdadero Negativo: 3432.0000 - Falso Negativo: 3.0000 - Accuracy: 0.9990 - Precision: 0.9988 - val_loss: 0.5938 - val_AUC: 0.9255 - val_PRC: 0.9132 - val_RECALL: 0.8714 - val_Error Cuadrático Medio: 0.1217 - val_Verdadero Positivo: 393.0000 - val_Falso Positivo: 64.0000 - val_Verdadero Negativo: 349.0000 - val_Falso Negativo: 58.0000 - val_Accuracy: 0.8588 - val_Precision: 0.8600
# Epoch 45/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0057 - AUC: 0.9998 - PRC: 0.9997 - RECALL: 0.9986 - Error Cuadrático Medio: 0.0015 - Verdadero Positivo: 3471.0000 - Falso Positivo: 7.0000 - Verdadero Negativo: 3429.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9983 - Precision: 0.9980 - val_loss: 0.7847 - val_AUC: 0.9217 - val_PRC: 0.9165 - val_RECALL: 0.8537 - val_Error Cuadrático Medio: 0.1232 - val_Verdadero Positivo: 385.0000 - val_Falso Positivo: 60.0000 - val_Verdadero Negativo: 353.0000 - val_Falso Negativo: 66.0000 - val_Accuracy: 0.8542 - val_Precision: 0.8652
# Epoch 46/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0125 - AUC: 0.9998 - PRC: 0.9998 - RECALL: 0.9957 - Error Cuadrático Medio: 0.0035 - Verdadero Positivo: 3461.0000 - Falso Positivo: 15.0000 - Verdadero Negativo: 3421.0000 - Falso Negativo: 15.0000 - Accuracy: 0.9957 - Precision: 0.9957 - val_loss: 0.9938 - val_AUC: 0.8864 - val_PRC: 0.9093 - val_RECALL: 0.6896 - val_Error Cuadrático Medio: 0.1653 - val_Verdadero Positivo: 311.0000 - val_Falso Positivo: 30.0000 - val_Verdadero Negativo: 383.0000 - val_Falso Negativo: 140.0000 - val_Accuracy: 0.8032 - val_Precision: 0.9120
# Epoch 47/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0084 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9971 - Error Cuadrático Medio: 0.0023 - Verdadero Positivo: 3466.0000 - Falso Positivo: 12.0000 - Verdadero Negativo: 3424.0000 - Falso Negativo: 10.0000 - Accuracy: 0.9968 - Precision: 0.9965 - val_loss: 0.8562 - val_AUC: 0.9174 - val_PRC: 0.9284 - val_RECALL: 0.8093 - val_Error Cuadrático Medio: 0.1295 - val_Verdadero Positivo: 365.0000 - val_Falso Positivo: 46.0000 - val_Verdadero Negativo: 367.0000 - val_Falso Negativo: 86.0000 - val_Accuracy: 0.8472 - val_Precision: 0.8881
# Epoch 48/50
# 216/216 [==============================] - 24s 111ms/step - loss: 0.0063 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9974 - Error Cuadrático Medio: 0.0017 - Verdadero Positivo: 3467.0000 - Falso Positivo: 6.0000 - Verdadero Negativo: 3430.0000 - Falso Negativo: 9.0000 - Accuracy: 0.9978 - Precision: 0.9983 - val_loss: 0.6047 - val_AUC: 0.9317 - val_PRC: 0.9380 - val_RECALL: 0.8426 - val_Error Cuadrático Medio: 0.1058 - val_Verdadero Positivo: 380.0000 - val_Falso Positivo: 41.0000 - val_Verdadero Negativo: 372.0000 - val_Falso Negativo: 71.0000 - val_Accuracy: 0.8704 - val_Precision: 0.9026
# Epoch 49/50
# 216/216 [==============================] - 23s 108ms/step - loss: 0.0038 - AUC: 1.0000 - PRC: 1.0000 - RECALL: 0.9986 - Error Cuadrático Medio: 0.0011 - Verdadero Positivo: 3471.0000 - Falso Positivo: 5.0000 - Verdadero Negativo: 3431.0000 - Falso Negativo: 5.0000 - Accuracy: 0.9986 - Precision: 0.9986 - val_loss: 0.8644 - val_AUC: 0.9015 - val_PRC: 0.8786 - val_RECALL: 0.9268 - val_Error Cuadrático Medio: 0.1493 - val_Verdadero Positivo: 418.0000 - val_Falso Positivo: 115.0000 - val_Verdadero Negativo: 298.0000 - val_Falso Negativo: 33.0000 - val_Accuracy: 0.8287 - val_Precision: 0.7842
# Epoch 50/50
# 216/216 [==============================] - 23s 109ms/step - loss: 0.0095 - AUC: 0.9998 - PRC: 0.9999 - RECALL: 0.9968 - Error Cuadrático Medio: 0.0028 - Verdadero Positivo: 3465.0000 - Falso Positivo: 16.0000 - Verdadero Negativo: 3420.0000 - Falso Negativo: 11.0000 - Accuracy: 0.9961 - Precision: 0.9954 - val_loss: 1.3062 - val_AUC: 0.8934 - val_PRC: 0.9188 - val_RECALL: 0.6829 - val_Error Cuadrático Medio: 0.1618 - val_Verdadero Positivo: 308.0000 - val_Falso Positivo: 18.0000 - val_Verdadero Negativo: 395.0000 - val_Falso Negativo: 143.0000 - val_Accuracy: 0.8137 - val_Precision: 0.9448
# 34/34 [==============================] - 3s 38ms/step - loss: 1.2706 - AUC: 0.8841 - PRC: 0.9004 - RECALL: 0.6856 - Error Cuadrático Medio: 0.1552 - Verdadero Positivo: 362.0000 - Falso Positivo: 26.0000 - Verdadero Negativo: 526.0000 - Falso Negativo: 166.0000 - Accuracy: 0.8222 - Precision: 0.9330
# {'loss': 1.2706365585327148, 'AUC': 0.8841351866722107, 'PRC': 0.9003784656524658, 'RECALL': 0.685606062412262, 'Error Cuadrático Medio': 0.15522834658622742, 'Verdadero Positivo': 362.0, 'Falso Positivo': 26.0, 'Verdadero Negativo': 526.0, 'Falso Negativo': 166.0, 'Accuracy': 0.8222222328186035, 'Precision': 0.9329897165298462}
#
#  ...Calculando valores predichos para train y test: ...
# 216/216 [==============================] - 7s 27ms/step
# 34/34 [==============================] - 2s 27ms/step
#
#  ** Resultados de las métricas:...
# loss :  1.2706365585327148
# AUC :  0.8841351866722107
# PRC :  0.9003784656524658
# RECALL :  0.685606062412262
# Error Cuadrático Medio :  0.15522834658622742
# Verdadero Positivo :  362.0
# Falso Positivo :  26.0
# Verdadero Negativo :  526.0
# Falso Negativo :  166.0
# Accuracy :  0.8222222328186035
# Precision :  0.9329897165298462
#
#
# --> Imágenes SIN cancer detectadas NEGATIVA :: CORRECTAMENTE (VERDADEROS NEGATIVOS):  526
# --> Imágenes SIN cancer detectada como POSITIVA :: INCORRECTAMENTE (FALSOS POSITIVOS):  26
# --> Imágenes CON cancer detectadas como NEGATIVA :: INCORRECTAMENTE (FALSOS NEGATIVOS):  166
# --> Imágenes CON cancer detectadas POSITIVA :: CORRECTAMENTE (VERDADEROS POSITIVOS):  362
